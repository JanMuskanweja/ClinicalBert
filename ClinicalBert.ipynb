# %%
# !pip install transformers
# !pip install datasets
# !pip install nervaluate
# !pip install accelerate -U
# Out:
# Requirement already satisfied: transformers in c:\users\expert\anaconda3\lib\site-packages (4.32.0)
# Requirement already satisfied: filelock in c:\users\expert\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\expert\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\expert\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\expert\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\expert\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\expert\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\expert\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\expert\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: datasets in c:\users\expert\anaconda3\lib\site-packages (2.14.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in c:\users\expert\anaconda3\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\expert\anaconda3\lib\site-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in c:\users\expert\anaconda3\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: aiohttp in c:\users\expert\anaconda3\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in c:\users\expert\anaconda3\lib\site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\expert\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\expert\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\expert\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\expert\anaconda3\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\expert\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: nervaluate in c:\users\expert\anaconda3\lib\site-packages (0.1.8)
# Requirement already satisfied: accelerate in c:\users\expert\anaconda3\lib\site-packages (0.22.0)
# Collecting accelerate
#   Obtaining dependency information for accelerate from https://files.pythonhosted.org/packages/d9/92/2d3aecf9f4a192968035880be3e2fc8b48d541c7128f7c936f430d6f96da/accelerate-0.23.0-py3-none-any.whl.metadata
#   Downloading accelerate-0.23.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (23.0)
# Requirement already satisfied: psutil in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: huggingface-hub in c:\users\expert\anaconda3\lib\site-packages (from accelerate) (0.16.4)
# Requirement already satisfied: filelock in c:\users\expert\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\expert\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in c:\users\expert\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in c:\users\expert\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\expert\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2023.3.0)
# Requirement already satisfied: requests in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (4.65.0)
# Requirement already satisfied: colorama in c:\users\expert\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\expert\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\expert\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\expert\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\expert\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\expert\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\expert\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#    ---------------------------------------- 0.0/258.1 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/258.1 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------- 92.2/258.1 kB 1.1 MB/s eta 0:00:01
#    ------------------------- -------------- 163.8/258.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 225.3/258.1 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 258.1/258.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.22.0
#     Uninstalling accelerate-0.22.0:
#       Successfully uninstalled accelerate-0.22.0
# Successfully installed accelerate-0.23.0

# %%
from datasets import load_dataset, ClassLabel, Sequence
custom_headers = ["Id", "tags", "text"] 
dataset = load_dataset('csv', data_files={'train': ['medical_ner.tsv']}, delimiter="\t",column_names=custom_headers)
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
lebel_set = ['B-age', 'I-age', 'B-allergy_name', 'I-allergy_name', 'B-bmi', 'I-bmi', 'B-cancer', 'I-cancer', 'B-chronic_disease', 'I-chronic_disease', 'B-clinical_variable', 'I-clinical_variable', 'B-contraception_consent', 'I-contraception_consent', 'B-ethnicity', 'I-ethnicity', 'B-gender', 'I-gender', 'B-language_fluency', 'I-language_fluency', 'B-lower_bound', 'I-lower_bound', 'B-pregnancy', 'I-pregnancy', 'B-technology_access', 'I-technology_access', 'B-treatment', 'I-treatment', 'B-upper_bound', 'I-upper_bound', 'O']
label2id={label: i for i,label in enumerate(lebel_set)}
label2id
# Out:
# {'B-age': 0,
#  'I-age': 1,
#  'B-allergy_name': 2,
#  'I-allergy_name': 3,
#  'B-bmi': 4,
#  'I-bmi': 5,
#  'B-cancer': 6,
#  'I-cancer': 7,
#  'B-chronic_disease': 8,
#  'I-chronic_disease': 9,
#  'B-clinical_variable': 10,
#  'I-clinical_variable': 11,
#  'B-contraception_consent': 12,
#  'I-contraception_consent': 13,
#  'B-ethnicity': 14,
#  'I-ethnicity': 15,
#  'B-gender': 16,
#  'I-gender': 17,
#  'B-language_fluency': 18,
#  'I-language_fluency': 19,
#  'B-lower_bound': 20,
#  'I-lower_bound': 21,
#  'B-pregnancy': 22,
#  'I-pregnancy': 23,
#  'B-technology_access': 24,
#  'I-technology_access': 25,
#  'B-treatment': 26,
#  'I-treatment': 27,
#  'B-upper_bound': 28,
#  'I-upper_bound': 29,
#  'O': 30}

# %%
dataset['train'].num_rows
# Out:
# 49903

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("medicalai/ClinicalBERT")
model = AutoModel.from_pretrained("medicalai/ClinicalBERT")
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/542M [00:00<?, ?B/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Id', 'tags', 'text'],
#         num_rows: 49903
#     })
# })

# %%
from tokenizers.pre_tokenizers import Whitespace
pre_tokenizer = Whitespace()
pre_tokenizer.pre_tokenize_str("Hello! How# are$ you? I'm% &fine, thank\" you.")
# Out:
# [('Hello', (0, 5)),
#  ('!', (5, 6)),
#  ('How', (7, 10)),
#  ('#', (10, 11)),
#  ('are', (12, 15)),
#  ('$', (15, 16)),
#  ('you', (17, 20)),
#  ('?', (20, 21)),
#  ('I', (22, 23)),
#  ("'", (23, 24)),
#  ('m', (24, 25)),
#  ('%', (25, 26)),
#  ('&', (27, 28)),
#  ('fine', (28, 32)),
#  (',', (32, 33)),
#  ('thank', (34, 39)),
#  ('"', (39, 40)),
#  ('you', (41, 44)),
#  ('.', (44, 45))]

# %%
from tqdm import tqdm
def get_ner(position, tags):
  all_ner_positions = list(tags.keys())
  prefix='N'
  for ner_position in all_ner_positions:
    if position[0] >= ner_position[0] and position[1] <= ner_position[1]:
      if position[0] == ner_position[0]:
        prefix = 'B-'
      else:
        prefix = 'I-'
      return  prefix+tags[ner_position]
  return 'O'

all_tokens = []
all_ner_tags = []
for idx in tqdm(range(dataset['train'].num_rows)):
  # print(dataset['train'][idx]['text'])
  position_pairs = []
  tags = {}
  tokens = []
  ner_tags = []
  for position_and_tag in dataset['train'][idx]['tags'].split(','):
    start_position, end_position, tag = int(position_and_tag.split(':')[0]), int(position_and_tag.split(':')[1]), position_and_tag.split(':')[2]
    tags[(start_position-1, end_position-1)] = tag
    position_pairs.append((start_position-1, end_position-1))
    tagged_text = dataset['train'][idx]['text'][start_position-1:end_position-1]
    # print(start_position, end_position, tag, tagged_text, dataset['train'][idx]['text'][start_position-1:end_position-1])
  # print(tags)
  # print(position_pairs)
  pre_tokenized_text = pre_tokenizer.pre_tokenize_str(dataset['train'][idx]['text'])
  for (word, position) in pre_tokenized_text:
    label = get_ner(position, tags)
    tokens.append(word)
    ner_tags.append(label2id[label])
  all_tokens.append(tokens)
  all_ner_tags.append(ner_tags)

print(len(all_tokens), len(all_ner_tags), all_tokens[100], all_ner_tags[100])
# Out:
#   0%|          | 0/49903 [00:00<?, ?it/s]
#   0%|          | 130/49903 [00:00<00:42, 1169.06it/s]
#   1%|          | 284/49903 [00:00<00:38, 1297.66it/s]
#   1%|          | 414/49903 [00:00<00:39, 1260.58it/s]
#   1%|          | 540/49903 [00:00<00:39, 1253.65it/s]
#   1%|▏         | 671/49903 [00:00<00:39, 1232.74it/s]
#   2%|▏         | 800/49903 [00:00<00:39, 1238.43it/s]
#   2%|▏         | 924/49903 [00:00<00:40, 1209.65it/s]
#   2%|▏         | 1059/49903 [00:00<00:40, 1211.88it/s]
#   2%|▏         | 1181/49903 [00:00<00:40, 1198.05it/s]
#   3%|▎         | 1313/49903 [00:01<00:39, 1233.33it/s]
#   3%|▎         | 1437/49903 [00:01<00:39, 1217.91it/s]
#   3%|▎         | 1566/49903 [00:01<00:39, 1223.73it/s]
#   3%|▎         | 1690/49903 [00:01<00:39, 1226.33it/s]
#   4%|▎         | 1813/49903 [00:01<00:40, 1197.37it/s]
#   4%|▍         | 1967/49903 [00:01<00:37, 1272.27it/s]
#   4%|▍         | 2095/49903 [00:01<00:37, 1266.94it/s]
#   4%|▍         | 2222/49903 [00:01<00:38, 1228.70it/s]
#   5%|▍         | 2353/49903 [00:01<00:38, 1251.11it/s]
#   5%|▍         | 2479/49903 [00:02<00:38, 1230.08it/s]
#   5%|▌         | 2607/49903 [00:02<00:38, 1220.08it/s]
#   5%|▌         | 2740/49903 [00:02<00:39, 1205.88it/s]
#   6%|▌         | 2861/49903 [00:02<00:40, 1170.07it/s]
#   6%|▌         | 2979/49903 [00:02<00:40, 1171.95it/s]
#   6%|▌         | 3097/49903 [00:02<00:41, 1123.84it/s]
#   6%|▋         | 3235/49903 [00:02<00:39, 1195.76it/s]
#   7%|▋         | 3356/49903 [00:02<00:39, 1186.58it/s]
#   7%|▋         | 3476/49903 [00:02<00:42, 1098.10it/s]
#   7%|▋         | 3634/49903 [00:02<00:37, 1229.80it/s]
#   8%|▊         | 3796/49903 [00:03<00:34, 1338.12it/s]
#   8%|▊         | 3932/49903 [00:03<00:35, 1278.04it/s]
#   8%|▊         | 4062/49903 [00:03<00:37, 1217.58it/s]
#   8%|▊         | 4224/49903 [00:03<00:34, 1320.70it/s]
#   9%|▊         | 4366/49903 [00:03<00:34, 1324.90it/s]
#   9%|▉         | 4500/49903 [00:03<00:36, 1244.63it/s]
#   9%|▉         | 4636/49903 [00:03<00:35, 1259.57it/s]
#  10%|▉         | 4771/49903 [00:03<00:35, 1283.39it/s]
#  10%|▉         | 4932/49903 [00:03<00:32, 1366.93it/s]
#  10%|█         | 5072/49903 [00:04<00:32, 1369.24it/s]
#  10%|█         | 5210/49903 [00:04<00:33, 1350.71it/s]
#  11%|█         | 5346/49903 [00:04<00:37, 1202.96it/s]
#  11%|█         | 5470/49903 [00:04<00:36, 1208.76it/s]
#  11%|█▏        | 5647/49903 [00:04<00:32, 1363.11it/s]
#  12%|█▏        | 5787/49903 [00:04<00:36, 1206.63it/s]
#  12%|█▏        | 5913/49903 [00:04<00:39, 1124.50it/s]
#  12%|█▏        | 6043/49903 [00:04<00:37, 1168.52it/s]
#  12%|█▏        | 6176/49903 [00:05<00:36, 1209.29it/s]
#  13%|█▎        | 6306/49903 [00:05<00:35, 1227.59it/s]
#  13%|█▎        | 6436/49903 [00:05<00:34, 1247.91it/s]
#  13%|█▎        | 6563/49903 [00:05<00:35, 1211.54it/s]
#  13%|█▎        | 6686/49903 [00:05<00:35, 1207.46it/s]
#  14%|█▎        | 6824/49903 [00:05<00:34, 1253.43it/s]
#  14%|█▍        | 7011/49903 [00:05<00:30, 1399.89it/s]
#  14%|█▍        | 7208/49903 [00:05<00:27, 1535.10it/s]
#  15%|█▍        | 7398/49903 [00:05<00:25, 1636.86it/s]
#  15%|█▌        | 7604/49903 [00:05<00:24, 1759.08it/s]
#  16%|█▌        | 7781/49903 [00:06<00:25, 1671.84it/s]
#  16%|█▌        | 7950/49903 [00:06<00:25, 1621.77it/s]
#  16%|█▋        | 8135/49903 [00:06<00:24, 1682.23it/s]
#  17%|█▋        | 8305/49903 [00:06<00:27, 1538.63it/s]
#  17%|█▋        | 8494/49903 [00:06<00:25, 1622.57it/s]
#  18%|█▊        | 8734/49903 [00:06<00:23, 1782.38it/s]
#  18%|█▊        | 8924/49903 [00:06<00:22, 1815.06it/s]
#  18%|█▊        | 9118/49903 [00:06<00:22, 1848.82it/s]
#  19%|█▊        | 9305/49903 [00:06<00:22, 1828.39it/s]
#  19%|█▉        | 9489/49903 [00:07<00:22, 1790.16it/s]
#  19%|█▉        | 9690/49903 [00:07<00:21, 1850.16it/s]
#  20%|█▉        | 9891/49903 [00:07<00:21, 1888.46it/s]
#  20%|██        | 10095/49903 [00:07<00:20, 1928.82it/s]
#  21%|██        | 10289/49903 [00:07<00:21, 1836.67it/s]
#  21%|██        | 10474/49903 [00:07<00:22, 1723.01it/s]
#  21%|██▏       | 10676/49903 [00:07<00:21, 1803.57it/s]
#  22%|██▏       | 10859/49903 [00:07<00:22, 1751.25it/s]
#  22%|██▏       | 11043/49903 [00:07<00:21, 1775.34it/s]
#  23%|██▎       | 11248/49903 [00:07<00:21, 1800.04it/s]
#  23%|██▎       | 11436/49903 [00:08<00:21, 1819.00it/s]
#  23%|██▎       | 11619/49903 [00:08<00:21, 1808.05it/s]
#  24%|██▎       | 11806/49903 [00:08<00:20, 1825.26it/s]
#  24%|██▍       | 11989/49903 [00:08<00:21, 1772.40it/s]
#  24%|██▍       | 12167/49903 [00:08<00:21, 1761.21it/s]
#  25%|██▍       | 12354/49903 [00:08<00:20, 1791.20it/s]
#  25%|██▌       | 12534/49903 [00:08<00:21, 1729.35it/s]
#  25%|██▌       | 12708/49903 [00:08<00:21, 1700.29it/s]
#  26%|██▌       | 12887/49903 [00:08<00:21, 1724.22it/s]
#  26%|██▌       | 13060/49903 [00:09<00:22, 1633.23it/s]
#  27%|██▋       | 13225/49903 [00:09<00:24, 1515.74it/s]
#  27%|██▋       | 13379/49903 [00:09<00:27, 1333.65it/s]
#  27%|██▋       | 13517/49903 [00:09<00:29, 1250.50it/s]
#  27%|██▋       | 13646/49903 [00:09<00:33, 1077.85it/s]
#  28%|██▊       | 13760/49903 [00:09<00:34, 1054.61it/s]
#  28%|██▊       | 13870/49903 [00:09<00:33, 1061.60it/s]
#  28%|██▊       | 13988/49903 [00:09<00:33, 1086.35it/s]
#  28%|██▊       | 14099/49903 [00:10<00:35, 1011.69it/s]
#  28%|██▊       | 14203/49903 [00:10<00:35, 1018.10it/s]
#  29%|██▊       | 14307/49903 [00:10<00:34, 1017.33it/s]
#  29%|██▉       | 14452/49903 [00:10<00:31, 1137.38it/s]
#  29%|██▉       | 14568/49903 [00:10<00:31, 1115.60it/s]
#  29%|██▉       | 14681/49903 [00:10<00:32, 1099.42it/s]
#  30%|██▉       | 14792/49903 [00:10<00:33, 1061.96it/s]
#  30%|██▉       | 14899/49903 [00:10<00:36, 954.85it/s]
#  30%|███       | 15009/49903 [00:10<00:35, 992.15it/s]
#  30%|███       | 15118/49903 [00:11<00:34, 1001.16it/s]
#  31%|███       | 15224/49903 [00:11<00:34, 1015.27it/s]
#  31%|███       | 15332/49903 [00:11<00:33, 1028.64it/s]
#  31%|███       | 15439/49903 [00:11<00:33, 1037.02it/s]
#  31%|███       | 15544/49903 [00:11<00:33, 1037.74it/s]
#  31%|███▏      | 15659/49903 [00:11<00:33, 1034.42it/s]
#  32%|███▏      | 15763/49903 [00:11<00:33, 1033.57it/s]
#  32%|███▏      | 15867/49903 [00:11<00:34, 990.76it/s]
#  32%|███▏      | 15970/49903 [00:11<00:33, 1000.66it/s]
#  32%|███▏      | 16088/49903 [00:11<00:32, 1050.57it/s]
#  32%|███▏      | 16216/49903 [00:12<00:30, 1105.50it/s]
#  33%|███▎      | 16327/49903 [00:12<00:30, 1101.75it/s]
#  33%|███▎      | 16443/49903 [00:12<00:30, 1105.65it/s]
#  33%|███▎      | 16554/49903 [00:12<00:30, 1084.44it/s]
#  33%|███▎      | 16663/49903 [00:12<00:31, 1060.23it/s]
#  34%|███▎      | 16790/49903 [00:12<00:30, 1079.51it/s]
#  34%|███▍      | 16902/49903 [00:12<00:31, 1056.21it/s]
#  34%|███▍      | 17024/49903 [00:12<00:29, 1099.29it/s]
#  34%|███▍      | 17136/49903 [00:12<00:29, 1102.90it/s]
#  35%|███▍      | 17247/49903 [00:13<00:30, 1084.52it/s]
#  35%|███▍      | 17356/49903 [00:13<00:31, 1023.66it/s]
#  35%|███▍      | 17460/49903 [00:13<00:34, 927.49it/s]
#  35%|███▌      | 17559/49903 [00:13<00:34, 928.13it/s]
#  35%|███▌      | 17666/49903 [00:13<00:34, 947.22it/s]
#  36%|███▌      | 17802/49903 [00:13<00:30, 1057.26it/s]
#  36%|███▌      | 17910/49903 [00:13<00:31, 1012.90it/s]
#  36%|███▌      | 18013/49903 [00:13<00:32, 979.51it/s]
#  36%|███▋      | 18112/49903 [00:14<00:36, 882.49it/s]
#  36%|███▋      | 18203/49903 [00:14<00:36, 864.12it/s]
#  37%|███▋      | 18291/49903 [00:14<00:36, 863.01it/s]
#  37%|███▋      | 18379/49903 [00:14<00:37, 834.40it/s]
#  37%|███▋      | 18481/49903 [00:14<00:36, 859.83it/s]
#  37%|███▋      | 18580/49903 [00:14<00:35, 893.48it/s]
#  37%|███▋      | 18686/49903 [00:14<00:33, 940.08it/s]
#  38%|███▊      | 18797/49903 [00:14<00:31, 986.90it/s]
#  38%|███▊      | 18897/49903 [00:14<00:32, 950.89it/s]
#  38%|███▊      | 18997/49903 [00:14<00:32, 964.66it/s]
#  38%|███▊      | 19095/49903 [00:15<00:32, 943.25it/s]
#  38%|███▊      | 19193/49903 [00:15<00:32, 951.06it/s]
#  39%|███▊      | 19300/49903 [00:15<00:31, 968.66it/s]
#  39%|███▉      | 19427/49903 [00:15<00:30, 1014.83it/s]
#  39%|███▉      | 19556/49903 [00:15<00:27, 1091.11it/s]
#  39%|███▉      | 19690/49903 [00:15<00:26, 1160.68it/s]
#  40%|███▉      | 19836/49903 [00:15<00:24, 1231.66it/s]
#  40%|███▉      | 19960/49903 [00:15<00:24, 1216.29it/s]
#  40%|████      | 20082/49903 [00:15<00:25, 1160.21it/s]
#  40%|████      | 20200/49903 [00:16<00:25, 1149.00it/s]
#  41%|████      | 20319/49903 [00:16<00:25, 1159.47it/s]
#  41%|████      | 20489/49903 [00:16<00:22, 1315.89it/s]
#  41%|████▏     | 20628/49903 [00:16<00:21, 1336.29it/s]
#  42%|████▏     | 20763/49903 [00:16<00:23, 1262.85it/s]
#  42%|████▏     | 20891/49903 [00:16<00:22, 1267.23it/s]
#  42%|████▏     | 21019/49903 [00:16<00:23, 1228.76it/s]
#  42%|████▏     | 21143/49903 [00:16<00:24, 1176.99it/s]
#  43%|████▎     | 21262/49903 [00:16<00:24, 1155.37it/s]
#  43%|████▎     | 21379/49903 [00:16<00:25, 1127.07it/s]
#  43%|████▎     | 21493/49903 [00:17<00:25, 1123.36it/s]
#  43%|████▎     | 21612/49903 [00:17<00:25, 1101.97it/s]
#  44%|████▎     | 21723/49903 [00:17<00:26, 1053.37it/s]
#  44%|████▍     | 21842/49903 [00:17<00:26, 1046.19it/s]
#  44%|████▍     | 21959/49903 [00:17<00:26, 1037.29it/s]
#  44%|████▍     | 22063/49903 [00:17<00:26, 1034.70it/s]
#  44%|████▍     | 22174/49903 [00:17<00:26, 1049.87it/s]
#  45%|████▍     | 22294/49903 [00:17<00:26, 1049.15it/s]
#  45%|████▍     | 22417/49903 [00:17<00:25, 1066.96it/s]
#  45%|████▌     | 22524/49903 [00:18<00:26, 1049.44it/s]
#  45%|████▌     | 22629/49903 [00:18<00:27, 1006.29it/s]
#  46%|████▌     | 22756/49903 [00:18<00:26, 1036.07it/s]
#  46%|████▌     | 22871/49903 [00:18<00:25, 1061.23it/s]
#  46%|████▌     | 22997/49903 [00:18<00:25, 1070.49it/s]
#  46%|████▋     | 23105/49903 [00:18<00:25, 1068.23it/s]
#  47%|████▋     | 23212/49903 [00:18<00:25, 1050.62it/s]
#  47%|████▋     | 23329/49903 [00:18<00:25, 1056.57it/s]
#  47%|████▋     | 23445/49903 [00:18<00:24, 1085.46it/s]
#  47%|████▋     | 23567/49903 [00:19<00:24, 1066.36it/s]
#  47%|████▋     | 23682/49903 [00:19<00:24, 1052.54it/s]
#  48%|████▊     | 23788/49903 [00:19<00:24, 1051.47it/s]
#  48%|████▊     | 23894/49903 [00:19<00:24, 1052.18it/s]
#  48%|████▊     | 24001/49903 [00:19<00:24, 1048.06it/s]
#  48%|████▊     | 24122/49903 [00:19<00:24, 1053.76it/s]
#  49%|████▊     | 24244/49903 [00:19<00:24, 1058.39it/s]
#  49%|████▉     | 24350/49903 [00:19<00:24, 1057.89it/s]
#  49%|████▉     | 24456/49903 [00:19<00:24, 1057.69it/s]
#  49%|████▉     | 24563/49903 [00:20<00:23, 1060.87it/s]
#  49%|████▉     | 24681/49903 [00:20<00:24, 1049.66it/s]
#  50%|████▉     | 24790/49903 [00:20<00:23, 1053.88it/s]
#  50%|████▉     | 24903/49903 [00:20<00:24, 1032.17it/s]
#  50%|█████     | 25007/49903 [00:20<00:25, 989.52it/s]
#  50%|█████     | 25111/49903 [00:20<00:24, 1000.57it/s]
#  51%|█████     | 25233/49903 [00:20<00:23, 1045.95it/s]
#  51%|█████     | 25435/49903 [00:20<00:18, 1321.00it/s]
#  51%|█████▏    | 25588/49903 [00:20<00:17, 1379.48it/s]
#  52%|█████▏    | 25772/49903 [00:20<00:15, 1511.71it/s]
#  52%|█████▏    | 25953/49903 [00:21<00:15, 1594.68it/s]
#  52%|█████▏    | 26126/49903 [00:21<00:14, 1630.54it/s]
#  53%|█████▎    | 26290/49903 [00:21<00:14, 1622.22it/s]
#  53%|█████▎    | 26471/49903 [00:21<00:14, 1669.84it/s]
#  53%|█████▎    | 26639/49903 [00:21<00:13, 1669.02it/s]
#  54%|█████▍    | 26824/49903 [00:21<00:13, 1717.98it/s]
#  54%|█████▍    | 26997/49903 [00:21<00:13, 1720.81it/s]
#  54%|█████▍    | 27170/49903 [00:21<00:13, 1684.87it/s]
#  55%|█████▍    | 27352/49903 [00:21<00:13, 1721.30it/s]
#  55%|█████▌    | 27546/49903 [00:21<00:12, 1784.22it/s]
#  56%|█████▌    | 27750/49903 [00:22<00:11, 1857.61it/s]
#  56%|█████▌    | 27937/49903 [00:22<00:11, 1847.75it/s]
#  56%|█████▋    | 28122/49903 [00:22<00:12, 1732.78it/s]
#  57%|█████▋    | 28301/49903 [00:22<00:12, 1689.25it/s]
#  57%|█████▋    | 28472/49903 [00:22<00:12, 1668.91it/s]
#  57%|█████▋    | 28668/49903 [00:22<00:12, 1687.91it/s]
#  58%|█████▊    | 28838/49903 [00:22<00:12, 1661.41it/s]
#  58%|█████▊    | 29008/49903 [00:22<00:12, 1631.14it/s]
#  58%|█████▊    | 29176/49903 [00:22<00:12, 1643.77it/s]
#  59%|█████▉    | 29341/49903 [00:23<00:12, 1644.24it/s]
#  59%|█████▉    | 29506/49903 [00:23<00:12, 1613.86it/s]
#  59%|█████▉    | 29688/49903 [00:23<00:12, 1662.92it/s]
#  60%|█████▉    | 29855/49903 [00:23<00:12, 1645.25it/s]
#  60%|██████    | 30020/49903 [00:23<00:12, 1551.32it/s]
#  60%|██████    | 30183/49903 [00:23<00:12, 1570.63it/s]
#  61%|██████    | 30341/49903 [00:23<00:12, 1544.45it/s]
#  61%|██████    | 30497/49903 [00:23<00:12, 1523.20it/s]
#  61%|██████▏   | 30670/49903 [00:23<00:12, 1578.25it/s]
#  62%|██████▏   | 30829/49903 [00:24<00:13, 1447.40it/s]
#  62%|██████▏   | 30976/49903 [00:24<00:14, 1344.39it/s]
#  62%|██████▏   | 31113/49903 [00:24<00:16, 1135.61it/s]
#  63%|██████▎   | 31233/49903 [00:24<00:17, 1087.78it/s]
#  63%|██████▎   | 31346/49903 [00:24<00:17, 1059.72it/s]
#  63%|██████▎   | 31465/49903 [00:24<00:16, 1091.90it/s]
#  63%|██████▎   | 31593/49903 [00:24<00:16, 1141.38it/s]
#  64%|██████▎   | 31710/49903 [00:24<00:16, 1122.89it/s]
#  64%|██████▍   | 31851/49903 [00:24<00:15, 1168.78it/s]
#  64%|██████▍   | 31986/49903 [00:25<00:14, 1205.63it/s]
#  64%|██████▍   | 32108/49903 [00:25<00:15, 1144.28it/s]
#  65%|██████▍   | 32224/49903 [00:25<00:15, 1105.94it/s]
#  65%|██████▍   | 32336/49903 [00:25<00:15, 1108.23it/s]
#  65%|██████▌   | 32468/49903 [00:25<00:14, 1165.35it/s]
#  65%|██████▌   | 32604/49903 [00:25<00:14, 1219.45it/s]
#  66%|██████▌   | 32727/49903 [00:25<00:14, 1211.63it/s]
#  66%|██████▌   | 32865/49903 [00:25<00:13, 1257.05it/s]
#  66%|██████▌   | 32992/49903 [00:25<00:13, 1223.49it/s]
#  66%|██████▋   | 33115/49903 [00:26<00:13, 1202.70it/s]
#  67%|██████▋   | 33291/49903 [00:26<00:12, 1345.70it/s]
#  67%|██████▋   | 33426/49903 [00:26<00:12, 1314.51it/s]
#  67%|██████▋   | 33566/49903 [00:26<00:12, 1338.71it/s]
#  68%|██████▊   | 33701/49903 [00:26<00:12, 1336.25it/s]
#  68%|██████▊   | 33835/49903 [00:26<00:12, 1306.81it/s]
#  68%|██████▊   | 33966/49903 [00:26<00:12, 1303.52it/s]
#  68%|██████▊   | 34110/49903 [00:26<00:11, 1340.08it/s]
#  69%|██████▊   | 34245/49903 [00:26<00:12, 1264.45it/s]
#  69%|██████▉   | 34374/49903 [00:27<00:12, 1269.90it/s]
#  69%|██████▉   | 34531/49903 [00:27<00:11, 1354.43it/s]
#  69%|██████▉   | 34668/49903 [00:27<00:11, 1353.06it/s]
#  70%|██████▉   | 34804/49903 [00:27<00:11, 1281.49it/s]
#  70%|███████   | 34934/49903 [00:27<00:12, 1222.13it/s]
#  70%|███████   | 35058/49903 [00:27<00:13, 1128.45it/s]
#  70%|███████   | 35173/49903 [00:27<00:13, 1062.03it/s]
#  71%|███████   | 35285/49903 [00:27<00:13, 1076.87it/s]
#  71%|███████   | 35401/49903 [00:27<00:13, 1096.89it/s]
#  71%|███████   | 35512/49903 [00:28<00:13, 1097.64it/s]
#  71%|███████▏  | 35623/49903 [00:28<00:12, 1099.18it/s]
#  72%|███████▏  | 35734/49903 [00:28<00:12, 1098.59it/s]
#  72%|███████▏  | 35845/49903 [00:28<00:12, 1084.57it/s]
#  72%|███████▏  | 35954/49903 [00:28<00:13, 1057.64it/s]
#  72%|███████▏  | 36085/49903 [00:28<00:12, 1121.86it/s]
#  73%|███████▎  | 36208/49903 [00:28<00:12, 1129.25it/s]
#  73%|███████▎  | 36335/49903 [00:28<00:11, 1167.87it/s]
#  73%|███████▎  | 36453/49903 [00:28<00:11, 1156.82it/s]
#  73%|███████▎  | 36569/49903 [00:28<00:11, 1112.33it/s]
#  74%|███████▎  | 36682/49903 [00:29<00:11, 1115.80it/s]
#  74%|███████▍  | 36825/49903 [00:29<00:10, 1206.60it/s]
#  74%|███████▍  | 36949/49903 [00:29<00:10, 1213.06it/s]
#  74%|███████▍  | 37074/49903 [00:29<00:10, 1221.45it/s]
#  75%|███████▍  | 37197/49903 [00:29<00:10, 1165.15it/s]
#  75%|███████▍  | 37315/49903 [00:29<00:11, 1130.25it/s]
#  75%|███████▌  | 37429/49903 [00:29<00:11, 1105.05it/s]
#  75%|███████▌  | 37540/49903 [00:29<00:11, 1035.27it/s]
#  75%|███████▌  | 37654/49903 [00:29<00:11, 1062.05it/s]
#  76%|███████▌  | 37762/49903 [00:30<00:12, 970.24it/s]
#  76%|███████▌  | 37861/49903 [00:30<00:13, 906.56it/s]
#  76%|███████▌  | 37955/49903 [00:30<00:13, 915.05it/s]
#  76%|███████▌  | 38048/49903 [00:30<00:13, 872.42it/s]
#  76%|███████▋  | 38138/49903 [00:30<00:13, 878.24it/s]
#  77%|███████▋  | 38227/49903 [00:30<00:13, 865.44it/s]
#  77%|███████▋  | 38316/49903 [00:30<00:13, 859.18it/s]
#  77%|███████▋  | 38403/49903 [00:30<00:14, 805.57it/s]
#  77%|███████▋  | 38509/49903 [00:30<00:13, 856.58it/s]
#  77%|███████▋  | 38600/49903 [00:31<00:13, 868.56it/s]
#  78%|███████▊  | 38719/49903 [00:31<00:11, 958.99it/s]
#  78%|███████▊  | 38833/49903 [00:31<00:10, 1010.16it/s]
#  78%|███████▊  | 38949/49903 [00:31<00:10, 1012.16it/s]
#  78%|███████▊  | 39086/49903 [00:31<00:09, 1113.59it/s]
#  79%|███████▊  | 39212/49903 [00:31<00:09, 1148.65it/s]
#  79%|███████▉  | 39328/49903 [00:31<00:09, 1127.88it/s]
#  79%|███████▉  | 39452/49903 [00:31<00:09, 1159.94it/s]
#  79%|███████▉  | 39572/49903 [00:31<00:08, 1169.34it/s]
#  80%|███████▉  | 39690/49903 [00:31<00:09, 1124.27it/s]
#  80%|███████▉  | 39804/49903 [00:32<00:09, 1011.24it/s]
#  80%|███████▉  | 39908/49903 [00:32<00:09, 1005.46it/s]
#  80%|████████  | 40051/49903 [00:32<00:08, 1120.81it/s]
#  80%|████████  | 40166/49903 [00:32<00:08, 1103.03it/s]
#  81%|████████  | 40279/49903 [00:32<00:08, 1103.33it/s]
#  81%|████████  | 40399/49903 [00:32<00:08, 1127.05it/s]
#  81%|████████  | 40527/49903 [00:32<00:08, 1168.94it/s]
#  81%|████████▏ | 40645/49903 [00:32<00:07, 1160.93it/s]
#  82%|████████▏ | 40762/49903 [00:32<00:07, 1143.47it/s]
#  82%|████████▏ | 40877/49903 [00:33<00:07, 1133.22it/s]
#  82%|████████▏ | 40991/49903 [00:33<00:08, 1079.86it/s]
#  82%|████████▏ | 41100/49903 [00:33<00:08, 1044.69it/s]
#  83%|████████▎ | 41205/49903 [00:33<00:08, 1016.99it/s]
#  83%|████████▎ | 41308/49903 [00:33<00:08, 1019.86it/s]
#  83%|████████▎ | 41411/49903 [00:33<00:08, 1007.02it/s]
#  83%|████████▎ | 41533/49903 [00:33<00:08, 1024.93it/s]
#  83%|████████▎ | 41639/49903 [00:33<00:07, 1034.26it/s]
#  84%|████████▎ | 41743/49903 [00:33<00:08, 1008.33it/s]
#  84%|████████▍ | 41873/49903 [00:34<00:07, 1083.74it/s]
#  84%|████████▍ | 42001/49903 [00:34<00:07, 1107.70it/s]
#  84%|████████▍ | 42112/49903 [00:34<00:12, 646.39it/s]
#  85%|████████▍ | 42208/49903 [00:34<00:10, 705.88it/s]
#  85%|████████▍ | 42313/49903 [00:34<00:09, 778.36it/s]
#  85%|████████▌ | 42440/49903 [00:34<00:08, 892.50it/s]
#  85%|████████▌ | 42544/49903 [00:34<00:07, 921.44it/s]
#  85%|████████▌ | 42647/49903 [00:35<00:07, 935.00it/s]
#  86%|████████▌ | 42749/49903 [00:35<00:07, 940.75it/s]
#  86%|████████▌ | 42849/49903 [00:35<00:07, 952.09it/s]
#  86%|████████▌ | 42951/49903 [00:35<00:07, 949.43it/s]
#  86%|████████▋ | 43067/49903 [00:35<00:06, 985.69it/s]
#  87%|████████▋ | 43183/49903 [00:35<00:06, 995.33it/s]
#  87%|████████▋ | 43292/49903 [00:35<00:06, 988.10it/s]
#  87%|████████▋ | 43412/49903 [00:35<00:06, 1043.68it/s]
#  87%|████████▋ | 43518/49903 [00:35<00:06, 1043.28it/s]
#  87%|████████▋ | 43654/49903 [00:35<00:05, 1091.23it/s]
#  88%|████████▊ | 43778/49903 [00:36<00:05, 1129.79it/s]
#  88%|████████▊ | 43906/49903 [00:36<00:05, 1170.75it/s]
#  88%|████████▊ | 44024/49903 [00:36<00:05, 1124.32it/s]
#  88%|████████▊ | 44138/49903 [00:36<00:05, 1071.78it/s]
#  89%|████████▊ | 44256/49903 [00:36<00:05, 1064.05it/s]
#  89%|████████▉ | 44363/49903 [00:36<00:05, 1034.14it/s]
#  89%|████████▉ | 44522/49903 [00:36<00:04, 1185.86it/s]
#  90%|████████▉ | 44699/49903 [00:36<00:03, 1349.62it/s]
#  90%|████████▉ | 44854/49903 [00:36<00:03, 1403.57it/s]
#  90%|█████████ | 45047/49903 [00:37<00:03, 1556.62it/s]
#  91%|█████████ | 45215/49903 [00:37<00:02, 1574.63it/s]
#  91%|█████████ | 45387/49903 [00:37<00:02, 1615.03it/s]
#  91%|█████████▏| 45550/49903 [00:37<00:02, 1612.47it/s]
#  92%|█████████▏| 45750/49903 [00:37<00:02, 1685.70it/s]
#  92%|█████████▏| 45919/49903 [00:37<00:02, 1658.77it/s]
#  92%|█████████▏| 46085/49903 [00:37<00:02, 1632.07it/s]
#  93%|█████████▎| 46249/49903 [00:37<00:02, 1552.36it/s]
#  93%|█████████▎| 46405/49903 [00:37<00:02, 1528.01it/s]
#  93%|█████████▎| 46559/49903 [00:37<00:02, 1517.03it/s]
#  94%|█████████▎| 46719/49903 [00:38<00:02, 1536.97it/s]
#  94%|█████████▍| 46873/49903 [00:38<00:02, 1509.24it/s]
#  94%|█████████▍| 47047/49903 [00:38<00:01, 1531.36it/s]
#  95%|█████████▍| 47243/49903 [00:38<00:01, 1604.56it/s]
#  95%|█████████▍| 47404/49903 [00:38<00:01, 1598.84it/s]
#  95%|█████████▌| 47569/49903 [00:38<00:01, 1610.55it/s]
#  96%|█████████▌| 47731/49903 [00:38<00:01, 1591.14it/s]
#  96%|█████████▌| 47898/49903 [00:38<00:01, 1601.01it/s]
#  96%|█████████▋| 48059/49903 [00:38<00:01, 1555.25it/s]
#  97%|█████████▋| 48228/49903 [00:39<00:01, 1528.41it/s]
#  97%|█████████▋| 48427/49903 [00:39<00:00, 1620.50it/s]
#  97%|█████████▋| 48590/49903 [00:39<00:00, 1548.64it/s]
#  98%|█████████▊| 48746/49903 [00:39<00:00, 1511.78it/s]
#  98%|█████████▊| 48917/49903 [00:39<00:00, 1565.59it/s]
#  98%|█████████▊| 49075/49903 [00:39<00:00, 1500.08it/s]
#  99%|█████████▊| 49233/49903 [00:39<00:00, 1514.16it/s]
#  99%|█████████▉| 49386/49903 [00:39<00:00, 1458.55it/s]
#  99%|█████████▉| 49537/49903 [00:39<00:00, 1452.63it/s]
# 100%|█████████▉| 49721/49903 [00:40<00:00, 1560.16it/s]
# 100%|██████████| 49903/49903 [00:40<00:00, 1242.56it/s]
# 49903 49903 ['Chronic', 'hepatobiliary', 'disease', ',', 'conservatively', 'defined', 'as', 'liver', 'function', 'tests', '(', 'AST', ',', 'ALT', ',', 'alkaline', 'phosphatase', ',', 'Total', 'Bilirubin', ')', '>', '1', '.', '5', 'times', 'the', 'upper', 'limit', 'of', 'normal'] [8, 9, 9, 30, 30, 30, 30, 30, 30, 30, 30, 10, 30, 10, 30, 10, 11, 30, 10, 11, 30, 30, 20, 21, 21, 21, 21, 21, 21, 21, 21]

# %%
list(tags.keys())
# Out:
# [(4, 12)]

# %%
from datasets import Dataset
my_dict = {"tokens": all_tokens, "ner_tags": all_ner_tags}
dataset = Dataset.from_dict(my_dict)

# %%
inputs = tokenizer(dataset[10]["tokens"], is_split_into_words=True)
inputs.tokens()
# Out:
# ['[CLS]',
#  'end',
#  '-',
#  'stage',
#  'organ',
#  'disease',
#  'or',
#  'medical',
#  'condition',
#  'with',
#  'subsequent',
#  'vision',
#  'loss',
#  '(',
#  'e',
#  '.',
#  'g',
#  '.',
#  ',',
#  'diabetes',
#  ',',
#  'stroke',
#  ')',
#  '[SEP]']

# %%
def align_labels_with_tokens(labels, word_ids):
    new_labels = []
    current_word = None
    for word_id in word_ids:
        if word_id != current_word:
            # Start of a new word!
            current_word = word_id
            label = -100 if word_id is None else labels[word_id]
            new_labels.append(label)
        elif word_id is None:
            # Special token
            new_labels.append(-100)
        else:
            # Same word as previous token
            label = labels[word_id]
            # If the label is B-XXX we change it to I-XXX
            if label % 2 == 1:
                label += 1
            new_labels.append(label)

    return new_labels

inputs = tokenizer(dataset[0]["tokens"], is_split_into_words=True)
inputs.tokens()

labels = dataset[0]["ner_tags"]
word_ids = inputs.word_ids()
print(labels)
print(align_labels_with_tokens(labels, word_ids))
# Out:
# [30, 30, 30, 30, 30, 8]
# [-100, 30, 30, 30, 30, 30, 8, -100]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"], truncation=True, is_split_into_words=True
    )
    all_labels = examples["ner_tags"]
    new_labels = []
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))

    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs

# %%
tokenized_datasets = dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=dataset.column_names,
)
# Out:
# Map:   0%|          | 0/49903 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
# !pip install seqeval
# !pip install evaluate
# Out:
# Requirement already satisfied: seqeval in c:\users\expert\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\expert\anaconda3\lib\site-packages (from seqeval) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\expert\anaconda3\lib\site-packages (from seqeval) (1.3.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\expert\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\expert\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\expert\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (2.2.0)
# Requirement already satisfied: evaluate in c:\users\expert\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (2.14.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: dill in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (3.3.0)
# Requirement already satisfied: multiprocess in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (2023.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (0.16.4)
# Requirement already satisfied: packaging in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (23.0)
# Requirement already satisfied: responses<0.19 in c:\users\expert\anaconda3\lib\site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\expert\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (11.0.0)
# Requirement already satisfied: aiohttp in c:\users\expert\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\expert\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\expert\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\expert\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\expert\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\expert\anaconda3\lib\site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\expert\anaconda3\lib\site-packages (from pandas->evaluate) (2022.7)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\expert\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\expert\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)

# %%
import evaluate

metric = evaluate.load("seqeval")

# %%
import numpy as np
from nervaluate import collect_named_entities
from nervaluate import compute_metrics as ner_compute_metrics
from nervaluate import Evaluator

label_names = lebel_set
def compute_metrics(eval_preds):

    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)

    # Remove ignored index (special tokens) and convert to labels
    true_labels = [[label_names[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    all_metrics = metric.compute(predictions=true_predictions, references=true_labels)

    true_labels_1 = [[l for l in label] for label in true_labels]
    true_predictions_1 = [[l for l in label] for label in true_predictions]
    evaluator = Evaluator(true_labels_1, true_predictions_1, tags=[l[2:] for l in label_names if l !='O'], loader="list")
    results, results_by_tag = evaluator.evaluate()

    return {
        "precision": all_metrics["overall_precision"],
        "recall": all_metrics["overall_recall"],
        "f1": all_metrics["overall_f1"],
        "accuracy": all_metrics["overall_accuracy"],
        "results": results,
        #"results_by_tag": results_by_tag,
    }

# %%
id2label = {i: label for i, label in enumerate(lebel_set)}
label2id = {v: k for k, v in id2label.items()}

# %%
from transformers import TrainingArguments

args = TrainingArguments(
    "clinical-bert-finetuned-ner",
    per_device_train_batch_size=32,
    per_device_eval_batch_size=8,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=3,
    weight_decay=0.01,
    push_to_hub=False,
)

# %%
tokenized_datasets= tokenized_datasets.train_test_split(test_size=0.20)

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 39922
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 9981
#     })
# })

# %%
from transformers import AutoModelForTokenClassification

model_checkpoint = "medicalai/ClinicalBERT"
model = AutoModelForTokenClassification.from_pretrained(
    model_checkpoint,
    id2label=id2label,
    label2id=label2id,
)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 23427a9f-ee6b-484d-9a8e-4e1f98ab6f64)')' thrown while requesting HEAD https://huggingface.co/medicalai/ClinicalBERT/resolve/main/config.json
# 2023-10-05 13:59:21 huggingface_hub.utils._http WARNING: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 23427a9f-ee6b-484d-9a8e-4e1f98ab6f64)')' thrown while requesting HEAD https://huggingface.co/medicalai/ClinicalBERT/resolve/main/config.json
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at medicalai/ClinicalBERT and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenized_datasets_1000 = tokenized_datasets.filter(lambda example, indice: indice <= 1000, with_indices=True)
# Out:
# Filter:   0%|          | 0/39922 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/9981 [00:00<?, ? examples/s]

# %%
tokenized_datasets_1000
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1001
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1001
#     })
# })

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='3744' max='3744' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3744/3744 22:01:45, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#       <th>Results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.449100</td>
#       <td>0.369593</td>
#       <td>0.774900</td>
#       <td>0.820641</td>
#       <td>0.797115</td>
#       <td>0.876897</td>
#       <td>{'ent_type': {'correct': 59802, 'incorrect': 5145, 'partial': 0, 'missed': 4205, 'spurious': 8287, 'possible': 69152, 'actual': 73234, 'precision': 0.8165879236420241, 'recall': 0.8647906062008329, 'f1': 0.8399983144410265}, 'partial': {'correct': 60825, 'incorrect': 0, 'partial': 4122, 'missed': 4205, 'spurious': 8287, 'possible': 69152, 'actual': 73234, 'precision': 0.8586995111560204, 'recall': 0.9093880148079593, 'f1': 0.8833171800598373}, 'strict': {'correct': 56749, 'incorrect': 8198, 'partial': 0, 'missed': 4205, 'spurious': 8287, 'possible': 69152, 'actual': 73234, 'precision': 0.7748996367807303, 'recall': 0.8206414854234151, 'f1': 0.7971148848903684}, 'exact': {'correct': 60825, 'incorrect': 4122, 'partial': 0, 'missed': 4205, 'spurious': 8287, 'possible': 69152, 'actual': 73234, 'precision': 0.8305568451812, 'recall': 0.8795841045812124, 'f1': 0.854367704690068}}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.349000</td>
#       <td>0.338022</td>
#       <td>0.799501</td>
#       <td>0.824936</td>
#       <td>0.812020</td>
#       <td>0.885756</td>
#       <td>{'ent_type': {'correct': 59842, 'incorrect': 4745, 'partial': 0, 'missed': 4565, 'spurious': 6765, 'possible': 69152, 'actual': 71352, 'precision': 0.8386870725417648, 'recall': 0.8653690421101342, 'f1': 0.8518191652906679}, 'partial': {'correct': 60821, 'incorrect': 0, 'partial': 3766, 'missed': 4565, 'spurious': 6765, 'possible': 69152, 'actual': 71352, 'precision': 0.8787980715326831, 'recall': 0.9067561314206386, 'f1': 0.8925582189830895}, 'strict': {'correct': 57046, 'incorrect': 7541, 'partial': 0, 'missed': 4565, 'spurious': 6765, 'possible': 69152, 'actual': 71352, 'precision': 0.7995010651418321, 'recall': 0.8249363720499768, 'f1': 0.8120195866309856}, 'exact': {'correct': 60821, 'incorrect': 3766, 'partial': 0, 'missed': 4565, 'spurious': 6765, 'possible': 69152, 'actual': 71352, 'precision': 0.8524077811413836, 'recall': 0.8795262609902823, 'f1': 0.8657547116096339}}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.299700</td>
#       <td>0.332872</td>
#       <td>0.802412</td>
#       <td>0.830215</td>
#       <td>0.816077</td>
#       <td>0.887881</td>
#       <td>{'ent_type': {'correct': 60114, 'incorrect': 4741, 'partial': 0, 'missed': 4297, 'spurious': 6693, 'possible': 69152, 'actual': 71548, 'precision': 0.8401912003130765, 'recall': 0.8693024062933827, 'f1': 0.854498933901919}, 'partial': {'correct': 61198, 'incorrect': 0, 'partial': 3657, 'missed': 4297, 'spurious': 6693, 'possible': 69152, 'actual': 71548, 'precision': 0.8808981383127411, 'recall': 0.9114197709393799, 'f1': 0.8958990760483299}, 'strict': {'correct': 57411, 'incorrect': 7444, 'partial': 0, 'missed': 4297, 'spurious': 6693, 'possible': 69152, 'actual': 71548, 'precision': 0.8024123665231733, 'recall': 0.8302145997223508, 'f1': 0.8160767590618336}, 'exact': {'correct': 61198, 'incorrect': 3657, 'partial': 0, 'missed': 4297, 'spurious': 6693, 'possible': 69152, 'actual': 71548, 'precision': 0.8553418683960419, 'recall': 0.8849780194354465, 'f1': 0.869907604832978}}</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3744, training_loss=0.40842092954195464, metrics={'train_runtime': 79314.1469, 'train_samples_per_second': 1.51, 'train_steps_per_second': 0.047, 'total_flos': 2621426290776948.0, 'train_loss': 0.40842092954195464, 'epoch': 3.0})

# %%
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification
import re

# Load the CSV dataset
data = pd.read_json('combined.jsonl'  , lines=True)['text'].values
print(data)
# Specify the number of rows to process (e.g., 500)
num_rows_to_process = 325

# Filter the dataset to select the first 'num_rows_to_process' rows
#data = data.head(num_rows_to_process)

# Initialize the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("clinical-bert-finetuned-ner/checkpoint-1248")
model = AutoModelForTokenClassification.from_pretrained("clinical-bert-finetuned-ner/checkpoint-1248")

# Function to extract token indices
def extract_token_indices(text):
    # Tokenize the text
    inputs = tokenizer(text, return_tensors="pt")
    
    # Get token logits
    with torch.no_grad():
        logits = model(**inputs).logits
    
    # Predict token labels
    predictions = torch.argmax(logits, dim=2)
    
    # Convert token ids to tokens
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())
    predicted_token_class = [model.config.id2label[t.item()] for t in predictions[0]]
    
    # Combine tokens and labels
    combined_tokens = []
    current_token = ""
    current_label = ""
    
    for token, label in zip(tokens, predicted_token_class):
        if token.startswith("##"):
            current_token += token[2:]  # Append '##' tokens to the previous token
        else:
            if current_token:
                combined_tokens.append((current_token, current_label))
            current_token = token
            current_label = label
    
    if current_token:
        combined_tokens.append((current_token, current_label))
    tokens_to_find = [token for token, label in combined_tokens if label != 'O']
    cleaned_sentence = re.sub(r'[^\w\s]', '', text.lower())
    
    # Find token indices
    token_indices = []
    start_index = 0
    
    current_word = ""
    
    for token in tokens_to_find:
#         print("Cleaned_sentence", cleaned_sentence)
        start = text.lower().find(token)
        end = start + len(token)
        label = None
        for t, l in combined_tokens:
            if t == token:
                label = l
                break
        token_indices.append({
            "label": label,
            "start_index": start,
            "end_index": end,
            "token": token
        })
        start_index = end + 1
    
    return token_indices

# Process each row in the dataset
result_list = []

for index, row in data.iterrows():
    text = row['cleaned_sent']  # Replace 'cleaned_sent' with the actual column name in your CSV
    token_indices = extract_token_indices(text)
    result_list.append(token_indices)
print(result_list)
# Print the results
# for result in result_list:
#     print(result)
# Out:
# ['NCT00351611 Insufficient response to pregabalin in the treatment of partial seizure'
#  'NCT00862446 Anticipated TPN treatment for at least one month'
#  'NCT00862446 TPN cholestasis of at least 2.5 mg/dl'
#  'NCT01175044 Patients scheduled to undergo revision total knee arthroplasty for infectious reasons'
#  'NCT01175044 Any condition requiring antibiotics 14 days prior to arriving for surgery'
#  'NCT01446094 Severe lung disease (active wheezing) Severe bradycardia (heart rate < 40 beats/min) Second- or third-degree atrioventricular heart block Sick sinus syndrome History of Long QT syndrome Severe hypotension (systolic BP < 80 mm Hg) Decompensated heart failure'
#  'NCT01446094 Inability to lie flat for 20-30 minutes (the anticipated amount of time to complete the MRI procedure)'
#  'NCT01446094 Stage 4 or 5 chronic kidney disease (eGFR < 30 ml/min/1.73 m2) Known allergy to GBCA'
#  'NCT01581749 history of an invasive malignancy (other than this prostate cancer,or basal or squamous skin cancers) within prior 5 years'
#  'NCT01774019 Diagnosis of probable pancreatic cancer, distal common bile duct (CBD) cholangiocarcinoma and other periampullary cancers (histology not required)'
#  'NCT01774019 Location of distal biliary obstruction is such that it would allow the proximal end of a stent to be positioned at least 2cm from the hilum'
#  'NCT01774019 Biliary strictures caused by malignancies other than pancreatic cancer, distal CBD cholangiocarcinoma and other periampullary cancers'
#  'NCT01793519 Absence of documentation of negative tuberculin skin test, negative QuantiFERON-TB Gold test, or treatment for latent tuberculosis prior to starting treatment with the anti-TNF agent'
#  'NCT01793519 Absence of documentation of negative hepatitis B serologies, absence of completion of treatment for chronic hepatitis B, or absence of suppressive antiviral treatment'
#  "NCT01794793 Patient is currently participating in a Novartis-sponsored study receiving pasireotide (LAR and/or s.c.) on monotherapy or combination therapy (for Cushing's Disease or Acromegaly), and has fulfilled all required assessments in the parent study and patients that are benefiting from the study treatment have no other alternatives"
#  'NCT01794793 Use of oral, injected or implanted hormonal methods of contraception or placement of an intrauterine device (IUD) or intrauterine system (IUS), or other forms of hormonal contraception that have comparable efficacy (failure rate <1%), for example hormone vaginal ring or transdermal hormone contraception'
#  'NCT01801072 Treating surgeon has recommended surgical repair of the aneurysm'
#  'NCT01801072 Presence of intracranial aneurysm (with or without rupture)'
#  'NCT01807897 Prior stroke with functional impairment or other severe, uncontrolled medical problems that may impair ability to participate in the study exams, based on medical history and review of medical records'
#  'NCT01807897 Severe daytime sleepiness, defined as Epworth Sleepiness Scale score 18 or higher or a report of falling asleep driving during the previous year, and deemed a safety risk by study physician'
#  'NCT01807897 Current use of a positive airway pressure device (including continuous or bi-level positive airway pressure or adaptive servo-ventilation) or supplemental oxygen therapy'
#  'NCT01912651 current or recent (within one week of surgery) systemic antibiotic use, intolerance to both clindamycin and cephalexin, discovery of a persistent cutaneous malignancy at the site of the defect following the reconstructive procedure and previous reconstruction at the site of the skin/soft-tissue defect'
#  'NCT01912651 all adult patients with a nasal or facial skin/soft tissue defect requiring reconstruction limited to or including a full-thickness skin graft'
#  'NCT01959425 Documented freedom from AF recurrence (symptomatic or asymptomatic arrhythmic recurrences lasting longer than 30 seconds) 3 months after successful cardiac ablation (AF recurrence during 3-month blanking period is excluded)'
#  'NCT01959425 Any cardiac surgery within the past 60 days (2 months) or valvular cardiac surgical procedure at any time (i.e., ventriculotomy, atriotomy, and valve repair or replacement and presence of a prosthetic valve)'
#  'NCT01959425 OAT required for reasons not related to AF (i.e., prosthetic valve, PV stenosis, previous pulmonary embolism, presence of spontaneous echo contrast [SEC] at standard echo performed at 3-months follow-up)'
#  'NCT01994382 Histological evidence: FL Grade 1-3A/iNHL, with relapsed or refractory disease (iNHL includes LPL/WM, MZL); aNHL, defined as DLBCL, FL Grade 3B, MCL, and transformed NHL with relapsed disease; CLL/SLL, PTCL, or CTCL (with MF/SS) with relapsed or refractory'
#  "NCT01994382 Measureable disease defined as: ≥ 1 lesion ≥ 1.5 cm single dimension via CT, CT/PET with nodal or mass lesions; Quantifiable circulating tumor cells; or for Waldenström's macroglobulinemia presence of IgM l > 2X ULN; For CTCL: mSWAT > 0"
#  'NCT01994382 Prior monoclonal antibody, radioimmunoconjugate, antibody drug conjugate, phototherapy, radiotherapy, chemotherapy, immunotherapy, immunosuppressive therapy, or any test agent within 3 weeks or for alemtuzumab 8 weeks of Day 1'
#  'NCT01996436 Adult patient, age 18-80 years old, with ruptured aneurysm(s) who experience cerebral vasospasm post operatively within 3-21 days'
#  'NCT01996436 Hunt Hess Grade 5 SAH'
#  'NCT02046395 Use of Ace Inh and ARB for control of blood pressure who are willing to be placed on alternate drug(s) in the washout period for blood pressure control'
#  'NCT02046395 Patients with chronic kidney disease stage with eGFR < 30 ml/min (CKD stage IV and V)'
#  'NCT02046395 Known history of hypersensitivity reaction or intolerability to Ace Inh or ARB'
#  'NCT02053246 with World Health Organization Group 2 Pulmonary Hypertension (Mean pulmonary artery pressure ≥ 25 mmHg and pulmonary capillary wedge pressure ≥ 15 mmHg)'
#  'NCT02053246 Other causes of heart failure other than diastolic dysfunction, such as restrictive cardiomyopathy or infiltrative cardiomyopathy'
#  'NCT02053246 Causes of PH other than that of heart failure, such as: chronic thromboembolic PH, sickle-cell disease, or sarcoidosis'
#  'NCT02055053 with unilateral or bilateral inguinal herna for laparoscopic repair'
#  'NCT02055053 History of Chronic pain or ongoing treatment for chronic pain'
#  'NCT02055053 Conversion from laparoscopic to open surgery'
#  'NCT02056288 Scheduled for closed reduction with percutaneous pinning under general anesthesia'
#  'NCT02101554 Columbia-Suicide Severity Rating Scale (C-SSRS) for suicidal ideation and behavior in past year'
#  'NCT02101554 with moderate to severe pain requiring around the clock treatment with an opioid analgesic'
#  "NCT02106598 At the discretion of the physician or surgeon, bilirubin level of < 2.0 mg/dl in the absence of a history of Gilbert's disease (or pattern consistent with Gilbert's)"
#  'NCT02106598 Medical illness unrelated to the tumor which in the opinion of the attending physician and principal investigator will preclude administration of the agent'
#  'NCT02106598 Newly-diagnosed colorectal cancer patients in whom SLN mapping and total mesorectal excision with lateral pelvic sidewall dissection is indicated'
#  'NCT02109081 undergoing a noncardiac surgical procedure under general anesthesia, with an anticipated duration of postoperative admission of at least 2 days'
#  'NCT02109081 MMSE score of ≤ 20 out of 30 on preoperative testing (more than mild cognitive impairment) or delirium on preoperative CAM testing'
#  'NCT02164734 Treated with nasal CPAP modalities ≥ 5 cm H2O and FiO2 between 0.30 and 0.60 for at least 2 hours to maintain SpO2 90-95%'
#  'NCT02164734 Craniofacial or cardiothoracic malformations'
#  'NCT02167022 Medical conditions that may prevent the administration of rehabilitation therapies at the intensity required by the study, or that may compromise the study ability to maintain blindness, or that have a co-morbidity not typically associated with CP (i.e. cancer, cystic fibrosis)'
#  'NCT02167022 insult to the central nervous system that caused the motor dysfunction must have occurred during gestation or within one year after birth independent of gestational age'
#  'NCT02202369 Patients with renal disease (documented glomerular filtration rate < 60mL/min/1.73m2)'
#  'NCT02202369 Patients with liver disease (documented liver function test abnormality)'
#  'NCT02203019 Patients with documented allergies to propofol, dexmedetomidine, fentanyl, eggs or egg products, or soy or soy products'
#  'NCT02203019 Mean arterial pressure less than 55 mmHg despite appropriate fluid resuscitation and vasopressor support'
#  'NCT02203019 with the diagnosis of sepsis (as specified below) within the previous 24 hours'
#  'NCT02209545 Uncontrolled intercurrent illness including, but not limited to, ongoing or active infection, symptomatic congestive heart failure, unstable angina pectoris, cardiac arrhythmia, or psychiatric illness/social situations that would limit compliance with study requirements'
#  'NCT02209545 presenting for abdominal myomectomy with documented uterine fibroids on pelvic imaging (pelvic ultrasound or MRI) within in last 12 months'
#  'NCT02209545 allergic reactions attributed to compounds of similar chemical or biologic composition to misoprostol'
#  'NCT02225548 unwilling to cease use of any treatment for erectile dysfunction during the study, including oral medication, vacuum devices, constrictive devices, injections, urethral suppositories, gels, any over-the-counter or nonprescription medications, and products purchased via the internet'
#  'NCT02225548 Diagnosis of moderate erectile dysfunction (defined according to the NIH Consensus Development Panel on Impotence) for more than 6 months and demonstrating and incomplete response to tadalafil alone'
#  "NCT02225548 Subject with a penile anatomical abnormality (e.g., penile fibrosis, fractures, or Peyronie's disease) which, in the investigator's opinion, could significantly impair sexual performance"
#  'NCT02270970 If WOCBP, inability or unwillingness to practice an acceptable method of contraception (including abstinence, barrier method with spermicide, or hormonal treatment'
#  'NCT02270970 Cancer within 5 years (except for completely excised cervical carcinoma in situ or excised non-melanoma skin cancer)'
#  'NCT02298504 Children with systemic illness that contraindicated vital pulp treatment such a sickle cell disease'
#  'NCT02298504 Pediatric patients with deep dental decay in primary molars'
#  'NCT02298504 Teeth with signs and symptoms of reversible pulpitis'
#  'NCT02322203 Subjects taking the following medications for at least six weeks, which may interfere with the study, will be excluded: BAS, antibiotics, anticoagulants, anticonvulsants, antiarrhythmic, Cyclosporine, Mycophenolate and Synthroid. Subjects with chronic diarrhea, gastric bypass or lap band procedures, ostomies, bowel motility problems, or other conditions that could affect intestinal fat absorption'
#  'NCT02322203 Female subjects taking hormonal contraceptives or hormone replacement therapy may be included in this study only if they have been on a stable dose for at least 3 months'
#  'NCT02322203 Subjects taking any lipid modification therapy, including but not limited to statins, fibrates and bile acid sequestrants'
#  'NCT02332291 Current diagnosis of major depressive disorder (DSM-IV-TR), single episode, recurrent or chronic, without psychotic features, as detected by MINI and clinical exam'
#  'NCT02332291 A failed therapeutic trial of escitalopram in the current depressive episode (defined as at least 6 weeks of treatment at a daily dose of 10mg or higher)'
#  'NCT02340169 Chronic infectious disease, system or organ disorder or other medical condition that would place patient at undue risk by study participation'
#  'NCT02340169 Allergy or sensitivity to corticosteroids or any drug hypersensitivity or intolerance that would compromise patient safety or study results'
#  'NCT02340169 Clinical diagnosis of stable plaque psoriasis with involvement of ≥ 10% body surface area'
#  'NCT02357654 women undergoing IVF/ICSI or frozen embryo transfers (FET) that less than 40 years old'
#  'NCT02366819 Histologically confirmed locally advanced gastric (primary endpoint includes proximal and mid-body stomach) or esophagogastric adenocarcinoma; distal gastric (antral) adenocarcinomas are eligible for enrolment but will not be included in the primary analysis'
#  'NCT02366819 Patients taking substrates, inhibitors, or inducers of cytochrome P450, family 3, subfamily A, polypeptide 4 (CYP3A4) should be encouraged to switch to alternative drugs whenever possible, given the potential for drug-drug interactions with irinotecan'
#  'NCT02366819 Women of child-bearing potential and men must agree to use adequate contraception (hormonal or barrier method of birth control; abstinence) prior to study entry and for the duration of study participation, up until 30 days after final study treatment'
#  'NCT02379156 Known allergies to midodrine hydrochloride'
#  'NCT02406885 18 to 65 years old with a BMI of 35 kg/m2 or greater who will be undergoing bariatric surgery (VSG and RYGB)'
#  'NCT02408120 Subjects with acute critical illness admitted to the ICU or expected to require ICU admission'
#  'NCT02408120 Known history of Type 2 diabetes mellitus for >3 months'
#  'NCT02413970 Active psychiatric disease (psychotic illness, major depression, or acute anxiety attacks) which prevents subject compliance with the requirements of the investigational study testing'
#  'NCT02413970 Any chronic medical illness or condition that contraindicates a surgical procedure under general anesthesia, as judged by the clinical study Investigator'
#  'NCT02413970 Subjects who have been prescribed, but refuse to try CPAP would be considered intolerant'
#  'NCT02445339 Currently prescribed pharmacotherapy for alcohol dependence (not including treatment of acute alcohol withdrawal syndrome)'
#  'NCT02445339 Acute liver injury (liver aminotransferase concentrations >5 times the upper limit of normal)'
#  'NCT02462590 Patients at risk for endovascular infection (previously documented rheumatic heart disease, congenital valve disease, surgically repaired congenital heart disease, unrepaired cyanotic congenital heart disease, any intracardiac repair with prosthetic material [mechanical or bio-prosthetic cardiac valves], previous or current endocarditis, permanent endovascular devices (e.g., endovascular grafts [e.g., aortic aneurysm repair, stents involving large arteries such as aorta, femorals and carotids], inferior vena cava filters, dialysis vascular grafts), tunnelled (not short-term) hemodialysis catheters, pacemakers or defibrillators. Patients with temporary central venous catheters, central venous dialysis catheters or peripherally inserted central catheters (PICCs) are not excluded and patients with coronary artery stents, coronary artery bypass grafts (CABG) or neurovascular coils are not excluded; patients with mitral valve prolapse or bicuspid aortic valve'
#  'NCT02462590 Patients at potential increased risk of iatrogenic probiotic infection (see Section 2.6 for detailed explanation) including specific immunocompromised populations (HIV <200 CD4 cells/μL, those receiving chronic immunosuppressive medications (e.g., azathioprine, cyclosporine, cyclophosphamide, tacrolimus, methotrexate, mycofenolate, Anti-IL2), previous transplantation (including stem cell) at any time, malignancy requiring chemotherapy in the last 3 months, neutropenia [absolute neutrophil count < 500]). However, patients receiving corticosteroids previously or presently or projected to receive corticosteroids are not excluded'
#  'NCT02462590 primary diagnosis of severe acute pancreatitis, without reference to a Ranson score [Ranson 1974])'
#  'NCT02488057 cardiovascular disease'
#  'NCT02489045 Patients with a history of anaphylactic allergy to eggs or egg products, manifested by one or more of the following symptoms: generalized urticaria, difficulty in breathing, swelling of the mouth and throat, hypotension, or shock. (Subjects with nonanaphylactic allergies to eggs or egg products may be enrolled in the study, but must be watched carefully for 1 h following the administration of SONAZOID)'
#  'NCT02489045 Patients who are medically unstable, patients who are seriously or terminally ill, and patients whose clinical course is unpredictable'
#  'NCT02515773 bipolar I, bipolar II, unspecified bipolar and related disorders, Disruptive Mood Dysregulation Disorder (DMDD), cyclothymic disorder, other specified bipolar and related disorders, as well as mood disorder not otherwise specified (if diagnosed in the past as per DSM-IV)'
#  'NCT02515773 Major neurological or medical illnesses that affect weight gain (e.g., unstable thyroid disease) or require a systemic medication that might impact weight or glucose regulation (e.g., diabetes mellitus [insulin], chronic renal failure [steroids])'
#  'NCT02542956 A medical condition that could interfere with study participation'
#  'NCT02542956 Undergoing abdominoplasty or TRAM flap breast reconstruction'
#  'NCT02560766 Sexually active patients must agree to use 2 medically accepted methods of contraception, 1 of which is a highly effective method (e.g., hormonal or intrauterine device [IUD]) [the second may be a barrier method (e.g., male condom, female condom, diaphragm or cervical cap)], during the course of the study treatment and for 4 weeks after the last dose of study treatment'
#  'NCT02560766 Uncontrolled hypertension defined as blood pressure (BP) ≥ 95 percentile adjusted for age, height, and sex, according to the tables published by the US Department of Health and Human Services 2005, at screening and before dosing'
#  'NCT02566928 presents with signs and symptoms of a SSTI'
#  'NCT02570321 Evidence of concomitant infection on exam or gram stain (i.e. herpes, both bacteria and acanthamoeba on gram stain)'
#  'NCT02570321 Corneal ulcer that is smear positive for either bacteria or filamentous fungus'
#  'NCT02573597 Narcotics within 3 hours prior to labor epidural placement'
#  'NCT02589353 has a history of taste or smell loss or other oral disorders (e.g., burning mouth syndrome)'
#  'NCT02589353 has current oral lesions, canker sores, or piercings'
#  'NCT02589977 elevated LV filling pressure by catheterization, echocardiographic criteria or B-type-natriuretic peptide > 100'
#  'NCT02589977 known cardiovascular disease, cardiac risk factors or use of cardiac medications'
#  'NCT02589977 preserved left ventricular ejection fraction (>= 50%) on echocardiography'
#  'NCT02607748 Stable Ischemic Heart Disease group: 40 patients who have undergone invasive coronary angiography within 21 days prior to the imaging visit, with history of typical angina prior to the angiogram, but no prior myocardial infarction or coronary revascularization'
#  'NCT02607748 Acute Coronary Syndrome group: 40 patients with type 1 myocardial infarction within 21 days prior to the imaging visit and invasive coronary angiography with angiographic evidence of at least a 50% stenosis in one or more coronary arteries'
#  'NCT02607748 Asymptomatic CAD group: 40 patients who have undergone Coronary Artery Calcium scanning within 6 months prior to the imaging visit, matched to the ACS patients for age, gender, and CAC score'
#  'NCT02632318 At least 20/200 corrected visual acuity'
#  'NCT02635893 Ongoing cord compression or a syrinx in the spinal cord or who suffer from a spinal cord disease such as spinal stenosis, spina bifida or herniated cervical disk'
#  'NCT02635893 Ongoing cord compression or a syrinx in the spinal cord or who suffer from a spinal cord disease such as spinal stenosis'
#  'NCT02635893 Any debilitating disease prior to the SCI that caused exercise intolerance'
#  'NCT02638935 Informed consent about histological examination (core cut biopsy (CCB), vacuum-assisted biopsy (VAB), fine needle aspiration (FNA) or surgery) has already been given in the course of clinical routine'
#  'NCT02638935 Patients with a lesion ≥ 0.5 cm in largest diameter size, initially scored BI-RADS® 3, 4a, 4b or 4c in B-mode ultrasound'
#  'NCT02638935 No lesion should be included when more than 50% of the lesion is further down than 4 cm beneath the skin level'
#  'NCT02643381 Adult patient (male or female) requiring emergency endotracheal intubation'
#  'NCT02643381 who require endotracheal intubation without sedative medication'
#  'NCT02692651 Patients receiving ≥ 1 high or medium risk antibiotic for treatment of an infection other than CDI, for an anticipated duration of ≥ 5 days from the time of enrollment'
#  'NCT02692651 Patients with severe-complicated disease that would compromise oral therapy (hypotenstion or shock, ileus or bowel obstruction, megacolon)'
#  'NCT02789111 More than three doses of any opioid within one week of surgery'
#  'NCT02789111 Major spine surgery scheduled as part of clinical care'
#  'NCT02789111 Chronic kidney disease stage 5'
#  'NCT02805504 Severe cardiovascular, hepatic, renal disease or neurological impairment'
#  'NCT02805504 Patients undergoing urologic surgery'
#  'NCT02805504 Allergy to bupivacaine'
#  'NCT02810704 Concurrently enrolled in another active interventional clinical trial testing a drug or intervention known or believed to interact with aspirin, warfarin, or rivaroxaban'
#  'NCT02810704 Undergoing elective primary, revision or second stage re-implantation total hip/knee replacement or uni-compartmental knee replacement or hip resurfacing arthroplasty'
#  'NCT02810704 Has had an operative procedure involving the eye, ear, or central nervous system within one month'
#  'NCT02822001 Patients weighing ≥ 80 pounds who are not -intubated prior to surgery'
#  'NCT02827526 Patients presenting for elective posterior spinal fusion surgery (lower thoracic, lumbar, sacral)'
#  'NCT02827526 Pulmonary disease necessitating home oxygen therapy'
#  'NCT02830360 One of the following VT events while not being treated with amiodarone, sotalol, or another class I or class III antiarrhythmic drug) within the last 6 months'
#  'NCT02830360 Are in renal failure (Creatinine clearance <15 mL/min), have NYHA Functional class IV heart failure, or a systemic illness likely to limit survival to <1 year'
#  'NCT02830360 Are ineligible to take the antiarrhythmic drug to which they would be assigned due to allergy, intolerance or contraindication'
#  'NCT02844907 Diagnosis or h/o PTSD, depression, substance use, mental health problems, sleep disorders, HPA disruption and/or TBI'
#  'NCT02844907 Anemia (hematocrit < 34%) as measured at screening visit'
#  'NCT02851888 Scheduled for arthroscopic labral repair with or without osteoplasty of the hip'
#  'NCT02851888 Radiographic signs of osteoarthritis (> Tonis grade 1)'
#  'NCT02872935 Any other physical or psychiatric condition that may impair their ability to cooperate with study data collection'
#  'NCT02872935 Antiemetic drug use in the 24 hours prior to cesarean delivery'
#  'NCT02872935 Chronic hypertension receiving antihypertensive treatment'
#  'NCT02893293 Hemosiderosis/hemochromatosis ( patients can still be included in the non-ferumoxytol arm)'
#  'NCT02893293 Osteonecrosis'
#  'NCT02946892 Known renovascular hypertension or evidence of pulmonary hypertension (pulmonary vascular resistance > 6 Wood units) unresponsive to vasodilator agents such as oxygen, nitroprusside, or nitric oxide'
#  'NCT02946892 anticipated to undergo heart transplantation, interventional catheterization, or corrective cardiac surgery during the 7 months following entry into the study'
#  'NCT02952365 Subjects who have previously undergone LASIK surgery'
#  'NCT02952365 Subjects with topographic evidence of keratoconus'
#  'NCT02952365 Subjects with ectatic eye disorders'
#  'NCT02968602 DSM-IV diagnosis of Alcohol or Substance Dependence within the last six months (except nicotine) or DSM-5 diagnosis of Substance Use Disorder in the last six months (except nicotine)'
#  'NCT02969187 History of hypersensitivity or adverse reaction to bupivacaine or narcotics'
#  'NCT02969187 Previous major abdominal surgery (possible adhesions and longer operation)'
#  'NCT02969187 laparoscopic sleeve gastrectomy (LSG) as primary bariatric procedure'
#  'NCT02974686 Wound healing issues at time of possible conversion (eg, wound dehiscence, wound infection, incisional hernia, lymphocele, seroma)'
#  'NCT02974686 Evidence of any GI disorder induced by an infection, underlying medical condition, or concomitant medication other than MPA'
#  'NCT02974686 Experiencing GI toxicity from MPA as determined by the treating physician within 12 months post-renal transplant'
#  'NCT03027115 Presenting with hernia requiring surgical intervention'
#  "NCT03056287 history of congestive heart failure, unstable cardiac arrhythmias, hypertrophic cardiomyopathy, severe aortic stenosis, angina or dyspnea at rest or during ADL's"
#  'NCT03056287 Uncontrolled diabetes with recent weight loss, diabetic coma, or frequent insulin reactions'
#  'NCT03118232 <15% of residents receiving at least one chlorhexidine bath or nasal decolonization treatment during their nursing home stay'
#  'NCT03118232 Minimal use of chlorhexidine bathing'
#  'NCT03120728 Use of a non-hormonal form of contraception, such as: sterilization (tubal ligation, Essure), copper IUD (intrauterine device), barrier methods or abstinence'
#  'NCT03140488 Estimated fetal weight greater than 4500 grams in diabetic and 5000 grams in non-diabetic mother'
#  'NCT03140488 Previous cervical ripening agents (cytotec, cervidil, cervical Foley Balloon)'
#  'NCT03185130 Lumbar puncture within the previous two weeks'
#  'NCT03185130 Head trauma within the previous two weeks'
#  'NCT03187379 patients undergoing other bariatric procedures'
#  'NCT03187379 previous history of roux-en-y gastric bypass'
#  'NCT03187379 laparoscopic roux-en-y gastric bypass'
#  'laparoscopic roux-en-y gastric bypass' 'use of EEA stapler anastomosis'
#  'Head trauma within the previous two weeks'
#  'Estimated fetal weight greater than 4500 grams in diabetic and 5000 grams in non-diabetic mother'
#  'Previous cervical ripening agents (cytotec, cervidil, cervical Foley Balloon)'
#  'Not seeking pregnancy during the study period'
#  'Use of a non-hormonal form of contraception, such as: sterilization (tubal ligation, Essure), copper IUD (intrauterine device), barrier methods or abstinence'
#  'Evidence of any GI disorder induced by an infection, underlying medical condition, or concomitant medication other than MPA'
#  'Hypersensitivity to everolimus, sirolimus, or other rapamycin deriviatives'
#  'Wound healing issues at time of possible conversion (eg, wound dehiscence, wound infection, incisional hernia, lymphocele, seroma)'
#  'History of hypersensitivity or adverse reaction to bupivacaine or narcotics'
#  'Severe liver dysfunction (LFT 3X upper limit of normal)'
#  'Current or planned pregnancy'
#  'Radiographic signs of osteoarthritis (> Tonis grade 1)'
#  'Are in renal failure (Creatinine clearance <15 mL/min), have NYHA Functional class IV heart failure, or a systemic illness likely to limit survival to <1 year'
#  'More than three doses of any opioid within one week of surgery'
#  'has a history of food allergy'
#  'has current oral lesions, canker sores, or piercings'
#  'A medical condition that could interfere with study participation'
#  'Patients with uncontrolled congestive heart failure (NYHA Class IV)'
#  'Patients who are pregnant or plan to become pregnant'
#  'History of cancer (within the last year)'
#  'Women must not be breastfeeding'
#  'Histologically confirmed locally advanced gastric (primary endpoint includes proximal and mid-body stomach) or esophagogastric adenocarcinoma; distal gastric (antral) adenocarcinomas are eligible for enrolment but will not be included in the primary analysis'
#  'Locally advanced disease as determined by endoscopic ultrasound (EUS) stage > primary tumor (T) 3 and/or any T, lymph nodes (N)+ disease without metastatic disease (Mx)'
#  'Patients taking substrates, inhibitors, or inducers of cytochrome P450, family 3, subfamily A, polypeptide 4 (CYP3A4) should be encouraged to switch to alternative drugs whenever possible, given the potential for drug-drug interactions with irinotecan'
#  'Allergy or sensitivity to corticosteroids or any drug hypersensitivity or intolerance that would compromise patient safety or study results'
#  'Chronic infectious disease, system or organ disorder or other medical condition that would place patient at undue risk by study participation'
#  'A failed therapeutic trial of escitalopram in the current depressive episode (defined as at least 6 weeks of treatment at a daily dose of 10mg or higher)'
#  'Acute grief (< 1 month)'
#  'Intraoperative use of vasopressin and uterine tourniquet is permissible'
#  'Severe bradycardia or greater than 1st degree heart block'
#  'History or renal transplantation'
#  'Nephrotic range proteinuria (urinary protein > 3.5 gm/day)'
#  'Willingness and ability to comply with scheduled visits, treatment plans and any other study procedures'
#  'Inability to lie flat for 20-30 minutes (the anticipated amount of time to complete the MRI procedure)'
#  'clearly demarcated tumor on magnetic resonance imaging (mri), as determined by treating physician (mri may be done after enrollment if not done prior)'
#  'significant screening electrocardiogram (ecg) abnormalities including but not limited to, left bundle branch block, 2nd degree atrioventricular (av) block type ii, 3rd degree block or corrected qt interval (qtc) >= 470 msecsubjects with a cardiac pacemaker who have a qtc interval of >= 470 msec may be eligible if these findings are considered not clinically significant as documented via a cardiology evaluation'
#  'gestational hypertension'
#  'use of hyperbaric oxygen therapy, prostanoids, spinal cord stimulation, lumbar sympathectomy, wound dressing containing cells or growth factors or topical platelet derived growth factor.'
#  'history of open angle glaucoma, seizures or psychosis'
#  'lifetime history of failure to respond to 4 or more sessions of cbt/ct for depression'
#  'child-pugh-turcotte score < 7 (for patients with hepatocellular carcinoma only)'
#  'autologous hematologic stem cell transplant within 6 months of study entry'
#  'prior therapy with a pi3k delta inhibitor' 'diabetes mellitus'
#  'carriers of hepatitis b virus should be closely monitored for clinical and laboratory signs of active hepatitis b virus infection and for signs of hepatitis throughout study participation.'
#  'histological confirmation of relapsed or refractory aml after prior anti-leukemic therapy by who classification'
#  'unable to communicate orally'
#  'participants who have started their treatment plan are not eligible.'
#  'patients with malignancies that are currently active with exception of non-melanoma skin cancer'
#  'patients with myelodysplasia and hemoglobin of < 8.5 mg/dl'
#  'decompensated liver disease (i.e., ascites, history of esophageal variceal bleeding, hepatic encephalopathy)'
#  'current or recent (within the past 6 months) substance dependence disorder(excluding nicotine and caffeine)'
#  'pregnancy or lactation for female subjects of child-bearing potential (i.e., < two years post-menopausal or not surgically sterile);'
#  'patient has a failed unicondylar knee prosthesis.'
#  'documented symptomatic carotid disease, defined as > 70% stenosis or > 50% stenosis with symptoms;'
#  'history of organ allograft (participant has had an allogenic tissue/solid organ transplant)'
#  'individuals considered an immediate suicide risk or who are likely to require hospitalization during the course of the study.'
#  'patients with obstructive sleep apnea'
#  'ability to understand and the willingness to sign a written informed consent document.'
#  'past history of headache syndromes- such as migraine and cluster headaches'
#  'history of substance abuse'
#  'local or systemic complications or other pathological states requiring therapy with corticosteroids and/or immunosuppressive agents.'
#  'normal renal function defined as serum creatinine less than 2.'
#  'measurable disease, defined as at least one lesion that can be accurately measured in at least one dimension (longest diameter to be recorded for non-nodal lesions and short axis for nodal lesions) as >20 mm with conventional techniques or as >10 mm with spiral computed tomography (ct) scan, magnetic resonance imaging (mri) or calipers by clinical examsee section 13.'
#  'female patients must either be of non-reproductive potential (ie, post-menopausal by history: 60 years old or no menses for 1 year without an alternative medical cause'
#  'progression free interval or treatment free interval of less than 12 months since the last rituximab-, rituximab biosimilars- or anti-cd20 monoclonal antibody (e.gfor patients considered unwilling/unfit to receive chemotherapy : progression free interval or treatment free interval of less than 6 months since the last rituximab-, rituximab biosimilars- or anti-cd20 monoclonal antibody-containing treatment (including maintenance with these drugs), as assessed by the investigator'
#  'ulcer of pressure/shear etiology (stage ii, iii and iv, see appendix 9 for stage definitions)'
#  'able to take aspirin (81 or 325 mg) daily for prophylactic anticoagulation (patients intolerant to acetylsalicylic acid, asa, may use warfarin or low molecular weight heparin or other anticoagulants as deemed appropriate by physician)'
#  'must not exhibit a non-healing wound or any skin breakdown'
#  'subject has inadequate venous access for repeated blood draw required for eclipse rpr administrations'
#  'any prior grade greater than or equal to 3 imae while receiving immunotherapy, including anti-cytotoxic t-lymphocyte-associated protein 4 (ctla4) treatment or any unresolved imae > grade 1'
#  'not fully recovered for at least 30 days from a copd exacerbation.'
#  'patients with a known human immunodeficiency (hiv) infection are not eligible'
#  'no currently active second malignancy'
#  'vasculitis requiring immunosuppressive therapy within the last year'
#  'alanine aminotransferase (alt) (serum glutamate pyruvate transaminase [sgpt]) and/or aspartate aminotransferase (ast) (serum glutamic oxaloacetic transaminase [sgot]) =< 3 x upper limit of normal (uln) or =< 5 x uln if related to disease'
#  'processing speed impairment'
#  'peripheral neuropathy =< grade 1 at the time of registration'
#  "patients with any medical illness or concurrent psychiatric illness which, in the investigators' opinion, cannot be adequately controlled with appropriate therapy"
#  'prior malignancy other than acute leukemia is allowed, provided it is in remission and there is no plan to treat the malignancy at the time of registration'
#  'full coverage of the acetabulum and minimal knee and ankle laxity'
#  'patient has a prior femoral fracture, with or without deformity, on the operative side.'
#  'diagnosis of stage 0-iii breast cancer within 12 years prior to enrollmentall indicated surgery, chemotherapy, and/or radiation therapy must have been completed at least 12 weeks prior to enrollment'
#  'at the time of planning, unable to deliver 10 gray (gy) or less to optic nerve/chiasm'
#  'allergy or intolerance to study medication'
#  'inability to swallow or absorb drug'
#  'men and women of reproductive potential must agree to use a reliable method of birth control during the treatment and women should do so for a period of 1 year following the transplant.'
#  'cerebral palsy or associated movement disorders such as dystonia, spasticity, and/or hypertonia'
#  'all women of childbearing potential (wocbp) must have practiced true abstinence from intercourse when it was in line with their preferred and usual lifestyle or used 2 different forms of highly effective contraception for the duration of the study and for at least 30 days after discontinuing study medication.'
#  'concurrent administration of any other investigational agents'
#  'patients considered in "vulnerable" populations.'
#  'history of electroconvulsive therapy.'
#  'patients with significant inter-current medical or psychiatric conditions that would place them at increased risk or affect their ability to receive or comply with treatment or post-treatment clinical monitoring.'
#  'mskcc patients without a histologic diagnosis of cancer of the breast, bladder, kidney, colon, testicles, lungs, prostate or lymphoid malignancy (including all types of lymphoma) will not be eligible for the amdec sponsored component of the study.'
#  'no psychotherapy within pcmh within past 6 months including with the psychologist stable on psychiatric meds for 4 weeks personality pathology or ptsd (captured from dsm-v cross cutting symptoms inventory already being used as part of routine care screening in this clinic) severe mood disorder (phq8 > 14) or evidence of active suicidality or psychosis (brief screen conducted by swer in clinic using dsm-v cross cutting symptom inventory) to assess for psychosis, etc'
#  'able to recruit 40+ participants for a breast, prostate or colorectal cancer educational workshop'
#  "presence of any medical 'red flags' suggestive of pain that is not of musculoskeletal origin"
#  'patients identified as having keratoconus or post refractive cornea ectasia with astigmatism of 1.5 diopters or greater.'
#  'congenital cardiac disease requiring surgery'
#  'history of schizophrenia, delusions or currently uncontrolled visual hallucinations'
#  'severe upper gi bleeding.' 'active perineal infection'
#  'chronic kidney disease requiring dialysis'
#  "acceptable liver function: bilirubin < 2.5 mg/dl (unless due to gilbert's disease, ast (sgot) and alt (sgpt) < 5 times upper limit of normal."
#  'subjects requiring bone augmentation or socket grafting prior to surgery.'
#  'having a first breast cancer diagnosis of stages 0-iii' 'liver disease,'
#  'danger to themselves or others'
#  'primary caregiver of a child under age 7 with a physical, emotional or behavioral health condition'
#  'recent intubation (within two weeks)' 'cardiac disease'
#  'newly diagnosed disease with either a diagnosis of "high-risk" mds (>= 10% blasts in marrow or blood), high-risk myeloproliferative neoplasm (mpn>= 10% blasts in blood or bone marrow) or aml other than acute promyelocytic leukemia (apl) with t(15;17)(q22;q12) or variants according to the 2008 world health organization (who) classification'
#  'presence of dementia or behavioral disorders that would prevent ability to follow the protocol'
#  'ipss-r intermediate, high- or very-high-risk mds.'
#  'significant immune disorder'
#  'severe autonomic neuropathy that restricts daily function and the ability to participate in study interventions'
#  'history of malabsorption or other gastrointestinal (gi) disease that may significantly alter the absorption of lam-002a'
#  'severe congenital abnormalities of the lung, thorax and diaphragm'
#  'diagnosed hcc by biopsy or liver protocol ct scan or mri characteristics'
#  'primary modality of treatment is potentially curative txp, surgical resection or ablation as deemed by gi mdc'
#  'unstable medical condition'
#  'extraction of maxillary premolar, canine or incisor or mandibular premolar and canine required'
#  'ongoing active infection with hepatitis a virus (hav), hepatitis b virus (hbv), hepatitis c virus (hcv) or human immunodeficiency virus (hiv) type 1 or 2 infection at the time of screening.'
#  "any other condition that would, in the investigator's judgment, contraindicate the patient's participation in the clinical study due to safety concerns or compliance with clinical study procedures"
#  'measurable disease as defined by response evaluation criteria in solid tumors (recist) v1.1 criteriabaseline measurements and evaluation of all sites of disease must be obtained within 4 weeks prior to enrollment.'
#  'pregnant women are excluded from this study because radiation has the potential for teratogenic or abortifacient effects.'
#  "neurological diseases (e.g., parkinson's disease, epilepsy, cortical stroke, alzheimer's disease, traumatic brain injury) or dementia."
#  'more than three systemic corticosteroid requiring asthma exacerbations in the past year'
#  'hemorrhagic cystitis or active prostatitis'
#  'patients must have completed at least 1 prior line of systemic therapy'
#  'patients must not have any prior history of hypertensive crisis or hypertensive encephalopathy'
#  'clinically compromised vertebral bodies at the affected level(s) due to current or past trauma'
#  'current concomitant chemotherapy, radiation therapy or immunotherapy other than as specified in the protocol'
#  'have metastatic breast cancer with severe organ dysfunction as assessed by symptoms and signs, laboratory studies and rapid progression of the disease.'
#  'diagnosis of hypocalcemia;'
#  'lifetime substance dependence disorder, excepting nicotine, alcohol and marijuana, as per scid interview'
#  'women of childbearing potential must have a negative pregnancy test within 7 days before enrollmentpostmenopause is defined as amenorrhea >= 12 consecutive monthsnote: women who have been amenorrheic for 12 or more months are still considered to be of childbearing potential if the amenorrhea is possibly due to prior chemotherapy, antiestrogens, ovarian suppression or any other reversible reason'
#  'recent uncontrolled angina, recent > new york heart association (nyha) class ii congestive heart failure or recent myocardial infarction (mi) within 6 months prior to start of study treatment'
#  'patient is medically stable enough to undergo surgery (cleared for anesthesia)'
#  'unable or unwilling to discontinue use of prohibited medications for at least 14 days or five half-lives of a drug (whichever is longer) prior to the first dose of study drug and for the duration of the studyadministration of any non-oncologic investigational drug within 30 days or 5 half-lives whichever is longer prior to receiving the first dose of study treatment'
#  'complete macroscopic resection of all known disease'
#  'patients with grade 3 toxicities or less using the common toxicity criteria (version 3.0) developed by the national cancer institute of the usa (ctcae v3.0) related to cardiac, neurological, pulmonary, renal, hepatic or gastrointestinal function as determined by blood tests or physical exam.'
#  'uncontrolled active infection.'
#  'use of disallowed concomitant therapy from 4 weeks prior to the baseline visit'
#  'known allergy to any of the study agents']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 82
#      79 # Process each row in the dataset
#      80 result_list = []
# ---> 82 for index, row in data.iterrows():
#      83     text = row['cleaned_sent']  # Replace 'cleaned_sent' with the actual column name in your CSV
#      84     token_indices = extract_token_indices(text)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iterrows'

# %%
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification
import re

# Load the CSV dataset
data = pd.read_json('combined.jsonl', lines=True)['text'].values

# Convert the NumPy array to a Pandas DataFrame
df = pd.DataFrame(data, columns=['text'])

# Specify the number of rows to process (e.g., 500)
num_rows_to_process = 325

# Filter the dataset to select the first 'num_rows_to_process' rows
df = df.head(num_rows_to_process)

# Initialize the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("clinical-bert-finetuned-ner/checkpoint-1248")
model = AutoModelForTokenClassification.from_pretrained("clinical-bert-finetuned-ner/checkpoint-1248")

# Function to extract token indices
def extract_token_indices(text):
    # Tokenize the text
    inputs = tokenizer(text, return_tensors="pt")
    
    # Get token logits
    with torch.no_grad():
        logits = model(**inputs).logits
    
    # Predict token labels
    predictions = torch.argmax(logits, dim=2)
    
    # Convert token ids to tokens
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"].squeeze().tolist())
    predicted_token_class = [model.config.id2label[t.item()] for t in predictions[0]]
    
    # Combine tokens and labels
    combined_tokens = []
    current_token = ""
    current_label = ""
    
    for token, label in zip(tokens, predicted_token_class):
        if token.startswith("##"):
            current_token += token[2:]  # Append '##' tokens to the previous token
        else:
            if current_token:
                combined_tokens.append((current_token, current_label))
            current_token = token
            current_label = label
    
    if current_token:
        combined_tokens.append((current_token, current_label))
    tokens_to_find = [token for token, label in combined_tokens if label != 'O']
    cleaned_sentence = re.sub(r'[^\w\s]', '', text.lower())
    
    # Find token indices
    token_indices = []
    start_index = 0
    
    current_word = ""
    
    for token in tokens_to_find:
#         print("Cleaned_sentence", cleaned_sentence)
        start = text.lower().find(token)
        end = start + len(token)
        label = None
        for t, l in combined_tokens:
            if t == token:
                label = l
                break
        token_indices.append({
            "label": label,
            "start_index": start,
            "end_index": end,
            "token": token
        })
        start_index = end + 1
    
    return token_indices

# Process each row in the dataset
result_list = []

for index, row in df.iterrows():
    text = row['text']  # Replace 'text' with the actual column name in your DataFrame
    token_indices = extract_token_indices(text)
    result_list.append(token_indices)

# Print the results
for result in result_list:
    print(result)
# Out:
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00351611'}, {'label': 'B-treatment', 'start_index': 37, 'end_index': 47, 'token': 'pregabalin'}, {'label': 'B-treatment', 'start_index': 55, 'end_index': 64, 'token': 'treatment'}, {'label': 'I-chronic_disease', 'start_index': 76, 'end_index': 83, 'token': 'seizure'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00862446'}, {'label': 'B-treatment', 'start_index': 24, 'end_index': 27, 'token': 'tpn'}, {'label': 'I-treatment', 'start_index': 28, 'end_index': 37, 'token': 'treatment'}, {'label': 'B-lower_bound', 'start_index': 51, 'end_index': 54, 'token': 'one'}, {'label': 'I-lower_bound', 'start_index': 55, 'end_index': 60, 'token': 'month'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00862446'}, {'label': 'B-clinical_variable', 'start_index': 12, 'end_index': 15, 'token': 'tpn'}, {'label': 'I-clinical_variable', 'start_index': 16, 'end_index': 27, 'token': 'cholestasis'}, {'label': 'B-lower_bound', 'start_index': 7, 'end_index': 8, 'token': '2'}, {'label': 'I-lower_bound', 'start_index': 41, 'end_index': 42, 'token': '.'}, {'label': 'I-lower_bound', 'start_index': 42, 'end_index': 43, 'token': '5'}, {'label': 'I-lower_bound', 'start_index': 44, 'end_index': 46, 'token': 'mg'}, {'label': 'I-lower_bound', 'start_index': 46, 'end_index': 47, 'token': '/'}, {'label': 'I-lower_bound', 'start_index': 47, 'end_index': 49, 'token': 'dl'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01175044'}, {'label': 'B-treatment', 'start_index': 42, 'end_index': 50, 'token': 'revision'}, {'label': 'B-treatment', 'start_index': 51, 'end_index': 56, 'token': 'total'}, {'label': 'I-treatment', 'start_index': 57, 'end_index': 61, 'token': 'knee'}, {'label': 'I-treatment', 'start_index': 62, 'end_index': 74, 'token': 'arthroplasty'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01175044'}, {'label': 'B-treatment', 'start_index': 36, 'end_index': 47, 'token': 'antibiotics'}, {'label': 'B-upper_bound', 'start_index': 48, 'end_index': 50, 'token': '14'}, {'label': 'I-upper_bound', 'start_index': 51, 'end_index': 55, 'token': 'days'}, {'label': 'I-upper_bound', 'start_index': 56, 'end_index': 61, 'token': 'prior'}, {'label': 'B-treatment', 'start_index': 78, 'end_index': 85, 'token': 'surgery'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01446094'}, {'label': 'B-chronic_disease', 'start_index': 12, 'end_index': 18, 'token': 'severe'}, {'label': 'B-chronic_disease', 'start_index': 19, 'end_index': 23, 'token': 'lung'}, {'label': 'I-chronic_disease', 'start_index': 24, 'end_index': 31, 'token': 'disease'}, {'label': 'I-chronic_disease', 'start_index': 40, 'end_index': 48, 'token': 'wheezing'}, {'label': 'B-chronic_disease', 'start_index': 57, 'end_index': 68, 'token': 'bradycardia'}, {'label': 'B-clinical_variable', 'start_index': 70, 'end_index': 75, 'token': 'heart'}, {'label': 'I-clinical_variable', 'start_index': 76, 'end_index': 80, 'token': 'rate'}, {'label': 'B-upper_bound', 'start_index': 83, 'end_index': 85, 'token': '40'}, {'label': 'I-upper_bound', 'start_index': 86, 'end_index': 91, 'token': 'beats'}, {'label': 'I-upper_bound', 'start_index': 91, 'end_index': 92, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 92, 'end_index': 95, 'token': 'min'}, {'label': 'I-chronic_disease', 'start_index': 103, 'end_index': 104, 'token': '-'}, {'label': 'I-chronic_disease', 'start_index': 121, 'end_index': 137, 'token': 'atrioventricular'}, {'label': 'B-clinical_variable', 'start_index': 70, 'end_index': 75, 'token': 'heart'}, {'label': 'I-chronic_disease', 'start_index': 144, 'end_index': 149, 'token': 'block'}, {'label': 'B-chronic_disease', 'start_index': 150, 'end_index': 154, 'token': 'sick'}, {'label': 'I-chronic_disease', 'start_index': 155, 'end_index': 160, 'token': 'sinus'}, {'label': 'I-chronic_disease', 'start_index': 161, 'end_index': 169, 'token': 'syndrome'}, {'label': 'B-chronic_disease', 'start_index': 181, 'end_index': 185, 'token': 'long'}, {'label': 'I-chronic_disease', 'start_index': 186, 'end_index': 188, 'token': 'qt'}, {'label': 'I-chronic_disease', 'start_index': 161, 'end_index': 169, 'token': 'syndrome'}, {'label': 'I-chronic_disease', 'start_index': 205, 'end_index': 216, 'token': 'hypotension'}, {'label': 'B-clinical_variable', 'start_index': 218, 'end_index': 226, 'token': 'systolic'}, {'label': 'I-clinical_variable', 'start_index': 227, 'end_index': 229, 'token': 'bp'}, {'label': 'B-upper_bound', 'start_index': 232, 'end_index': 234, 'token': '80'}, {'label': 'I-upper_bound', 'start_index': 235, 'end_index': 237, 'token': 'mm'}, {'label': 'I-upper_bound', 'start_index': 238, 'end_index': 240, 'token': 'hg'}, {'label': 'B-clinical_variable', 'start_index': 70, 'end_index': 75, 'token': 'heart'}, {'label': 'I-chronic_disease', 'start_index': 262, 'end_index': 269, 'token': 'failure'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01446094'}, {'label': 'B-lower_bound', 'start_index': 38, 'end_index': 40, 'token': '20'}, {'label': 'B-upper_bound', 'start_index': 41, 'end_index': 43, 'token': '30'}, {'label': 'I-upper_bound', 'start_index': 44, 'end_index': 51, 'token': 'minutes'}, {'label': 'B-treatment', 'start_index': 100, 'end_index': 103, 'token': 'mri'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01446094'}, {'label': 'B-chronic_disease', 'start_index': 25, 'end_index': 32, 'token': 'chronic'}, {'label': 'I-chronic_disease', 'start_index': 33, 'end_index': 39, 'token': 'kidney'}, {'label': 'I-chronic_disease', 'start_index': 40, 'end_index': 47, 'token': 'disease'}, {'label': 'B-clinical_variable', 'start_index': 49, 'end_index': 53, 'token': 'egfr'}, {'label': 'B-upper_bound', 'start_index': 56, 'end_index': 58, 'token': '30'}, {'label': 'I-upper_bound', 'start_index': 59, 'end_index': 61, 'token': 'ml'}, {'label': 'I-upper_bound', 'start_index': 61, 'end_index': 62, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 62, 'end_index': 65, 'token': 'min'}, {'label': 'I-upper_bound', 'start_index': 61, 'end_index': 62, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 4, 'end_index': 5, 'token': '1'}, {'label': 'I-upper_bound', 'start_index': 67, 'end_index': 68, 'token': '.'}, {'label': 'I-upper_bound', 'start_index': 68, 'end_index': 70, 'token': '73'}, {'label': 'I-upper_bound', 'start_index': 71, 'end_index': 73, 'token': 'm2'}, {'label': 'B-allergy_name', 'start_index': 92, 'end_index': 96, 'token': 'gbca'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01581749'}, {'label': 'B-cancer', 'start_index': 26, 'end_index': 34, 'token': 'invasive'}, {'label': 'I-cancer', 'start_index': 35, 'end_index': 45, 'token': 'malignancy'}, {'label': 'B-cancer', 'start_index': 63, 'end_index': 71, 'token': 'prostate'}, {'label': 'I-cancer', 'start_index': 72, 'end_index': 78, 'token': 'cancer'}, {'label': 'B-cancer', 'start_index': 82, 'end_index': 87, 'token': 'basal'}, {'label': 'B-cancer', 'start_index': 91, 'end_index': 99, 'token': 'squamous'}, {'label': 'I-cancer', 'start_index': 100, 'end_index': 104, 'token': 'skin'}, {'label': 'I-cancer', 'start_index': 105, 'end_index': 112, 'token': 'cancers'}, {'label': 'B-upper_bound', 'start_index': 121, 'end_index': 126, 'token': 'prior'}, {'label': 'I-upper_bound', 'start_index': 5, 'end_index': 6, 'token': '5'}, {'label': 'I-upper_bound', 'start_index': 129, 'end_index': 134, 'token': 'years'}]
# [{'label': 'B-cancer', 'start_index': 34, 'end_index': 44, 'token': 'pancreatic'}, {'label': 'I-cancer', 'start_index': 45, 'end_index': 51, 'token': 'cancer'}, {'label': 'B-cancer', 'start_index': 53, 'end_index': 59, 'token': 'distal'}, {'label': 'I-cancer', 'start_index': 60, 'end_index': 66, 'token': 'common'}, {'label': 'I-cancer', 'start_index': 67, 'end_index': 71, 'token': 'bile'}, {'label': 'I-cancer', 'start_index': 72, 'end_index': 76, 'token': 'duct'}, {'label': 'I-cancer', 'start_index': 77, 'end_index': 78, 'token': '('}, {'label': 'I-cancer', 'start_index': 78, 'end_index': 81, 'token': 'cbd'}, {'label': 'I-cancer', 'start_index': 81, 'end_index': 82, 'token': ')'}, {'label': 'I-cancer', 'start_index': 83, 'end_index': 101, 'token': 'cholangiocarcinoma'}, {'label': 'B-cancer', 'start_index': 112, 'end_index': 125, 'token': 'periampullary'}, {'label': 'I-cancer', 'start_index': 126, 'end_index': 133, 'token': 'cancers'}]
# [{'label': 'B-chronic_disease', 'start_index': 24, 'end_index': 30, 'token': 'distal'}, {'label': 'I-chronic_disease', 'start_index': 31, 'end_index': 38, 'token': 'biliary'}, {'label': 'I-chronic_disease', 'start_index': 39, 'end_index': 50, 'token': 'obstruction'}, {'label': 'B-treatment', 'start_index': 101, 'end_index': 106, 'token': 'stent'}, {'label': 'B-lower_bound', 'start_index': 133, 'end_index': 136, 'token': '2cm'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01774019'}, {'label': 'I-cancer', 'start_index': 12, 'end_index': 19, 'token': 'biliary'}, {'label': 'I-cancer', 'start_index': 20, 'end_index': 30, 'token': 'strictures'}, {'label': 'B-cancer', 'start_index': 41, 'end_index': 53, 'token': 'malignancies'}, {'label': 'B-cancer', 'start_index': 65, 'end_index': 75, 'token': 'pancreatic'}, {'label': 'I-cancer', 'start_index': 76, 'end_index': 82, 'token': 'cancer'}, {'label': 'B-cancer', 'start_index': 84, 'end_index': 90, 'token': 'distal'}, {'label': 'I-cancer', 'start_index': 91, 'end_index': 94, 'token': 'cbd'}, {'label': 'I-cancer', 'start_index': 95, 'end_index': 113, 'token': 'cholangiocarcinoma'}, {'label': 'B-cancer', 'start_index': 124, 'end_index': 137, 'token': 'periampullary'}, {'label': 'I-cancer', 'start_index': 138, 'end_index': 145, 'token': 'cancers'}]
# [{'label': 'I-treatment', 'start_index': 92, 'end_index': 94, 'token': 'tb'}, {'label': 'B-treatment', 'start_index': 109, 'end_index': 118, 'token': 'treatment'}, {'label': 'B-chronic_disease', 'start_index': 123, 'end_index': 129, 'token': 'latent'}, {'label': 'I-chronic_disease', 'start_index': 130, 'end_index': 142, 'token': 'tuberculosis'}, {'label': 'B-treatment', 'start_index': 109, 'end_index': 118, 'token': 'treatment'}, {'label': 'I-treatment', 'start_index': 171, 'end_index': 175, 'token': 'with'}, {'label': 'I-treatment', 'start_index': 176, 'end_index': 179, 'token': 'the'}, {'label': 'I-treatment', 'start_index': 82, 'end_index': 86, 'token': 'anti'}, {'label': 'O', 'start_index': 91, 'end_index': 92, 'token': '-'}, {'label': 'I-treatment', 'start_index': 185, 'end_index': 188, 'token': 'tnf'}, {'label': 'I-treatment', 'start_index': 189, 'end_index': 194, 'token': 'agent'}]
# [{'label': 'B-chronic_disease', 'start_index': 49, 'end_index': 58, 'token': 'hepatitis'}, {'label': 'I-chronic_disease', 'start_index': 13, 'end_index': 14, 'token': 'b'}, {'label': 'B-treatment', 'start_index': 98, 'end_index': 107, 'token': 'treatment'}, {'label': 'B-chronic_disease', 'start_index': 112, 'end_index': 119, 'token': 'chronic'}, {'label': 'B-chronic_disease', 'start_index': 49, 'end_index': 58, 'token': 'hepatitis'}, {'label': 'I-chronic_disease', 'start_index': 13, 'end_index': 14, 'token': 'b'}, {'label': 'B-treatment', 'start_index': 147, 'end_index': 158, 'token': 'suppressive'}, {'label': 'I-treatment', 'start_index': 159, 'end_index': 168, 'token': 'antiviral'}, {'label': 'B-treatment', 'start_index': 98, 'end_index': 107, 'token': 'treatment'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01794793'}, {'label': 'B-treatment', 'start_index': 87, 'end_index': 98, 'token': 'pasireotide'}, {'label': 'B-treatment', 'start_index': 120, 'end_index': 131, 'token': 'monotherapy'}, {'label': 'B-treatment', 'start_index': 135, 'end_index': 146, 'token': 'combination'}, {'label': 'I-treatment', 'start_index': 124, 'end_index': 131, 'token': 'therapy'}, {'label': 'B-chronic_disease', 'start_index': 160, 'end_index': 167, 'token': 'cushing'}, {'label': 'I-chronic_disease', 'start_index': 167, 'end_index': 168, 'token': "'"}, {'label': 'O', 'start_index': 21, 'end_index': 22, 'token': 's'}, {'label': 'I-chronic_disease', 'start_index': 170, 'end_index': 177, 'token': 'disease'}, {'label': 'B-treatment', 'start_index': 181, 'end_index': 191, 'token': 'acromegaly'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01794793'}, {'label': 'I-contraception_consent', 'start_index': 12, 'end_index': 15, 'token': 'use'}, {'label': 'I-contraception_consent', 'start_index': 16, 'end_index': 18, 'token': 'of'}, {'label': 'I-contraception_consent', 'start_index': 19, 'end_index': 23, 'token': 'oral'}, {'label': 'I-contraception_consent', 'start_index': 23, 'end_index': 24, 'token': ','}, {'label': 'I-contraception_consent', 'start_index': 25, 'end_index': 33, 'token': 'injected'}, {'label': 'I-contraception_consent', 'start_index': 19, 'end_index': 21, 'token': 'or'}, {'label': 'I-contraception_consent', 'start_index': 37, 'end_index': 46, 'token': 'implanted'}, {'label': 'I-contraception_consent', 'start_index': 47, 'end_index': 55, 'token': 'hormonal'}, {'label': 'I-contraception_consent', 'start_index': 56, 'end_index': 63, 'token': 'methods'}, {'label': 'I-contraception_consent', 'start_index': 16, 'end_index': 18, 'token': 'of'}, {'label': 'I-contraception_consent', 'start_index': 67, 'end_index': 80, 'token': 'contraception'}, {'label': 'I-contraception_consent', 'start_index': 19, 'end_index': 21, 'token': 'or'}, {'label': 'I-contraception_consent', 'start_index': 84, 'end_index': 93, 'token': 'placement'}, {'label': 'I-contraception_consent', 'start_index': 16, 'end_index': 18, 'token': 'of'}, {'label': 'I-contraception_consent', 'start_index': 41, 'end_index': 43, 'token': 'an'}, {'label': 'I-contraception_consent', 'start_index': 100, 'end_index': 112, 'token': 'intrauterine'}, {'label': 'I-contraception_consent', 'start_index': 113, 'end_index': 119, 'token': 'device'}, {'label': 'I-contraception_consent', 'start_index': 120, 'end_index': 121, 'token': '('}, {'label': 'I-contraception_consent', 'start_index': 121, 'end_index': 124, 'token': 'iud'}, {'label': 'I-contraception_consent', 'start_index': 124, 'end_index': 125, 'token': ')'}, {'label': 'I-contraception_consent', 'start_index': 19, 'end_index': 21, 'token': 'or'}, {'label': 'I-contraception_consent', 'start_index': 100, 'end_index': 112, 'token': 'intrauterine'}, {'label': 'I-contraception_consent', 'start_index': 142, 'end_index': 148, 'token': 'system'}, {'label': 'I-contraception_consent', 'start_index': 120, 'end_index': 121, 'token': '('}, {'label': 'I-contraception_consent', 'start_index': 150, 'end_index': 153, 'token': 'ius'}, {'label': 'I-contraception_consent', 'start_index': 124, 'end_index': 125, 'token': ')'}, {'label': 'I-contraception_consent', 'start_index': 16, 'end_index': 18, 'token': 'of'}, {'label': 'I-contraception_consent', 'start_index': 47, 'end_index': 55, 'token': 'hormonal'}, {'label': 'I-contraception_consent', 'start_index': 67, 'end_index': 80, 'token': 'contraception'}, {'label': 'B-clinical_variable', 'start_index': 228, 'end_index': 235, 'token': 'failure'}, {'label': 'I-clinical_variable', 'start_index': 236, 'end_index': 240, 'token': 'rate'}, {'label': 'B-upper_bound', 'start_index': 4, 'end_index': 5, 'token': '1'}, {'label': 'I-upper_bound', 'start_index': 243, 'end_index': 244, 'token': '%'}, {'label': 'B-contraception_consent', 'start_index': 259, 'end_index': 266, 'token': 'hormone'}, {'label': 'I-contraception_consent', 'start_index': 267, 'end_index': 274, 'token': 'vaginal'}, {'label': 'I-contraception_consent', 'start_index': 275, 'end_index': 279, 'token': 'ring'}, {'label': 'B-contraception_consent', 'start_index': 283, 'end_index': 294, 'token': 'transdermal'}, {'label': 'B-contraception_consent', 'start_index': 259, 'end_index': 266, 'token': 'hormone'}, {'label': 'I-contraception_consent', 'start_index': 67, 'end_index': 80, 'token': 'contraception'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01801072'}, {'label': 'B-treatment', 'start_index': 45, 'end_index': 53, 'token': 'surgical'}, {'label': 'I-treatment', 'start_index': 54, 'end_index': 60, 'token': 'repair'}, {'label': 'B-chronic_disease', 'start_index': 68, 'end_index': 76, 'token': 'aneurysm'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01801072'}, {'label': 'B-chronic_disease', 'start_index': 24, 'end_index': 36, 'token': 'intracranial'}, {'label': 'I-chronic_disease', 'start_index': 37, 'end_index': 45, 'token': 'aneurysm'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01807897'}, {'label': 'B-chronic_disease', 'start_index': 18, 'end_index': 24, 'token': 'stroke'}, {'label': 'B-chronic_disease', 'start_index': 30, 'end_index': 40, 'token': 'functional'}, {'label': 'I-chronic_disease', 'start_index': 41, 'end_index': 51, 'token': 'impairment'}]
# [{'label': 'B-clinical_variable', 'start_index': 50, 'end_index': 57, 'token': 'epworth'}, {'label': 'O', 'start_index': 27, 'end_index': 37, 'token': 'sleepiness'}, {'label': 'I-clinical_variable', 'start_index': 69, 'end_index': 74, 'token': 'scale'}, {'label': 'I-clinical_variable', 'start_index': 75, 'end_index': 80, 'token': 'score'}, {'label': 'B-lower_bound', 'start_index': 4, 'end_index': 6, 'token': '18'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01807897'}, {'label': 'B-treatment', 'start_index': 29, 'end_index': 37, 'token': 'positive'}, {'label': 'I-treatment', 'start_index': 38, 'end_index': 44, 'token': 'airway'}, {'label': 'I-treatment', 'start_index': 45, 'end_index': 53, 'token': 'pressure'}, {'label': 'I-treatment', 'start_index': 54, 'end_index': 60, 'token': 'device'}, {'label': 'I-treatment', 'start_index': 88, 'end_index': 89, 'token': '-'}, {'label': 'B-treatment', 'start_index': 123, 'end_index': 131, 'token': 'adaptive'}, {'label': 'I-treatment', 'start_index': 132, 'end_index': 137, 'token': 'servo'}, {'label': 'I-treatment', 'start_index': 88, 'end_index': 89, 'token': '-'}, {'label': 'I-treatment', 'start_index': 138, 'end_index': 149, 'token': 'ventilation'}, {'label': 'B-treatment', 'start_index': 154, 'end_index': 166, 'token': 'supplemental'}, {'label': 'I-treatment', 'start_index': 167, 'end_index': 173, 'token': 'oxygen'}, {'label': 'I-treatment', 'start_index': 174, 'end_index': 181, 'token': 'therapy'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01912651'}, {'label': 'B-upper_bound', 'start_index': 38, 'end_index': 41, 'token': 'one'}, {'label': 'I-upper_bound', 'start_index': 42, 'end_index': 46, 'token': 'week'}, {'label': 'B-treatment', 'start_index': 50, 'end_index': 57, 'token': 'surgery'}, {'label': 'B-treatment', 'start_index': 59, 'end_index': 67, 'token': 'systemic'}, {'label': 'I-treatment', 'start_index': 68, 'end_index': 78, 'token': 'antibiotic'}, {'label': 'B-treatment', 'start_index': 104, 'end_index': 115, 'token': 'clindamycin'}, {'label': 'B-treatment', 'start_index': 120, 'end_index': 130, 'token': 'cephalexin'}, {'label': 'B-cancer', 'start_index': 158, 'end_index': 167, 'token': 'cutaneous'}, {'label': 'I-cancer', 'start_index': 168, 'end_index': 178, 'token': 'malignancy'}, {'label': 'B-treatment', 'start_index': 219, 'end_index': 233, 'token': 'reconstructive'}, {'label': 'I-treatment', 'start_index': 234, 'end_index': 243, 'token': 'procedure'}, {'label': 'B-treatment', 'start_index': 248, 'end_index': 256, 'token': 'previous'}, {'label': 'I-treatment', 'start_index': 257, 'end_index': 271, 'token': 'reconstruction'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01912651'}, {'label': 'B-treatment', 'start_index': 129, 'end_index': 133, 'token': 'full'}, {'label': 'I-treatment', 'start_index': 133, 'end_index': 134, 'token': '-'}, {'label': 'I-treatment', 'start_index': 134, 'end_index': 143, 'token': 'thickness'}, {'label': 'O', 'start_index': 54, 'end_index': 58, 'token': 'skin'}, {'label': 'I-treatment', 'start_index': 149, 'end_index': 154, 'token': 'graft'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01959425'}, {'label': 'B-chronic_disease', 'start_index': 36, 'end_index': 38, 'token': 'af'}, {'label': 'B-chronic_disease', 'start_index': 79, 'end_index': 89, 'token': 'arrhythmic'}, {'label': 'B-lower_bound', 'start_index': 122, 'end_index': 124, 'token': '30'}, {'label': 'I-upper_bound', 'start_index': 125, 'end_index': 132, 'token': 'seconds'}, {'label': 'B-upper_bound', 'start_index': 122, 'end_index': 123, 'token': '3'}, {'label': 'I-upper_bound', 'start_index': 136, 'end_index': 142, 'token': 'months'}, {'label': 'B-treatment', 'start_index': 160, 'end_index': 167, 'token': 'cardiac'}, {'label': 'I-treatment', 'start_index': 168, 'end_index': 176, 'token': 'ablation'}, {'label': 'B-upper_bound', 'start_index': 122, 'end_index': 123, 'token': '3'}, {'label': 'I-upper_bound', 'start_index': 200, 'end_index': 201, 'token': '-'}, {'label': 'I-upper_bound', 'start_index': 136, 'end_index': 141, 'token': 'month'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01959425'}, {'label': 'B-treatment', 'start_index': 16, 'end_index': 23, 'token': 'cardiac'}, {'label': 'I-treatment', 'start_index': 24, 'end_index': 31, 'token': 'surgery'}, {'label': 'B-upper_bound', 'start_index': 43, 'end_index': 47, 'token': 'past'}, {'label': 'I-upper_bound', 'start_index': 48, 'end_index': 50, 'token': '60'}, {'label': 'I-upper_bound', 'start_index': 51, 'end_index': 55, 'token': 'days'}, {'label': 'I-upper_bound', 'start_index': 56, 'end_index': 57, 'token': '('}, {'label': 'I-upper_bound', 'start_index': 9, 'end_index': 10, 'token': '2'}, {'label': 'I-upper_bound', 'start_index': 59, 'end_index': 65, 'token': 'months'}, {'label': 'B-treatment', 'start_index': 70, 'end_index': 78, 'token': 'valvular'}, {'label': 'B-treatment', 'start_index': 16, 'end_index': 23, 'token': 'cardiac'}, {'label': 'I-treatment', 'start_index': 87, 'end_index': 95, 'token': 'surgical'}, {'label': 'I-treatment', 'start_index': 96, 'end_index': 105, 'token': 'procedure'}, {'label': 'B-treatment', 'start_index': 125, 'end_index': 139, 'token': 'ventriculotomy'}, {'label': 'B-treatment', 'start_index': 141, 'end_index': 150, 'token': 'atriotomy'}, {'label': 'B-treatment', 'start_index': 156, 'end_index': 161, 'token': 'valve'}, {'label': 'I-treatment', 'start_index': 162, 'end_index': 168, 'token': 'repair'}, {'label': 'B-treatment', 'start_index': 172, 'end_index': 183, 'token': 'replacement'}, {'label': 'B-treatment', 'start_index': 202, 'end_index': 212, 'token': 'prosthetic'}, {'label': 'B-treatment', 'start_index': 156, 'end_index': 161, 'token': 'valve'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01959425'}, {'label': 'B-chronic_disease', 'start_index': 52, 'end_index': 54, 'token': 'af'}, {'label': 'B-chronic_disease', 'start_index': 62, 'end_index': 72, 'token': 'prosthetic'}, {'label': 'I-treatment', 'start_index': 73, 'end_index': 78, 'token': 'valve'}, {'label': 'B-chronic_disease', 'start_index': 80, 'end_index': 82, 'token': 'pv'}, {'label': 'I-chronic_disease', 'start_index': 83, 'end_index': 91, 'token': 'stenosis'}, {'label': 'B-chronic_disease', 'start_index': 102, 'end_index': 111, 'token': 'pulmonary'}, {'label': 'I-chronic_disease', 'start_index': 112, 'end_index': 120, 'token': 'embolism'}, {'label': 'B-upper_bound', 'start_index': 196, 'end_index': 197, 'token': '3'}, {'label': 'I-upper_bound', 'start_index': 197, 'end_index': 198, 'token': '-'}, {'label': 'I-upper_bound', 'start_index': 198, 'end_index': 204, 'token': 'months'}]
# [{'label': 'B-cancer', 'start_index': 35, 'end_index': 37, 'token': 'fl'}, {'label': 'I-cancer', 'start_index': 38, 'end_index': 43, 'token': 'grade'}, {'label': 'I-cancer', 'start_index': 4, 'end_index': 5, 'token': '1'}, {'label': 'I-cancer', 'start_index': 46, 'end_index': 48, 'token': '3a'}, {'label': 'B-cancer', 'start_index': 49, 'end_index': 53, 'token': 'inhl'}, {'label': 'B-cancer', 'start_index': 106, 'end_index': 109, 'token': 'lpl'}, {'label': 'B-cancer', 'start_index': 110, 'end_index': 112, 'token': 'wm'}, {'label': 'B-cancer', 'start_index': 114, 'end_index': 117, 'token': 'mzl'}, {'label': 'B-cancer', 'start_index': 120, 'end_index': 124, 'token': 'anhl'}, {'label': 'B-cancer', 'start_index': 137, 'end_index': 142, 'token': 'dlbcl'}, {'label': 'I-cancer', 'start_index': 153, 'end_index': 155, 'token': '3b'}, {'label': 'B-cancer', 'start_index': 157, 'end_index': 160, 'token': 'mcl'}, {'label': 'I-cancer', 'start_index': 50, 'end_index': 53, 'token': 'nhl'}, {'label': 'B-cancer', 'start_index': 205, 'end_index': 208, 'token': 'cll'}, {'label': 'I-cancer', 'start_index': 209, 'end_index': 212, 'token': 'sll'}, {'label': 'B-cancer', 'start_index': 214, 'end_index': 218, 'token': 'ptcl'}]
# [{'label': 'B-clinical_variable', 'start_index': 0, 'end_index': 11, 'token': 'nct01994382'}, {'label': 'B-lower_bound', 'start_index': 4, 'end_index': 5, 'token': '1'}, {'label': 'I-lower_bound', 'start_index': 48, 'end_index': 54, 'token': 'lesion'}, {'label': 'B-lower_bound', 'start_index': 4, 'end_index': 5, 'token': '1'}, {'label': 'I-lower_bound', 'start_index': 58, 'end_index': 59, 'token': '.'}, {'label': 'I-lower_bound', 'start_index': 59, 'end_index': 60, 'token': '5'}, {'label': 'I-lower_bound', 'start_index': 61, 'end_index': 63, 'token': 'cm'}, {'label': 'I-lower_bound', 'start_index': 64, 'end_index': 70, 'token': 'single'}, {'label': 'I-lower_bound', 'start_index': 71, 'end_index': 80, 'token': 'dimension'}, {'label': 'B-treatment', 'start_index': 1, 'end_index': 3, 'token': 'ct'}, {'label': 'B-treatment', 'start_index': 1, 'end_index': 3, 'token': 'ct'}, {'label': 'B-cancer', 'start_index': 110, 'end_index': 114, 'token': 'mass'}, {'label': 'B-cancer', 'start_index': 149, 'end_index': 154, 'token': 'tumor'}, {'label': 'B-cancer', 'start_index': -1, 'end_index': 10, 'token': 'waldenstrom'}, {'label': 'I-chronic_disease', 'start_index': 180, 'end_index': 181, 'token': "'"}, {'label': 'I-chronic_disease', 'start_index': 15, 'end_index': 16, 'token': 's'}, {'label': 'I-cancer', 'start_index': 183, 'end_index': 200, 'token': 'macroglobulinemia'}, {'label': 'B-clinical_variable', 'start_index': 213, 'end_index': 216, 'token': 'igm'}, {'label': 'I-clinical_variable', 'start_index': 21, 'end_index': 22, 'token': 'l'}, {'label': 'B-lower_bound', 'start_index': 221, 'end_index': 223, 'token': '2x'}, {'label': 'I-lower_bound', 'start_index': 224, 'end_index': 227, 'token': 'uln'}, {'label': 'B-clinical_variable', 'start_index': 239, 'end_index': 244, 'token': 'mswat'}, {'label': 'B-lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01994382'}, {'label': 'B-treatment', 'start_index': 12, 'end_index': 17, 'token': 'prior'}, {'label': 'I-treatment', 'start_index': 18, 'end_index': 28, 'token': 'monoclonal'}, {'label': 'I-treatment', 'start_index': 29, 'end_index': 37, 'token': 'antibody'}, {'label': 'B-treatment', 'start_index': 39, 'end_index': 59, 'token': 'radioimmunoconjugate'}, {'label': 'I-treatment', 'start_index': 29, 'end_index': 37, 'token': 'antibody'}, {'label': 'I-treatment', 'start_index': 70, 'end_index': 74, 'token': 'drug'}, {'label': 'I-treatment', 'start_index': 50, 'end_index': 59, 'token': 'conjugate'}, {'label': 'B-treatment', 'start_index': 86, 'end_index': 98, 'token': 'phototherapy'}, {'label': 'B-treatment', 'start_index': 100, 'end_index': 112, 'token': 'radiotherapy'}, {'label': 'B-treatment', 'start_index': 114, 'end_index': 126, 'token': 'chemotherapy'}, {'label': 'B-treatment', 'start_index': 128, 'end_index': 141, 'token': 'immunotherapy'}, {'label': 'B-treatment', 'start_index': 143, 'end_index': 160, 'token': 'immunosuppressive'}, {'label': 'I-treatment', 'start_index': 91, 'end_index': 98, 'token': 'therapy'}, {'label': 'B-upper_bound', 'start_index': 8, 'end_index': 9, 'token': '3'}, {'label': 'I-upper_bound', 'start_index': 197, 'end_index': 202, 'token': 'weeks'}, {'label': 'B-treatment', 'start_index': 210, 'end_index': 221, 'token': 'alemtuzumab'}, {'label': 'I-upper_bound', 'start_index': 197, 'end_index': 202, 'token': 'weeks'}]
# [{'label': 'B-age', 'start_index': 27, 'end_index': 30, 'token': 'age'}, {'label': 'B-lower_bound', 'start_index': 31, 'end_index': 33, 'token': '18'}, {'label': 'B-upper_bound', 'start_index': 34, 'end_index': 36, 'token': '80'}, {'label': 'I-upper_bound', 'start_index': 37, 'end_index': 42, 'token': 'years'}, {'label': 'B-chronic_disease', 'start_index': 53, 'end_index': 61, 'token': 'ruptured'}, {'label': 'I-chronic_disease', 'start_index': 62, 'end_index': 70, 'token': 'aneurysm'}, {'label': 'I-chronic_disease', 'start_index': 70, 'end_index': 71, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 41, 'end_index': 42, 'token': 's'}, {'label': 'I-chronic_disease', 'start_index': 72, 'end_index': 73, 'token': ')'}, {'label': 'B-chronic_disease', 'start_index': 89, 'end_index': 97, 'token': 'cerebral'}, {'label': 'I-chronic_disease', 'start_index': 98, 'end_index': 107, 'token': 'vasospasm'}, {'label': 'B-lower_bound', 'start_index': 9, 'end_index': 10, 'token': '3'}, {'label': 'B-upper_bound', 'start_index': 134, 'end_index': 136, 'token': '21'}, {'label': 'I-upper_bound', 'start_index': 137, 'end_index': 141, 'token': 'days'}]
# [{'label': 'B-chronic_disease', 'start_index': -1, 'end_index': 4, 'token': '[CLS]'}, {'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01996436'}, {'label': 'I-chronic_disease', 'start_index': 17, 'end_index': 21, 'token': 'hess'}, {'label': 'I-cancer', 'start_index': 22, 'end_index': 27, 'token': 'grade'}, {'label': 'I-chronic_disease', 'start_index': 28, 'end_index': 29, 'token': '5'}, {'label': 'I-chronic_disease', 'start_index': 30, 'end_index': 33, 'token': 'sah'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02046395'}, {'label': 'B-treatment', 'start_index': 19, 'end_index': 22, 'token': 'ace'}, {'label': 'I-treatment', 'start_index': 23, 'end_index': 26, 'token': 'inh'}, {'label': 'B-treatment', 'start_index': 31, 'end_index': 34, 'token': 'arb'}, {'label': 'I-treatment', 'start_index': 111, 'end_index': 112, 'token': '('}]
# [{'label': 'B-chronic_disease', 'start_index': 26, 'end_index': 33, 'token': 'chronic'}, {'label': 'I-chronic_disease', 'start_index': 34, 'end_index': 40, 'token': 'kidney'}, {'label': 'I-chronic_disease', 'start_index': 41, 'end_index': 48, 'token': 'disease'}, {'label': 'B-clinical_variable', 'start_index': 60, 'end_index': 64, 'token': 'egfr'}, {'label': 'B-upper_bound', 'start_index': 67, 'end_index': 69, 'token': '30'}, {'label': 'I-upper_bound', 'start_index': 70, 'end_index': 72, 'token': 'ml'}, {'label': 'I-upper_bound', 'start_index': 72, 'end_index': 73, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 73, 'end_index': 76, 'token': 'min'}, {'label': 'B-clinical_variable', 'start_index': 78, 'end_index': 81, 'token': 'ckd'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02046395'}, {'label': 'B-allergy_name', 'start_index': 76, 'end_index': 79, 'token': 'ace'}, {'label': 'I-allergy_name', 'start_index': 80, 'end_index': 83, 'token': 'inh'}, {'label': 'B-allergy_name', 'start_index': 87, 'end_index': 90, 'token': 'arb'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02053246'}, {'label': 'B-chronic_disease', 'start_index': 51, 'end_index': 60, 'token': 'pulmonary'}, {'label': 'I-chronic_disease', 'start_index': 61, 'end_index': 73, 'token': 'hypertension'}, {'label': 'B-clinical_variable', 'start_index': 75, 'end_index': 79, 'token': 'mean'}, {'label': 'B-chronic_disease', 'start_index': 51, 'end_index': 60, 'token': 'pulmonary'}, {'label': 'I-clinical_variable', 'start_index': 90, 'end_index': 96, 'token': 'artery'}, {'label': 'I-clinical_variable', 'start_index': 97, 'end_index': 105, 'token': 'pressure'}, {'label': 'B-lower_bound', 'start_index': 108, 'end_index': 110, 'token': '25'}, {'label': 'I-lower_bound', 'start_index': 111, 'end_index': 115, 'token': 'mmhg'}, {'label': 'B-chronic_disease', 'start_index': 51, 'end_index': 60, 'token': 'pulmonary'}, {'label': 'I-clinical_variable', 'start_index': 130, 'end_index': 139, 'token': 'capillary'}, {'label': 'I-clinical_variable', 'start_index': 140, 'end_index': 145, 'token': 'wedge'}, {'label': 'I-clinical_variable', 'start_index': 97, 'end_index': 105, 'token': 'pressure'}, {'label': 'B-lower_bound', 'start_index': 157, 'end_index': 159, 'token': '15'}, {'label': 'I-lower_bound', 'start_index': 111, 'end_index': 115, 'token': 'mmhg'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02053246'}, {'label': 'B-chronic_disease', 'start_index': 28, 'end_index': 33, 'token': 'heart'}, {'label': 'I-chronic_disease', 'start_index': 34, 'end_index': 41, 'token': 'failure'}, {'label': 'B-chronic_disease', 'start_index': 53, 'end_index': 62, 'token': 'diastolic'}, {'label': 'I-chronic_disease', 'start_index': 63, 'end_index': 74, 'token': 'dysfunction'}, {'label': 'B-chronic_disease', 'start_index': 84, 'end_index': 95, 'token': 'restrictive'}, {'label': 'I-chronic_disease', 'start_index': 96, 'end_index': 110, 'token': 'cardiomyopathy'}, {'label': 'B-chronic_disease', 'start_index': 114, 'end_index': 126, 'token': 'infiltrative'}, {'label': 'I-chronic_disease', 'start_index': 96, 'end_index': 110, 'token': 'cardiomyopathy'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02053246'}, {'label': 'B-chronic_disease', 'start_index': 22, 'end_index': 24, 'token': 'ph'}, {'label': 'B-chronic_disease', 'start_index': 44, 'end_index': 49, 'token': 'heart'}, {'label': 'I-chronic_disease', 'start_index': 50, 'end_index': 57, 'token': 'failure'}, {'label': 'B-chronic_disease', 'start_index': 68, 'end_index': 75, 'token': 'chronic'}, {'label': 'I-chronic_disease', 'start_index': 76, 'end_index': 90, 'token': 'thromboembolic'}, {'label': 'B-chronic_disease', 'start_index': 22, 'end_index': 24, 'token': 'ph'}, {'label': 'B-chronic_disease', 'start_index': 95, 'end_index': 101, 'token': 'sickle'}, {'label': 'I-chronic_disease', 'start_index': 101, 'end_index': 102, 'token': '-'}, {'label': 'I-chronic_disease', 'start_index': 102, 'end_index': 106, 'token': 'cell'}, {'label': 'I-chronic_disease', 'start_index': 107, 'end_index': 114, 'token': 'disease'}, {'label': 'B-chronic_disease', 'start_index': 119, 'end_index': 130, 'token': 'sarcoidosis'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02055053'}, {'label': 'I-treatment', 'start_index': 41, 'end_index': 49, 'token': 'inguinal'}, {'label': 'I-treatment', 'start_index': 50, 'end_index': 55, 'token': 'herna'}, {'label': 'B-treatment', 'start_index': 60, 'end_index': 72, 'token': 'laparoscopic'}, {'label': 'I-treatment', 'start_index': 73, 'end_index': 79, 'token': 'repair'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02055053'}, {'label': 'B-chronic_disease', 'start_index': 23, 'end_index': 30, 'token': 'chronic'}, {'label': 'I-chronic_disease', 'start_index': 31, 'end_index': 35, 'token': 'pain'}, {'label': 'B-treatment', 'start_index': 47, 'end_index': 56, 'token': 'treatment'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02055053'}, {'label': 'B-treatment', 'start_index': 28, 'end_index': 40, 'token': 'laparoscopic'}, {'label': 'B-treatment', 'start_index': 44, 'end_index': 48, 'token': 'open'}, {'label': 'I-treatment', 'start_index': 49, 'end_index': 56, 'token': 'surgery'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02056288'}, {'label': 'I-treatment', 'start_index': 33, 'end_index': 42, 'token': 'reduction'}, {'label': 'I-treatment', 'start_index': 48, 'end_index': 60, 'token': 'percutaneous'}, {'label': 'I-treatment', 'start_index': 61, 'end_index': 68, 'token': 'pinning'}, {'label': 'B-treatment', 'start_index': 75, 'end_index': 82, 'token': 'general'}, {'label': 'I-treatment', 'start_index': 83, 'end_index': 93, 'token': 'anesthesia'}]
# [{'label': 'B-clinical_variable', 'start_index': 0, 'end_index': 11, 'token': 'nct02101554'}, {'label': 'I-clinical_variable', 'start_index': 12, 'end_index': 20, 'token': 'columbia'}, {'label': 'I-clinical_variable', 'start_index': 20, 'end_index': 21, 'token': '-'}, {'label': 'I-clinical_variable', 'start_index': 21, 'end_index': 28, 'token': 'suicide'}, {'label': 'I-clinical_variable', 'start_index': 29, 'end_index': 37, 'token': 'severity'}, {'label': 'I-clinical_variable', 'start_index': 38, 'end_index': 44, 'token': 'rating'}, {'label': 'I-clinical_variable', 'start_index': 45, 'end_index': 50, 'token': 'scale'}, {'label': 'I-clinical_variable', 'start_index': 51, 'end_index': 52, 'token': '('}, {'label': 'I-clinical_variable', 'start_index': 1, 'end_index': 2, 'token': 'c'}, {'label': 'I-clinical_variable', 'start_index': 20, 'end_index': 21, 'token': '-'}, {'label': 'I-clinical_variable', 'start_index': 54, 'end_index': 58, 'token': 'ssrs'}, {'label': 'I-clinical_variable', 'start_index': 58, 'end_index': 59, 'token': ')'}, {'label': 'B-chronic_disease', 'start_index': 64, 'end_index': 72, 'token': 'suicidal'}, {'label': 'I-chronic_disease', 'start_index': 73, 'end_index': 81, 'token': 'ideation'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02101554'}, {'label': 'I-treatment', 'start_index': 68, 'end_index': 77, 'token': 'treatment'}, {'label': 'B-treatment', 'start_index': 86, 'end_index': 92, 'token': 'opioid'}, {'label': 'I-treatment', 'start_index': 93, 'end_index': 102, 'token': 'analgesic'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02106598'}, {'label': 'B-clinical_variable', 'start_index': 59, 'end_index': 68, 'token': 'bilirubin'}, {'label': 'I-clinical_variable', 'start_index': 69, 'end_index': 74, 'token': 'level'}, {'label': 'B-upper_bound', 'start_index': 4, 'end_index': 5, 'token': '2'}, {'label': 'I-upper_bound', 'start_index': 81, 'end_index': 82, 'token': '.'}, {'label': 'I-upper_bound', 'start_index': 3, 'end_index': 4, 'token': '0'}, {'label': 'I-upper_bound', 'start_index': 84, 'end_index': 86, 'token': 'mg'}, {'label': 'I-upper_bound', 'start_index': 86, 'end_index': 87, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 87, 'end_index': 89, 'token': 'dl'}, {'label': 'B-chronic_disease', 'start_index': 121, 'end_index': 128, 'token': 'gilbert'}, {'label': 'I-chronic_disease', 'start_index': 128, 'end_index': 129, 'token': "'"}, {'label': 'I-chronic_disease', 'start_index': 21, 'end_index': 22, 'token': 's'}, {'label': 'I-chronic_disease', 'start_index': 131, 'end_index': 138, 'token': 'disease'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02106598'}, {'label': 'B-cancer', 'start_index': 45, 'end_index': 50, 'token': 'tumor'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02106598'}, {'label': 'B-cancer', 'start_index': 28, 'end_index': 38, 'token': 'colorectal'}, {'label': 'I-cancer', 'start_index': 39, 'end_index': 45, 'token': 'cancer'}, {'label': 'B-treatment', 'start_index': 63, 'end_index': 66, 'token': 'sln'}, {'label': 'I-treatment', 'start_index': 67, 'end_index': 74, 'token': 'mapping'}, {'label': 'B-treatment', 'start_index': 79, 'end_index': 84, 'token': 'total'}, {'label': 'I-treatment', 'start_index': 85, 'end_index': 95, 'token': 'mesorectal'}, {'label': 'I-treatment', 'start_index': 96, 'end_index': 104, 'token': 'excision'}, {'label': 'B-treatment', 'start_index': 110, 'end_index': 117, 'token': 'lateral'}, {'label': 'I-treatment', 'start_index': 118, 'end_index': 124, 'token': 'pelvic'}, {'label': 'I-treatment', 'start_index': 125, 'end_index': 133, 'token': 'sidewall'}, {'label': 'I-treatment', 'start_index': 134, 'end_index': 144, 'token': 'dissection'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02109081'}, {'label': 'B-treatment', 'start_index': 25, 'end_index': 35, 'token': 'noncardiac'}, {'label': 'I-treatment', 'start_index': 36, 'end_index': 44, 'token': 'surgical'}, {'label': 'I-treatment', 'start_index': 45, 'end_index': 54, 'token': 'procedure'}, {'label': 'B-treatment', 'start_index': 61, 'end_index': 68, 'token': 'general'}, {'label': 'I-treatment', 'start_index': 69, 'end_index': 79, 'token': 'anesthesia'}, {'label': 'B-lower_bound', 'start_index': 4, 'end_index': 5, 'token': '2'}, {'label': 'I-lower_bound', 'start_index': 151, 'end_index': 155, 'token': 'days'}]
# [{'label': 'B-clinical_variable', 'start_index': 0, 'end_index': 11, 'token': 'nct02109081'}, {'label': 'I-clinical_variable', 'start_index': 12, 'end_index': 16, 'token': 'mmse'}, {'label': 'I-clinical_variable', 'start_index': 17, 'end_index': 22, 'token': 'score'}, {'label': 'B-upper_bound', 'start_index': 28, 'end_index': 30, 'token': '20'}, {'label': 'B-upper_bound', 'start_index': 38, 'end_index': 40, 'token': '30'}, {'label': 'B-chronic_disease', 'start_index': 76, 'end_index': 80, 'token': 'mild'}, {'label': 'B-chronic_disease', 'start_index': 81, 'end_index': 90, 'token': 'cognitive'}, {'label': 'I-chronic_disease', 'start_index': 91, 'end_index': 101, 'token': 'impairment'}, {'label': 'B-chronic_disease', 'start_index': 106, 'end_index': 114, 'token': 'delirium'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02164734'}, {'label': 'B-clinical_variable', 'start_index': 25, 'end_index': 30, 'token': 'nasal'}, {'label': 'I-clinical_variable', 'start_index': 31, 'end_index': 35, 'token': 'cpap'}, {'label': 'I-clinical_variable', 'start_index': 36, 'end_index': 46, 'token': 'modalities'}, {'label': 'B-lower_bound', 'start_index': 49, 'end_index': 50, 'token': '5'}, {'label': 'I-lower_bound', 'start_index': 51, 'end_index': 53, 'token': 'cm'}, {'label': 'I-lower_bound', 'start_index': 54, 'end_index': 57, 'token': 'h2o'}, {'label': 'B-clinical_variable', 'start_index': 62, 'end_index': 66, 'token': 'fio2'}, {'label': 'B-lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'}, {'label': 'I-lower_bound', 'start_index': 76, 'end_index': 77, 'token': '.'}, {'label': 'I-lower_bound', 'start_index': 77, 'end_index': 79, 'token': '30'}, {'label': 'B-lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'}, {'label': 'I-lower_bound', 'start_index': 76, 'end_index': 77, 'token': '.'}, {'label': 'I-lower_bound', 'start_index': 86, 'end_index': 88, 'token': '60'}, {'label': 'B-lower_bound', 'start_index': 4, 'end_index': 5, 'token': '2'}, {'label': 'I-lower_bound', 'start_index': 104, 'end_index': 109, 'token': 'hours'}, {'label': 'B-clinical_variable', 'start_index': 122, 'end_index': 126, 'token': 'spo2'}, {'label': 'B-lower_bound', 'start_index': 127, 'end_index': 129, 'token': '90'}, {'label': 'B-upper_bound', 'start_index': 130, 'end_index': 132, 'token': '95'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02164734'}, {'label': 'B-chronic_disease', 'start_index': 12, 'end_index': 24, 'token': 'craniofacial'}, {'label': 'B-chronic_disease', 'start_index': 28, 'end_index': 42, 'token': 'cardiothoracic'}, {'label': 'I-chronic_disease', 'start_index': 43, 'end_index': 56, 'token': 'malformations'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02167022'}, {'label': 'B-treatment', 'start_index': 70, 'end_index': 84, 'token': 'rehabilitation'}, {'label': 'I-treatment', 'start_index': 85, 'end_index': 94, 'token': 'therapies'}, {'label': 'B-chronic_disease', 'start_index': 257, 'end_index': 259, 'token': 'cp'}, {'label': 'B-cancer', 'start_index': 266, 'end_index': 272, 'token': 'cancer'}, {'label': 'B-cancer', 'start_index': 274, 'end_index': 280, 'token': 'cystic'}, {'label': 'I-chronic_disease', 'start_index': 281, 'end_index': 289, 'token': 'fibrosis'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02167022'}, {'label': 'B-chronic_disease', 'start_index': 65, 'end_index': 70, 'token': 'motor'}, {'label': 'B-upper_bound', 'start_index': 129, 'end_index': 132, 'token': 'one'}, {'label': 'I-upper_bound', 'start_index': 133, 'end_index': 137, 'token': 'year'}, {'label': 'B-age', 'start_index': 177, 'end_index': 180, 'token': 'age'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02202369'}, {'label': 'B-chronic_disease', 'start_index': 26, 'end_index': 31, 'token': 'renal'}, {'label': 'I-chronic_disease', 'start_index': 32, 'end_index': 39, 'token': 'disease'}, {'label': 'B-clinical_variable', 'start_index': 52, 'end_index': 62, 'token': 'glomerular'}, {'label': 'I-clinical_variable', 'start_index': 63, 'end_index': 73, 'token': 'filtration'}, {'label': 'I-clinical_variable', 'start_index': 74, 'end_index': 78, 'token': 'rate'}, {'label': 'B-upper_bound', 'start_index': 81, 'end_index': 85, 'token': '60ml'}, {'label': 'I-upper_bound', 'start_index': 85, 'end_index': 86, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 86, 'end_index': 89, 'token': 'min'}, {'label': 'I-upper_bound', 'start_index': 85, 'end_index': 86, 'token': '/'}, {'label': 'I-upper_bound', 'start_index': 90, 'end_index': 91, 'token': '1'}, {'label': 'I-upper_bound', 'start_index': 91, 'end_index': 92, 'token': '.'}, {'label': 'I-upper_bound', 'start_index': 92, 'end_index': 96, 'token': '73m2'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02202369'}, {'label': 'B-chronic_disease', 'start_index': 26, 'end_index': 31, 'token': 'liver'}, {'label': 'I-chronic_disease', 'start_index': 32, 'end_index': 39, 'token': 'disease'}]
# [{'label': 'B-allergy_name', 'start_index': 0, 'end_index': 11, 'token': 'nct02203019'}, {'label': 'B-allergy_name', 'start_index': 50, 'end_index': 58, 'token': 'propofol'}, {'label': 'B-allergy_name', 'start_index': 60, 'end_index': 75, 'token': 'dexmedetomidine'}, {'label': 'B-allergy_name', 'start_index': 77, 'end_index': 85, 'token': 'fentanyl'}, {'label': 'B-allergy_name', 'start_index': 87, 'end_index': 91, 'token': 'eggs'}, {'label': 'B-allergy_name', 'start_index': 87, 'end_index': 90, 'token': 'egg'}, {'label': 'I-allergy_name', 'start_index': 99, 'end_index': 107, 'token': 'products'}, {'label': 'B-allergy_name', 'start_index': 112, 'end_index': 115, 'token': 'soy'}, {'label': 'B-allergy_name', 'start_index': 112, 'end_index': 115, 'token': 'soy'}, {'label': 'I-allergy_name', 'start_index': 99, 'end_index': 107, 'token': 'products'}]
# [{'label': 'B-clinical_variable', 'start_index': 0, 'end_index': 11, 'token': 'nct02203019'}, {'label': 'I-clinical_variable', 'start_index': 12, 'end_index': 16, 'token': 'mean'}, {'label': 'I-clinical_variable', 'start_index': 17, 'end_index': 25, 'token': 'arterial'}, {'label': 'I-clinical_variable', 'start_index': 26, 'end_index': 34, 'token': 'pressure'}, {'label': 'B-upper_bound', 'start_index': 45, 'end_index': 47, 'token': '55'}, {'label': 'I-upper_bound', 'start_index': 48, 'end_index': 52, 'token': 'mmhg'}, {'label': 'B-treatment', 'start_index': 73, 'end_index': 78, 'token': 'fluid'}, {'label': 'B-treatment', 'start_index': 97, 'end_index': 108, 'token': 'vasopressor'}]
# [{'label': 'B-treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct02203019'}, {'label': 'B-chronic_disease', 'start_index': 34, 'end_index': 40, 'token': 'sepsis'}, {'label': 'B-upper_bound', 'start_index': 73, 'end_index': 81, 'token': 'previous'}, {'label': 'I-upper_bound', 'start_index': 82, 'end_index': 84, 'token': '24'}, {'label': 'I-upper_bound', 'start_index': 85, 'end_index': 90, 'token': 'hours'}]
# ...
# [{'label': 'B-chronic_disease', 'start_index': 11, 'end_index': 24, 'token': 'malabsorption'}, {'label': 'B-chronic_disease', 'start_index': 34, 'end_index': 50, 'token': 'gastrointestinal'}, {'label': 'I-chronic_disease', 'start_index': 51, 'end_index': 52, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 52, 'end_index': 54, 'token': 'gi'}, {'label': 'I-chronic_disease', 'start_index': 54, 'end_index': 55, 'token': ')'}, {'label': 'I-chronic_disease', 'start_index': 56, 'end_index': 63, 'token': 'disease'}, {'label': 'B-treatment', 'start_index': 111, 'end_index': 114, 'token': 'lam'}, {'label': 'I-treatment', 'start_index': 114, 'end_index': 115, 'token': '-'}, {'label': 'I-treatment', 'start_index': 115, 'end_index': 119, 'token': '002a'}]
# [{'label': 'B-chronic_disease', 'start_index': 7, 'end_index': 17, 'token': 'congenital'}, {'label': 'I-chronic_disease', 'start_index': 18, 'end_index': 31, 'token': 'abnormalities'}]
# [{'label': 'B-cancer', 'start_index': 10, 'end_index': 13, 'token': 'hcc'}, {'label': 'B-treatment', 'start_index': 17, 'end_index': 23, 'token': 'biopsy'}, {'label': 'B-treatment', 'start_index': 27, 'end_index': 32, 'token': 'liver'}, {'label': 'I-treatment', 'start_index': 33, 'end_index': 41, 'token': 'protocol'}, {'label': 'B-treatment', 'start_index': 42, 'end_index': 44, 'token': 'ct'}, {'label': 'I-treatment', 'start_index': 45, 'end_index': 49, 'token': 'scan'}, {'label': 'B-treatment', 'start_index': 53, 'end_index': 56, 'token': 'mri'}]
# [{'label': 'B-treatment', 'start_index': 20, 'end_index': 29, 'token': 'treatment'}, {'label': 'B-treatment', 'start_index': 45, 'end_index': 53, 'token': 'curative'}, {'label': 'I-treatment', 'start_index': 54, 'end_index': 57, 'token': 'txp'}, {'label': 'B-treatment', 'start_index': 59, 'end_index': 67, 'token': 'surgical'}, {'label': 'I-treatment', 'start_index': 68, 'end_index': 77, 'token': 'resection'}, {'label': 'B-treatment', 'start_index': 81, 'end_index': 89, 'token': 'ablation'}]
# [{'label': 'B-chronic_disease', 'start_index': -1, 'end_index': 4, 'token': '[CLS]'}, {'label': 'B-chronic_disease', 'start_index': 0, 'end_index': 8, 'token': 'unstable'}, {'label': 'I-chronic_disease', 'start_index': 9, 'end_index': 16, 'token': 'medical'}, {'label': 'I-chronic_disease', 'start_index': 17, 'end_index': 26, 'token': 'condition'}]
# [{'label': 'I-treatment', 'start_index': 24, 'end_index': 32, 'token': 'premolar'}, {'label': 'I-treatment', 'start_index': 24, 'end_index': 32, 'token': 'premolar'}]
# [{'label': 'B-chronic_disease', 'start_index': 8, 'end_index': 14, 'token': 'active'}, {'label': 'I-chronic_disease', 'start_index': 15, 'end_index': 24, 'token': 'infection'}, {'label': 'B-chronic_disease', 'start_index': 30, 'end_index': 39, 'token': 'hepatitis'}, {'label': 'I-chronic_disease', 'start_index': 8, 'end_index': 9, 'token': 'a'}, {'label': 'I-chronic_disease', 'start_index': 42, 'end_index': 47, 'token': 'virus'}, {'label': 'I-chronic_disease', 'start_index': 48, 'end_index': 49, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 49, 'end_index': 52, 'token': 'hav'}, {'label': 'I-chronic_disease', 'start_index': 52, 'end_index': 53, 'token': ')'}, {'label': 'B-chronic_disease', 'start_index': 30, 'end_index': 39, 'token': 'hepatitis'}, {'label': 'I-chronic_disease', 'start_index': 65, 'end_index': 66, 'token': 'b'}, {'label': 'I-chronic_disease', 'start_index': 42, 'end_index': 47, 'token': 'virus'}, {'label': 'I-chronic_disease', 'start_index': 48, 'end_index': 49, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 74, 'end_index': 77, 'token': 'hbv'}, {'label': 'I-chronic_disease', 'start_index': 52, 'end_index': 53, 'token': ')'}, {'label': 'B-chronic_disease', 'start_index': 30, 'end_index': 39, 'token': 'hepatitis'}, {'label': 'I-chronic_disease', 'start_index': 9, 'end_index': 10, 'token': 'c'}, {'label': 'I-chronic_disease', 'start_index': 42, 'end_index': 47, 'token': 'virus'}, {'label': 'I-chronic_disease', 'start_index': 48, 'end_index': 49, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 99, 'end_index': 102, 'token': 'hcv'}, {'label': 'I-chronic_disease', 'start_index': 52, 'end_index': 53, 'token': ')'}, {'label': 'B-chronic_disease', 'start_index': 107, 'end_index': 112, 'token': 'human'}, {'label': 'I-chronic_disease', 'start_index': 113, 'end_index': 129, 'token': 'immunodeficiency'}, {'label': 'I-chronic_disease', 'start_index': 42, 'end_index': 47, 'token': 'virus'}, {'label': 'I-chronic_disease', 'start_index': 48, 'end_index': 49, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 137, 'end_index': 140, 'token': 'hiv'}, {'label': 'I-chronic_disease', 'start_index': 52, 'end_index': 53, 'token': ')'}, {'label': 'I-chronic_disease', 'start_index': 142, 'end_index': 146, 'token': 'type'}, {'label': 'I-chronic_disease', 'start_index': 147, 'end_index': 148, 'token': '1'}, {'label': 'O', 'start_index': 104, 'end_index': 106, 'token': 'or'}, {'label': 'I-chronic_disease', 'start_index': 15, 'end_index': 24, 'token': 'infection'}]
# []
# [{'label': 'B-cancer', 'start_index': 65, 'end_index': 70, 'token': 'solid'}, {'label': 'B-upper_bound', 'start_index': 185, 'end_index': 186, 'token': '4'}, {'label': 'I-upper_bound', 'start_index': 187, 'end_index': 192, 'token': 'weeks'}, {'label': 'I-upper_bound', 'start_index': 193, 'end_index': 198, 'token': 'prior'}]
# [{'label': 'B-pregnancy', 'start_index': 0, 'end_index': 8, 'token': 'pregnant'}, {'label': 'B-gender', 'start_index': 9, 'end_index': 14, 'token': 'women'}, {'label': 'B-treatment', 'start_index': 52, 'end_index': 61, 'token': 'radiation'}, {'label': 'B-treatment', 'start_index': 84, 'end_index': 95, 'token': 'teratogenic'}]
# [{'label': 'B-chronic_disease', 'start_index': 0, 'end_index': 12, 'token': 'neurological'}, {'label': 'I-chronic_disease', 'start_index': 13, 'end_index': 21, 'token': 'diseases'}, {'label': 'B-chronic_disease', 'start_index': 29, 'end_index': 38, 'token': 'parkinson'}, {'label': 'I-chronic_disease', 'start_index': 38, 'end_index': 39, 'token': "'"}, {'label': 'I-chronic_disease', 'start_index': 15, 'end_index': 16, 'token': 's'}, {'label': 'I-chronic_disease', 'start_index': 13, 'end_index': 20, 'token': 'disease'}, {'label': 'B-chronic_disease', 'start_index': 50, 'end_index': 58, 'token': 'epilepsy'}, {'label': 'B-chronic_disease', 'start_index': 60, 'end_index': 68, 'token': 'cortical'}, {'label': 'I-chronic_disease', 'start_index': 69, 'end_index': 75, 'token': 'stroke'}, {'label': 'B-chronic_disease', 'start_index': 77, 'end_index': 86, 'token': 'alzheimer'}, {'label': 'I-chronic_disease', 'start_index': 38, 'end_index': 39, 'token': "'"}, {'label': 'I-chronic_disease', 'start_index': 15, 'end_index': 16, 'token': 's'}, {'label': 'I-chronic_disease', 'start_index': 13, 'end_index': 20, 'token': 'disease'}, {'label': 'B-chronic_disease', 'start_index': 98, 'end_index': 107, 'token': 'traumatic'}, {'label': 'I-chronic_disease', 'start_index': 108, 'end_index': 113, 'token': 'brain'}, {'label': 'I-chronic_disease', 'start_index': 114, 'end_index': 120, 'token': 'injury'}, {'label': 'B-chronic_disease', 'start_index': 125, 'end_index': 133, 'token': 'dementia'}]
# [{'label': 'B-lower_bound', 'start_index': 10, 'end_index': 15, 'token': 'three'}, {'label': 'B-treatment', 'start_index': 16, 'end_index': 24, 'token': 'systemic'}, {'label': 'I-treatment', 'start_index': 25, 'end_index': 39, 'token': 'corticosteroid'}, {'label': 'B-chronic_disease', 'start_index': 50, 'end_index': 56, 'token': 'asthma'}]
# [{'label': 'B-chronic_disease', 'start_index': -1, 'end_index': 4, 'token': '[CLS]'}, {'label': 'B-chronic_disease', 'start_index': 0, 'end_index': 11, 'token': 'hemorrhagic'}, {'label': 'I-chronic_disease', 'start_index': 12, 'end_index': 20, 'token': 'cystitis'}, {'label': 'B-chronic_disease', 'start_index': 24, 'end_index': 30, 'token': 'active'}, {'label': 'I-chronic_disease', 'start_index': 31, 'end_index': 42, 'token': 'prostatitis'}]
# [{'label': 'B-lower_bound', 'start_index': 38, 'end_index': 39, 'token': '1'}, {'label': 'B-treatment', 'start_index': 54, 'end_index': 62, 'token': 'systemic'}, {'label': 'I-treatment', 'start_index': 63, 'end_index': 70, 'token': 'therapy'}]
# [{'label': 'B-chronic_disease', 'start_index': 44, 'end_index': 56, 'token': 'hypertensive'}, {'label': 'I-chronic_disease', 'start_index': 57, 'end_index': 63, 'token': 'crisis'}, {'label': 'B-chronic_disease', 'start_index': 44, 'end_index': 56, 'token': 'hypertensive'}, {'label': 'I-chronic_disease', 'start_index': 80, 'end_index': 94, 'token': 'encephalopathy'}]
# [{'label': 'B-chronic_disease', 'start_index': 88, 'end_index': 94, 'token': 'trauma'}]
# [{'label': 'B-treatment', 'start_index': 8, 'end_index': 19, 'token': 'concomitant'}, {'label': 'B-treatment', 'start_index': 20, 'end_index': 32, 'token': 'chemotherapy'}, {'label': 'B-treatment', 'start_index': 34, 'end_index': 43, 'token': 'radiation'}, {'label': 'I-treatment', 'start_index': 25, 'end_index': 32, 'token': 'therapy'}, {'label': 'B-treatment', 'start_index': 55, 'end_index': 68, 'token': 'immunotherapy'}]
# [{'label': 'B-cancer', 'start_index': 5, 'end_index': 15, 'token': 'metastatic'}, {'label': 'I-cancer', 'start_index': 16, 'end_index': 22, 'token': 'breast'}, {'label': 'I-cancer', 'start_index': 23, 'end_index': 29, 'token': 'cancer'}, {'label': 'I-chronic_disease', 'start_index': 48, 'end_index': 59, 'token': 'dysfunction'}]
# [{'label': 'B-chronic_disease', 'start_index': 13, 'end_index': 25, 'token': 'hypocalcemia'}]
# [{'label': 'I-chronic_disease', 'start_index': 19, 'end_index': 29, 'token': 'dependence'}, {'label': 'I-chronic_disease', 'start_index': 30, 'end_index': 38, 'token': 'disorder'}]
# [{'label': 'B-gender', 'start_index': 0, 'end_index': 5, 'token': 'women'}, {'label': 'B-pregnancy', 'start_index': 44, 'end_index': 52, 'token': 'negative'}, {'label': 'I-pregnancy', 'start_index': 53, 'end_index': 62, 'token': 'pregnancy'}, {'label': 'B-upper_bound', 'start_index': 75, 'end_index': 76, 'token': '7'}, {'label': 'I-upper_bound', 'start_index': 77, 'end_index': 81, 'token': 'days'}, {'label': 'B-clinical_variable', 'start_index': 127, 'end_index': 137, 'token': 'amenorrhea'}, {'label': 'B-lower_bound', 'start_index': 141, 'end_index': 143, 'token': '12'}, {'label': 'I-lower_bound', 'start_index': 144, 'end_index': 155, 'token': 'consecutive'}, {'label': 'I-lower_bound', 'start_index': 156, 'end_index': 166, 'token': 'monthsnote'}, {'label': 'B-gender', 'start_index': 0, 'end_index': 5, 'token': 'women'}, {'label': 'B-chronic_disease', 'start_index': 188, 'end_index': 199, 'token': 'amenorrheic'}, {'label': 'B-lower_bound', 'start_index': 141, 'end_index': 143, 'token': '12'}, {'label': 'B-treatment', 'start_index': 312, 'end_index': 317, 'token': 'prior'}, {'label': 'I-treatment', 'start_index': 318, 'end_index': 330, 'token': 'chemotherapy'}, {'label': 'B-treatment', 'start_index': 332, 'end_index': 345, 'token': 'antiestrogens'}, {'label': 'B-treatment', 'start_index': 347, 'end_index': 354, 'token': 'ovarian'}, {'label': 'I-treatment', 'start_index': 355, 'end_index': 366, 'token': 'suppression'}]
# [{'label': 'I-chronic_disease', 'start_index': 20, 'end_index': 26, 'token': 'angina'}, {'label': 'B-clinical_variable', 'start_index': 37, 'end_index': 40, 'token': 'new'}, {'label': 'I-clinical_variable', 'start_index': 41, 'end_index': 45, 'token': 'york'}, {'label': 'I-clinical_variable', 'start_index': 46, 'end_index': 51, 'token': 'heart'}, {'label': 'I-clinical_variable', 'start_index': 52, 'end_index': 63, 'token': 'association'}, {'label': 'I-clinical_variable', 'start_index': 64, 'end_index': 65, 'token': '('}, {'label': 'I-clinical_variable', 'start_index': 65, 'end_index': 69, 'token': 'nyha'}, {'label': 'I-clinical_variable', 'start_index': 69, 'end_index': 70, 'token': ')'}, {'label': 'I-clinical_variable', 'start_index': 71, 'end_index': 76, 'token': 'class'}, {'label': 'B-chronic_disease', 'start_index': 80, 'end_index': 90, 'token': 'congestive'}, {'label': 'I-clinical_variable', 'start_index': 46, 'end_index': 51, 'token': 'heart'}, {'label': 'I-chronic_disease', 'start_index': 97, 'end_index': 104, 'token': 'failure'}, {'label': 'B-chronic_disease', 'start_index': 115, 'end_index': 125, 'token': 'myocardial'}, {'label': 'I-chronic_disease', 'start_index': 126, 'end_index': 136, 'token': 'infarction'}, {'label': 'I-clinical_variable', 'start_index': 64, 'end_index': 65, 'token': '('}, {'label': 'I-chronic_disease', 'start_index': 138, 'end_index': 140, 'token': 'mi'}, {'label': 'I-clinical_variable', 'start_index': 69, 'end_index': 70, 'token': ')'}, {'label': 'B-upper_bound', 'start_index': 149, 'end_index': 150, 'token': '6'}, {'label': 'I-upper_bound', 'start_index': 151, 'end_index': 157, 'token': 'months'}, {'label': 'I-upper_bound', 'start_index': 158, 'end_index': 163, 'token': 'prior'}, {'label': 'B-treatment', 'start_index': 182, 'end_index': 191, 'token': 'treatment'}]
# [{'label': 'B-treatment', 'start_index': 46, 'end_index': 53, 'token': 'surgery'}, {'label': 'B-treatment', 'start_index': 67, 'end_index': 77, 'token': 'anesthesia'}]
# [{'label': 'B-treatment', 'start_index': 53, 'end_index': 64, 'token': 'medications'}, {'label': 'B-lower_bound', 'start_index': 78, 'end_index': 80, 'token': '14'}, {'label': 'I-lower_bound', 'start_index': 81, 'end_index': 85, 'token': 'days'}, {'label': 'B-lower_bound', 'start_index': 89, 'end_index': 93, 'token': 'five'}, {'label': 'I-lower_bound', 'start_index': 94, 'end_index': 98, 'token': 'half'}, {'label': 'B-treatment', 'start_index': 164, 'end_index': 169, 'token': 'study'}, {'label': 'O', 'start_index': 110, 'end_index': 114, 'token': 'drug'}, {'label': 'B-treatment', 'start_index': 230, 'end_index': 233, 'token': 'non'}, {'label': 'O', 'start_index': 98, 'end_index': 99, 'token': '-'}, {'label': 'I-treatment', 'start_index': 234, 'end_index': 243, 'token': 'oncologic'}, {'label': 'I-treatment', 'start_index': 244, 'end_index': 259, 'token': 'investigational'}, {'label': 'O', 'start_index': 110, 'end_index': 114, 'token': 'drug'}, {'label': 'B-upper_bound', 'start_index': 272, 'end_index': 274, 'token': '30'}, {'label': 'I-lower_bound', 'start_index': 81, 'end_index': 85, 'token': 'days'}, {'label': 'I-treatment', 'start_index': 359, 'end_index': 368, 'token': 'treatment'}]
# [{'label': 'B-treatment', 'start_index': 9, 'end_index': 20, 'token': 'macroscopic'}, {'label': 'I-treatment', 'start_index': 21, 'end_index': 30, 'token': 'resection'}]
# [{'label': 'B-chronic_disease', 'start_index': 168, 'end_index': 175, 'token': 'cardiac'}, {'label': 'B-chronic_disease', 'start_index': 177, 'end_index': 189, 'token': 'neurological'}, {'label': 'B-chronic_disease', 'start_index': 191, 'end_index': 200, 'token': 'pulmonary'}, {'label': 'B-chronic_disease', 'start_index': 202, 'end_index': 207, 'token': 'renal'}, {'label': 'B-chronic_disease', 'start_index': 209, 'end_index': 216, 'token': 'hepatic'}]
# [{'label': 'B-chronic_disease', 'start_index': 13, 'end_index': 19, 'token': 'active'}, {'label': 'I-chronic_disease', 'start_index': 20, 'end_index': 29, 'token': 'infection'}]
# [{'label': 'B-treatment', 'start_index': 18, 'end_index': 29, 'token': 'concomitant'}, {'label': 'I-treatment', 'start_index': 30, 'end_index': 37, 'token': 'therapy'}, {'label': 'B-upper_bound', 'start_index': 43, 'end_index': 44, 'token': '4'}, {'label': 'I-upper_bound', 'start_index': 45, 'end_index': 50, 'token': 'weeks'}, {'label': 'I-upper_bound', 'start_index': 51, 'end_index': 56, 'token': 'prior'}]
# [{'label': 'B-chronic_disease', 'start_index': -1, 'end_index': 4, 'token': '[CLS]'}, {'label': 'B-allergy_name', 'start_index': 28, 'end_index': 33, 'token': 'study'}, {'label': 'I-allergy_name', 'start_index': 34, 'end_index': 40, 'token': 'agents'}]

# %%
filtered_clinical_result = []

for result in result_list:
    clinical_result = []
    for sub in result:
        if sub['start_index'] >= 0 and sub['label'] != 'O':
            print(sub['label'])
            label = sub['label'].split('-')[1]  # Remove 'B-' and 'I-' prefixes
            clinical_result.append({
                'label': label,
                'start_index': sub['start_index'],
                'end_index': sub['end_index'],
                'token': sub['token']
            })
    filtered_clinical_result.append(clinical_result)

print(filtered_clinical_result)
# Out:
# B-treatment
# B-treatment
# B-treatment
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-clinical_variable
# I-chronic_disease
# B-treatment
# B-lower_bound
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-allergy_name
# B-treatment
# B-cancer
# I-cancer
# B-cancer
# I-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-cancer
# I-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# I-cancer
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-lower_bound
# B-treatment
# I-cancer
# I-cancer
# B-cancer
# B-cancer
# I-cancer
# B-cancer
# I-cancer
# I-cancer
# B-cancer
# I-cancer
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# B-contraception_consent
# I-contraception_consent
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-cancer
# I-cancer
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-lower_bound
# I-upper_bound
# B-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# B-cancer
# I-cancer
# B-cancer
# I-cancer
# B-cancer
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-cancer
# B-cancer
# I-chronic_disease
# I-chronic_disease
# I-cancer
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-clinical_variable
# B-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# I-upper_bound
# B-age
# B-lower_bound
# B-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-lower_bound
# B-upper_bound
# I-upper_bound
# B-treatment
# I-chronic_disease
# I-cancer
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-clinical_variable
# B-treatment
# B-allergy_name
# I-allergy_name
# B-allergy_name
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-chronic_disease
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-chronic_disease
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-cancer
# B-treatment
# B-cancer
# I-cancer
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-lower_bound
# I-lower_bound
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# B-upper_bound
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-lower_bound
# I-lower_bound
# B-clinical_variable
# B-lower_bound
# B-upper_bound
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-cancer
# B-cancer
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-upper_bound
# I-upper_bound
# B-age
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-allergy_name
# B-allergy_name
# B-allergy_name
# B-allergy_name
# B-allergy_name
# B-allergy_name
# I-allergy_name
# B-allergy_name
# B-allergy_name
# I-allergy_name
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-treatment
# B-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# B-cancer
# I-cancer
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-allergy_name
# B-allergy_name
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-treatment
# B-cancer
# I-cancer
# B-upper_bound
# I-upper_bound
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-gender
# I-gender
# I-contraception_consent
# I-contraception_consent
# B-treatment
# I-treatment
# I-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-allergy_name
# B-allergy_name
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-lower_bound
# I-lower_bound
# B-gender
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# I-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-gender
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-allergy_name
# B-allergy_name
# I-allergy_name
# B-clinical_variable
# B-lower_bound
# B-upper_bound
# I-upper_bound
# B-bmi
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-lower_bound
# I-lower_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# B-treatment
# B-chronic_disease
# I-treatment
# B-chronic_disease
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-chronic_disease
# I-treatment
# B-treatment
# B-treatment
# I-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-cancer
# B-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# B-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-allergy_name
# I-allergy_name
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-treatment
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-treatment
# B-treatment
# B-chronic_disease
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# B-gender
# I-contraception_consent
# B-gender
# I-contraception_consent
# B-contraception_consent
# B-contraception_consent
# I-contraception_consent
# B-treatment
# B-upper_bound
# I-upper_bound
# B-clinical_variable
# B-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-age
# B-treatment
# B-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-cancer
# B-cancer
# B-cancer
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-cancer
# B-cancer
# I-cancer
# B-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-treatment
# B-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-treatment
# B-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# B-chronic_disease
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# I-chronic_disease
# I-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-age
# B-clinical_variable
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-clinical_variable
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-clinical_variable
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-clinical_variable
# I-treatment
# I-treatment
# B-lower_bound
# I-lower_bound
# B-lower_bound
# I-lower_bound
# B-gender
# B-gender
# B-gender
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-clinical_variable
# B-lower_bound
# B-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-lower_bound
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# I-treatment
# B-allergy_name
# B-allergy_name
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-clinical_variable
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-treatment
# B-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-allergy_name
# B-allergy_name
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-cancer
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# B-lower_bound
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# B-clinical_variable
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-pregnancy
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-contraception_consent
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-treatment
# B-treatment
# B-allergy_name
# B-allergy_name
# B-allergy_name
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-cancer
# B-allergy_name
# B-allergy_name
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-lower_bound
# B-pregnancy
# B-chronic_disease
# B-clinical_variable
# I-lower_bound
# I-lower_bound
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# B-lower_bound
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-pregnancy
# B-pregnancy
# B-pregnancy
# I-pregnancy
# I-pregnancy
# B-pregnancy
# B-cancer
# B-gender
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# I-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# B-treatment
# I-treatment
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-cancer
# I-cancer
# I-clinical_variable
# I-cancer
# B-cancer
# I-cancer
# I-clinical_variable
# I-cancer
# B-cancer
# I-clinical_variable
# I-cancer
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-allergy_name
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# B-lower_bound
# I-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# I-lower_bound
# B-treatment
# B-lower_bound
# B-upper_bound
# I-upper_bound
# B-treatment
# B-cancer
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-treatment
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-treatment
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# I-clinical_variable
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-lower_bound
# B-treatment
# B-treatment
# B-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# B-cancer
# I-cancer
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-cancer
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-language_fluency
# I-language_fluency
# I-language_fluency
# B-treatment
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# I-cancer
# B-cancer
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# B-pregnancy
# B-gender
# I-gender
# B-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-lower_bound
# I-lower_bound
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# B-lower_bound
# B-lower_bound
# B-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# B-lower_bound
# I-lower_bound
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-gender
# I-gender
# B-lower_bound
# I-lower_bound
# B-upper_bound
# I-upper_bound
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# B-lower_bound
# I-lower_bound
# B-upper_bound
# B-upper_bound
# B-treatment
# B-lower_bound
# B-upper_bound
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# B-clinical_variable
# I-clinical_variable
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-clinical_variable
# I-lower_bound
# B-lower_bound
# I-lower_bound
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-cancer
# B-chronic_disease
# B-treatment
# I-treatment
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-clinical_variable
# I-upper_bound
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# B-treatment
# I-treatment
# I-treatment
# I-treatment
# I-treatment
# I-chronic_disease
# B-cancer
# B-lower_bound
# I-cancer
# B-upper_bound
# B-cancer
# I-cancer
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-upper_bound
# I-lower_bound
# I-upper_bound
# B-lower_bound
# I-lower_bound
# B-allergy_name
# B-allergy_name
# B-gender
# I-gender
# B-gender
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-treatment
# B-upper_bound
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-gender
# B-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# I-contraception_consent
# B-lower_bound
# I-lower_bound
# I-lower_bound
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# B-cancer
# B-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-lower_bound
# B-chronic_disease
# B-chronic_disease
# B-lower_bound
# B-cancer
# B-cancer
# B-cancer
# I-cancer
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# B-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-cancer
# I-cancer
# B-lower_bound
# B-lower_bound
# B-upper_bound
# B-chronic_disease
# I-chronic_disease
# B-age
# B-lower_bound
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# B-upper_bound
# I-upper_bound
# B-chronic_disease
# I-chronic_disease
# B-cancer
# B-lower_bound
# I-lower_bound
# B-cancer
# I-cancer
# B-cancer
# B-cancer
# I-cancer
# I-cancer
# I-cancer
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-cancer
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-cancer
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# I-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-cancer
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-pregnancy
# B-gender
# B-treatment
# B-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-lower_bound
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-lower_bound
# B-treatment
# I-treatment
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-chronic_disease
# B-treatment
# B-treatment
# B-treatment
# I-treatment
# B-treatment
# B-cancer
# I-cancer
# I-cancer
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-chronic_disease
# B-gender
# B-pregnancy
# I-pregnancy
# B-upper_bound
# I-upper_bound
# B-clinical_variable
# B-lower_bound
# I-lower_bound
# I-lower_bound
# B-gender
# B-chronic_disease
# B-lower_bound
# B-treatment
# I-treatment
# B-treatment
# B-treatment
# I-treatment
# I-chronic_disease
# B-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# I-clinical_variable
# B-chronic_disease
# I-clinical_variable
# I-chronic_disease
# B-chronic_disease
# I-chronic_disease
# I-clinical_variable
# I-chronic_disease
# I-clinical_variable
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-treatment
# B-treatment
# B-treatment
# B-treatment
# B-lower_bound
# I-lower_bound
# B-lower_bound
# I-lower_bound
# B-treatment
# B-treatment
# I-treatment
# I-treatment
# B-upper_bound
# I-lower_bound
# I-treatment
# B-treatment
# I-treatment
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# B-chronic_disease
# I-chronic_disease
# B-treatment
# I-treatment
# B-upper_bound
# I-upper_bound
# I-upper_bound
# B-allergy_name
# I-allergy_name
# [[{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00351611'}, {'label': 'treatment', 'start_index': 37, 'end_index': 47, 'token': 'pregabalin'}, {'label': 'treatment', 'start_index': 55, 'end_index': 64, 'token': 'treatment'}, {'label': 'chronic_disease', 'start_index': 76, 'end_index': 83, 'token': 'seizure'}], [{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00862446'}, {'label': 'treatment', 'start_index': 24, 'end_index': 27, 'token': 'tpn'}, {'label': 'treatment', 'start_index': 28, 'end_index': 37, 'token': 'treatment'}, {'label': 'lower_bound', 'start_index': 51, 'end_index': 54, 'token': 'one'}, {'label': 'lower_bound', 'start_index': 55, 'end_index': 60, 'token': 'month'}], [{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct00862446'}, {'label': 'clinical_variable', 'start_index': 12, 'end_index': 15, 'token': 'tpn'}, {'label': 'clinical_variable', 'start_index': 16, 'end_index': 27, 'token': 'cholestasis'}, {'label': 'lower_bound', 'start_index': 7, 'end_index': 8, 'token': '2'}, {'label': 'lower_bound', 'start_index': 41, 'end_index': 42, 'token': '.'}, {'label': 'lower_bound', 'start_index': 42, 'end_index': 43, 'token': '5'}, {'label': 'lower_bound', 'start_index': 44, 'end_index': 46, 'token': 'mg'}, {'label': 'lower_bound', 'start_index': 46, 'end_index': 47, 'token': '/'}, {'label': 'lower_bound', 'start_index': 47, 'end_index': 49, 'token': 'dl'}], [{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01175044'}, {'label': 'treatment', 'start_index': 42, 'end_index': 50, 'token': 'revision'}, {'label': 'treatment', 'start_index': 51, 'end_index': 56, 'token': 'total'}, {'label': 'treatment', 'start_index': 57, 'end_index': 61, 'token': 'knee'}, {'label': 'treatment', 'start_index': 62, 'end_index': 74, 'token': 'arthroplasty'}], [{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01175044'}, {'label': 'treatment', 'start_index': 36, 'end_index': 47, 'token': 'antibiotics'}, {'label': 'upper_bound', 'start_index': 48, 'end_index': 50, 'token': '14'}, {'label': 'upper_bound', 'start_index': 51, 'end_index': 55, 'token': 'days'}, {'label': 'upper_bound', 'start_index': 56, 'end_index': 61, 'token': 'prior'}, {'label': 'treatment', 'start_index': 78, 'end_index': 85, 'token': 'surgery'}], [{'label': 'treatment', 'start_index': 0, 'end_index': 11, 'token': 'nct01446094'}, {'label': 'chronic_disease', 'start_index': 12, 'end_index': 18, 'token': 'severe'}, {'label': 'chronic_disease', 'start_index': 19, 'end_index': 23, 'token': 'lung'}, {'label': 'chronic_disease', 'start_index': 24, 'end_index': 31, 'token': 'disease'}, {'label': 'chronic_disease', 'start_index': 40, 'end_index': 48, 'token': 'wheezing'}, {'label': 'chronic_disease', 'start_index': 57, 'end_index': 68, 'token': 'bradycardia'}, {'label': 'clinical_variable', 'start_index': 70, 'end_index': 75, 'token': 'heart'}, {'label': 'clinical_variable', 'start_index': 76, 'end_index': 80, 'token': 'rate'}, {'label': 'upper_bound', 'start_index': 83, 'end_index': 85, 'token': '40'}, {'label': 'upper_bound', 'start_index': 86, 'end_index': 91, 'token': 'beats'}, {'label': 'upper_bound', 'start_index': 91, 'end_index': 92, 'token': '/'}, {'label': 'upper_bound', 'start_index': 92, 'end_index': 95, 'token': 'min'}, {'label': 'chronic_disease', 'start_index': 103, 'end_index': 104, 'token': '-'}, {'label': 'chronic_disease', 'start_index': 121, 'end_index': 137, 'token': 'atrioventricular'}, {'label': 'clinical_variable', 'start_index': 70, 'end_index': 75, 'token': 'heart'}, {'label': 'chronic_disease', 'start_index': 144, 'end_index': 149, 'token': 'block'}, {'label': 'chronic_disease', 'start_index': 150, 'end_index': 154, 'token': 'sick'}, {'label': 'chronic_disease', 'start_index': 155, 'end_index': 160, 'token': 'sinus'}, {'label': 'chronic_disease', 'start_index': 161, 'end_index': 169, 'token': 'syndrome'}, {'label': 'chronic_disease', 'start_index': 18 ...

# %%
filtered_clinical_result
# Out:
# [[{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct00351611'},
#   {'label': 'treatment',
#    'start_index': 37,
#    'end_index': 47,
#    'token': 'pregabalin'},
#   {'label': 'treatment',
#    'start_index': 55,
#    'end_index': 64,
#    'token': 'treatment'},
#   {'label': 'chronic_disease',
#    'start_index': 76,
#    'end_index': 83,
#    'token': 'seizure'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct00862446'},
#   {'label': 'treatment', 'start_index': 24, 'end_index': 27, 'token': 'tpn'},
#   {'label': 'treatment',
#    'start_index': 28,
#    'end_index': 37,
#    'token': 'treatment'},
#   {'label': 'lower_bound', 'start_index': 51, 'end_index': 54, 'token': 'one'},
#   {'label': 'lower_bound',
#    'start_index': 55,
#    'end_index': 60,
#    'token': 'month'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct00862446'},
#   {'label': 'clinical_variable',
#    'start_index': 12,
#    'end_index': 15,
#    'token': 'tpn'},
#   {'label': 'clinical_variable',
#    'start_index': 16,
#    'end_index': 27,
#    'token': 'cholestasis'},
#   {'label': 'lower_bound', 'start_index': 7, 'end_index': 8, 'token': '2'},
#   {'label': 'lower_bound', 'start_index': 41, 'end_index': 42, 'token': '.'},
#   {'label': 'lower_bound', 'start_index': 42, 'end_index': 43, 'token': '5'},
#   {'label': 'lower_bound', 'start_index': 44, 'end_index': 46, 'token': 'mg'},
#   {'label': 'lower_bound', 'start_index': 46, 'end_index': 47, 'token': '/'},
#   {'label': 'lower_bound', 'start_index': 47, 'end_index': 49, 'token': 'dl'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01175044'},
#   {'label': 'treatment',
#    'start_index': 42,
#    'end_index': 50,
#    'token': 'revision'},
#   {'label': 'treatment', 'start_index': 51, 'end_index': 56, 'token': 'total'},
#   {'label': 'treatment', 'start_index': 57, 'end_index': 61, 'token': 'knee'},
#   {'label': 'treatment',
#    'start_index': 62,
#    'end_index': 74,
#    'token': 'arthroplasty'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01175044'},
#   {'label': 'treatment',
#    'start_index': 36,
#    'end_index': 47,
#    'token': 'antibiotics'},
#   {'label': 'upper_bound', 'start_index': 48, 'end_index': 50, 'token': '14'},
#   {'label': 'upper_bound',
#    'start_index': 51,
#    'end_index': 55,
#    'token': 'days'},
#   {'label': 'upper_bound',
#    'start_index': 56,
#    'end_index': 61,
#    'token': 'prior'},
#   {'label': 'treatment',
#    'start_index': 78,
#    'end_index': 85,
#    'token': 'surgery'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01446094'},
#   {'label': 'chronic_disease',
#    'start_index': 12,
#    'end_index': 18,
#    'token': 'severe'},
#   {'label': 'chronic_disease',
#    'start_index': 19,
#    'end_index': 23,
#    'token': 'lung'},
#   {'label': 'chronic_disease',
#    'start_index': 24,
#    'end_index': 31,
#    'token': 'disease'},
#   {'label': 'chronic_disease',
#    'start_index': 40,
#    'end_index': 48,
#    'token': 'wheezing'},
#   {'label': 'chronic_disease',
#    'start_index': 57,
#    'end_index': 68,
#    'token': 'bradycardia'},
#   {'label': 'clinical_variable',
#    'start_index': 70,
#    'end_index': 75,
#    'token': 'heart'},
#   {'label': 'clinical_variable',
#    'start_index': 76,
#    'end_index': 80,
#    'token': 'rate'},
#   {'label': 'upper_bound', 'start_index': 83, 'end_index': 85, 'token': '40'},
#   {'label': 'upper_bound',
#    'start_index': 86,
#    'end_index': 91,
#    'token': 'beats'},
#   {'label': 'upper_bound', 'start_index': 91, 'end_index': 92, 'token': '/'},
#   {'label': 'upper_bound', 'start_index': 92, 'end_index': 95, 'token': 'min'},
#   {'label': 'chronic_disease',
#    'start_index': 103,
#    'end_index': 104,
#    'token': '-'},
#   {'label': 'chronic_disease',
#    'start_index': 121,
#    'end_index': 137,
#    'token': 'atrioventricular'},
#   {'label': 'clinical_variable',
#    'start_index': 70,
#    'end_index': 75,
#    'token': 'heart'},
#   {'label': 'chronic_disease',
#    'start_index': 144,
#    'end_index': 149,
#    'token': 'block'},
#   {'label': 'chronic_disease',
#    'start_index': 150,
#    'end_index': 154,
#    'token': 'sick'},
#   {'label': 'chronic_disease',
#    'start_index': 155,
#    'end_index': 160,
#    'token': 'sinus'},
#   {'label': 'chronic_disease',
#    'start_index': 161,
#    'end_index': 169,
#    'token': 'syndrome'},
#   {'label': 'chronic_disease',
#    'start_index': 181,
#    'end_index': 185,
#    'token': 'long'},
#   {'label': 'chronic_disease',
#    'start_index': 186,
#    'end_index': 188,
#    'token': 'qt'},
#   {'label': 'chronic_disease',
#    'start_index': 161,
#    'end_index': 169,
#    'token': 'syndrome'},
#   {'label': 'chronic_disease',
#    'start_index': 205,
#    'end_index': 216,
#    'token': 'hypotension'},
#   {'label': 'clinical_variable',
#    'start_index': 218,
#    'end_index': 226,
#    'token': 'systolic'},
#   {'label': 'clinical_variable',
#    'start_index': 227,
#    'end_index': 229,
#    'token': 'bp'},
#   {'label': 'upper_bound',
#    'start_index': 232,
#    'end_index': 234,
#    'token': '80'},
#   {'label': 'upper_bound',
#    'start_index': 235,
#    'end_index': 237,
#    'token': 'mm'},
#   {'label': 'upper_bound',
#    'start_index': 238,
#    'end_index': 240,
#    'token': 'hg'},
#   {'label': 'clinical_variable',
#    'start_index': 70,
#    'end_index': 75,
#    'token': 'heart'},
#   {'label': 'chronic_disease',
#    'start_index': 262,
#    'end_index': 269,
#    'token': 'failure'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01446094'},
#   {'label': 'lower_bound', 'start_index': 38, 'end_index': 40, 'token': '20'},
#   {'label': 'upper_bound', 'start_index': 41, 'end_index': 43, 'token': '30'},
#   {'label': 'upper_bound',
#    'start_index': 44,
#    'end_index': 51,
#    'token': 'minutes'},
#   {'label': 'treatment',
#    'start_index': 100,
#    'end_index': 103,
#    'token': 'mri'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01446094'},
#   {'label': 'chronic_disease',
#    'start_index': 25,
#    'end_index': 32,
#    'token': 'chronic'},
#   {'label': 'chronic_disease',
#    'start_index': 33,
#    'end_index': 39,
#    'token': 'kidney'},
#   {'label': 'chronic_disease',
#    'start_index': 40,
#    'end_index': 47,
#    'token': 'disease'},
#   {'label': 'clinical_variable',
#    'start_index': 49,
#    'end_index': 53,
#    'token': 'egfr'},
#   {'label': 'upper_bound', 'start_index': 56, 'end_index': 58, 'token': '30'},
#   {'label': 'upper_bound', 'start_index': 59, 'end_index': 61, 'token': 'ml'},
#   {'label': 'upper_bound', 'start_index': 61, 'end_index': 62, 'token': '/'},
#   {'label': 'upper_bound', 'start_index': 62, 'end_index': 65, 'token': 'min'},
#   {'label': 'upper_bound', 'start_index': 61, 'end_index': 62, 'token': '/'},
#   {'label': 'upper_bound', 'start_index': 4, 'end_index': 5, 'token': '1'},
#   {'label': 'upper_bound', 'start_index': 67, 'end_index': 68, 'token': '.'},
#   {'label': 'upper_bound', 'start_index': 68, 'end_index': 70, 'token': '73'},
#   {'label': 'upper_bound', 'start_index': 71, 'end_index': 73, 'token': 'm2'},
#   {'label': 'allergy_name',
#    'start_index': 92,
#    'end_index': 96,
#    'token': 'gbca'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01581749'},
#   {'label': 'cancer', 'start_index': 26, 'end_index': 34, 'token': 'invasive'},
#   {'label': 'cancer',
#    'start_index': 35,
#    'end_index': 45,
#    'token': 'malignancy'},
#   {'label': 'cancer', 'start_index': 63, 'end_index': 71, 'token': 'prostate'},
#   {'label': 'cancer', 'start_index': 72, 'end_index': 78, 'token': 'cancer'},
#   {'label': 'cancer', 'start_index': 82, 'end_index': 87, 'token': 'basal'},
#   {'label': 'cancer', 'start_index': 91, 'end_index': 99, 'token': 'squamous'},
#   {'label': 'cancer', 'start_index': 100, 'end_index': 104, 'token': 'skin'},
#   {'label': 'cancer',
#    'start_index': 105,
#    'end_index': 112,
#    'token': 'cancers'},
#   {'label': 'upper_bound',
#    'start_index': 121,
#    'end_index': 126,
#    'token': 'prior'},
#   {'label': 'upper_bound', 'start_index': 5, 'end_index': 6, 'token': '5'},
#   {'label': 'upper_bound',
#    'start_index': 129,
#    'end_index': 134,
#    'token': 'years'}],
#  [{'label': 'cancer',
#    'start_index': 34,
#    'end_index': 44,
#    'token': 'pancreatic'},
#   {'label': 'cancer', 'start_index': 45, 'end_index': 51, 'token': 'cancer'},
#   {'label': 'cancer', 'start_index': 53, 'end_index': 59, 'token': 'distal'},
#   {'label': 'cancer', 'start_index': 60, 'end_index': 66, 'token': 'common'},
#   {'label': 'cancer', 'start_index': 67, 'end_index': 71, 'token': 'bile'},
#   {'label': 'cancer', 'start_index': 72, 'end_index': 76, 'token': 'duct'},
#   {'label': 'cancer', 'start_index': 77, 'end_index': 78, 'token': '('},
#   {'label': 'cancer', 'start_index': 78, 'end_index': 81, 'token': 'cbd'},
#   {'label': 'cancer', 'start_index': 81, 'end_index': 82, 'token': ')'},
#   {'label': 'cancer',
#    'start_index': 83,
#    'end_index': 101,
#    'token': 'cholangiocarcinoma'},
#   {'label': 'cancer',
#    'start_index': 112,
#    'end_index': 125,
#    'token': 'periampullary'},
#   {'label': 'cancer',
#    'start_index': 126,
#    'end_index': 133,
#    'token': 'cancers'}],
#  [{'label': 'chronic_disease',
#    'start_index': 24,
#    'end_index': 30,
#    'token': 'distal'},
#   {'label': 'chronic_disease',
#    'start_index': 31,
#    'end_index': 38,
#    'token': 'biliary'},
#   {'label': 'chronic_disease',
#    'start_index': 39,
#    'end_index': 50,
#    'token': 'obstruction'},
#   {'label': 'treatment',
#    'start_index': 101,
#    'end_index': 106,
#    'token': 'stent'},
#   {'label': 'lower_bound',
#    'start_index': 133,
#    'end_index': 136,
#    'token': '2cm'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01774019'},
#   {'label': 'cancer', 'start_index': 12, 'end_index': 19, 'token': 'biliary'},
#   {'label': 'cancer',
#    'start_index': 20,
#    'end_index': 30,
#    'token': 'strictures'},
#   {'label': 'cancer',
#    'start_index': 41,
#    'end_index': 53,
#    'token': 'malignancies'},
#   {'label': 'cancer',
#    'start_index': 65,
#    'end_index': 75,
#    'token': 'pancreatic'},
#   {'label': 'cancer', 'start_index': 76, 'end_index': 82, 'token': 'cancer'},
#   {'label': 'cancer', 'start_index': 84, 'end_index': 90, 'token': 'distal'},
#   {'label': 'cancer', 'start_index': 91, 'end_index': 94, 'token': 'cbd'},
#   {'label': 'cancer',
#    'start_index': 95,
#    'end_index': 113,
#    'token': 'cholangiocarcinoma'},
#   {'label': 'cancer',
#    'start_index': 124,
#    'end_index': 137,
#    'token': 'periampullary'},
#   {'label': 'cancer',
#    'start_index': 138,
#    'end_index': 145,
#    'token': 'cancers'}],
#  [{'label': 'treatment', 'start_index': 92, 'end_index': 94, 'token': 'tb'},
#   {'label': 'treatment',
#    'start_index': 109,
#    'end_index': 118,
#    'token': 'treatment'},
#   {'label': 'chronic_disease',
#    'start_index': 123,
#    'end_index': 129,
#    'token': 'latent'},
#   {'label': 'chronic_disease',
#    'start_index': 130,
#    'end_index': 142,
#    'token': 'tuberculosis'},
#   {'label': 'treatment',
#    'start_index': 109,
#    'end_index': 118,
#    'token': 'treatment'},
#   {'label': 'treatment',
#    'start_index': 171,
#    'end_index': 175,
#    'token': 'with'},
#   {'label': 'treatment', 'start_index': 176, 'end_index': 179, 'token': 'the'},
#   {'label': 'treatment', 'start_index': 82, 'end_index': 86, 'token': 'anti'},
#   {'label': 'treatment', 'start_index': 185, 'end_index': 188, 'token': 'tnf'},
#   {'label': 'treatment',
#    'start_index': 189,
#    'end_index': 194,
#    'token': 'agent'}],
#  [{'label': 'chronic_disease',
#    'start_index': 49,
#    'end_index': 58,
#    'token': 'hepatitis'},
#   {'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 14,
#    'token': 'b'},
#   {'label': 'treatment',
#    'start_index': 98,
#    'end_index': 107,
#    'token': 'treatment'},
#   {'label': 'chronic_disease',
#    'start_index': 112,
#    'end_index': 119,
#    'token': 'chronic'},
#   {'label': 'chronic_disease',
#    'start_index': 49,
#    'end_index': 58,
#    'token': 'hepatitis'},
#   {'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 14,
#    'token': 'b'},
#   {'label': 'treatment',
#    'start_index': 147,
#    'end_index': 158,
#    'token': 'suppressive'},
#   {'label': 'treatment',
#    'start_index': 159,
#    'end_index': 168,
#    'token': 'antiviral'},
#   {'label': 'treatment',
#    'start_index': 98,
#    'end_index': 107,
#    'token': 'treatment'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01794793'},
#   {'label': 'treatment',
#    'start_index': 87,
#    'end_index': 98,
#    'token': 'pasireotide'},
#   {'label': 'treatment',
#    'start_index': 120,
#    'end_index': 131,
#    'token': 'monotherapy'},
#   {'label': 'treatment',
#    'start_index': 135,
#    'end_index': 146,
#    'token': 'combination'},
#   {'label': 'treatment',
#    'start_index': 124,
#    'end_index': 131,
#    'token': 'therapy'},
#   {'label': 'chronic_disease',
#    'start_index': 160,
#    'end_index': 167,
#    'token': 'cushing'},
#   {'label': 'chronic_disease',
#    'start_index': 167,
#    'end_index': 168,
#    'token': "'"},
#   {'label': 'chronic_disease',
#    'start_index': 170,
#    'end_index': 177,
#    'token': 'disease'},
#   {'label': 'treatment',
#    'start_index': 181,
#    'end_index': 191,
#    'token': 'acromegaly'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01794793'},
#   {'label': 'contraception_consent',
#    'start_index': 12,
#    'end_index': 15,
#    'token': 'use'},
#   {'label': 'contraception_consent',
#    'start_index': 16,
#    'end_index': 18,
#    'token': 'of'},
#   {'label': 'contraception_consent',
#    'start_index': 19,
#    'end_index': 23,
#    'token': 'oral'},
#   {'label': 'contraception_consent',
#    'start_index': 23,
#    'end_index': 24,
#    'token': ','},
#   {'label': 'contraception_consent',
#    'start_index': 25,
#    'end_index': 33,
#    'token': 'injected'},
#   {'label': 'contraception_consent',
#    'start_index': 19,
#    'end_index': 21,
#    'token': 'or'},
#   {'label': 'contraception_consent',
#    'start_index': 37,
#    'end_index': 46,
#    'token': 'implanted'},
#   {'label': 'contraception_consent',
#    'start_index': 47,
#    'end_index': 55,
#    'token': 'hormonal'},
#   {'label': 'contraception_consent',
#    'start_index': 56,
#    'end_index': 63,
#    'token': 'methods'},
#   {'label': 'contraception_consent',
#    'start_index': 16,
#    'end_index': 18,
#    'token': 'of'},
#   {'label': 'contraception_consent',
#    'start_index': 67,
#    'end_index': 80,
#    'token': 'contraception'},
#   {'label': 'contraception_consent',
#    'start_index': 19,
#    'end_index': 21,
#    'token': 'or'},
#   {'label': 'contraception_consent',
#    'start_index': 84,
#    'end_index': 93,
#    'token': 'placement'},
#   {'label': 'contraception_consent',
#    'start_index': 16,
#    'end_index': 18,
#    'token': 'of'},
#   {'label': 'contraception_consent',
#    'start_index': 41,
#    'end_index': 43,
#    'token': 'an'},
#   {'label': 'contraception_consent',
#    'start_index': 100,
#    'end_index': 112,
#    'token': 'intrauterine'},
#   {'label': 'contraception_consent',
#    'start_index': 113,
#    'end_index': 119,
#    'token': 'device'},
#   {'label': 'contraception_consent',
#    'start_index': 120,
#    'end_index': 121,
#    'token': '('},
#   {'label': 'contraception_consent',
#    'start_index': 121,
#    'end_index': 124,
#    'token': 'iud'},
#   {'label': 'contraception_consent',
#    'start_index': 124,
#    'end_index': 125,
#    'token': ')'},
#   {'label': 'contraception_consent',
#    'start_index': 19,
#    'end_index': 21,
#    'token': 'or'},
#   {'label': 'contraception_consent',
#    'start_index': 100,
#    'end_index': 112,
#    'token': 'intrauterine'},
#   {'label': 'contraception_consent',
#    'start_index': 142,
#    'end_index': 148,
#    'token': 'system'},
#   {'label': 'contraception_consent',
#    'start_index': 120,
#    'end_index': 121,
#    'token': '('},
#   {'label': 'contraception_consent',
#    'start_index': 150,
#    'end_index': 153,
#    'token': 'ius'},
#   {'label': 'contraception_consent',
#    'start_index': 124,
#    'end_index': 125,
#    'token': ')'},
#   {'label': 'contraception_consent',
#    'start_index': 16,
#    'end_index': 18,
#    'token': 'of'},
#   {'label': 'contraception_consent',
#    'start_index': 47,
#    'end_index': 55,
#    'token': 'hormonal'},
#   {'label': 'contraception_consent',
#    'start_index': 67,
#    'end_index': 80,
#    'token': 'contraception'},
#   {'label': 'clinical_variable',
#    'start_index': 228,
#    'end_index': 235,
#    'token': 'failure'},
#   {'label': 'clinical_variable',
#    'start_index': 236,
#    'end_index': 240,
#    'token': 'rate'},
#   {'label': 'upper_bound', 'start_index': 4, 'end_index': 5, 'token': '1'},
#   {'label': 'upper_bound', 'start_index': 243, 'end_index': 244, 'token': '%'},
#   {'label': 'contraception_consent',
#    'start_index': 259,
#    'end_index': 266,
#    'token': 'hormone'},
#   {'label': 'contraception_consent',
#    'start_index': 267,
#    'end_index': 274,
#    'token': 'vaginal'},
#   {'label': 'contraception_consent',
#    'start_index': 275,
#    'end_index': 279,
#    'token': 'ring'},
#   {'label': 'contraception_consent',
#    'start_index': 283,
#    'end_index': 294,
#    'token': 'transdermal'},
#   {'label': 'contraception_consent',
#    'start_index': 259,
#    'end_index': 266,
#    'token': 'hormone'},
#   {'label': 'contraception_consent',
#    'start_index': 67,
#    'end_index': 80,
#    'token': 'contraception'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01801072'},
#   {'label': 'treatment',
#    'start_index': 45,
#    'end_index': 53,
#    'token': 'surgical'},
#   {'label': 'treatment',
#    'start_index': 54,
#    'end_index': 60,
#    'token': 'repair'},
#   {'label': 'chronic_disease',
#    'start_index': 68,
#    'end_index': 76,
#    'token': 'aneurysm'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01801072'},
#   {'label': 'chronic_disease',
#    'start_index': 24,
#    'end_index': 36,
#    'token': 'intracranial'},
#   {'label': 'chronic_disease',
#    'start_index': 37,
#    'end_index': 45,
#    'token': 'aneurysm'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01807897'},
#   {'label': 'chronic_disease',
#    'start_index': 18,
#    'end_index': 24,
#    'token': 'stroke'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 40,
#    'token': 'functional'},
#   {'label': 'chronic_disease',
#    'start_index': 41,
#    'end_index': 51,
#    'token': 'impairment'}],
#  [{'label': 'clinical_variable',
#    'start_index': 50,
#    'end_index': 57,
#    'token': 'epworth'},
#   {'label': 'clinical_variable',
#    'start_index': 69,
#    'end_index': 74,
#    'token': 'scale'},
#   {'label': 'clinical_variable',
#    'start_index': 75,
#    'end_index': 80,
#    'token': 'score'},
#   {'label': 'lower_bound', 'start_index': 4, 'end_index': 6, 'token': '18'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01807897'},
#   {'label': 'treatment',
#    'start_index': 29,
#    'end_index': 37,
#    'token': 'positive'},
#   {'label': 'treatment',
#    'start_index': 38,
#    'end_index': 44,
#    'token': 'airway'},
#   {'label': 'treatment',
#    'start_index': 45,
#    'end_index': 53,
#    'token': 'pressure'},
#   {'label': 'treatment',
#    'start_index': 54,
#    'end_index': 60,
#    'token': 'device'},
#   {'label': 'treatment', 'start_index': 88, 'end_index': 89, 'token': '-'},
#   {'label': 'treatment',
#    'start_index': 123,
#    'end_index': 131,
#    'token': 'adaptive'},
#   {'label': 'treatment',
#    'start_index': 132,
#    'end_index': 137,
#    'token': 'servo'},
#   {'label': 'treatment', 'start_index': 88, 'end_index': 89, 'token': '-'},
#   {'label': 'treatment',
#    'start_index': 138,
#    'end_index': 149,
#    'token': 'ventilation'},
#   {'label': 'treatment',
#    'start_index': 154,
#    'end_index': 166,
#    'token': 'supplemental'},
#   {'label': 'treatment',
#    'start_index': 167,
#    'end_index': 173,
#    'token': 'oxygen'},
#   {'label': 'treatment',
#    'start_index': 174,
#    'end_index': 181,
#    'token': 'therapy'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01912651'},
#   {'label': 'upper_bound', 'start_index': 38, 'end_index': 41, 'token': 'one'},
#   {'label': 'upper_bound',
#    'start_index': 42,
#    'end_index': 46,
#    'token': 'week'},
#   {'label': 'treatment',
#    'start_index': 50,
#    'end_index': 57,
#    'token': 'surgery'},
#   {'label': 'treatment',
#    'start_index': 59,
#    'end_index': 67,
#    'token': 'systemic'},
#   {'label': 'treatment',
#    'start_index': 68,
#    'end_index': 78,
#    'token': 'antibiotic'},
#   {'label': 'treatment',
#    'start_index': 104,
#    'end_index': 115,
#    'token': 'clindamycin'},
#   {'label': 'treatment',
#    'start_index': 120,
#    'end_index': 130,
#    'token': 'cephalexin'},
#   {'label': 'cancer',
#    'start_index': 158,
#    'end_index': 167,
#    'token': 'cutaneous'},
#   {'label': 'cancer',
#    'start_index': 168,
#    'end_index': 178,
#    'token': 'malignancy'},
#   {'label': 'treatment',
#    'start_index': 219,
#    'end_index': 233,
#    'token': 'reconstructive'},
#   {'label': 'treatment',
#    'start_index': 234,
#    'end_index': 243,
#    'token': 'procedure'},
#   {'label': 'treatment',
#    'start_index': 248,
#    'end_index': 256,
#    'token': 'previous'},
#   {'label': 'treatment',
#    'start_index': 257,
#    'end_index': 271,
#    'token': 'reconstruction'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01912651'},
#   {'label': 'treatment',
#    'start_index': 129,
#    'end_index': 133,
#    'token': 'full'},
#   {'label': 'treatment', 'start_index': 133, 'end_index': 134, 'token': '-'},
#   {'label': 'treatment',
#    'start_index': 134,
#    'end_index': 143,
#    'token': 'thickness'},
#   {'label': 'treatment',
#    'start_index': 149,
#    'end_index': 154,
#    'token': 'graft'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01959425'},
#   {'label': 'chronic_disease',
#    'start_index': 36,
#    'end_index': 38,
#    'token': 'af'},
#   {'label': 'chronic_disease',
#    'start_index': 79,
#    'end_index': 89,
#    'token': 'arrhythmic'},
#   {'label': 'lower_bound',
#    'start_index': 122,
#    'end_index': 124,
#    'token': '30'},
#   {'label': 'upper_bound',
#    'start_index': 125,
#    'end_index': 132,
#    'token': 'seconds'},
#   {'label': 'upper_bound', 'start_index': 122, 'end_index': 123, 'token': '3'},
#   {'label': 'upper_bound',
#    'start_index': 136,
#    'end_index': 142,
#    'token': 'months'},
#   {'label': 'treatment',
#    'start_index': 160,
#    'end_index': 167,
#    'token': 'cardiac'},
#   {'label': 'treatment',
#    'start_index': 168,
#    'end_index': 176,
#    'token': 'ablation'},
#   {'label': 'upper_bound', 'start_index': 122, 'end_index': 123, 'token': '3'},
#   {'label': 'upper_bound', 'start_index': 200, 'end_index': 201, 'token': '-'},
#   {'label': 'upper_bound',
#    'start_index': 136,
#    'end_index': 141,
#    'token': 'month'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01959425'},
#   {'label': 'treatment',
#    'start_index': 16,
#    'end_index': 23,
#    'token': 'cardiac'},
#   {'label': 'treatment',
#    'start_index': 24,
#    'end_index': 31,
#    'token': 'surgery'},
#   {'label': 'upper_bound',
#    'start_index': 43,
#    'end_index': 47,
#    'token': 'past'},
#   {'label': 'upper_bound', 'start_index': 48, 'end_index': 50, 'token': '60'},
#   {'label': 'upper_bound',
#    'start_index': 51,
#    'end_index': 55,
#    'token': 'days'},
#   {'label': 'upper_bound', 'start_index': 56, 'end_index': 57, 'token': '('},
#   {'label': 'upper_bound', 'start_index': 9, 'end_index': 10, 'token': '2'},
#   {'label': 'upper_bound',
#    'start_index': 59,
#    'end_index': 65,
#    'token': 'months'},
#   {'label': 'treatment',
#    'start_index': 70,
#    'end_index': 78,
#    'token': 'valvular'},
#   {'label': 'treatment',
#    'start_index': 16,
#    'end_index': 23,
#    'token': 'cardiac'},
#   {'label': 'treatment',
#    'start_index': 87,
#    'end_index': 95,
#    'token': 'surgical'},
#   {'label': 'treatment',
#    'start_index': 96,
#    'end_index': 105,
#    'token': 'procedure'},
#   {'label': 'treatment',
#    'start_index': 125,
#    'end_index': 139,
#    'token': 'ventriculotomy'},
#   {'label': 'treatment',
#    'start_index': 141,
#    'end_index': 150,
#    'token': 'atriotomy'},
#   {'label': 'treatment',
#    'start_index': 156,
#    'end_index': 161,
#    'token': 'valve'},
#   {'label': 'treatment',
#    'start_index': 162,
#    'end_index': 168,
#    'token': 'repair'},
#   {'label': 'treatment',
#    'start_index': 172,
#    'end_index': 183,
#    'token': 'replacement'},
#   {'label': 'treatment',
#    'start_index': 202,
#    'end_index': 212,
#    'token': 'prosthetic'},
#   {'label': 'treatment',
#    'start_index': 156,
#    'end_index': 161,
#    'token': 'valve'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01959425'},
#   {'label': 'chronic_disease',
#    'start_index': 52,
#    'end_index': 54,
#    'token': 'af'},
#   {'label': 'chronic_disease',
#    'start_index': 62,
#    'end_index': 72,
#    'token': 'prosthetic'},
#   {'label': 'treatment', 'start_index': 73, 'end_index': 78, 'token': 'valve'},
#   {'label': 'chronic_disease',
#    'start_index': 80,
#    'end_index': 82,
#    'token': 'pv'},
#   {'label': 'chronic_disease',
#    'start_index': 83,
#    'end_index': 91,
#    'token': 'stenosis'},
#   {'label': 'chronic_disease',
#    'start_index': 102,
#    'end_index': 111,
#    'token': 'pulmonary'},
#   {'label': 'chronic_disease',
#    'start_index': 112,
#    'end_index': 120,
#    'token': 'embolism'},
#   {'label': 'upper_bound', 'start_index': 196, 'end_index': 197, 'token': '3'},
#   {'label': 'upper_bound', 'start_index': 197, 'end_index': 198, 'token': '-'},
#   {'label': 'upper_bound',
#    'start_index': 198,
#    'end_index': 204,
#    'token': 'months'}],
#  [{'label': 'cancer', 'start_index': 35, 'end_index': 37, 'token': 'fl'},
#   {'label': 'cancer', 'start_index': 38, 'end_index': 43, 'token': 'grade'},
#   {'label': 'cancer', 'start_index': 4, 'end_index': 5, 'token': '1'},
#   {'label': 'cancer', 'start_index': 46, 'end_index': 48, 'token': '3a'},
#   {'label': 'cancer', 'start_index': 49, 'end_index': 53, 'token': 'inhl'},
#   {'label': 'cancer', 'start_index': 106, 'end_index': 109, 'token': 'lpl'},
#   {'label': 'cancer', 'start_index': 110, 'end_index': 112, 'token': 'wm'},
#   {'label': 'cancer', 'start_index': 114, 'end_index': 117, 'token': 'mzl'},
#   {'label': 'cancer', 'start_index': 120, 'end_index': 124, 'token': 'anhl'},
#   {'label': 'cancer', 'start_index': 137, 'end_index': 142, 'token': 'dlbcl'},
#   {'label': 'cancer', 'start_index': 153, 'end_index': 155, 'token': '3b'},
#   {'label': 'cancer', 'start_index': 157, 'end_index': 160, 'token': 'mcl'},
#   {'label': 'cancer', 'start_index': 50, 'end_index': 53, 'token': 'nhl'},
#   {'label': 'cancer', 'start_index': 205, 'end_index': 208, 'token': 'cll'},
#   {'label': 'cancer', 'start_index': 209, 'end_index': 212, 'token': 'sll'},
#   {'label': 'cancer', 'start_index': 214, 'end_index': 218, 'token': 'ptcl'}],
#  [{'label': 'clinical_variable',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01994382'},
#   {'label': 'lower_bound', 'start_index': 4, 'end_index': 5, 'token': '1'},
#   {'label': 'lower_bound',
#    'start_index': 48,
#    'end_index': 54,
#    'token': 'lesion'},
#   {'label': 'lower_bound', 'start_index': 4, 'end_index': 5, 'token': '1'},
#   {'label': 'lower_bound', 'start_index': 58, 'end_index': 59, 'token': '.'},
#   {'label': 'lower_bound', 'start_index': 59, 'end_index': 60, 'token': '5'},
#   {'label': 'lower_bound', 'start_index': 61, 'end_index': 63, 'token': 'cm'},
#   {'label': 'lower_bound',
#    'start_index': 64,
#    'end_index': 70,
#    'token': 'single'},
#   {'label': 'lower_bound',
#    'start_index': 71,
#    'end_index': 80,
#    'token': 'dimension'},
#   {'label': 'treatment', 'start_index': 1, 'end_index': 3, 'token': 'ct'},
#   {'label': 'treatment', 'start_index': 1, 'end_index': 3, 'token': 'ct'},
#   {'label': 'cancer', 'start_index': 110, 'end_index': 114, 'token': 'mass'},
#   {'label': 'cancer', 'start_index': 149, 'end_index': 154, 'token': 'tumor'},
#   {'label': 'chronic_disease',
#    'start_index': 180,
#    'end_index': 181,
#    'token': "'"},
#   {'label': 'chronic_disease',
#    'start_index': 15,
#    'end_index': 16,
#    'token': 's'},
#   {'label': 'cancer',
#    'start_index': 183,
#    'end_index': 200,
#    'token': 'macroglobulinemia'},
#   {'label': 'clinical_variable',
#    'start_index': 213,
#    'end_index': 216,
#    'token': 'igm'},
#   {'label': 'clinical_variable',
#    'start_index': 21,
#    'end_index': 22,
#    'token': 'l'},
#   {'label': 'lower_bound',
#    'start_index': 221,
#    'end_index': 223,
#    'token': '2x'},
#   {'label': 'lower_bound',
#    'start_index': 224,
#    'end_index': 227,
#    'token': 'uln'},
#   {'label': 'clinical_variable',
#    'start_index': 239,
#    'end_index': 244,
#    'token': 'mswat'},
#   {'label': 'lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01994382'},
#   {'label': 'treatment', 'start_index': 12, 'end_index': 17, 'token': 'prior'},
#   {'label': 'treatment',
#    'start_index': 18,
#    'end_index': 28,
#    'token': 'monoclonal'},
#   {'label': 'treatment',
#    'start_index': 29,
#    'end_index': 37,
#    'token': 'antibody'},
#   {'label': 'treatment',
#    'start_index': 39,
#    'end_index': 59,
#    'token': 'radioimmunoconjugate'},
#   {'label': 'treatment',
#    'start_index': 29,
#    'end_index': 37,
#    'token': 'antibody'},
#   {'label': 'treatment', 'start_index': 70, 'end_index': 74, 'token': 'drug'},
#   {'label': 'treatment',
#    'start_index': 50,
#    'end_index': 59,
#    'token': 'conjugate'},
#   {'label': 'treatment',
#    'start_index': 86,
#    'end_index': 98,
#    'token': 'phototherapy'},
#   {'label': 'treatment',
#    'start_index': 100,
#    'end_index': 112,
#    'token': 'radiotherapy'},
#   {'label': 'treatment',
#    'start_index': 114,
#    'end_index': 126,
#    'token': 'chemotherapy'},
#   {'label': 'treatment',
#    'start_index': 128,
#    'end_index': 141,
#    'token': 'immunotherapy'},
#   {'label': 'treatment',
#    'start_index': 143,
#    'end_index': 160,
#    'token': 'immunosuppressive'},
#   {'label': 'treatment',
#    'start_index': 91,
#    'end_index': 98,
#    'token': 'therapy'},
#   {'label': 'upper_bound', 'start_index': 8, 'end_index': 9, 'token': '3'},
#   {'label': 'upper_bound',
#    'start_index': 197,
#    'end_index': 202,
#    'token': 'weeks'},
#   {'label': 'treatment',
#    'start_index': 210,
#    'end_index': 221,
#    'token': 'alemtuzumab'},
#   {'label': 'upper_bound',
#    'start_index': 197,
#    'end_index': 202,
#    'token': 'weeks'}],
#  [{'label': 'age', 'start_index': 27, 'end_index': 30, 'token': 'age'},
#   {'label': 'lower_bound', 'start_index': 31, 'end_index': 33, 'token': '18'},
#   {'label': 'upper_bound', 'start_index': 34, 'end_index': 36, 'token': '80'},
#   {'label': 'upper_bound',
#    'start_index': 37,
#    'end_index': 42,
#    'token': 'years'},
#   {'label': 'chronic_disease',
#    'start_index': 53,
#    'end_index': 61,
#    'token': 'ruptured'},
#   {'label': 'chronic_disease',
#    'start_index': 62,
#    'end_index': 70,
#    'token': 'aneurysm'},
#   {'label': 'chronic_disease',
#    'start_index': 70,
#    'end_index': 71,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 41,
#    'end_index': 42,
#    'token': 's'},
#   {'label': 'chronic_disease',
#    'start_index': 72,
#    'end_index': 73,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 89,
#    'end_index': 97,
#    'token': 'cerebral'},
#   {'label': 'chronic_disease',
#    'start_index': 98,
#    'end_index': 107,
#    'token': 'vasospasm'},
#   {'label': 'lower_bound', 'start_index': 9, 'end_index': 10, 'token': '3'},
#   {'label': 'upper_bound',
#    'start_index': 134,
#    'end_index': 136,
#    'token': '21'},
#   {'label': 'upper_bound',
#    'start_index': 137,
#    'end_index': 141,
#    'token': 'days'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct01996436'},
#   {'label': 'chronic_disease',
#    'start_index': 17,
#    'end_index': 21,
#    'token': 'hess'},
#   {'label': 'cancer', 'start_index': 22, 'end_index': 27, 'token': 'grade'},
#   {'label': 'chronic_disease',
#    'start_index': 28,
#    'end_index': 29,
#    'token': '5'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 33,
#    'token': 'sah'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02046395'},
#   {'label': 'treatment', 'start_index': 19, 'end_index': 22, 'token': 'ace'},
#   {'label': 'treatment', 'start_index': 23, 'end_index': 26, 'token': 'inh'},
#   {'label': 'treatment', 'start_index': 31, 'end_index': 34, 'token': 'arb'},
#   {'label': 'treatment', 'start_index': 111, 'end_index': 112, 'token': '('}],
#  [{'label': 'chronic_disease',
#    'start_index': 26,
#    'end_index': 33,
#    'token': 'chronic'},
#   {'label': 'chronic_disease',
#    'start_index': 34,
#    'end_index': 40,
#    'token': 'kidney'},
#   {'label': 'chronic_disease',
#    'start_index': 41,
#    'end_index': 48,
#    'token': 'disease'},
#   {'label': 'clinical_variable',
#    'start_index': 60,
#    'end_index': 64,
#    'token': 'egfr'},
#   {'label': 'upper_bound', 'start_index': 67, 'end_index': 69, 'token': '30'},
#   {'label': 'upper_bound', 'start_index': 70, 'end_index': 72, 'token': 'ml'},
#   {'label': 'upper_bound', 'start_index': 72, 'end_index': 73, 'token': '/'},
#   {'label': 'upper_bound', 'start_index': 73, 'end_index': 76, 'token': 'min'},
#   {'label': 'clinical_variable',
#    'start_index': 78,
#    'end_index': 81,
#    'token': 'ckd'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02046395'},
#   {'label': 'allergy_name',
#    'start_index': 76,
#    'end_index': 79,
#    'token': 'ace'},
#   {'label': 'allergy_name',
#    'start_index': 80,
#    'end_index': 83,
#    'token': 'inh'},
#   {'label': 'allergy_name',
#    'start_index': 87,
#    'end_index': 90,
#    'token': 'arb'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02053246'},
#   {'label': 'chronic_disease',
#    'start_index': 51,
#    'end_index': 60,
#    'token': 'pulmonary'},
#   {'label': 'chronic_disease',
#    'start_index': 61,
#    'end_index': 73,
#    'token': 'hypertension'},
#   {'label': 'clinical_variable',
#    'start_index': 75,
#    'end_index': 79,
#    'token': 'mean'},
#   {'label': 'chronic_disease',
#    'start_index': 51,
#    'end_index': 60,
#    'token': 'pulmonary'},
#   {'label': 'clinical_variable',
#    'start_index': 90,
#    'end_index': 96,
#    'token': 'artery'},
#   {'label': 'clinical_variable',
#    'start_index': 97,
#    'end_index': 105,
#    'token': 'pressure'},
#   {'label': 'lower_bound',
#    'start_index': 108,
#    'end_index': 110,
#    'token': '25'},
#   {'label': 'lower_bound',
#    'start_index': 111,
#    'end_index': 115,
#    'token': 'mmhg'},
#   {'label': 'chronic_disease',
#    'start_index': 51,
#    'end_index': 60,
#    'token': 'pulmonary'},
#   {'label': 'clinical_variable',
#    'start_index': 130,
#    'end_index': 139,
#    'token': 'capillary'},
#   {'label': 'clinical_variable',
#    'start_index': 140,
#    'end_index': 145,
#    'token': 'wedge'},
#   {'label': 'clinical_variable',
#    'start_index': 97,
#    'end_index': 105,
#    'token': 'pressure'},
#   {'label': 'lower_bound',
#    'start_index': 157,
#    'end_index': 159,
#    'token': '15'},
#   {'label': 'lower_bound',
#    'start_index': 111,
#    'end_index': 115,
#    'token': 'mmhg'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02053246'},
#   {'label': 'chronic_disease',
#    'start_index': 28,
#    'end_index': 33,
#    'token': 'heart'},
#   {'label': 'chronic_disease',
#    'start_index': 34,
#    'end_index': 41,
#    'token': 'failure'},
#   {'label': 'chronic_disease',
#    'start_index': 53,
#    'end_index': 62,
#    'token': 'diastolic'},
#   {'label': 'chronic_disease',
#    'start_index': 63,
#    'end_index': 74,
#    'token': 'dysfunction'},
#   {'label': 'chronic_disease',
#    'start_index': 84,
#    'end_index': 95,
#    'token': 'restrictive'},
#   {'label': 'chronic_disease',
#    'start_index': 96,
#    'end_index': 110,
#    'token': 'cardiomyopathy'},
#   {'label': 'chronic_disease',
#    'start_index': 114,
#    'end_index': 126,
#    'token': 'infiltrative'},
#   {'label': 'chronic_disease',
#    'start_index': 96,
#    'end_index': 110,
#    'token': 'cardiomyopathy'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02053246'},
#   {'label': 'chronic_disease',
#    'start_index': 22,
#    'end_index': 24,
#    'token': 'ph'},
#   {'label': 'chronic_disease',
#    'start_index': 44,
#    'end_index': 49,
#    'token': 'heart'},
#   {'label': 'chronic_disease',
#    'start_index': 50,
#    'end_index': 57,
#    'token': 'failure'},
#   {'label': 'chronic_disease',
#    'start_index': 68,
#    'end_index': 75,
#    'token': 'chronic'},
#   {'label': 'chronic_disease',
#    'start_index': 76,
#    'end_index': 90,
#    'token': 'thromboembolic'},
#   {'label': 'chronic_disease',
#    'start_index': 22,
#    'end_index': 24,
#    'token': 'ph'},
#   {'label': 'chronic_disease',
#    'start_index': 95,
#    'end_index': 101,
#    'token': 'sickle'},
#   {'label': 'chronic_disease',
#    'start_index': 101,
#    'end_index': 102,
#    'token': '-'},
#   {'label': 'chronic_disease',
#    'start_index': 102,
#    'end_index': 106,
#    'token': 'cell'},
#   {'label': 'chronic_disease',
#    'start_index': 107,
#    'end_index': 114,
#    'token': 'disease'},
#   {'label': 'chronic_disease',
#    'start_index': 119,
#    'end_index': 130,
#    'token': 'sarcoidosis'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02055053'},
#   {'label': 'treatment',
#    'start_index': 41,
#    'end_index': 49,
#    'token': 'inguinal'},
#   {'label': 'treatment', 'start_index': 50, 'end_index': 55, 'token': 'herna'},
#   {'label': 'treatment',
#    'start_index': 60,
#    'end_index': 72,
#    'token': 'laparoscopic'},
#   {'label': 'treatment',
#    'start_index': 73,
#    'end_index': 79,
#    'token': 'repair'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02055053'},
#   {'label': 'chronic_disease',
#    'start_index': 23,
#    'end_index': 30,
#    'token': 'chronic'},
#   {'label': 'chronic_disease',
#    'start_index': 31,
#    'end_index': 35,
#    'token': 'pain'},
#   {'label': 'treatment',
#    'start_index': 47,
#    'end_index': 56,
#    'token': 'treatment'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02055053'},
#   {'label': 'treatment',
#    'start_index': 28,
#    'end_index': 40,
#    'token': 'laparoscopic'},
#   {'label': 'treatment', 'start_index': 44, 'end_index': 48, 'token': 'open'},
#   {'label': 'treatment',
#    'start_index': 49,
#    'end_index': 56,
#    'token': 'surgery'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02056288'},
#   {'label': 'treatment',
#    'start_index': 33,
#    'end_index': 42,
#    'token': 'reduction'},
#   {'label': 'treatment',
#    'start_index': 48,
#    'end_index': 60,
#    'token': 'percutaneous'},
#   {'label': 'treatment',
#    'start_index': 61,
#    'end_index': 68,
#    'token': 'pinning'},
#   {'label': 'treatment',
#    'start_index': 75,
#    'end_index': 82,
#    'token': 'general'},
#   {'label': 'treatment',
#    'start_index': 83,
#    'end_index': 93,
#    'token': 'anesthesia'}],
#  [{'label': 'clinical_variable',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02101554'},
#   {'label': 'clinical_variable',
#    'start_index': 12,
#    'end_index': 20,
#    'token': 'columbia'},
#   {'label': 'clinical_variable',
#    'start_index': 20,
#    'end_index': 21,
#    'token': '-'},
#   {'label': 'clinical_variable',
#    'start_index': 21,
#    'end_index': 28,
#    'token': 'suicide'},
#   {'label': 'clinical_variable',
#    'start_index': 29,
#    'end_index': 37,
#    'token': 'severity'},
#   {'label': 'clinical_variable',
#    'start_index': 38,
#    'end_index': 44,
#    'token': 'rating'},
#   {'label': 'clinical_variable',
#    'start_index': 45,
#    'end_index': 50,
#    'token': 'scale'},
#   {'label': 'clinical_variable',
#    'start_index': 51,
#    'end_index': 52,
#    'token': '('},
#   {'label': 'clinical_variable',
#    'start_index': 1,
#    'end_index': 2,
#    'token': 'c'},
#   {'label': 'clinical_variable',
#    'start_index': 20,
#    'end_index': 21,
#    'token': '-'},
#   {'label': 'clinical_variable',
#    'start_index': 54,
#    'end_index': 58,
#    'token': 'ssrs'},
#   {'label': 'clinical_variable',
#    'start_index': 58,
#    'end_index': 59,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 64,
#    'end_index': 72,
#    'token': 'suicidal'},
#   {'label': 'chronic_disease',
#    'start_index': 73,
#    'end_index': 81,
#    'token': 'ideation'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02101554'},
#   {'label': 'treatment',
#    'start_index': 68,
#    'end_index': 77,
#    'token': 'treatment'},
#   {'label': 'treatment',
#    'start_index': 86,
#    'end_index': 92,
#    'token': 'opioid'},
#   {'label': 'treatment',
#    'start_index': 93,
#    'end_index': 102,
#    'token': 'analgesic'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02106598'},
#   {'label': 'clinical_variable',
#    'start_index': 59,
#    'end_index': 68,
#    'token': 'bilirubin'},
#   {'label': 'clinical_variable',
#    'start_index': 69,
#    'end_index': 74,
#    'token': 'level'},
#   {'label': 'upper_bound', 'start_index': 4, 'end_index': 5, 'token': '2'},
#   {'label': 'upper_bound', 'start_index': 81, 'end_index': 82, 'token': '.'},
#   {'label': 'upper_bound', 'start_index': 3, 'end_index': 4, 'token': '0'},
#   {'label': 'upper_bound', 'start_index': 84, 'end_index': 86, 'token': 'mg'},
#   {'label': 'upper_bound', 'start_index': 86, 'end_index': 87, 'token': '/'},
#   {'label': 'upper_bound', 'start_index': 87, 'end_index': 89, 'token': 'dl'},
#   {'label': 'chronic_disease',
#    'start_index': 121,
#    'end_index': 128,
#    'token': 'gilbert'},
#   {'label': 'chronic_disease',
#    'start_index': 128,
#    'end_index': 129,
#    'token': "'"},
#   {'label': 'chronic_disease',
#    'start_index': 21,
#    'end_index': 22,
#    'token': 's'},
#   {'label': 'chronic_disease',
#    'start_index': 131,
#    'end_index': 138,
#    'token': 'disease'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02106598'},
#   {'label': 'cancer', 'start_index': 45, 'end_index': 50, 'token': 'tumor'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02106598'},
#   {'label': 'cancer',
#    'start_index': 28,
#    'end_index': 38,
#    'token': 'colorectal'},
#   {'label': 'cancer', 'start_index': 39, 'end_index': 45, 'token': 'cancer'},
#   {'label': 'treatment', 'start_index': 63, 'end_index': 66, 'token': 'sln'},
#   {'label': 'treatment',
#    'start_index': 67,
#    'end_index': 74,
#    'token': 'mapping'},
#   {'label': 'treatment', 'start_index': 79, 'end_index': 84, 'token': 'total'},
#   {'label': 'treatment',
#    'start_index': 85,
#    'end_index': 95,
#    'token': 'mesorectal'},
#   {'label': 'treatment',
#    'start_index': 96,
#    'end_index': 104,
#    'token': 'excision'},
#   {'label': 'treatment',
#    'start_index': 110,
#    'end_index': 117,
#    'token': 'lateral'},
#   {'label': 'treatment',
#    'start_index': 118,
#    'end_index': 124,
#    'token': 'pelvic'},
#   {'label': 'treatment',
#    'start_index': 125,
#    'end_index': 133,
#    'token': 'sidewall'},
#   {'label': 'treatment',
#    'start_index': 134,
#    'end_index': 144,
#    'token': 'dissection'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02109081'},
#   {'label': 'treatment',
#    'start_index': 25,
#    'end_index': 35,
#    'token': 'noncardiac'},
#   {'label': 'treatment',
#    'start_index': 36,
#    'end_index': 44,
#    'token': 'surgical'},
#   {'label': 'treatment',
#    'start_index': 45,
#    'end_index': 54,
#    'token': 'procedure'},
#   {'label': 'treatment',
#    'start_index': 61,
#    'end_index': 68,
#    'token': 'general'},
#   {'label': 'treatment',
#    'start_index': 69,
#    'end_index': 79,
#    'token': 'anesthesia'},
#   {'label': 'lower_bound', 'start_index': 4, 'end_index': 5, 'token': '2'},
#   {'label': 'lower_bound',
#    'start_index': 151,
#    'end_index': 155,
#    'token': 'days'}],
#  [{'label': 'clinical_variable',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02109081'},
#   {'label': 'clinical_variable',
#    'start_index': 12,
#    'end_index': 16,
#    'token': 'mmse'},
#   {'label': 'clinical_variable',
#    'start_index': 17,
#    'end_index': 22,
#    'token': 'score'},
#   {'label': 'upper_bound', 'start_index': 28, 'end_index': 30, 'token': '20'},
#   {'label': 'upper_bound', 'start_index': 38, 'end_index': 40, 'token': '30'},
#   {'label': 'chronic_disease',
#    'start_index': 76,
#    'end_index': 80,
#    'token': 'mild'},
#   {'label': 'chronic_disease',
#    'start_index': 81,
#    'end_index': 90,
#    'token': 'cognitive'},
#   {'label': 'chronic_disease',
#    'start_index': 91,
#    'end_index': 101,
#    'token': 'impairment'},
#   {'label': 'chronic_disease',
#    'start_index': 106,
#    'end_index': 114,
#    'token': 'delirium'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02164734'},
#   {'label': 'clinical_variable',
#    'start_index': 25,
#    'end_index': 30,
#    'token': 'nasal'},
#   {'label': 'clinical_variable',
#    'start_index': 31,
#    'end_index': 35,
#    'token': 'cpap'},
#   {'label': 'clinical_variable',
#    'start_index': 36,
#    'end_index': 46,
#    'token': 'modalities'},
#   {'label': 'lower_bound', 'start_index': 49, 'end_index': 50, 'token': '5'},
#   {'label': 'lower_bound', 'start_index': 51, 'end_index': 53, 'token': 'cm'},
#   {'label': 'lower_bound', 'start_index': 54, 'end_index': 57, 'token': 'h2o'},
#   {'label': 'clinical_variable',
#    'start_index': 62,
#    'end_index': 66,
#    'token': 'fio2'},
#   {'label': 'lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'},
#   {'label': 'lower_bound', 'start_index': 76, 'end_index': 77, 'token': '.'},
#   {'label': 'lower_bound', 'start_index': 77, 'end_index': 79, 'token': '30'},
#   {'label': 'lower_bound', 'start_index': 3, 'end_index': 4, 'token': '0'},
#   {'label': 'lower_bound', 'start_index': 76, 'end_index': 77, 'token': '.'},
#   {'label': 'lower_bound', 'start_index': 86, 'end_index': 88, 'token': '60'},
#   {'label': 'lower_bound', 'start_index': 4, 'end_index': 5, 'token': '2'},
#   {'label': 'lower_bound',
#    'start_index': 104,
#    'end_index': 109,
#    'token': 'hours'},
#   {'label': 'clinical_variable',
#    'start_index': 122,
#    'end_index': 126,
#    'token': 'spo2'},
#   {'label': 'lower_bound',
#    'start_index': 127,
#    'end_index': 129,
#    'token': '90'},
#   {'label': 'upper_bound',
#    'start_index': 130,
#    'end_index': 132,
#    'token': '95'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02164734'},
#   {'label': 'chronic_disease',
#    'start_index': 12,
#    'end_index': 24,
#    'token': 'craniofacial'},
#   {'label': 'chronic_disease',
#    'start_index': 28,
#    'end_index': 42,
#    'token': 'cardiothoracic'},
#   {'label': 'chronic_disease',
#    'start_index': 43,
#    'end_index': 56,
#    'token': 'malformations'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02167022'},
#   {'label': 'treatment',
#    'start_index': 70,
#    'end_index': 84,
#    'token': 'rehabilitation'},
#   {'label': 'treatment',
#    'start_index': 85,
#    'end_index': 94,
#    'token': 'therapies'},
#   {'label': 'chronic_disease',
#    'start_index': 257,
#    'end_index': 259,
#    'token': 'cp'},
#   {'label': 'cancer', 'start_index': 266, 'end_index': 272, 'token': 'cancer'},
#   {'label': 'cancer', 'start_index': 274, 'end_index': 280, 'token': 'cystic'},
#   {'label': 'chronic_disease',
#    'start_index': 281,
#    'end_index': 289,
#    'token': 'fibrosis'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02167022'},
#   {'label': 'chronic_disease',
#    'start_index': 65,
#    'end_index': 70,
#    'token': 'motor'},
#   {'label': 'upper_bound',
#    'start_index': 129,
#    'end_index': 132,
#    'token': 'one'},
#   {'label': 'upper_bound',
#    'start_index': 133,
#    'end_index': 137,
#    'token': 'year'},
#   {'label': 'age', 'start_index': 177, 'end_index': 180, 'token': 'age'}],
#  [{'label': 'treatment',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'nct02202369'},
#   {'label': 'chronic_disease',
#    'start_index': 26,
#    'end_index': 31,
#    'token': 'renal'},
#   {'label': 'chronic_disease',
#    'start_index': 32,
#    'end_index': 39,
#    'token': 'disease'},
#   {'label': 'clinical_variable',
#    'start_index': 52,
#    'end_index': 62,
# ...
#   {'label': 'treatment',
#    'start_index': 115,
#    'end_index': 119,
#    'token': '002a'}],
#  [{'label': 'chronic_disease',
#    'start_index': 7,
#    'end_index': 17,
#    'token': 'congenital'},
#   {'label': 'chronic_disease',
#    'start_index': 18,
#    'end_index': 31,
#    'token': 'abnormalities'}],
#  [{'label': 'cancer', 'start_index': 10, 'end_index': 13, 'token': 'hcc'},
#   {'label': 'treatment',
#    'start_index': 17,
#    'end_index': 23,
#    'token': 'biopsy'},
#   {'label': 'treatment', 'start_index': 27, 'end_index': 32, 'token': 'liver'},
#   {'label': 'treatment',
#    'start_index': 33,
#    'end_index': 41,
#    'token': 'protocol'},
#   {'label': 'treatment', 'start_index': 42, 'end_index': 44, 'token': 'ct'},
#   {'label': 'treatment', 'start_index': 45, 'end_index': 49, 'token': 'scan'},
#   {'label': 'treatment', 'start_index': 53, 'end_index': 56, 'token': 'mri'}],
#  [{'label': 'treatment',
#    'start_index': 20,
#    'end_index': 29,
#    'token': 'treatment'},
#   {'label': 'treatment',
#    'start_index': 45,
#    'end_index': 53,
#    'token': 'curative'},
#   {'label': 'treatment', 'start_index': 54, 'end_index': 57, 'token': 'txp'},
#   {'label': 'treatment',
#    'start_index': 59,
#    'end_index': 67,
#    'token': 'surgical'},
#   {'label': 'treatment',
#    'start_index': 68,
#    'end_index': 77,
#    'token': 'resection'},
#   {'label': 'treatment',
#    'start_index': 81,
#    'end_index': 89,
#    'token': 'ablation'}],
#  [{'label': 'chronic_disease',
#    'start_index': 0,
#    'end_index': 8,
#    'token': 'unstable'},
#   {'label': 'chronic_disease',
#    'start_index': 9,
#    'end_index': 16,
#    'token': 'medical'},
#   {'label': 'chronic_disease',
#    'start_index': 17,
#    'end_index': 26,
#    'token': 'condition'}],
#  [{'label': 'treatment',
#    'start_index': 24,
#    'end_index': 32,
#    'token': 'premolar'},
#   {'label': 'treatment',
#    'start_index': 24,
#    'end_index': 32,
#    'token': 'premolar'}],
#  [{'label': 'chronic_disease',
#    'start_index': 8,
#    'end_index': 14,
#    'token': 'active'},
#   {'label': 'chronic_disease',
#    'start_index': 15,
#    'end_index': 24,
#    'token': 'infection'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 39,
#    'token': 'hepatitis'},
#   {'label': 'chronic_disease', 'start_index': 8, 'end_index': 9, 'token': 'a'},
#   {'label': 'chronic_disease',
#    'start_index': 42,
#    'end_index': 47,
#    'token': 'virus'},
#   {'label': 'chronic_disease',
#    'start_index': 48,
#    'end_index': 49,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 49,
#    'end_index': 52,
#    'token': 'hav'},
#   {'label': 'chronic_disease',
#    'start_index': 52,
#    'end_index': 53,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 39,
#    'token': 'hepatitis'},
#   {'label': 'chronic_disease',
#    'start_index': 65,
#    'end_index': 66,
#    'token': 'b'},
#   {'label': 'chronic_disease',
#    'start_index': 42,
#    'end_index': 47,
#    'token': 'virus'},
#   {'label': 'chronic_disease',
#    'start_index': 48,
#    'end_index': 49,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 74,
#    'end_index': 77,
#    'token': 'hbv'},
#   {'label': 'chronic_disease',
#    'start_index': 52,
#    'end_index': 53,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 39,
#    'token': 'hepatitis'},
#   {'label': 'chronic_disease',
#    'start_index': 9,
#    'end_index': 10,
#    'token': 'c'},
#   {'label': 'chronic_disease',
#    'start_index': 42,
#    'end_index': 47,
#    'token': 'virus'},
#   {'label': 'chronic_disease',
#    'start_index': 48,
#    'end_index': 49,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 99,
#    'end_index': 102,
#    'token': 'hcv'},
#   {'label': 'chronic_disease',
#    'start_index': 52,
#    'end_index': 53,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 107,
#    'end_index': 112,
#    'token': 'human'},
#   {'label': 'chronic_disease',
#    'start_index': 113,
#    'end_index': 129,
#    'token': 'immunodeficiency'},
#   {'label': 'chronic_disease',
#    'start_index': 42,
#    'end_index': 47,
#    'token': 'virus'},
#   {'label': 'chronic_disease',
#    'start_index': 48,
#    'end_index': 49,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 137,
#    'end_index': 140,
#    'token': 'hiv'},
#   {'label': 'chronic_disease',
#    'start_index': 52,
#    'end_index': 53,
#    'token': ')'},
#   {'label': 'chronic_disease',
#    'start_index': 142,
#    'end_index': 146,
#    'token': 'type'},
#   {'label': 'chronic_disease',
#    'start_index': 147,
#    'end_index': 148,
#    'token': '1'},
#   {'label': 'chronic_disease',
#    'start_index': 15,
#    'end_index': 24,
#    'token': 'infection'}],
#  [],
#  [{'label': 'cancer', 'start_index': 65, 'end_index': 70, 'token': 'solid'},
#   {'label': 'upper_bound', 'start_index': 185, 'end_index': 186, 'token': '4'},
#   {'label': 'upper_bound',
#    'start_index': 187,
#    'end_index': 192,
#    'token': 'weeks'},
#   {'label': 'upper_bound',
#    'start_index': 193,
#    'end_index': 198,
#    'token': 'prior'}],
#  [{'label': 'pregnancy',
#    'start_index': 0,
#    'end_index': 8,
#    'token': 'pregnant'},
#   {'label': 'gender', 'start_index': 9, 'end_index': 14, 'token': 'women'},
#   {'label': 'treatment',
#    'start_index': 52,
#    'end_index': 61,
#    'token': 'radiation'},
#   {'label': 'treatment',
#    'start_index': 84,
#    'end_index': 95,
#    'token': 'teratogenic'}],
#  [{'label': 'chronic_disease',
#    'start_index': 0,
#    'end_index': 12,
#    'token': 'neurological'},
#   {'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 21,
#    'token': 'diseases'},
#   {'label': 'chronic_disease',
#    'start_index': 29,
#    'end_index': 38,
#    'token': 'parkinson'},
#   {'label': 'chronic_disease',
#    'start_index': 38,
#    'end_index': 39,
#    'token': "'"},
#   {'label': 'chronic_disease',
#    'start_index': 15,
#    'end_index': 16,
#    'token': 's'},
#   {'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 20,
#    'token': 'disease'},
#   {'label': 'chronic_disease',
#    'start_index': 50,
#    'end_index': 58,
#    'token': 'epilepsy'},
#   {'label': 'chronic_disease',
#    'start_index': 60,
#    'end_index': 68,
#    'token': 'cortical'},
#   {'label': 'chronic_disease',
#    'start_index': 69,
#    'end_index': 75,
#    'token': 'stroke'},
#   {'label': 'chronic_disease',
#    'start_index': 77,
#    'end_index': 86,
#    'token': 'alzheimer'},
#   {'label': 'chronic_disease',
#    'start_index': 38,
#    'end_index': 39,
#    'token': "'"},
#   {'label': 'chronic_disease',
#    'start_index': 15,
#    'end_index': 16,
#    'token': 's'},
#   {'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 20,
#    'token': 'disease'},
#   {'label': 'chronic_disease',
#    'start_index': 98,
#    'end_index': 107,
#    'token': 'traumatic'},
#   {'label': 'chronic_disease',
#    'start_index': 108,
#    'end_index': 113,
#    'token': 'brain'},
#   {'label': 'chronic_disease',
#    'start_index': 114,
#    'end_index': 120,
#    'token': 'injury'},
#   {'label': 'chronic_disease',
#    'start_index': 125,
#    'end_index': 133,
#    'token': 'dementia'}],
#  [{'label': 'lower_bound',
#    'start_index': 10,
#    'end_index': 15,
#    'token': 'three'},
#   {'label': 'treatment',
#    'start_index': 16,
#    'end_index': 24,
#    'token': 'systemic'},
#   {'label': 'treatment',
#    'start_index': 25,
#    'end_index': 39,
#    'token': 'corticosteroid'},
#   {'label': 'chronic_disease',
#    'start_index': 50,
#    'end_index': 56,
#    'token': 'asthma'}],
#  [{'label': 'chronic_disease',
#    'start_index': 0,
#    'end_index': 11,
#    'token': 'hemorrhagic'},
#   {'label': 'chronic_disease',
#    'start_index': 12,
#    'end_index': 20,
#    'token': 'cystitis'},
#   {'label': 'chronic_disease',
#    'start_index': 24,
#    'end_index': 30,
#    'token': 'active'},
#   {'label': 'chronic_disease',
#    'start_index': 31,
#    'end_index': 42,
#    'token': 'prostatitis'}],
#  [{'label': 'lower_bound', 'start_index': 38, 'end_index': 39, 'token': '1'},
#   {'label': 'treatment',
#    'start_index': 54,
#    'end_index': 62,
#    'token': 'systemic'},
#   {'label': 'treatment',
#    'start_index': 63,
#    'end_index': 70,
#    'token': 'therapy'}],
#  [{'label': 'chronic_disease',
#    'start_index': 44,
#    'end_index': 56,
#    'token': 'hypertensive'},
#   {'label': 'chronic_disease',
#    'start_index': 57,
#    'end_index': 63,
#    'token': 'crisis'},
#   {'label': 'chronic_disease',
#    'start_index': 44,
#    'end_index': 56,
#    'token': 'hypertensive'},
#   {'label': 'chronic_disease',
#    'start_index': 80,
#    'end_index': 94,
#    'token': 'encephalopathy'}],
#  [{'label': 'chronic_disease',
#    'start_index': 88,
#    'end_index': 94,
#    'token': 'trauma'}],
#  [{'label': 'treatment',
#    'start_index': 8,
#    'end_index': 19,
#    'token': 'concomitant'},
#   {'label': 'treatment',
#    'start_index': 20,
#    'end_index': 32,
#    'token': 'chemotherapy'},
#   {'label': 'treatment',
#    'start_index': 34,
#    'end_index': 43,
#    'token': 'radiation'},
#   {'label': 'treatment',
#    'start_index': 25,
#    'end_index': 32,
#    'token': 'therapy'},
#   {'label': 'treatment',
#    'start_index': 55,
#    'end_index': 68,
#    'token': 'immunotherapy'}],
#  [{'label': 'cancer',
#    'start_index': 5,
#    'end_index': 15,
#    'token': 'metastatic'},
#   {'label': 'cancer', 'start_index': 16, 'end_index': 22, 'token': 'breast'},
#   {'label': 'cancer', 'start_index': 23, 'end_index': 29, 'token': 'cancer'},
#   {'label': 'chronic_disease',
#    'start_index': 48,
#    'end_index': 59,
#    'token': 'dysfunction'}],
#  [{'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 25,
#    'token': 'hypocalcemia'}],
#  [{'label': 'chronic_disease',
#    'start_index': 19,
#    'end_index': 29,
#    'token': 'dependence'},
#   {'label': 'chronic_disease',
#    'start_index': 30,
#    'end_index': 38,
#    'token': 'disorder'}],
#  [{'label': 'gender', 'start_index': 0, 'end_index': 5, 'token': 'women'},
#   {'label': 'pregnancy',
#    'start_index': 44,
#    'end_index': 52,
#    'token': 'negative'},
#   {'label': 'pregnancy',
#    'start_index': 53,
#    'end_index': 62,
#    'token': 'pregnancy'},
#   {'label': 'upper_bound', 'start_index': 75, 'end_index': 76, 'token': '7'},
#   {'label': 'upper_bound',
#    'start_index': 77,
#    'end_index': 81,
#    'token': 'days'},
#   {'label': 'clinical_variable',
#    'start_index': 127,
#    'end_index': 137,
#    'token': 'amenorrhea'},
#   {'label': 'lower_bound',
#    'start_index': 141,
#    'end_index': 143,
#    'token': '12'},
#   {'label': 'lower_bound',
#    'start_index': 144,
#    'end_index': 155,
#    'token': 'consecutive'},
#   {'label': 'lower_bound',
#    'start_index': 156,
#    'end_index': 166,
#    'token': 'monthsnote'},
#   {'label': 'gender', 'start_index': 0, 'end_index': 5, 'token': 'women'},
#   {'label': 'chronic_disease',
#    'start_index': 188,
#    'end_index': 199,
#    'token': 'amenorrheic'},
#   {'label': 'lower_bound',
#    'start_index': 141,
#    'end_index': 143,
#    'token': '12'},
#   {'label': 'treatment',
#    'start_index': 312,
#    'end_index': 317,
#    'token': 'prior'},
#   {'label': 'treatment',
#    'start_index': 318,
#    'end_index': 330,
#    'token': 'chemotherapy'},
#   {'label': 'treatment',
#    'start_index': 332,
#    'end_index': 345,
#    'token': 'antiestrogens'},
#   {'label': 'treatment',
#    'start_index': 347,
#    'end_index': 354,
#    'token': 'ovarian'},
#   {'label': 'treatment',
#    'start_index': 355,
#    'end_index': 366,
#    'token': 'suppression'}],
#  [{'label': 'chronic_disease',
#    'start_index': 20,
#    'end_index': 26,
#    'token': 'angina'},
#   {'label': 'clinical_variable',
#    'start_index': 37,
#    'end_index': 40,
#    'token': 'new'},
#   {'label': 'clinical_variable',
#    'start_index': 41,
#    'end_index': 45,
#    'token': 'york'},
#   {'label': 'clinical_variable',
#    'start_index': 46,
#    'end_index': 51,
#    'token': 'heart'},
#   {'label': 'clinical_variable',
#    'start_index': 52,
#    'end_index': 63,
#    'token': 'association'},
#   {'label': 'clinical_variable',
#    'start_index': 64,
#    'end_index': 65,
#    'token': '('},
#   {'label': 'clinical_variable',
#    'start_index': 65,
#    'end_index': 69,
#    'token': 'nyha'},
#   {'label': 'clinical_variable',
#    'start_index': 69,
#    'end_index': 70,
#    'token': ')'},
#   {'label': 'clinical_variable',
#    'start_index': 71,
#    'end_index': 76,
#    'token': 'class'},
#   {'label': 'chronic_disease',
#    'start_index': 80,
#    'end_index': 90,
#    'token': 'congestive'},
#   {'label': 'clinical_variable',
#    'start_index': 46,
#    'end_index': 51,
#    'token': 'heart'},
#   {'label': 'chronic_disease',
#    'start_index': 97,
#    'end_index': 104,
#    'token': 'failure'},
#   {'label': 'chronic_disease',
#    'start_index': 115,
#    'end_index': 125,
#    'token': 'myocardial'},
#   {'label': 'chronic_disease',
#    'start_index': 126,
#    'end_index': 136,
#    'token': 'infarction'},
#   {'label': 'clinical_variable',
#    'start_index': 64,
#    'end_index': 65,
#    'token': '('},
#   {'label': 'chronic_disease',
#    'start_index': 138,
#    'end_index': 140,
#    'token': 'mi'},
#   {'label': 'clinical_variable',
#    'start_index': 69,
#    'end_index': 70,
#    'token': ')'},
#   {'label': 'upper_bound', 'start_index': 149, 'end_index': 150, 'token': '6'},
#   {'label': 'upper_bound',
#    'start_index': 151,
#    'end_index': 157,
#    'token': 'months'},
#   {'label': 'upper_bound',
#    'start_index': 158,
#    'end_index': 163,
#    'token': 'prior'},
#   {'label': 'treatment',
#    'start_index': 182,
#    'end_index': 191,
#    'token': 'treatment'}],
#  [{'label': 'treatment',
#    'start_index': 46,
#    'end_index': 53,
#    'token': 'surgery'},
#   {'label': 'treatment',
#    'start_index': 67,
#    'end_index': 77,
#    'token': 'anesthesia'}],
#  [{'label': 'treatment',
#    'start_index': 53,
#    'end_index': 64,
#    'token': 'medications'},
#   {'label': 'lower_bound', 'start_index': 78, 'end_index': 80, 'token': '14'},
#   {'label': 'lower_bound',
#    'start_index': 81,
#    'end_index': 85,
#    'token': 'days'},
#   {'label': 'lower_bound',
#    'start_index': 89,
#    'end_index': 93,
#    'token': 'five'},
#   {'label': 'lower_bound',
#    'start_index': 94,
#    'end_index': 98,
#    'token': 'half'},
#   {'label': 'treatment',
#    'start_index': 164,
#    'end_index': 169,
#    'token': 'study'},
#   {'label': 'treatment', 'start_index': 230, 'end_index': 233, 'token': 'non'},
#   {'label': 'treatment',
#    'start_index': 234,
#    'end_index': 243,
#    'token': 'oncologic'},
#   {'label': 'treatment',
#    'start_index': 244,
#    'end_index': 259,
#    'token': 'investigational'},
#   {'label': 'upper_bound',
#    'start_index': 272,
#    'end_index': 274,
#    'token': '30'},
#   {'label': 'lower_bound',
#    'start_index': 81,
#    'end_index': 85,
#    'token': 'days'},
#   {'label': 'treatment',
#    'start_index': 359,
#    'end_index': 368,
#    'token': 'treatment'}],
#  [{'label': 'treatment',
#    'start_index': 9,
#    'end_index': 20,
#    'token': 'macroscopic'},
#   {'label': 'treatment',
#    'start_index': 21,
#    'end_index': 30,
#    'token': 'resection'}],
#  [{'label': 'chronic_disease',
#    'start_index': 168,
#    'end_index': 175,
#    'token': 'cardiac'},
#   {'label': 'chronic_disease',
#    'start_index': 177,
#    'end_index': 189,
#    'token': 'neurological'},
#   {'label': 'chronic_disease',
#    'start_index': 191,
#    'end_index': 200,
#    'token': 'pulmonary'},
#   {'label': 'chronic_disease',
#    'start_index': 202,
#    'end_index': 207,
#    'token': 'renal'},
#   {'label': 'chronic_disease',
#    'start_index': 209,
#    'end_index': 216,
#    'token': 'hepatic'}],
#  [{'label': 'chronic_disease',
#    'start_index': 13,
#    'end_index': 19,
#    'token': 'active'},
#   {'label': 'chronic_disease',
#    'start_index': 20,
#    'end_index': 29,
#    'token': 'infection'}],
#  [{'label': 'treatment',
#    'start_index': 18,
#    'end_index': 29,
#    'token': 'concomitant'},
#   {'label': 'treatment',
#    'start_index': 30,
#    'end_index': 37,
#    'token': 'therapy'},
#   {'label': 'upper_bound', 'start_index': 43, 'end_index': 44, 'token': '4'},
#   {'label': 'upper_bound',
#    'start_index': 45,
#    'end_index': 50,
#    'token': 'weeks'},
#   {'label': 'upper_bound',
#    'start_index': 51,
#    'end_index': 56,
#    'token': 'prior'}],
#  [{'label': 'allergy_name',
#    'start_index': 28,
#    'end_index': 33,
#    'token': 'study'},
#   {'label': 'allergy_name',
#    'start_index': 34,
#    'end_index': 40,
#    'token': 'agents'}]]

# %%
import json
json_file_path = "ClinicalBert_output.json"
with open(json_file_path, "w") as json_file:
    json.dump(filtered_clinical_result, json_file)

# %%
import os
import pandas as pd
import openai
import time
import warnings
from copy import deepcopy
warnings.filterwarnings("ignore")
from typing import List, Tuple, Dict, Optional, Union, Sequence
from nervaluate import Evaluator
openai.api_key = "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"

# %%
df = pd.read_csv("All_purpose_test_data.csv")
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head(500)
# Out:
#                                           cleaned_sent  \
# 0    Subject is suitable for oral administration of...
# 1                                    Current pregnancy
# 2                                  Singleton pregnancy
# 3    All patients currently taking steroids at the ...
# 4    rheumatic valve disease since this produces a ...
# ..                                                 ...
# 495  Men must agree to use adequate contraception p...
# 496                         Serum creatinine 1.5 x ULN
# 497                        History of seizure disorder
# 498  Participants who have received any other inves...
# 499  ALT or BUN > 2.0 ULN or estimated creatinine >...
#
#                                           actaul_index  \
# 0    [{'label': 'treatment', 'start': 24, 'end': 57...
# 1    [{'label': 'pregnancy', 'start': 0, 'end': 17,...
# 2    [{'label': 'pregnancy', 'start': 10, 'end': 19...
# 3    [{'label': 'treatment', 'start': 30, 'end': 38...
# 4    [{'label': 'chronic_disease', 'start': 0, 'end...
# ..                                                 ...
# 495  [{'label': 'gender', 'start': 0, 'end': 3, 'va...
# 496  [{'label': 'clinical_variable', 'start': 0, 'e...
# 497  [{'label': 'chronic_disease', 'start': 11, 'en...
# 498  [{'label': 'treatment', 'start': 41, 'end': 63...
# 499  [{'label': 'clinical_variable', 'start': 0, 'e...
#
#                                              Formatted
# 0    - Subject is suitable for [oral administration...
# 1          - [Current pregnancy]{"entity":"pregnancy"}
# 2        - Singleton [pregnancy]{"entity":"pregnancy"}
# 3    - All patients currently taking [steroids]{"en...
# 4    - [rheumatic valve disease]{"entity":"chronic_...
# ..                                                 ...
# 495  - [Men]{"entity":"gender"} must [agree to use ...
# 496  - [Serum creatinine]{"entity":"clinical_variab...
# 497  - History of [seizure disorder]{"entity":"chro...
# 498  - Participants who have received any other [in...
# 499  - [ALT]{"entity":"clinical_variable"} or [BUN]...
#
# [500 rows x 3 columns]

# %%
df_test = df.iloc[:500]
sentences_to_predict = list(df_test.cleaned_sent.values)
sentences_to_predict
# Out:
# ['Subject is suitable for oral administration of study drug',
#  'Current pregnancy',
#  'Singleton pregnancy',
#  'All patients currently taking steroids at the time of surgery or during the six-week recovery period as well as patients with betamethasone hypersensitivity',
#  'rheumatic valve disease since this produces a unique AF phenotype',
#  'Severe liver dysfunction LFT 3X upper limit of normal',
#  'Serum M-protein >= 1.0 g/dL',
#  'Males or females',
#  'Negative for malignancy for past 5 years',
#  'available for up to 6 hrs every day for two 2-week test periods with an intervening break of 7- 10 days each',
#  'Diagnosis of recurrent and/or metastatic thyroid cancer',
#  'No other investigational or commercial therapeutic agents may be given concurrently with the paclitaxel',
#  'Mean arterial pressure < 65',
#  'White blood cells WBC > 15,000 cells/mcL at screening',
#  'Acute medical illness',
#  'At least one prior chemotherapy',
#  'History of prior thromboembolism with known thrombophilia',
#  'Inability to tolerate stationary position during HIFU',
#  'Known history of hepatitis B defined as hepatitis B survace antigen HBsAg reactive or known active hepatitis C defined as HCV RNA qualitative is detected infection',
#  'History or concurrent condition of interstitial lung disease of any severity and/or severely impaired lung function',
#  'Diabetes Mellitus',
#  'Seizure disorder requiring medication',
#  'Body mass index BMI >= 25 kg/m^2',
#  'Life expectancy of at least 12 weeks',
#  'History/physical examination to include at a minimum digital rectal examination of the prostate and examination of the skeletal system and abdomen within 90 days prior to registration',
#  'no secondary primary lung cancer diagnosed concurrently or within 2 year prior to registration',
#  'Subjects who have a positive serum human chorionic gonadotropin hCG',
#  "Total bilirubin: =< 1.5 x institutional upper limit of normal ULN or =< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation, and must have a total bilirubin less than 3.0 mg/dL within 2 weeks prior to enrollment participants may receive GCSF and transfusions to meet these parameters",
#  'Other neurological diagnosis',
#  'Major neurological disorder',
#  'Anti-tumor necrosis factor agents',
#  'Clinically significant heart disease as evidenced by myocardial infarction or arterial thrombotic events in the past 6 months severe or unstable angina or New York Heart Association NYHA class II- IV heart disease',
#  'In normal sinus rhythm ECG documented within the two weeks prior to the screening Holter',
#  'Women of childbearing potential must have a negative pregnancy test to participate in this study',
#  'Hematologic abnormalities e.g., pancytopenia aplastic anemia',
#  'Poor English comprehension',
#  'Documented diagnosis of multiple myeloma according to International Myeloma Working Group IMWG diagnostic criteria',
#  'Patients with a history of hypercontractile bladder non-compliant bladder hydronephrosis or neurogenic bladder',
#  'Patients 40 - 59 years of age with 15% TBSA',
#  'at least 2 years of age',
#  'Paediatric patients aged 1 year to < 18 years at the time of informed consent',
#  'Therapeutic antibodies such as bevacizumab',
#  'Have postmenopausal status due to either surgical/natural menopause or ovarian suppression initiated at least 28 days prior to Day 1 of Cycle 1 with a gonadotropin-releasing hormone GnRH agonist such as goserelin',
#  'Pancreatic Cancer Patients who are potentially surgically resectable',
#  'Patient has experienced lower urinary tract symptoms LUTS for at least 1 year prior to study enrollment',
#  'Prior implantation of a pacemaker ICD',
#  'spinal block are unsafe to undergo BBBD chemotherapy and are not eligible',
#  'are linked to care/evaluation within 30 days of diagnosis',
#  'Dry weight and height parameters obtained within 7 days prior to study entry may be used',
#  'antipsychotics',
#  'lactating women',
#  'SGPT ALT 5 x ULN for age',
#  'Pregnant',
#  'Subject with a history of anaphylaxis attributed to an echinocandin',
#  'possibly pregnant',
#  'Prior ipsilateral knee surgery such as ligament reconstruction or osteotomy',
#  'congestive heart failure',
#  'Ongoing, tapering therapy for resolved acute GVHD is permissible',
#  'IV docetaxel 75 mg/m^2 5 mg/m^2 and carboplatin AUC 5- 6 every 21 days',
#  'documented agreement to use an effective form of birth control',
#  'HIV- positive patients on combination antiretroviral therapy are ineligible because of the potential for pharmacokinetic interactions with LY2606368',
#  'ECOG performance status less than or equal to 2 Karnofsky greater than or equal to 60%',
#  'Metastatic breast cancer 7 triple negative, 23 ER after the first 15 patients are enrolled on the non- CCND1c ohort; in addition 10 HER2 for combination trastuzumab and PD0332991 therapy up to 55 total enrollment slots B',
#  '> 18 years old',
#  'Parts A & C: patients with recurrent or refractory solid tumors without central nervous system CNS tumors or known CNS metastases',
#  'Known history of testing positive for human immunodeficiency virus HIV or known acquired immunodeficiency syndrome AIDS',
#  'planned surgery requiring general anesthesia during the pharmacotherapy period',
#  'Maximal diameter of any one hepatocellular carcinoma > 15 cm',
#  'Females must be menopausal or have had a bilateral oophorectomy',
#  'female',
#  'For Control Group: NO diagnosis of ADHD as determined by clinician administered CAADID and clinical interview',
#  'Other active malignancy =< 3 years prior to registration',
#  'Concurrent intensive induction chemotherapy radiotherapy or biologic treatment for active malignancy subjects on maintenance chemotherapy may only be enrolled after consultation with the study medical monitor',
#  'Patients for who CEM carboplatin, etoposide, melphalan therapy therapy is administered within 30 days 30 days prior to 131I-MIBG therapy 131I-MIBG therapy or for whom this therapy is planned within 30 days following administration of 131I-MIBG',
#  'HIV positive with CD4 count < 350 cells/microliter',
#  'at least 6 times duration of the reported half life or minimum four 4 months for other depot or long-acting antipsychotics',
#  'Known positive Hepatitis B antigen HBs Ag unless positive test can be attributed to receipt of Hepatitis B vaccination in childhood or Hepatitis C viral antibody HCV with evidence of active hepatitis i.e., AST ALT greater than two times the ULN',
#  'Sexually active males must use a condom during intercourse',
#  'Active, uncontrolled infection and/or human immunodeficiency virus HIV positive constitute progressive disease',
#  'a contraceptive implant',
#  'Preoperative evaluation to rule-out extra-uterine disease may include CT scan, MRI, or ultrasound',
#  'people who are extremely claustrophobic',
#  'current or previous history of malignancy',
#  'Report drinking on 80% of days in the past 90 days',
#  'Must be fluent in English',
#  'Recent within 6 months prior to index procedure date cerebrovascular accident CVA or a transient ischemic attack TIA',
#  'Have progression during or following platinum-containing chemotherapy or within 1 2 months of neoadjuvant or adjuvant treatment with platinum-containing chemotherapy',
#  'At least 4 weeks since receiving any investigational drug',
#  'have an allergy to gadolinium Gd contrast material',
#  'Wheezing on exam',
#  'Has not recovered to Grade 1 from toxic effects of prior therapy',
#  'Subjects with any known uncontrolled inter-current illness including ongoing or active infection symptomatic congestive heart failure NYHA Gr.2 or > , myocardial infarction unstable angina pectoris within the past 12 months',
#  'Age > 18 and < 75 years',
#  'Patients with recurrent carcinoma of the vulva regardless of previous treatment',
#  'PaO2/FiO2 300',
#  'Individuals willing to participate in a randomized clinical trial of amyloid imaging disclosure',
#  'Healthy infants 4 to 6 months of age',
#  'Presence of asthma',
#  'Bleeding disorder',
#  'Age 18 years or older',
#  'Prior therapy with one second line hormonal therapy is allowed i.e. bicalutamide nilutamide flutamide ketoconazole abiraterone enzalutamide ARN-509',
#  'This test is now done routinely for every newly diagnosed endometrial cancer patient in most centers in the US',
#  'Active central nervous system lymphoma',
#  'other autoimmune diseases',
#  'This includes, but is not limited to: acute myeloid leukemia AML acute lymphoblastic leukemia ALL chronic myelogenous leukemia CML chronic lymphocytic leukemia CLL non-Hodgkin lymphoma NHL Hodgkin lymphoma NHL , Hodgkin lymphoma, multiple myeloma MM myelodysplastic syndrome MDS AL amyloidosis diamond blackfan anemia myelofibrosis or other myeloproliferative disease sickle cell anemia and thalassemia',
#  'Tumor sample must be available for HPV p16 and PD-L1 testing',
#  'ECOG status 3 or 4',
#  "Any serious and/or unstable pre-existing medical psychiatric or other condition that could interfere with subject's safety, provision of informed consent, or compliance to study procedures",
#  'Have any medical conditions that prevent subject from safely exercising e.g., orthopedic injuries, cardiovascular liver endocrine or pulmonary diseases',
#  'Patients with any prior history of lung cancer',
#  'Ongoing cord compression or a syrinx in the spinal cord or who suffer from a spinal cord disease such as spinal stenosis spina bifida or herniated cervical disk',
#  'nursing woman',
#  'pregnant women',
#  'myocardial infarction < 6 months before enrollment',
#  'Sickle cell anemia',
#  'Myelodysplastic syndrome',
#  'patients who have received corneal transplants cadaver skin or bone transplants are eligible',
#  'Lovaza prescription fish oil and not willing to go off Lovaza for 3 weeks prior to enrollment to end of study',
#  'Presence of cardiac condition, asthma obstructive pulmonary disease seizure disorder urinary incontinence and/or peptic ulcer disease receiving concurrent NSAIDs',
#  'Karnofsky performance status >= 70%',
#  'Grade 4 - Fibrosis',
#  'Follicular 17-hydroxyprogesterone > 300 ng/dl which suggests the possibility of congenital adrenal hyperplasia',
#  'Current oral steroid use > 4 weeks prior to registration',
#  'Not pregnant',
#  'History of DVT or pulmonary embolism within 6 months',
#  'Hepatitis C positive donor liver',
#  'Renal insufficiency creatinine > 1.5 mg/dL',
#  'Administration of any investigational agent =< 30 days prior to pre-registration',
#  'for subjects who are receiving warfarin for prophylaxis or treatment of thrombosis INR values should be carefully monitored while patients are on study',
#  'Patients must be >/= 18 years of age',
#  'Documented history of a cerebral vascular event stroke or transient ischemic attack , unstable angina myocardial infarction or cardiac symptoms including congestive heart failure consistent with New York Heart Association Class III- IV within 6 months prior to the first dose of enfortumab vedotin',
#  'Eligible for breast conserving surgery lumpectomy and radiation',
#  'age > 49',
#  'Current use of medication that may involve potentially dangerous interaction with propranolol',
#  'Subjects who have received rIX-FP for 100 EDs single-dose cohorts or for 50 EDs repeated-dose cohort',
#  'Bilirubin 2 x the ULN',
#  'History of organ allograft including corneal transplant',
#  'Autologous stem cell transplantation SCT within 100 days prior to study drug or any prior allogeneic SCT or solid organ transplantation',
#  'Diagnosis of type 2 diabetes',
#  'History of an active malignancy within the last 3 years',
#  'All adverse events Grade > 1 related to prior therapies chemotherapy radiotherapy and/or surgery must be resolved, except for alopecia',
#  'Pre-bronchodilator 50% FEV1 of < 85 % of the predicted normal value for the patient after withholding bronchodilators at both Visit 101 and 102, according to ATS/ERS criteria',
#  'Prior treatment with cetuximab for incurable disease is not permitted',
#  'Patients who are taking any herbal alternative medicines are NOT eligible for participation',
#  'Age 21 years',
#  'Subjects who have received prior intravesical chemotherapy are allowed',
#  'a case by case determination will be made by study physician for medication on precautionary list, i.e. nitroglycerin',
#  'Severe aortic regurgitation > 3',
#  'A serious psychiatric or medical condition which, in the opinion of the Investigator, could interfere with treatment',
#  'Donors must be >= 17 years of age',
#  'Disease: FL Criteria for diagnosis: histopathologic confirmation',
#  'age 16 years of age or older and weighs',
#  'Interval from start of initial radiation therapy to enrollment > 9 months',
#  'diabetes requiring medication',
#  'Not pregnant or nursing and report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal',
#  'Pregnant women',
#  'Known active hepatitis B hepatitis B e.g., hepatitis B virus surface antigen HBsAg reactive or hepatitis C e.g., hepatitis C virus HCV ribonucleic acid RNA qualitative is detected',
#  'he/she must have a pretreatment calculated creatinine clearance of >= 50 mL/minute',
#  'Second primary malignancy malignancy except most situ carcinoma e.g. in situ carcinoma of the cervix adequately treated non-melanomatous carcinoma of the skin or other malignancy treated at least 5 years previously with no evidence of recurrence',
#  'Patients who received iodinated intravenous contrast as part of a radiographic procedure within 3 months of study registration',
#  'History or presence of clinically relevant CNS pathology such as uncontrolled seizure disorder recent stroke severe brain injuries dementia cerebellar disease or psychosis',
#  'Patients with solid tumors must have measurable disease Response Evaluation Criteria in Solid Tumors RECIST 1.1',
#  'Patients with refractory-relapsed ALL of any age are eligible',
#  'Active or recurrent herpes or varicella-zoster virus infection requiring treatment or chronic suppression',
#  'Severe hepatic impairment defined by two or more liver function enzyme values greater than 2.5 the upper limit of normal',
#  'Other serious uncontrolled medical condition e.g., cancer or acute myocardial infarction',
#  'Aspartate aminotransferase AST and alanine aminotransferase ALT < 3 x the institutional upper limit of normal',
#  'Known hepatitis B surface antigen positivity',
#  'Must be between 2 and 40 years of age',
#  'Epilepsy partial seizure subjects',
#  'Patients of reproductive potential and their partners must agree to use an effective > 90% reliability form of contraception 90% reliability form of contraception during the study and for 4 weeks following the last study drug administration',
#  'Sufficient vascular access to receive study drug and to allow blood sampling at a site separate from the study drug infusion site',
#  'Untreated sleep apnea',
#  'Presence of a secondary headache disorder e.g., brain tumor',
#  'Prior bilateral orchiectomy',
#  'Is a known drug or alcohol abuser or has a psychological disorder that could affect the ability to complete patient reported questionnaires',
#  'Serum total bilirubin > 1.5 times the upper limit of normal ULN',
#  'HIV- positive patients are eligible, provided they are under treatment with highly active antiretroviral therapy HAART and have a CD4 count >= 200 cells/microliter no more than 30 days prior to registration',
#  "total bilirubin =< upper normal institutional limits except for patients with Gilbert's disease who are eligible despite elevated serum bilirubin level",
#  'No prior RAI therapy therapy is allowed < 6 months prior to initiation of therapy on this protocol',
#  'who wish to become pregnant during the study period',
#  'lactating women',
#  'Poorly controlled depression',
#  'Male and females',
#  'ages 18 to 70',
#  'Adequate venous access in the arms for blood drawing and 5 day infusions, and lymphapheresis',
#  'Eastern Cooperative Oncology Group ECOG performance status PS 0 1, or 2',
#  'Insomnia complaints for 6+ months',
#  'No blood, sperm, or semen donation during and for 28 days after completion of study therapy',
#  'Patients presenting for hysterectomy for any benign indication including but not limited to abnormal uterine bleeding menorrhagia uterine fibroids adenomyosis pelvic pain dysmenorrhea pelvic organ prolapse or endometriosis',
#  'uncontrolled bacterial viral or fungal infection currently taking medication and with progression or no clinical improvement at time of enrollment',
#  'Women of childbearing potential must have a negative pregnancy test',
#  'Patient must consent to a biopsy of a site of disease unless the only site of disease is lung/pleura, bone, or deemed unsafe by the principal investigator',
#  'No distant metastases',
#  'Insulin requirement of > 1.0 U/kg/day or, > 60 U/day total or < 15 U/day',
#  'Residual symptoms will be defined as a total score of 110 and 60 of PANSS per Visit 1 evaluations',
#  '10% or more probability of BRCA mutation by BRCAPRO or similar model',
#  'Previous therapeutic radiation in the region of the study eye',
#  'Metallic implant',
#  'Fluoxetine',
#  'Therapy-related MDS MDS defined as the occurrence of MDS due to prior exposure to systemic chemotherapy and/or radiation for malignancy',
#  'Recent weight change +/- 25 pounds in 1 year',
#  'Active varicella zoster infection',
#  'after fluid resuscitation Clinical definition of kidney damage',
#  'Prior monoclonal antibody within 4 weeks prior to study',
#  'Known, clinically significant carotid artery disease',
#  'Hypocitraturic CaP stone formers',
#  'Has received non-permitted inflammatory bowel disease IBD therapies including natalizumab vedolizumab and efalizumab as stated in the protocol',
#  'Known to be positive for human immunodeficiency virus HIV or infectious hepatitis type B or C',
#  'Measurable disease as defined by RECIST v1.1 criteria. Baseline measurements and evaluation of ALL sites of disease must be obtained within 4 weeks prior to Enrollment',
#  'Patient must have performance status of 0- 2 on the ECOG Performance Scale and life expectancy > 3 months',
#  'substrates of CYP 3A4/5 or CYP1A2 that are sensitive or have a narrow therapeutic window at least three weeks prior to study registration',
#  'Self- reported CPP defined as pelvic pain that is non-cyclical and of at least 6 months duration and refractory to other treatments',
#  'Current use of opioid pain medications',
#  'Diet with frequent 1- 2 days per week oily fish mackerel, salmon, sardines, cold water fish, et al',
#  'Individuals who are allergic to iodine',
#  'NYHA classification of III or IV',
#  "History of connective tissue disorder e.g. vascular Ehlers Danlos Marfan's syndrome , with the exception of those patients who had prior open surgical aortic replacement or endovascular repair where a surgical graft or an endograft would serve as landing zone for the investigational endograft",
#  'Patients on PDEV inhibition for erectile dysfunction who are not willing to stop the medication for the duration of the study',
#  'More than one surgical procedure at any combination of lumbar levels',
#  'Patients who become pregnant after enrollment may be excluded from the study',
#  'alkaline phosphatase AP > 3 upper limit of normal ULN within 3 months of screening',
#  'Implanted pacemaker or cardiac defibrillator',
#  "Informed consent must be signed by the participant's legally authorized guardian acknowledging written consent to join the study",
#  'Major birth defect or malformation syndrome',
#  'Patients 18 - 39 years of age with 15% TBSA',
#  'female',
#  'Known hypersensitivity to both allopurinol and rasburicase',
#  'Malabsorption syndrome',
#  'Subjects who are cognitively impaired',
#  'Phantom limb pain',
#  'Pregnancy',
#  'Child not completing all pre-procedure work-up within 10 days of the Stage II Glenn surgery as listed in section 6 of this protocol AND lack of pre-procedure work-up documented as a safety concern by a site investigator',
#  'Presence of any non-healing wound, fracture, or ulcer',
#  'nursing women',
#  'Patients with a past cancer history within 2 years of entry and/or ongoing active malignancy or substantial potential for recurrence must be discussed with the Sponsor before study entry',
#  'Any history of second or third degree heart block may be eligible of the subject currently has a pacemaker',
#  'Patients must not have a myocardial infarction within 6 months prior to registration',
#  'Patients who are on chronic transfusions for clinical stroke with MRA cerebral vasculopathy will be excluded since patients in the SWITCH study who were randomized to the hydroxyurea arm had recurrent stroke, while none in the chronic transfusion arm',
#  'Concomitant cardiac surgery',
#  'Alcohol use of more than 4 drinks per day',
#  'Age > = 18 years',
#  'History of acute pancreatitis within 1 year of study or history of chronic pancreatitis',
#  'Estimated glomerular filtration rate < 60 mL/min 1.73m2',
#  'Cochlear nerve deficiency',
#  'Creatinine 1.5 x institutional upper limit of normal OR creatinine clearance > 60 mL/min/1.73 m2 for subjects with creatinine levels above institutional normal',
#  'Radiation therapy for bone or brain metastasis within 2 weeks any other external radiation therapy within 4 weeks of first dose of study drug. Systemic treatment with radionuclides within 4weeks Subjects with clinically relevant ongoing complications from prior radiation therapy are not eligible',
#  'Platelets >= 100,000/mcL',
#  'HIV- 1 infected treatment- experienced, virologically suppressed males',
#  'Active, known or suspected autoimmune disease',
#  'patients with prostate cancer may continue LHRH agonists or antagonists',
#  'Age 18 yo and 60 yo for patients in Cohort 1 only',
#  'Third degree heart block',
#  'Confirmed diagnosis of intrahepatic carcinoma',
#  'Pregnant',
#  "Liver cirrhosis transaminases > 3x of normal limits or bilirubin > 2.0 unless due to Gilbert's disease",
#  'Absolute contraindications to liver biopsy including coagulopathy',
#  'English speaking',
#  'At least 18 years of age',
#  'Histologically documented CD20- positive B-cell lymphoma as determined by the local laboratory',
#  'Bilirubin < 3x AST <3x, Serum creatinine < 2x upper limit of normal Hgb > 8.0 plts > 20',
#  'have a diagnosis of mTBI based upon Veterans Health Administration VHA /Department of Defense DoD criteria with persisting symptoms > 3 months post injury',
#  'Must be optimally medicated at the start of the study. This means that there should be no change in mediction type or dosage in 3 months prior to enrolling in the study. The medications should not be causing significant or serious advese effects',
#  'women who are breast feeding',
#  'uncontrolled coagulation blood disorders like haemophilia malignant tumors and fear of needles',
#  'recurrent seizures',
#  'Patients must have one of the following malignancies',
#  'Patients who demonstrate > 25% decrease in depressive symptoms as reflected by the QIDS-SR score from Screening to Randomization',
#  'Severe hypersensitivity Grade 3 to pembrolizumab and/or any of its excipients',
#  'Available for follow-up for 12 months',
#  'Invasive infection',
#  'Women in good health aged 40- 80',
#  'Reversible causes of atrial arrhythmia such as hyperthyroidism sarcoidosis pulmonary embolism etc',
#  'Be receiving any prostanoid to treat portopulmonary hypertension',
#  'Patients with diabetes',
#  'Score of 50 on screening ISR Erythema Index',
#  'Atrial fibrillation with rapid ventricular response',
#  'Pre-existing stable medication see protocol for details , tic or otherwise, will also be allowed provided the family agrees to refrain from med changes over the course of the acute phase of the study',
#  'Subject has an active autoimmune disease in the past 2 years',
#  'Bone lesions: one or more osteolytic lesions on skeletal radiography computerized tomography CT or 2-deoxy-2 F-18 fluoro-D-glucose positron emission tomography CT PET-CT',
#  'pulmonary embolus',
#  'No class 3 or higher New York Heart Association congestive heart failure',
#  'Age 18',
#  'History of bariatric surgery',
#  'Castrate testosterone levels < 50 ng/dL achieved by orchiectomy or maintenance on a luteinizing hormone-releasing hormone LHRH agonist or antagonist',
#  'History of any solid organ or bone marrow transplant',
#  'Clinical diagnosis of asthma bronchiectasis cystic fibrosis or severe alpha-1 antitrypsin deficiency',
#  'esophageal spasm',
#  'A bone marrow biopsy must be performed within four weeks prior to Cycle 1 Day 1 treatment to establish the baseline fibrosis score and consent is required prior to that bone marrow biopsy to assure tissue is collected for protocol mandated testing',
#  'Potentially confounding neurodegenerative diseases e.g. MS',
#  'Asymptomatic CAD group: 40 patients who have undergone Coronary Artery Calcium scanning within 6 months prior to the imaging visit, matched to the ACS patients for age gender, and CAC score',
#  'patients who have CKD stage 5 End Stage Renal Disease ESRD',
#  'Any other disease, metabolic dysfunction, physical examination finding, or clinical laboratory finding that contraindicates the use of an investigational drug may affect the interpretation of the results, or may render the participant at high risk from treatment complications',
#  'Subjects must agree to avoid consuming alcohol within 72 hours of each rTMS session',
#  'ubjects undergoing primary debulking surgery surgery must have stage III or IV disease and have undergone surgery to include, at a minimum, removal of the uterus ovaries and fallopian tubes',
#  'Pregnant Women',
#  'Lesion larger than 3 cm in diameter',
#  'Connective tissue disease',
#  '12-lead electrocardiogram ECG conducted at the screening visit within normal limits or abnormal but not clinically significant to the Investigator',
#  'Claustrophobia precluding chamber or hood tolerance',
#  'Patients must have maintained peripheral blood evidence of a remission and must have a CR or CRi, confirmed on restaging BM aspirate and biopsy',
#  'Enrolment in any other clinical study, for any condition, including those relating to Usher syndrome Type 1B throughout the duration of the SAR421869 study',
#  'for patients with AML evolving from myelodysplastic syndrome they should have completed at least one cycle of induction chemotherapy',
#  'English speaking and reading',
#  'Pathologically confirmed diagnosis of DLBCL with or without simultaneous or antecedent indolent lymphoma',
#  'Prior stroke with functional impairment or other severe, uncontrolled medical problems that may impair ability to participate in the study exams, based on medical history and review of medical records',
#  'HIV- infected individuals in HIV care',
#  'Hemoglobin 8 g/dl',
#  'Subject has immediately life-threatening, severe complications of leukemia such as uncontrolled bleeding pneumonia with hypoxia or shock and/or disseminated intravascular coagulation',
#  'Patients must be at least 28 days post systemic steroids prior to enrollment',
#  'Patients with T1 tumors',
#  'Life expectancy of at least 3 months',
#  'DNA damage repair deficiency as assessed centrally by a gene mutation biomarker panel testing of de novo or archival tumor tissue via central laboratory or prior historical testing with Sponsor approval using the Foundation Medicine, FoundationOne CDx NGS gene panel test',
#  'age 18- 65',
#  'Smoking history 10 pack-years',
#  'SBRT target size > 6 cm in maximum diameter or greater than 100 cc in volume',
#  'SLEDAI2K score 4 indicating active disease',
#  'Patients diagnosed with solid tumors who are eligible for participation in Phase I clinical trials of investigational cancer therapies',
#  'relapsed with radiologic evidence of progression within 1 year from completion of adjuvant endocrine therapy endocrine therapy with no subsequent endocrine therapy received following progression',
#  'Patients must be on no more than 0.1 mg/kg/day max 4 mg/day dexamethasone for at least one week before study registration',
#  'Acute leukemia in 1st or 2nd CR',
#  'Absolute CD4 count > 100 cells/uL',
#  'Patients with underlying abnormal brain pathology e.g. mass or bleed as the potential cause of the migraine',
#  'Clinical or radiologic evidence of untreated and/or progressive brain metastases',
#  'Albumin >= 2.5 g/dL',
#  'History of allergic/hypersensitivity reaction to any substance having required hospitalization and/or treatment with IV steroids epinephrine',
#  'Uncontrolled angina within 3 months of Screening visit',
#  'Female participants who are breast feeding must agree to stop breast feeding',
#  'at least one of the following: rest tremor muscular rigidity and postural instability not cause by visual vestibular cerebellar or proprioceptive dysfunction',
#  'Subjects with known allergies to injectable lidocaine or other topical anesthetics',
#  'Sexually active males unless they use a condom during intercourse while taking the drug and for 30 days after stopping treatment ment and should not father a child in this period. A condom is required to be used by vasectomized men in order to prevent delivery of the drug via seminal fluid',
#  'Measurable or evaluable disease by Response Evaluation Criteria in Solid Tumors RECIST version v 1.1',
#  'chronic obstructive pulmonary disease',
#  'Patients undergoing open elective liver resection for primary liver pathology benign or malignant or secondary metastatic liver disease including patients undergoing concomitant surgical procedures such as colorectal resection or debulking procedures , with no contraindication to the insertion of an epidural catheter localized infection septicemia or pre-operative coagulopathy',
#  'Ulcer not of VLU pathophysiology e.g., pure diabetic vasculitic radiation, rheumatoid collagen vascular disease pressure, or arterial etiology',
#  'Patients with evidence of uncontrolled bacterial viral or fungal infections currently taking medication and progression of clinical symptoms within one month prior to starting the conditioning regimen',
#  'Total and ionized serum calcium outside of normal limits',
#  'patients with confirmed Gilberts syndrome the TBil should be less than or equal to 1.5 SqrRoot ULN',
#  'Sexually active participants must agree to use adequate birth control for the during the study period from before the start of the preparative chemotherapy through 1 year post-transplant',
#  'Intensive medical treatment means that the subject is undergoing chemotherapy for a hematologic/oncologic condition, is carrying a pacemaker or has been diagnosed with a cardiac anomaly which causes cardiac insufficiency not compensated with medications',
#  'Serum glutamic oxaloacetic transaminase SGOT aspartate aminotransferase AST =< 3 x ULN obtained =< 21 days prior to registration',
#  'Hemoglobin 6 gm/dL',
#  'female',
#  'At least 2 years postmenarche',
#  'Prevalent congestive heart failure prior to randomization',
#  'Treatment with a cholinesterase inhibitor or an NMDA N-methyl-D-asparate antagonist with stable dose for at least 12 weeks',
#  'receiving immunosuppressive therapy',
#  '9 to 14 years of age',
#  'Hb< 5 g/dl',
#  'The patient should not have any serious medical of psychiatric illness that would prevent either the giving of informed consent or the receipt of treatment',
#  'Patients with prior contraindications for the use of irinotecan gemcitabine or cisplatin',
#  'No evidence of coronary heart disease',
#  'female',
#  'severe uncontrolled ventricular arrhythmias',
#  'Smoking history > 10 pack years',
#  'Clinical evidence of bowel obstruction at the time of study enrollment',
#  'Not on current androgen deprivation therapy or plan for withdrawal of androgen deprivation therapy',
#  'Failed to make adequate improvement and must initiate Acthar Gel therapy within two weeks +/- 72 hours after the first day of 5 treatments with 1000 mg IVMP as judged by their treating neurologist',
#  'Women of child-bearing potential must agree to use adequate contraception hormonal or barrier method of birth control abstinence starting the day entering the study, and for 60 days after injection of the imaging agent',
#  'Absolute neutrophil count 1,500/mcL',
#  '18- 85 years old',
#  'Previous treatment with a c-MET inhibitor or HGF-targeting therapy applies only to Group 2',
#  'Stable on ivacaftor/lumacaftor dosing for both label indication and per label dosing for a minimum of 3 months at the time of dosing',
#  'Prior local therapies such as surgical resection radiofrequency ablation or alcohol injection are allowed as long as tumor progresses from the prior treatment and the patients are still candidates for TAE All prior therapy must be at least 4 weeks prior to enrollment and free from treatment-related toxicity',
#  'archival sections within 4 months of sectioning that have been stored at 2 degree to 8 degree Celsius in the dark',
#  'Patients with known HIV positivity or AIDS-related illness',
#  'Regimens for transplantation',
#  'Clinical Dementia Rating Scale score greater than 0',
#  'Total abstinence from sexual intercourse minimum one complete menstrual cycle prior to study drug administration',
#  'Male',
#  'Patient is currently receiving prostacyclin therapy Epoprostenol Flolan or Veltri , Iloprost Ventavis Treprostinil Orenitram oral Remodulin, IV or SC',
#  'Undergoing or planned chemotherapy immunotherapy or hematopoietic stem cell transplantation',
#  'Systemic corticosteroids at physiologic doses not to exceed 10 mg/day of prednisone or equivalent',
#  'Concordant for autoimmune neurological disease s as determined by neurological evaluation',
#  'DONOR: HLA-matched sibling cord blood exclusions: Any cord blood units that have not passed donor screening for infectious disease markers as recommended by the National Marrow Donor Project NMDP will not be used unless a waiver is signed by the clinical attending allowing use of cord blood unit; cord blood units are presumed to be cytomegalovirus CMV negative regardless of serologic testing due to passive transmission of maternal CMV antibodies',
#  'Occasionally donor derived engraftment may be present, but sustained aplasia or failed recovery of sufficient hematopoiesis requires administration of a second graft',
#  'Adequacy of collected material will be determined within 5 business days of each collected case',
#  'Hypertension as defined by the Seventh Report of US National Committee on Prevention, Detection, Education and Treatment of High Blood Pressure or hypertensive medications',
#  'Axis-I psychotic disorder',
#  'mean arterial pressure 65 mmHg',
#  'Examples include remote > 30 days participation in a thoracic, abdominal or iliac branch device trial or participation in a percutaneous aortic valve trial',
#  'Other immunosuppressive immunosuppressive therapies include all cancer chemotherapeutic agents drugs to prevent transplant rejection interferons monoclonal antibodies protein kinase inhibitors methotrexate TNF tumor necrosis factor inhibitors and any other drug determined to be immunosuppressive by the PI',
#  'For patients whose CURRENT disease is vascular only: Enhancing vascular thrombosis involving portal vein, IVC and/or hepatic vein demonstrating early arterial enhancement and delayed washout on multi-phasic CT or MRI in a patient with known HCC diagnosed according to criteria in a or b',
#  'Female patients who are lactating or have a positive serum pregnancy test during the screening period',
#  'Previously undergone 2 cycles of lenalidomide and a proteasome inhibitor in separate therapeutic regimens not for maintenance or in combination',
#  'EaTCL',
#  'Prior monoclonal antibody within 4 weeks prior to first dose of study drug',
#  'Evidence of metastatic disease',
#  'T 1-2N+MO or T3-4 NxMo or borderline resectable and unresectable adenocarcinoma without distant metastatic disease or resectable T3-4 NxMo disease or M1 with controlled distant disease',
#  "Chronic disease such as heart or renal failure would raise the participant's risk of adverse events during hyperbaric oxygen",
#  'CD4 nadir 500 cells/mm3',
#  'prior to evidence of vaccine clearance',
#  'Liver transplant',
#  'A parent or legal guardian of a patient < 18 years of age will provide informed consent and patients 11 to 18 years of age will provide written assent or as per participating institutional policy',
#  'Psychotropic medication free or on stable psychotropic medication no changes in past 6 weeks and no planned changes for the next 6 months',
#  'Adequately treated psychiatric disorders and appropriate psychotropic medications',
#  'Less than 70% of liver parenchymal tumor replacement',
#  'Active cancer with or without metastases',
#  'Karnofsky 80% subjects 16 years of age',
#  'Platelets plts > 90,000',
#  'currently taking steroids and/or benzodiazepines',
#  'Uncontrolled viral or bacterial infection at the time of study enrollment',
#  'Current known active or chronic infection with human immunodeficiency virus HIV Hepatitis B or Hepatitis C',
#  'Transplant recipient able to give informed consent',
#  'Documented visceral metastases or current lymphadenopathy > 3 cm by standard imaging e.g. MRI CT ultrasound FDG PET CT',
#  'Significant liver disease defined as known cirrhosis or elevated transaminases of at least 3- fold upper limit of normal',
#  'Active systemic infection',
#  'Patient does not have a support person ie. Spouse, partner, mother available to support the patient for the duration of the pregnancy',
#  'Advanced or metastatic esophageal and/or gastric cancer 15- 30 enrollment slots',
#  'report having had a severe adverse reaction to study medications',
#  'Aged 18- 69 years',
#  'requirement for red blood cell and/or platelet transfusions',
#  'Immunotherapy Interferons Cytokines except PD-1/PD-L1 antagonists',
#  'Elevated serum PSA prostate specific antigen> 4 ng/ml and/or abnormal digital rectal exam',
#  'Patients must have smart phone and/or device for app usage',
#  'Relapsed or primary refractory metastatic',
#  'Head trauma central nervous system injury',
#  'Patients who are a serious suicide or homicide risk',
#  'acute decompensated HF',
#  'diabetic retinopathy',
#  'Subjects with known liver cirrhosis in severity that would preclude tolerability of cyclosporine and eltrombopag as evidenced by albumin < 35g/L',
#  'platelets < 100,000/ L',
#  'primary anxiety disorder or primary eating disorders primary refers to the diagnosis associated with the most functional impairment',
#  'Patients with stabilizing implants in the bone where the cyst is located',
#  'Status of HIV must be confirmed via a HIV antibody test or other confirmatory tests available within 12 months before screening or at screening',
#  'Breath alcohol level > 0.01 participants with a positive screen will be allowed to re-screen once',
#  'Total bilirubin 1.5 x ULN upper limit of normal',
#  'ALT and AST 2.5 X upper limit of normal ULN',
#  'Patients must not have an uncontrolled bacterial fungal or viral infection defined as progressive symptoms despite therapy at the time of the CD8+ memory T-cell infusion',
#  'Commit to using birth control during the study all participants',
#  'Recurrent ovarian cancer',
#  'Be able to read, write, and speak English',
#  'Prior whole-lung or hemi-thorax irradiation of greater than 12 Gy received less than 6 months prior to consent',
#  'history of deep vein thrombosis or pulmonary embolus',
#  'lactating females',
#  'Subjects must have an Eastern Cooperative Oncology Group ECOG Performance Status of 0- 2',
#  'Newly diagnosed acute lymphoblastic leukemia lymphoma',
#  'previous treatment with ketotifen',
#  'Pregnant or breast-feeding females are excluded because of the potential mutagenic effects on a developing fetus or newborn',
#  'Infiltrating ductal carcinoma or DCIS stage T0 T1 and T2 less than or equal to 3.0 cm N0 and M0',
#  'Adequately treated non-melanomatous skin cancer or lentigo maligna without evidence of disease',
#  'Insulin dependent diabetes mellitus',
#  'total bilirubin 2.5 X institutional upper limit of normal',
#  'Patients receiving IV tPA > 3 hours from stroke onset',
#  'Hamilton Depression Rating Scale-24 HRSD-24 score 24 HRSD-24 score of 8- 24',
#  'Surgery intent within 4 weeks',
#  'A female of childbearing potential is a sexually mature woman who: 1 has not undergone a hysterectomy or bilateral oophorectomy or 2 has not been naturally postmenopausal for at least 24 consecutive months i.e., has had menses at any time in the preceding 24 consecutive months',
#  'active acute or chronic or uncontrolled severe infections',
#  'Either has a diagnosis of PAH isolated left heart disease or lung disease chronic obstructive pulmonary disease or interstitial lung disease or CTEPH using established clinical criteria',
#  'Planning to initiate treatment with doxorubicin starting dose 75 mg/m2 as routine care',
#  'Has a known psychiatric or substance abuse disorders that would interfere with cooperation with the requirements of the trial',
#  'A child with a catheter- associated UTI',
#  'If malignancy- associated microcalcifications were initially present, the post-excision mammography must be negative',
#  'evidence of lung and other organ involvement renal angiomyolipomas chylous effusions lymphangioleiomyomas',
#  'Epilepsy with history of seizures',
#  'Concurrent use of amifostine concurrent abdominal radiotherapy concurrent use of quinolone antibiotic therapy',
#  'be able to ambulate at least household distances 50ft',
#  'At least 18 years of age',
#  'Male',
#  'Known active CNS metastases',
#  'Diagnosed with MAS under 98-D-0145',
#  'Patient must have completed a minimum of 8 weeks of standard neoadjuvant chemotherapy consisting of an anthracycline and/or taxane-based regimen',
#  'bone marrow metastases plus high urine catecholamine levels',
#  'Osteoporosis or recent fracture of the hip or spinal joints',
#  'with unilateral or bilateral inguinal herna for laparoscopic repair',
#  'Corticosteroid injection at treatment site within 1 month',
#  'ECOG Performance Status 0- 1',
#  'Allergy or adverse reaction to dextromethorphan vitamin A or isotretinoin',
#  'Participation in an investigational drug or device study that would impact the safety or scientific integrity of this study in the opinion of the Investigator and with the approval of the Sponsor within the past 6 weeks prior to enrollment into this trial',
#  'Known sensitivity to conductive hydrogels',
#  'Caregiver severe cognitive impairment',
#  'Current smoking or history of smoking in the past 12 months',
#  'For 18 year olds',
#  'Patients with history of prior pelvic irradiation',
#  "Subject has a lifetime history of suicide attempt including an active attempt, interrupted attempt, or aborted attempt , or has suicidal ideation in the past 6 months as indicated by a positive response 'Yes' to either Question 4 or Question 5 of the C-SSRS at Screening",
#  'AST ALT 2 times upper limit of normal ULN',
#  'Human papillomavirus HPV 16-positive disease by PCR',
#  'Patients who have had prior treatment with LY2606368 or other Chk inhibitors',
#  'Test negative for recent cannabis use in urine at the screening visit confirmed by Gas Chromatography GC Mass Spectrometry MS laboratory test and at clinic admission',
#  'schizophrenia',
#  'women of childbearing potential',
#  'who have not been on gonadal steroid preparations for at least 1 month',
#  'Pregnant',
#  'Absolute neutrophil count ANC >= 1,500/mcL',
#  'Patients with a known hypersensitivity to Everolimus or other rapamycins sirolimus temsirolimus or to its excipients',
#  'Clinically significant cardiac/cardiovascular disease or pulmonary compromise',
#  'radiculopathy',
#  '18 years of age or older',
#  'Gastrointestinal Bleed',
#  'Known positive for human immunodeficiency virus HIV or with known active infectious hepatitis, type A, B or C',
#  'Women who exhibit serious psychiatric symptoms determined by CNO trained staff',
#  'Patients who have disease relapse, active GVHD or history of more than Stage 1 skin acute GVHD history of cGVHD',
#  'Patients with thyroid disease',
#  'Immunocompromised patients, e.g., patients who are known to be serologically positive for human immunodeficiency virus HIV and are receiving antiviral therapy testing is not part of the protocol',
#  'Subjects with a positive Hepatitis B surface antigen and/or antihepatitis B core antibody',
#  'Men must agree to use adequate contraception prior to enrollment, for the duration of study participation and for at least 3 months thereafter',
#  'Serum creatinine 1.5 x ULN',
#  'History of seizure disorder',
#  'Participants who have received any other investigational agents within the 4 weeks prior to enrollment; concurrent radiation therapy',
#  'ALT or BUN > 2.0 ULN or estimated creatinine > 1.5 X ULN for age or any other laboratory abnormality considered by the Investigator to be clinically significant within 14 days before Screening']

# %%
input_cost_per_1k_tokens = 0.0015
output_cost_per_1k_tokens = 0.002
total_cost =  0
doller_to_rs = 83.19


def calculate_gpt_cost(result:Dict, input_cost_per_1k_tokens:float, output_cost_per_1k_tokens:float)->float:
    
    """
    Args:
    result: Response json from the gpt output
    input_cost_per_1k_tokens: The model usage cost for input tokens as mentioned by openai for model being used
    output_cost_per_1k_tokens: The model usage cost for output tokens as mentioned by openai for model being used
    
    Returns
    Total cost for GPT model in the Session
    """
    
    prompt_tokens = result["usage"]['prompt_tokens']
    completion_tokens = result["usage"]['completion_tokens']

    total_input_cost = (prompt_tokens / 1000) * input_cost_per_1k_tokens
    total_output_cost = (completion_tokens / 1000) * output_cost_per_1k_tokens
    total_cost = total_input_cost + total_output_cost

    return total_cost

# %%
instructions = """ Identify and extract entities from the inclusion/exclusion criteria of a clinical trial. Categorize the extracted entities based on the provided tags. If there are any numerical values, categorize them with appropriate lower_bound or upper_bound tags as needed.

Categories and sample entities for each tag:

- technology_access: ["working cellphone or landline", "cell phone", "touch-tone telephone keypad"]
- bmi: ["Body Mass Index", "BMI"]
- chronic_disease: ["metabolic bone disorder", "hypertension", "GI disease", "class IV heart failure"]
- gender: ["Female participants", "Men or women", "male", "Women"]
- contraception_consent: ["Agree to practice effective barrier contraception", "agree to use adequate contraception"]
- age: ["age"]
- Cancer: ["cervical cancer", "acute lymphoblastic leukemia ALL", "lymphoblastic lymphoma LL", "cancer"]
- language_fluency: ["Lack of English fluency", "not English speaking", "must be English speaking"]
- treatment: ["structured barium esophagram", "therapy", "radiotherapy", "investigational agents"]
- ethnicity: ["European ancestry", "Caucasian", "Black", "Latino"]
- clinical_variable: ["fundus autofluorescence", "Gleason score", "Hemoglobin", "eGFR", "Heart rate"]
- pregnancy: ["currently pregnant", "Pregnant", "unable to become pregnant"]
- allergy_name: ["stainless steel", "polyester", "abiraterone acetate"]

- For each sentence, extract and categorize the entities.
- If there are numerical values, use the format lower_bound/upper_bound as appropriate.
  for example, less than gives upper_bound, greater than gives lower_bound  

Examples 1:
Input Sentence: 
[1. "Subject has a history of hospitalization for acute illness in the previous 3 months"
2. "age less than 30"
3. "Auto-immune disease, acute stage (e.g., rheumatoid arthritis)"
4. "Singleton pregnancy"
5. "Current pregnancy"]

Output:
{"senttence_1":[{"label": "treatment","value": "hospitalization"},{"label": "chronic_disease", "value": "acute illness"},{"label": "upper_bound", "value": "previous 3 months"}],
"senttence_2":[{"label": "age", "value": "age"},{"label": "upper_bound", "value": "30"}],
"senttence_3":[{"label": "chronic_disease", "value": "Auto-immune disease"}, {"label": "clinical_variable", "value": "acute stage"}, {"label": "clinical_variable", "value": "rheumatoid arthritis"}],
"senttence_4" :[{"label": "pregnancy", "value": "Singleton pregnancy"}}],
"senttence_5" :[{"label": "pregnancy", "value": "Current pregnancy"}}]
}

it very very important to Always follow below Instruction 
## Give the reult only in the mentioned format that is Dict[str,List[Dict[str,str]]]and do not give the sentences
### Extract for the below-mentioned  5 sentences:

"""

# %%
def prompt_maker(instructions:str , sentences_to_predict:str)->str:
    
    """
    Args:
    This function takes the input as instructions to the model and the sentences to predict and returns prompt
    instructions: Common Instructions to the model
    sentences_to_predict: The senetnces/words to be predicted
    
    Returns:
    Final prompt 
    """
    
    prompt = instructions + sentences_to_predict
    
    return prompt

# %%
def entity_extractor(prompt:str)-> Sequence[[str, float]]:
    
    """
    Args 
    prompt : prompt containing the insturnctions and sentences from which entities to be extracted
    
    Returns
    result : The extracted ENtities from the sentences
    cost : Cost for the GPT model for the Session
    """
    
    messages = [
        {"role": "system", "content":"You are a helpful assistant who is helping in extracting entites from the sentences"},
        {"role": "user", "content": prompt}
    ] 
    response  = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      messages=messages,
      max_tokens=1000,
      temperature=0
    )
    
    cost = calculate_gpt_cost(response,input_cost_per_1k_tokens, output_cost_per_1k_tokens )
    result = response["choices"][0].message['content']
    
    return result , cost

# %%
batch_size= 5
start_index =  0
end_index = batch_size
total_batches = int(len(sentences_to_predict)/batch_size)
final_result_gpt = []
error_results =[]
for i in range(total_batches):
    print(f"Current Iteration :  {i} ")
    sentences_to_extract = sentences_to_predict[start_index:end_index]
    print(f"Sentences to predict {sentences_to_extract}")
    start_index= end_index
    end_index = end_index+batch_size
    
    sent = []
    num_of_sentences = len(sentences_to_extract)
    for j in range(num_of_sentences):
        sent.append(f'{j+1}. "{sentences_to_extract[j]}"')
        
    extract = "\n".join(sent)
    
    prompt = prompt_maker(instructions, extract)
    result , cost = entity_extractor(prompt)
    total_cost = total_cost + cost
    try:
        result_dict = eval(result)
        if len(result_dict.keys())==batch_size:
            for key in result_dict.keys():
                final_result_gpt.append(result_dict[key])
        else:
            for k in range(batch_size):
                final_result_gpt.append("None")
                
    except Exception as e:
        print(f"Error {e}")
        print(f"The result is {result}")
        error_results.append(result)
        for jk in range(batch_size):
            final_result_gpt.append("None")
            
    print(f"iteration {i} completed and complted for total {len(final_result_gpt)} sentences")
    print("-"*100)
# Out:
# Current Iteration :  0
# Sentences to predict ['Subject is suitable for oral administration of study drug', 'Current pregnancy', 'Singleton pregnancy', 'All patients currently taking steroids at the time of surgery or during the six-week recovery period as well as patients with betamethasone hypersensitivity', 'rheumatic valve disease since this produces a unique AF phenotype']
# iteration 0 completed and complted for total 5 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  1
# Sentences to predict ['Severe liver dysfunction LFT 3X upper limit of normal', 'Serum M-protein >= 1.0 g/dL', 'Males or females', 'Negative for malignancy for past 5 years', 'available for up to 6 hrs every day for two 2-week test periods with an intervening break of 7- 10 days each']
# iteration 1 completed and complted for total 10 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  2
# Sentences to predict ['Diagnosis of recurrent and/or metastatic thyroid cancer', 'No other investigational or commercial therapeutic agents may be given concurrently with the paclitaxel', 'Mean arterial pressure < 65', 'White blood cells WBC > 15,000 cells/mcL at screening', 'Acute medical illness']
# iteration 2 completed and complted for total 15 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  3
# Sentences to predict ['At least one prior chemotherapy', 'History of prior thromboembolism with known thrombophilia', 'Inability to tolerate stationary position during HIFU', 'Known history of hepatitis B defined as hepatitis B survace antigen HBsAg reactive or known active hepatitis C defined as HCV RNA qualitative is detected infection', 'History or concurrent condition of interstitial lung disease of any severity and/or severely impaired lung function']
# iteration 3 completed and complted for total 20 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  4
# Sentences to predict ['Diabetes Mellitus', 'Seizure disorder requiring medication', 'Body mass index BMI >= 25 kg/m^2', 'Life expectancy of at least 12 weeks', 'History/physical examination to include at a minimum digital rectal examination of the prostate and examination of the skeletal system and abdomen within 90 days prior to registration']
# iteration 4 completed and complted for total 25 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  5
# Sentences to predict ['no secondary primary lung cancer diagnosed concurrently or within 2 year prior to registration', 'Subjects who have a positive serum human chorionic gonadotropin hCG', "Total bilirubin: =< 1.5 x institutional upper limit of normal ULN or =< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation, and must have a total bilirubin less than 3.0 mg/dL within 2 weeks prior to enrollment participants may receive GCSF and transfusions to meet these parameters", 'Other neurological diagnosis', 'Major neurological disorder']
# iteration 5 completed and complted for total 30 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  6
# Sentences to predict ['Anti-tumor necrosis factor agents', 'Clinically significant heart disease as evidenced by myocardial infarction or arterial thrombotic events in the past 6 months severe or unstable angina or New York Heart Association NYHA class II- IV heart disease', 'In normal sinus rhythm ECG documented within the two weeks prior to the screening Holter', 'Women of childbearing potential must have a negative pregnancy test to participate in this study', 'Hematologic abnormalities e.g., pancytopenia aplastic anemia']
# iteration 6 completed and complted for total 35 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  7
# Sentences to predict ['Poor English comprehension', 'Documented diagnosis of multiple myeloma according to International Myeloma Working Group IMWG diagnostic criteria', 'Patients with a history of hypercontractile bladder non-compliant bladder hydronephrosis or neurogenic bladder', 'Patients 40 - 59 years of age with 15% TBSA', 'at least 2 years of age']
# iteration 7 completed and complted for total 40 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  8
# Sentences to predict ['Paediatric patients aged 1 year to < 18 years at the time of informed consent', 'Therapeutic antibodies such as bevacizumab', 'Have postmenopausal status due to either surgical/natural menopause or ovarian suppression initiated at least 28 days prior to Day 1 of Cycle 1 with a gonadotropin-releasing hormone GnRH agonist such as goserelin', 'Pancreatic Cancer Patients who are potentially surgically resectable', 'Patient has experienced lower urinary tract symptoms LUTS for at least 1 year prior to study enrollment']
# iteration 8 completed and complted for total 45 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  9
# Sentences to predict ['Prior implantation of a pacemaker ICD', 'spinal block are unsafe to undergo BBBD chemotherapy and are not eligible', 'are linked to care/evaluation within 30 days of diagnosis', 'Dry weight and height parameters obtained within 7 days prior to study entry may be used', 'antipsychotics']
# iteration 9 completed and complted for total 50 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  10
# Sentences to predict ['lactating women', 'SGPT ALT 5 x ULN for age', 'Pregnant', 'Subject with a history of anaphylaxis attributed to an echinocandin', 'possibly pregnant']
# iteration 10 completed and complted for total 55 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  11
# Sentences to predict ['Prior ipsilateral knee surgery such as ligament reconstruction or osteotomy', 'congestive heart failure', 'Ongoing, tapering therapy for resolved acute GVHD is permissible', 'IV docetaxel 75 mg/m^2 5 mg/m^2 and carboplatin AUC 5- 6 every 21 days', 'documented agreement to use an effective form of birth control']
# iteration 11 completed and complted for total 60 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  12
# Sentences to predict ['HIV- positive patients on combination antiretroviral therapy are ineligible because of the potential for pharmacokinetic interactions with LY2606368', 'ECOG performance status less than or equal to 2 Karnofsky greater than or equal to 60%', 'Metastatic breast cancer 7 triple negative, 23 ER after the first 15 patients are enrolled on the non- CCND1c ohort; in addition 10 HER2 for combination trastuzumab and PD0332991 therapy up to 55 total enrollment slots B', '> 18 years old', 'Parts A & C: patients with recurrent or refractory solid tumors without central nervous system CNS tumors or known CNS metastases']
# iteration 12 completed and complted for total 65 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  13
# Sentences to predict ['Known history of testing positive for human immunodeficiency virus HIV or known acquired immunodeficiency syndrome AIDS', 'planned surgery requiring general anesthesia during the pharmacotherapy period', 'Maximal diameter of any one hepatocellular carcinoma > 15 cm', 'Females must be menopausal or have had a bilateral oophorectomy', 'female']
# iteration 13 completed and complted for total 70 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  14
# Sentences to predict ['For Control Group: NO diagnosis of ADHD as determined by clinician administered CAADID and clinical interview', 'Other active malignancy =< 3 years prior to registration', 'Concurrent intensive induction chemotherapy radiotherapy or biologic treatment for active malignancy subjects on maintenance chemotherapy may only be enrolled after consultation with the study medical monitor', 'Patients for who CEM carboplatin, etoposide, melphalan therapy therapy is administered within 30 days 30 days prior to 131I-MIBG therapy 131I-MIBG therapy or for whom this therapy is planned within 30 days following administration of 131I-MIBG', 'HIV positive with CD4 count < 350 cells/microliter']
# iteration 14 completed and complted for total 75 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  15
# Sentences to predict ['at least 6 times duration of the reported half life or minimum four 4 months for other depot or long-acting antipsychotics', 'Known positive Hepatitis B antigen HBs Ag unless positive test can be attributed to receipt of Hepatitis B vaccination in childhood or Hepatitis C viral antibody HCV with evidence of active hepatitis i.e., AST ALT greater than two times the ULN', 'Sexually active males must use a condom during intercourse', 'Active, uncontrolled infection and/or human immunodeficiency virus HIV positive constitute progressive disease', 'a contraceptive implant']
# Error unmatched '}' (<string>, line 2)
# The result is {"sentence_1": [{"label": "clinical_variable", "value": "duration"}, {"label": "clinical_variable", "value": "reported half life"}, {"label": "lower_bound", "value": "6 times"}, {"label": "lower_bound", "value": "minimum four 4 months"}, {"label": "treatment", "value": "depot or long-acting antipsychotics"}]},
# "sentence_2": [{"label": "chronic_disease", "value": "Hepatitis B antigen HBs Ag"}, {"label": "clinical_variable", "value": "positive test"}, {"label": "clinical_variable", "value": "Hepatitis B vaccination"}, {"label": "clinical_variable", "value": "Hepatitis C viral antibody HCV"}, {"label": "clinical_variable", "value": "active hepatitis"}, {"label": "clinical_variable", "value": "AST ALT"}, {"label": "lower_bound", "value": "two times"}, {"label": "clinical_variable", "value": "ULN"}]},
# "sentence_3": [{"label": "gender", "value": "Sexually active males"}, {"label": "contraception_consent", "value": "use a condom during intercourse"}]},
# "sentence_4": [{"label": "chronic_disease", "value": "Active, uncontrolled infection"}, {"label": "clinical_variable", "value": "human immunodeficiency virus HIV positive"}, {"label": "clinical_variable", "value": "progressive disease"}]},
# "sentence_5": [{"label": "contraception_consent", "value": "a contraceptive implant"}]}
# iteration 15 completed and complted for total 80 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  16
# Sentences to predict ['Preoperative evaluation to rule-out extra-uterine disease may include CT scan, MRI, or ultrasound', 'people who are extremely claustrophobic', 'current or previous history of malignancy', 'Report drinking on 80% of days in the past 90 days', 'Must be fluent in English']
# iteration 16 completed and complted for total 85 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  17
# Sentences to predict ['Recent within 6 months prior to index procedure date cerebrovascular accident CVA or a transient ischemic attack TIA', 'Have progression during or following platinum-containing chemotherapy or within 1 2 months of neoadjuvant or adjuvant treatment with platinum-containing chemotherapy', 'At least 4 weeks since receiving any investigational drug', 'have an allergy to gadolinium Gd contrast material', 'Wheezing on exam']
# iteration 17 completed and complted for total 90 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  18
# Sentences to predict ['Has not recovered to Grade 1 from toxic effects of prior therapy', 'Subjects with any known uncontrolled inter-current illness including ongoing or active infection symptomatic congestive heart failure NYHA Gr.2 or > , myocardial infarction unstable angina pectoris within the past 12 months', 'Age > 18 and < 75 years', 'Patients with recurrent carcinoma of the vulva regardless of previous treatment', 'PaO2/FiO2 300']
# iteration 18 completed and complted for total 95 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  19
# Sentences to predict ['Individuals willing to participate in a randomized clinical trial of amyloid imaging disclosure', 'Healthy infants 4 to 6 months of age', 'Presence of asthma', 'Bleeding disorder', 'Age 18 years or older']
# iteration 19 completed and complted for total 100 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  20
# Sentences to predict ['Prior therapy with one second line hormonal therapy is allowed i.e. bicalutamide nilutamide flutamide ketoconazole abiraterone enzalutamide ARN-509', 'This test is now done routinely for every newly diagnosed endometrial cancer patient in most centers in the US', 'Active central nervous system lymphoma', 'other autoimmune diseases', 'This includes, but is not limited to: acute myeloid leukemia AML acute lymphoblastic leukemia ALL chronic myelogenous leukemia CML chronic lymphocytic leukemia CLL non-Hodgkin lymphoma NHL Hodgkin lymphoma NHL , Hodgkin lymphoma, multiple myeloma MM myelodysplastic syndrome MDS AL amyloidosis diamond blackfan anemia myelofibrosis or other myeloproliferative disease sickle cell anemia and thalassemia']
# iteration 20 completed and complted for total 105 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  21
# Sentences to predict ['Tumor sample must be available for HPV p16 and PD-L1 testing', 'ECOG status 3 or 4', "Any serious and/or unstable pre-existing medical psychiatric or other condition that could interfere with subject's safety, provision of informed consent, or compliance to study procedures", 'Have any medical conditions that prevent subject from safely exercising e.g., orthopedic injuries, cardiovascular liver endocrine or pulmonary diseases', 'Patients with any prior history of lung cancer']
# iteration 21 completed and complted for total 110 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  22
# Sentences to predict ['Ongoing cord compression or a syrinx in the spinal cord or who suffer from a spinal cord disease such as spinal stenosis spina bifida or herniated cervical disk', 'nursing woman', 'pregnant women', 'myocardial infarction < 6 months before enrollment', 'Sickle cell anemia']
# iteration 22 completed and complted for total 115 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  23
# Sentences to predict ['Myelodysplastic syndrome', 'patients who have received corneal transplants cadaver skin or bone transplants are eligible', 'Lovaza prescription fish oil and not willing to go off Lovaza for 3 weeks prior to enrollment to end of study', 'Presence of cardiac condition, asthma obstructive pulmonary disease seizure disorder urinary incontinence and/or peptic ulcer disease receiving concurrent NSAIDs', 'Karnofsky performance status >= 70%']
# iteration 23 completed and complted for total 120 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  24
# Sentences to predict ['Grade 4 - Fibrosis', 'Follicular 17-hydroxyprogesterone > 300 ng/dl which suggests the possibility of congenital adrenal hyperplasia', 'Current oral steroid use > 4 weeks prior to registration', 'Not pregnant', 'History of DVT or pulmonary embolism within 6 months']
# iteration 24 completed and complted for total 125 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  25
# Sentences to predict ['Hepatitis C positive donor liver', 'Renal insufficiency creatinine > 1.5 mg/dL', 'Administration of any investigational agent =< 30 days prior to pre-registration', 'for subjects who are receiving warfarin for prophylaxis or treatment of thrombosis INR values should be carefully monitored while patients are on study', 'Patients must be >/= 18 years of age']
# iteration 25 completed and complted for total 130 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  26
# Sentences to predict ['Documented history of a cerebral vascular event stroke or transient ischemic attack , unstable angina myocardial infarction or cardiac symptoms including congestive heart failure consistent with New York Heart Association Class III- IV within 6 months prior to the first dose of enfortumab vedotin', 'Eligible for breast conserving surgery lumpectomy and radiation', 'age > 49', 'Current use of medication that may involve potentially dangerous interaction with propranolol', 'Subjects who have received rIX-FP for 100 EDs single-dose cohorts or for 50 EDs repeated-dose cohort']
# iteration 26 completed and complted for total 135 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  27
# Sentences to predict ['Bilirubin 2 x the ULN', 'History of organ allograft including corneal transplant', 'Autologous stem cell transplantation SCT within 100 days prior to study drug or any prior allogeneic SCT or solid organ transplantation', 'Diagnosis of type 2 diabetes', 'History of an active malignancy within the last 3 years']
# iteration 27 completed and complted for total 140 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  28
# Sentences to predict ['All adverse events Grade > 1 related to prior therapies chemotherapy radiotherapy and/or surgery must be resolved, except for alopecia', 'Pre-bronchodilator 50% FEV1 of < 85 % of the predicted normal value for the patient after withholding bronchodilators at both Visit 101 and 102, according to ATS/ERS criteria', 'Prior treatment with cetuximab for incurable disease is not permitted', 'Patients who are taking any herbal alternative medicines are NOT eligible for participation', 'Age 21 years']
# iteration 28 completed and complted for total 145 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  29
# Sentences to predict ['Subjects who have received prior intravesical chemotherapy are allowed', 'a case by case determination will be made by study physician for medication on precautionary list, i.e. nitroglycerin', 'Severe aortic regurgitation > 3', 'A serious psychiatric or medical condition which, in the opinion of the Investigator, could interfere with treatment', 'Donors must be >= 17 years of age']
# iteration 29 completed and complted for total 150 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  30
# Sentences to predict ['Disease: FL Criteria for diagnosis: histopathologic confirmation', 'age 16 years of age or older and weighs', 'Interval from start of initial radiation therapy to enrollment > 9 months', 'diabetes requiring medication', 'Not pregnant or nursing and report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal']
# iteration 30 completed and complted for total 155 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  31
# Sentences to predict ['Pregnant women', 'Known active hepatitis B hepatitis B e.g., hepatitis B virus surface antigen HBsAg reactive or hepatitis C e.g., hepatitis C virus HCV ribonucleic acid RNA qualitative is detected', 'he/she must have a pretreatment calculated creatinine clearance of >= 50 mL/minute', 'Second primary malignancy malignancy except most situ carcinoma e.g. in situ carcinoma of the cervix adequately treated non-melanomatous carcinoma of the skin or other malignancy treated at least 5 years previously with no evidence of recurrence', 'Patients who received iodinated intravenous contrast as part of a radiographic procedure within 3 months of study registration']
# iteration 31 completed and complted for total 160 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  32
# Sentences to predict ['History or presence of clinically relevant CNS pathology such as uncontrolled seizure disorder recent stroke severe brain injuries dementia cerebellar disease or psychosis', 'Patients with solid tumors must have measurable disease Response Evaluation Criteria in Solid Tumors RECIST 1.1', 'Patients with refractory-relapsed ALL of any age are eligible', 'Active or recurrent herpes or varicella-zoster virus infection requiring treatment or chronic suppression', 'Severe hepatic impairment defined by two or more liver function enzyme values greater than 2.5 the upper limit of normal']
# Error unmatched '}' (<string>, line 2)
# The result is {"sentence_1": [{"label": "chronic_disease", "value": "clinically relevant CNS pathology"}, {"label": "clinical_variable", "value": "uncontrolled seizure disorder"}, {"label": "clinical_variable", "value": "recent stroke"}, {"label": "clinical_variable", "value": "severe brain injuries"}, {"label": "clinical_variable", "value": "dementia"}, {"label": "clinical_variable", "value": "cerebellar disease"}, {"label": "clinical_variable", "value": "psychosis"}]},
# "sentence_2": [{"label": "Cancer", "value": "solid tumors"}, {"label": "clinical_variable", "value": "measurable disease"}, {"label": "clinical_variable", "value": "Response Evaluation Criteria in Solid Tumors RECIST 1.1"}]},
# "sentence_3": [{"label": "Cancer", "value": "refractory-relapsed ALL"}, {"label": "age", "value": "any age"}]},
# "sentence_4": [{"label": "clinical_variable", "value": "herpes"}, {"label": "clinical_variable", "value": "varicella-zoster virus infection"}, {"label": "clinical_variable", "value": "treatment"}, {"label": "clinical_variable", "value": "chronic suppression"}]},
# "sentence_5": [{"label": "clinical_variable", "value": "hepatic impairment"}, {"label": "clinical_variable", "value": "liver function enzyme values"}, {"label": "lower_bound", "value": "2.5"}, {"label": "upper_bound", "value": "the upper limit of normal"}]}
# iteration 32 completed and complted for total 165 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  33
# Sentences to predict ['Other serious uncontrolled medical condition e.g., cancer or acute myocardial infarction', 'Aspartate aminotransferase AST and alanine aminotransferase ALT < 3 x the institutional upper limit of normal', 'Known hepatitis B surface antigen positivity', 'Must be between 2 and 40 years of age', 'Epilepsy partial seizure subjects']
# iteration 33 completed and complted for total 170 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  34
# Sentences to predict ['Patients of reproductive potential and their partners must agree to use an effective > 90% reliability form of contraception 90% reliability form of contraception during the study and for 4 weeks following the last study drug administration', 'Sufficient vascular access to receive study drug and to allow blood sampling at a site separate from the study drug infusion site', 'Untreated sleep apnea', 'Presence of a secondary headache disorder e.g., brain tumor', 'Prior bilateral orchiectomy']
# iteration 34 completed and complted for total 175 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  35
# Sentences to predict ['Is a known drug or alcohol abuser or has a psychological disorder that could affect the ability to complete patient reported questionnaires', 'Serum total bilirubin > 1.5 times the upper limit of normal ULN', 'HIV- positive patients are eligible, provided they are under treatment with highly active antiretroviral therapy HAART and have a CD4 count >= 200 cells/microliter no more than 30 days prior to registration', "total bilirubin =< upper normal institutional limits except for patients with Gilbert's disease who are eligible despite elevated serum bilirubin level", 'No prior RAI therapy therapy is allowed < 6 months prior to initiation of therapy on this protocol']
# iteration 35 completed and complted for total 180 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  36
# Sentences to predict ['who wish to become pregnant during the study period', 'lactating women', 'Poorly controlled depression', 'Male and females', 'ages 18 to 70']
# iteration 36 completed and complted for total 185 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  37
# Sentences to predict ['Adequate venous access in the arms for blood drawing and 5 day infusions, and lymphapheresis', 'Eastern Cooperative Oncology Group ECOG performance status PS 0 1, or 2', 'Insomnia complaints for 6+ months', 'No blood, sperm, or semen donation during and for 28 days after completion of study therapy', 'Patients presenting for hysterectomy for any benign indication including but not limited to abnormal uterine bleeding menorrhagia uterine fibroids adenomyosis pelvic pain dysmenorrhea pelvic organ prolapse or endometriosis']
# iteration 37 completed and complted for total 190 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  38
# Sentences to predict ['uncontrolled bacterial viral or fungal infection currently taking medication and with progression or no clinical improvement at time of enrollment', 'Women of childbearing potential must have a negative pregnancy test', 'Patient must consent to a biopsy of a site of disease unless the only site of disease is lung/pleura, bone, or deemed unsafe by the principal investigator', 'No distant metastases', 'Insulin requirement of > 1.0 U/kg/day or, > 60 U/day total or < 15 U/day']
# iteration 38 completed and complted for total 195 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  39
# Sentences to predict ['Residual symptoms will be defined as a total score of 110 and 60 of PANSS per Visit 1 evaluations', '10% or more probability of BRCA mutation by BRCAPRO or similar model', 'Previous therapeutic radiation in the region of the study eye', 'Metallic implant', 'Fluoxetine']
# iteration 39 completed and complted for total 200 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  40
# Sentences to predict ['Therapy-related MDS MDS defined as the occurrence of MDS due to prior exposure to systemic chemotherapy and/or radiation for malignancy', 'Recent weight change +/- 25 pounds in 1 year', 'Active varicella zoster infection', 'after fluid resuscitation Clinical definition of kidney damage', 'Prior monoclonal antibody within 4 weeks prior to study']
# iteration 40 completed and complted for total 205 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  41
# Sentences to predict ['Known, clinically significant carotid artery disease', 'Hypocitraturic CaP stone formers', 'Has received non-permitted inflammatory bowel disease IBD therapies including natalizumab vedolizumab and efalizumab as stated in the protocol', 'Known to be positive for human immunodeficiency virus HIV or infectious hepatitis type B or C', 'Measurable disease as defined by RECIST v1.1 criteria. Baseline measurements and evaluation of ALL sites of disease must be obtained within 4 weeks prior to Enrollment']
# iteration 41 completed and complted for total 210 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  42
# Sentences to predict ['Patient must have performance status of 0- 2 on the ECOG Performance Scale and life expectancy > 3 months', 'substrates of CYP 3A4/5 or CYP1A2 that are sensitive or have a narrow therapeutic window at least three weeks prior to study registration', 'Self- reported CPP defined as pelvic pain that is non-cyclical and of at least 6 months duration and refractory to other treatments', 'Current use of opioid pain medications', 'Diet with frequent 1- 2 days per week oily fish mackerel, salmon, sardines, cold water fish, et al']
# iteration 42 completed and complted for total 215 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  43
# Sentences to predict ['Individuals who are allergic to iodine', 'NYHA classification of III or IV', "History of connective tissue disorder e.g. vascular Ehlers Danlos Marfan's syndrome , with the exception of those patients who had prior open surgical aortic replacement or endovascular repair where a surgical graft or an endograft would serve as landing zone for the investigational endograft", 'Patients on PDEV inhibition for erectile dysfunction who are not willing to stop the medication for the duration of the study', 'More than one surgical procedure at any combination of lumbar levels']
# iteration 43 completed and complted for total 220 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  44
# Sentences to predict ['Patients who become pregnant after enrollment may be excluded from the study', 'alkaline phosphatase AP > 3 upper limit of normal ULN within 3 months of screening', 'Implanted pacemaker or cardiac defibrillator', "Informed consent must be signed by the participant's legally authorized guardian acknowledging written consent to join the study", 'Major birth defect or malformation syndrome']
# iteration 44 completed and complted for total 225 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  45
# Sentences to predict ['Patients 18 - 39 years of age with 15% TBSA', 'female', 'Known hypersensitivity to both allopurinol and rasburicase', 'Malabsorption syndrome', 'Subjects who are cognitively impaired']
# iteration 45 completed and complted for total 230 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  46
# Sentences to predict ['Phantom limb pain', 'Pregnancy', 'Child not completing all pre-procedure work-up within 10 days of the Stage II Glenn surgery as listed in section 6 of this protocol AND lack of pre-procedure work-up documented as a safety concern by a site investigator', 'Presence of any non-healing wound, fracture, or ulcer', 'nursing women']
# iteration 46 completed and complted for total 235 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  47
# Sentences to predict ['Patients with a past cancer history within 2 years of entry and/or ongoing active malignancy or substantial potential for recurrence must be discussed with the Sponsor before study entry', 'Any history of second or third degree heart block may be eligible of the subject currently has a pacemaker', 'Patients must not have a myocardial infarction within 6 months prior to registration', 'Patients who are on chronic transfusions for clinical stroke with MRA cerebral vasculopathy will be excluded since patients in the SWITCH study who were randomized to the hydroxyurea arm had recurrent stroke, while none in the chronic transfusion arm', 'Concomitant cardiac surgery']
# iteration 47 completed and complted for total 240 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  48
# Sentences to predict ['Alcohol use of more than 4 drinks per day', 'Age > = 18 years', 'History of acute pancreatitis within 1 year of study or history of chronic pancreatitis', 'Estimated glomerular filtration rate < 60 mL/min 1.73m2', 'Cochlear nerve deficiency']
# iteration 48 completed and complted for total 245 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  49
# Sentences to predict ['Creatinine 1.5 x institutional upper limit of normal OR creatinine clearance > 60 mL/min/1.73 m2 for subjects with creatinine levels above institutional normal', 'Radiation therapy for bone or brain metastasis within 2 weeks any other external radiation therapy within 4 weeks of first dose of study drug. Systemic treatment with radionuclides within 4weeks Subjects with clinically relevant ongoing complications from prior radiation therapy are not eligible', 'Platelets >= 100,000/mcL', 'HIV- 1 infected treatment- experienced, virologically suppressed males', 'Active, known or suspected autoimmune disease']
# iteration 49 completed and complted for total 250 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  50
# Sentences to predict ['patients with prostate cancer may continue LHRH agonists or antagonists', 'Age 18 yo and 60 yo for patients in Cohort 1 only', 'Third degree heart block', 'Confirmed diagnosis of intrahepatic carcinoma', 'Pregnant']
# iteration 50 completed and complted for total 255 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  51
# Sentences to predict ["Liver cirrhosis transaminases > 3x of normal limits or bilirubin > 2.0 unless due to Gilbert's disease", 'Absolute contraindications to liver biopsy including coagulopathy', 'English speaking', 'At least 18 years of age', 'Histologically documented CD20- positive B-cell lymphoma as determined by the local laboratory']
# iteration 51 completed and complted for total 260 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  52
# Sentences to predict ['Bilirubin < 3x AST <3x, Serum creatinine < 2x upper limit of normal Hgb > 8.0 plts > 20', 'have a diagnosis of mTBI based upon Veterans Health Administration VHA /Department of Defense DoD criteria with persisting symptoms > 3 months post injury', 'Must be optimally medicated at the start of the study. This means that there should be no change in mediction type or dosage in 3 months prior to enrolling in the study. The medications should not be causing significant or serious advese effects', 'women who are breast feeding', 'uncontrolled coagulation blood disorders like haemophilia malignant tumors and fear of needles']
# iteration 52 completed and complted for total 265 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  53
# Sentences to predict ['recurrent seizures', 'Patients must have one of the following malignancies', 'Patients who demonstrate > 25% decrease in depressive symptoms as reflected by the QIDS-SR score from Screening to Randomization', 'Severe hypersensitivity Grade 3 to pembrolizumab and/or any of its excipients', 'Available for follow-up for 12 months']
# iteration 53 completed and complted for total 270 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  54
# Sentences to predict ['Invasive infection', 'Women in good health aged 40- 80', 'Reversible causes of atrial arrhythmia such as hyperthyroidism sarcoidosis pulmonary embolism etc', 'Be receiving any prostanoid to treat portopulmonary hypertension', 'Patients with diabetes']
# iteration 54 completed and complted for total 275 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  55
# Sentences to predict ['Score of 50 on screening ISR Erythema Index', 'Atrial fibrillation with rapid ventricular response', 'Pre-existing stable medication see protocol for details , tic or otherwise, will also be allowed provided the family agrees to refrain from med changes over the course of the acute phase of the study', 'Subject has an active autoimmune disease in the past 2 years', 'Bone lesions: one or more osteolytic lesions on skeletal radiography computerized tomography CT or 2-deoxy-2 F-18 fluoro-D-glucose positron emission tomography CT PET-CT']
# iteration 55 completed and complted for total 280 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  56
# Sentences to predict ['pulmonary embolus', 'No class 3 or higher New York Heart Association congestive heart failure', 'Age 18', 'History of bariatric surgery', 'Castrate testosterone levels < 50 ng/dL achieved by orchiectomy or maintenance on a luteinizing hormone-releasing hormone LHRH agonist or antagonist']
# iteration 56 completed and complted for total 285 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  57
# Sentences to predict ['History of any solid organ or bone marrow transplant', 'Clinical diagnosis of asthma bronchiectasis cystic fibrosis or severe alpha-1 antitrypsin deficiency', 'esophageal spasm', 'A bone marrow biopsy must be performed within four weeks prior to Cycle 1 Day 1 treatment to establish the baseline fibrosis score and consent is required prior to that bone marrow biopsy to assure tissue is collected for protocol mandated testing', 'Potentially confounding neurodegenerative diseases e.g. MS']
# iteration 57 completed and complted for total 290 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  58
# Sentences to predict ['Asymptomatic CAD group: 40 patients who have undergone Coronary Artery Calcium scanning within 6 months prior to the imaging visit, matched to the ACS patients for age gender, and CAC score', 'patients who have CKD stage 5 End Stage Renal Disease ESRD', 'Any other disease, metabolic dysfunction, physical examination finding, or clinical laboratory finding that contraindicates the use of an investigational drug may affect the interpretation of the results, or may render the participant at high risk from treatment complications', 'Subjects must agree to avoid consuming alcohol within 72 hours of each rTMS session', 'ubjects undergoing primary debulking surgery surgery must have stage III or IV disease and have undergone surgery to include, at a minimum, removal of the uterus ovaries and fallopian tubes']
# iteration 58 completed and complted for total 295 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  59
# Sentences to predict ['Pregnant Women', 'Lesion larger than 3 cm in diameter', 'Connective tissue disease', '12-lead electrocardiogram ECG conducted at the screening visit within normal limits or abnormal but not clinically significant to the Investigator', 'Claustrophobia precluding chamber or hood tolerance']
# iteration 59 completed and complted for total 300 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  60
# Sentences to predict ['Patients must have maintained peripheral blood evidence of a remission and must have a CR or CRi, confirmed on restaging BM aspirate and biopsy', 'Enrolment in any other clinical study, for any condition, including those relating to Usher syndrome Type 1B throughout the duration of the SAR421869 study', 'for patients with AML evolving from myelodysplastic syndrome they should have completed at least one cycle of induction chemotherapy', 'English speaking and reading', 'Pathologically confirmed diagnosis of DLBCL with or without simultaneous or antecedent indolent lymphoma']
# iteration 60 completed and complted for total 305 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  61
# Sentences to predict ['Prior stroke with functional impairment or other severe, uncontrolled medical problems that may impair ability to participate in the study exams, based on medical history and review of medical records', 'HIV- infected individuals in HIV care', 'Hemoglobin 8 g/dl', 'Subject has immediately life-threatening, severe complications of leukemia such as uncontrolled bleeding pneumonia with hypoxia or shock and/or disseminated intravascular coagulation', 'Patients must be at least 28 days post systemic steroids prior to enrollment']
# iteration 61 completed and complted for total 310 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  62
# Sentences to predict ['Patients with T1 tumors', 'Life expectancy of at least 3 months', 'DNA damage repair deficiency as assessed centrally by a gene mutation biomarker panel testing of de novo or archival tumor tissue via central laboratory or prior historical testing with Sponsor approval using the Foundation Medicine, FoundationOne CDx NGS gene panel test', 'age 18- 65', 'Smoking history 10 pack-years']
# iteration 62 completed and complted for total 315 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  63
# Sentences to predict ['SBRT target size > 6 cm in maximum diameter or greater than 100 cc in volume', 'SLEDAI2K score 4 indicating active disease', 'Patients diagnosed with solid tumors who are eligible for participation in Phase I clinical trials of investigational cancer therapies', 'relapsed with radiologic evidence of progression within 1 year from completion of adjuvant endocrine therapy endocrine therapy with no subsequent endocrine therapy received following progression', 'Patients must be on no more than 0.1 mg/kg/day max 4 mg/day dexamethasone for at least one week before study registration']
# iteration 63 completed and complted for total 320 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  64
# Sentences to predict ['Acute leukemia in 1st or 2nd CR', 'Absolute CD4 count > 100 cells/uL', 'Patients with underlying abnormal brain pathology e.g. mass or bleed as the potential cause of the migraine', 'Clinical or radiologic evidence of untreated and/or progressive brain metastases', 'Albumin >= 2.5 g/dL']
# iteration 64 completed and complted for total 325 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  65
# Sentences to predict ['History of allergic/hypersensitivity reaction to any substance having required hospitalization and/or treatment with IV steroids epinephrine', 'Uncontrolled angina within 3 months of Screening visit', 'Female participants who are breast feeding must agree to stop breast feeding', 'at least one of the following: rest tremor muscular rigidity and postural instability not cause by visual vestibular cerebellar or proprioceptive dysfunction', 'Subjects with known allergies to injectable lidocaine or other topical anesthetics']
# iteration 65 completed and complted for total 330 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  66
# Sentences to predict ['Sexually active males unless they use a condom during intercourse while taking the drug and for 30 days after stopping treatment ment and should not father a child in this period. A condom is required to be used by vasectomized men in order to prevent delivery of the drug via seminal fluid', 'Measurable or evaluable disease by Response Evaluation Criteria in Solid Tumors RECIST version v 1.1', 'chronic obstructive pulmonary disease', 'Patients undergoing open elective liver resection for primary liver pathology benign or malignant or secondary metastatic liver disease including patients undergoing concomitant surgical procedures such as colorectal resection or debulking procedures , with no contraindication to the insertion of an epidural catheter localized infection septicemia or pre-operative coagulopathy', 'Ulcer not of VLU pathophysiology e.g., pure diabetic vasculitic radiation, rheumatoid collagen vascular disease pressure, or arterial etiology']
# iteration 66 completed and complted for total 335 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  67
# Sentences to predict ['Patients with evidence of uncontrolled bacterial viral or fungal infections currently taking medication and progression of clinical symptoms within one month prior to starting the conditioning regimen', 'Total and ionized serum calcium outside of normal limits', 'patients with confirmed Gilberts syndrome the TBil should be less than or equal to 1.5 SqrRoot ULN', 'Sexually active participants must agree to use adequate birth control for the during the study period from before the start of the preparative chemotherapy through 1 year post-transplant', 'Intensive medical treatment means that the subject is undergoing chemotherapy for a hematologic/oncologic condition, is carrying a pacemaker or has been diagnosed with a cardiac anomaly which causes cardiac insufficiency not compensated with medications']
# iteration 67 completed and complted for total 340 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  68
# Sentences to predict ['Serum glutamic oxaloacetic transaminase SGOT aspartate aminotransferase AST =< 3 x ULN obtained =< 21 days prior to registration', 'Hemoglobin 6 gm/dL', 'female', 'At least 2 years postmenarche', 'Prevalent congestive heart failure prior to randomization']
# iteration 68 completed and complted for total 345 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  69
# Sentences to predict ['Treatment with a cholinesterase inhibitor or an NMDA N-methyl-D-asparate antagonist with stable dose for at least 12 weeks', 'receiving immunosuppressive therapy', '9 to 14 years of age', 'Hb< 5 g/dl', 'The patient should not have any serious medical of psychiatric illness that would prevent either the giving of informed consent or the receipt of treatment']
# iteration 69 completed and complted for total 350 sentences
# ----------------------------------------------------------------------------------------------------
# ...
# iteration 74 completed and complted for total 375 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  75
# Sentences to predict ['Occasionally donor derived engraftment may be present, but sustained aplasia or failed recovery of sufficient hematopoiesis requires administration of a second graft', 'Adequacy of collected material will be determined within 5 business days of each collected case', 'Hypertension as defined by the Seventh Report of US National Committee on Prevention, Detection, Education and Treatment of High Blood Pressure or hypertensive medications', 'Axis-I psychotic disorder', 'mean arterial pressure 65 mmHg']
# iteration 75 completed and complted for total 380 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  76
# Sentences to predict ['Examples include remote > 30 days participation in a thoracic, abdominal or iliac branch device trial or participation in a percutaneous aortic valve trial', 'Other immunosuppressive immunosuppressive therapies include all cancer chemotherapeutic agents drugs to prevent transplant rejection interferons monoclonal antibodies protein kinase inhibitors methotrexate TNF tumor necrosis factor inhibitors and any other drug determined to be immunosuppressive by the PI', 'For patients whose CURRENT disease is vascular only: Enhancing vascular thrombosis involving portal vein, IVC and/or hepatic vein demonstrating early arterial enhancement and delayed washout on multi-phasic CT or MRI in a patient with known HCC diagnosed according to criteria in a or b', 'Female patients who are lactating or have a positive serum pregnancy test during the screening period', 'Previously undergone 2 cycles of lenalidomide and a proteasome inhibitor in separate therapeutic regimens not for maintenance or in combination']
# iteration 76 completed and complted for total 385 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  77
# Sentences to predict ['EaTCL', 'Prior monoclonal antibody within 4 weeks prior to first dose of study drug', 'Evidence of metastatic disease', 'T 1-2N+MO or T3-4 NxMo or borderline resectable and unresectable adenocarcinoma without distant metastatic disease or resectable T3-4 NxMo disease or M1 with controlled distant disease', "Chronic disease such as heart or renal failure would raise the participant's risk of adverse events during hyperbaric oxygen"]
# iteration 77 completed and complted for total 390 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  78
# Sentences to predict ['CD4 nadir 500 cells/mm3', 'prior to evidence of vaccine clearance', 'Liver transplant', 'A parent or legal guardian of a patient < 18 years of age will provide informed consent and patients 11 to 18 years of age will provide written assent or as per participating institutional policy', 'Psychotropic medication free or on stable psychotropic medication no changes in past 6 weeks and no planned changes for the next 6 months']
# iteration 78 completed and complted for total 395 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  79
# Sentences to predict ['Adequately treated psychiatric disorders and appropriate psychotropic medications', 'Less than 70% of liver parenchymal tumor replacement', 'Active cancer with or without metastases', 'Karnofsky 80% subjects 16 years of age', 'Platelets plts > 90,000']
# iteration 79 completed and complted for total 400 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  80
# Sentences to predict ['currently taking steroids and/or benzodiazepines', 'Uncontrolled viral or bacterial infection at the time of study enrollment', 'Current known active or chronic infection with human immunodeficiency virus HIV Hepatitis B or Hepatitis C', 'Transplant recipient able to give informed consent', 'Documented visceral metastases or current lymphadenopathy > 3 cm by standard imaging e.g. MRI CT ultrasound FDG PET CT']
# iteration 80 completed and complted for total 405 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  81
# Sentences to predict ['Significant liver disease defined as known cirrhosis or elevated transaminases of at least 3- fold upper limit of normal', 'Active systemic infection', 'Patient does not have a support person ie. Spouse, partner, mother available to support the patient for the duration of the pregnancy', 'Advanced or metastatic esophageal and/or gastric cancer 15- 30 enrollment slots', 'report having had a severe adverse reaction to study medications']
# iteration 81 completed and complted for total 410 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  82
# Sentences to predict ['Aged 18- 69 years', 'requirement for red blood cell and/or platelet transfusions', 'Immunotherapy Interferons Cytokines except PD-1/PD-L1 antagonists', 'Elevated serum PSA prostate specific antigen> 4 ng/ml and/or abnormal digital rectal exam', 'Patients must have smart phone and/or device for app usage']
# iteration 82 completed and complted for total 415 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  83
# Sentences to predict ['Relapsed or primary refractory metastatic', 'Head trauma central nervous system injury', 'Patients who are a serious suicide or homicide risk', 'acute decompensated HF', 'diabetic retinopathy']
# iteration 83 completed and complted for total 420 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  84
# Sentences to predict ['Subjects with known liver cirrhosis in severity that would preclude tolerability of cyclosporine and eltrombopag as evidenced by albumin < 35g/L', 'platelets < 100,000/ L', 'primary anxiety disorder or primary eating disorders primary refers to the diagnosis associated with the most functional impairment', 'Patients with stabilizing implants in the bone where the cyst is located', 'Status of HIV must be confirmed via a HIV antibody test or other confirmatory tests available within 12 months before screening or at screening']
# iteration 84 completed and complted for total 425 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  85
# Sentences to predict ['Breath alcohol level > 0.01 participants with a positive screen will be allowed to re-screen once', 'Total bilirubin 1.5 x ULN upper limit of normal', 'ALT and AST 2.5 X upper limit of normal ULN', 'Patients must not have an uncontrolled bacterial fungal or viral infection defined as progressive symptoms despite therapy at the time of the CD8+ memory T-cell infusion', 'Commit to using birth control during the study all participants']
# iteration 85 completed and complted for total 430 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  86
# Sentences to predict ['Recurrent ovarian cancer', 'Be able to read, write, and speak English', 'Prior whole-lung or hemi-thorax irradiation of greater than 12 Gy received less than 6 months prior to consent', 'history of deep vein thrombosis or pulmonary embolus', 'lactating females']
# iteration 86 completed and complted for total 435 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  87
# Sentences to predict ['Subjects must have an Eastern Cooperative Oncology Group ECOG Performance Status of 0- 2', 'Newly diagnosed acute lymphoblastic leukemia lymphoma', 'previous treatment with ketotifen', 'Pregnant or breast-feeding females are excluded because of the potential mutagenic effects on a developing fetus or newborn', 'Infiltrating ductal carcinoma or DCIS stage T0 T1 and T2 less than or equal to 3.0 cm N0 and M0']
# iteration 87 completed and complted for total 440 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  88
# Sentences to predict ['Adequately treated non-melanomatous skin cancer or lentigo maligna without evidence of disease', 'Insulin dependent diabetes mellitus', 'total bilirubin 2.5 X institutional upper limit of normal', 'Patients receiving IV tPA > 3 hours from stroke onset', 'Hamilton Depression Rating Scale-24 HRSD-24 score 24 HRSD-24 score of 8- 24']
# iteration 88 completed and complted for total 445 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  89
# Sentences to predict ['Surgery intent within 4 weeks', 'A female of childbearing potential is a sexually mature woman who: 1 has not undergone a hysterectomy or bilateral oophorectomy or 2 has not been naturally postmenopausal for at least 24 consecutive months i.e., has had menses at any time in the preceding 24 consecutive months', 'active acute or chronic or uncontrolled severe infections', 'Either has a diagnosis of PAH isolated left heart disease or lung disease chronic obstructive pulmonary disease or interstitial lung disease or CTEPH using established clinical criteria', 'Planning to initiate treatment with doxorubicin starting dose 75 mg/m2 as routine care']
# iteration 89 completed and complted for total 450 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  90
# Sentences to predict ['Has a known psychiatric or substance abuse disorders that would interfere with cooperation with the requirements of the trial', 'A child with a catheter- associated UTI', 'If malignancy- associated microcalcifications were initially present, the post-excision mammography must be negative', 'evidence of lung and other organ involvement renal angiomyolipomas chylous effusions lymphangioleiomyomas', 'Epilepsy with history of seizures']
# iteration 90 completed and complted for total 455 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  91
# Sentences to predict ['Concurrent use of amifostine concurrent abdominal radiotherapy concurrent use of quinolone antibiotic therapy', 'be able to ambulate at least household distances 50ft', 'At least 18 years of age', 'Male', 'Known active CNS metastases']
# iteration 91 completed and complted for total 460 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  92
# Sentences to predict ['Diagnosed with MAS under 98-D-0145', 'Patient must have completed a minimum of 8 weeks of standard neoadjuvant chemotherapy consisting of an anthracycline and/or taxane-based regimen', 'bone marrow metastases plus high urine catecholamine levels', 'Osteoporosis or recent fracture of the hip or spinal joints', 'with unilateral or bilateral inguinal herna for laparoscopic repair']
# iteration 92 completed and complted for total 465 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  93
# Sentences to predict ['Corticosteroid injection at treatment site within 1 month', 'ECOG Performance Status 0- 1', 'Allergy or adverse reaction to dextromethorphan vitamin A or isotretinoin', 'Participation in an investigational drug or device study that would impact the safety or scientific integrity of this study in the opinion of the Investigator and with the approval of the Sponsor within the past 6 weeks prior to enrollment into this trial', 'Known sensitivity to conductive hydrogels']
# iteration 93 completed and complted for total 470 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  94
# Sentences to predict ['Caregiver severe cognitive impairment', 'Current smoking or history of smoking in the past 12 months', 'For 18 year olds', 'Patients with history of prior pelvic irradiation', "Subject has a lifetime history of suicide attempt including an active attempt, interrupted attempt, or aborted attempt , or has suicidal ideation in the past 6 months as indicated by a positive response 'Yes' to either Question 4 or Question 5 of the C-SSRS at Screening"]
# iteration 94 completed and complted for total 475 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  95
# Sentences to predict ['AST ALT 2 times upper limit of normal ULN', 'Human papillomavirus HPV 16-positive disease by PCR', 'Patients who have had prior treatment with LY2606368 or other Chk inhibitors', 'Test negative for recent cannabis use in urine at the screening visit confirmed by Gas Chromatography GC Mass Spectrometry MS laboratory test and at clinic admission', 'schizophrenia']
# iteration 95 completed and complted for total 480 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  96
# Sentences to predict ['women of childbearing potential', 'who have not been on gonadal steroid preparations for at least 1 month', 'Pregnant', 'Absolute neutrophil count ANC >= 1,500/mcL', 'Patients with a known hypersensitivity to Everolimus or other rapamycins sirolimus temsirolimus or to its excipients']
# iteration 96 completed and complted for total 485 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  97
# Sentences to predict ['Clinically significant cardiac/cardiovascular disease or pulmonary compromise', 'radiculopathy', '18 years of age or older', 'Gastrointestinal Bleed', 'Known positive for human immunodeficiency virus HIV or with known active infectious hepatitis, type A, B or C']
# iteration 97 completed and complted for total 490 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  98
# Sentences to predict ['Women who exhibit serious psychiatric symptoms determined by CNO trained staff', 'Patients who have disease relapse, active GVHD or history of more than Stage 1 skin acute GVHD history of cGVHD', 'Patients with thyroid disease', 'Immunocompromised patients, e.g., patients who are known to be serologically positive for human immunodeficiency virus HIV and are receiving antiviral therapy testing is not part of the protocol', 'Subjects with a positive Hepatitis B surface antigen and/or antihepatitis B core antibody']
# iteration 98 completed and complted for total 495 sentences
# ----------------------------------------------------------------------------------------------------
# Current Iteration :  99
# Sentences to predict ['Men must agree to use adequate contraception prior to enrollment, for the duration of study participation and for at least 3 months thereafter', 'Serum creatinine 1.5 x ULN', 'History of seizure disorder', 'Participants who have received any other investigational agents within the 4 weeks prior to enrollment; concurrent radiation therapy', 'ALT or BUN > 2.0 ULN or estimated creatinine > 1.5 X ULN for age or any other laboratory abnormality considered by the Investigator to be clinically significant within 14 days before Screening']
# iteration 99 completed and complted for total 500 sentences
# ----------------------------------------------------------------------------------------------------

# %%
final_result_gpt
# Out:
# [[{'label': 'treatment', 'value': 'oral administration'},
#   {'label': 'treatment', 'value': 'study drug'}],
#  [{'label': 'pregnancy', 'value': 'Current pregnancy'}],
#  [{'label': 'pregnancy', 'value': 'Singleton pregnancy'}],
#  [{'label': 'clinical_variable', 'value': 'steroids'},
#   {'label': 'clinical_variable', 'value': 'surgery'},
#   {'label': 'clinical_variable', 'value': 'recovery period'},
#   {'label': 'clinical_variable', 'value': 'betamethasone hypersensitivity'}],
#  [{'label': 'clinical_variable', 'value': 'rheumatic valve disease'},
#   {'label': 'clinical_variable', 'value': 'AF phenotype'}],
#  [{'label': 'chronic_disease', 'value': 'Severe liver dysfunction'},
#   {'label': 'clinical_variable', 'value': 'LFT'},
#   {'label': 'upper_bound', 'value': '3X upper limit of normal'}],
#  [{'label': 'clinical_variable', 'value': 'Serum M-protein'},
#   {'label': 'lower_bound', 'value': '1.0 g/dL'}],
#  [{'label': 'gender', 'value': 'Males or females'}],
#  [{'label': 'Cancer', 'value': 'Negative for malignancy'},
#   {'label': 'clinical_variable', 'value': 'past 5 years'}],
#  [{'label': 'technology_access',
#    'value': 'available for up to 6 hrs every day'},
#   {'label': 'clinical_variable', 'value': 'two 2-week test periods'},
#   {'label': 'clinical_variable',
#    'value': 'intervening break of 7- 10 days each'}],
#  [{'label': 'Cancer', 'value': 'recurrent and/or metastatic thyroid cancer'}],
#  [{'label': 'treatment', 'value': 'paclitaxel'}],
#  [{'label': 'clinical_variable', 'value': 'Mean arterial pressure'},
#   {'label': 'lower_bound', 'value': '65'}],
#  [{'label': 'clinical_variable', 'value': 'White blood cells WBC'},
#   {'label': 'upper_bound', 'value': '15,000 cells/mcL'}],
#  [{'label': 'chronic_disease', 'value': 'Acute medical illness'}],
#  [{'label': 'treatment', 'value': 'chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'prior'}],
#  [{'label': 'chronic_disease', 'value': 'thromboembolism'},
#   {'label': 'clinical_variable', 'value': 'thrombophilia'}],
#  [{'label': 'clinical_variable', 'value': 'stationary position'},
#   {'label': 'treatment', 'value': 'HIFU'}],
#  [{'label': 'chronic_disease', 'value': 'hepatitis B'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis B survace antigen HBsAg reactive'},
#   {'label': 'clinical_variable', 'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'value': 'HCV RNA qualitative is detected infection'}],
#  [{'label': 'chronic_disease', 'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable', 'value': 'severely impaired lung function'}],
#  [{'label': 'chronic_disease', 'value': 'Diabetes Mellitus'}],
#  [{'label': 'chronic_disease',
#    'value': 'Seizure disorder requiring medication'}],
#  [{'label': 'bmi', 'value': 'BMI'},
#   {'label': 'lower_bound', 'value': '25 kg/m^2'}],
#  [{'label': 'clinical_variable', 'value': 'Life expectancy'},
#   {'label': 'lower_bound', 'value': '12 weeks'}],
#  [{'label': 'clinical_variable', 'value': 'History/physical examination'},
#   {'label': 'clinical_variable', 'value': 'digital rectal examination'},
#   {'label': 'clinical_variable', 'value': 'prostate examination'},
#   {'label': 'clinical_variable', 'value': 'skeletal system examination'},
#   {'label': 'clinical_variable', 'value': 'abdomen examination'},
#   {'label': 'lower_bound', 'value': '90 days prior to registration'}],
#  [{'label': 'Cancer', 'value': 'secondary primary lung cancer'},
#   {'label': 'chronic_disease', 'value': 'lung cancer'},
#   {'label': 'upper_bound', 'value': '2 year prior to registration'}],
#  [{'label': 'clinical_variable',
#    'value': 'serum human chorionic gonadotropin hCG'},
#   {'label': 'pregnancy', 'value': 'positive'}],
#  [{'label': 'clinical_variable', 'value': 'Total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '=< 1.5 x institutional upper limit of normal ULN'},
#   {'label': 'upper_bound',
#    'value': "=< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation"},
#   {'label': 'upper_bound',
#    'value': '3.0 mg/dL within 2 weeks prior to enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'Other neurological diagnosis'}],
#  [{'label': 'clinical_variable', 'value': 'Major neurological disorder'}],
#  [{'label': 'treatment', 'value': 'Anti-tumor necrosis factor agents'}],
#  [{'label': 'chronic_disease',
#    'value': 'Clinically significant heart disease'},
#   {'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': 'arterial thrombotic events'},
#   {'label': 'clinical_variable', 'value': 'severe or unstable angina'},
#   {'label': 'clinical_variable',
#    'value': 'New York Heart Association NYHA class II- IV heart disease'}],
#  [{'label': 'clinical_variable', 'value': 'normal sinus rhythm'},
#   {'label': 'clinical_variable', 'value': 'ECG documented'},
#   {'label': 'clinical_variable',
#    'value': 'within the two weeks prior to the screening Holter'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'clinical_variable', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'negative pregnancy test'}],
#  [{'label': 'clinical_variable', 'value': 'Hematologic abnormalities'},
#   {'label': 'clinical_variable', 'value': 'pancytopenia'},
#   {'label': 'clinical_variable', 'value': 'aplastic anemia'}],
#  [{'label': 'language_fluency', 'value': 'Poor English comprehension'}],
#  [{'label': 'clinical_variable', 'value': 'multiple myeloma'},
#   {'label': 'clinical_variable',
#    'value': 'International Myeloma Working Group IMWG diagnostic criteria'}],
#  [{'label': 'chronic_disease', 'value': 'hypercontractile bladder'},
#   {'label': 'chronic_disease', 'value': 'non-compliant bladder'},
#   {'label': 'chronic_disease', 'value': 'hydronephrosis'},
#   {'label': 'chronic_disease', 'value': 'neurogenic bladder'}],
#  [{'label': 'age', 'value': '40'},
#   {'label': 'age', 'value': '59'},
#   {'label': 'clinical_variable', 'value': '15% TBSA'}],
#  [{'label': 'age', 'value': '2'},
#   {'label': 'lower_bound', 'value': 'at least'}],
#  [{'label': 'age', 'value': '1 year'},
#   {'label': 'upper_bound', 'value': '18 years'}],
#  [{'label': 'treatment', 'value': 'Therapeutic antibodies'},
#   {'label': 'treatment', 'value': 'bevacizumab'}],
#  [{'label': 'clinical_variable', 'value': 'postmenopausal status'},
#   {'label': 'clinical_variable', 'value': 'surgical/natural menopause'},
#   {'label': 'clinical_variable', 'value': 'ovarian suppression'},
#   {'label': 'clinical_variable', 'value': '28 days'},
#   {'label': 'clinical_variable', 'value': 'Day 1 of Cycle 1'},
#   {'label': 'clinical_variable', 'value': 'gonadotropin-releasing hormone'},
#   {'label': 'clinical_variable', 'value': 'goserelin'}],
#  [{'label': 'Cancer', 'value': 'Pancreatic Cancer'},
#   {'label': 'clinical_variable',
#    'value': 'potentially surgically resectable'}],
#  [{'label': 'clinical_variable', 'value': 'lower urinary tract symptoms'},
#   {'label': 'clinical_variable', 'value': 'LUTS'},
#   {'label': 'clinical_variable', 'value': '1 year'}],
#  [{'label': 'treatment', 'value': 'pacemaker ICD'}],
#  [{'label': 'treatment', 'value': 'spinal block'},
#   {'label': 'treatment', 'value': 'BBBD chemotherapy'}],
#  [{'label': 'clinical_variable', 'value': 'linked to care/evaluation'},
#   {'label': 'upper_bound', 'value': '30 days'}],
#  [{'label': 'clinical_variable', 'value': 'Dry weight'},
#   {'label': 'clinical_variable', 'value': 'height'},
#   {'label': 'upper_bound', 'value': '7 days'}],
#  [{'label': 'treatment', 'value': 'antipsychotics'}],
#  [{'label': 'gender', 'value': 'lactating women'}],
#  [{'label': 'clinical_variable', 'value': 'SGPT ALT'},
#   {'label': 'upper_bound', 'value': '5 x ULN for age'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'chronic_disease', 'value': 'anaphylaxis'},
#   {'label': 'treatment', 'value': 'echinocandin'}],
#  [{'label': 'pregnancy', 'value': 'possibly pregnant'}],
#  [{'label': 'treatment', 'value': 'ipsilateral knee surgery'},
#   {'label': 'treatment', 'value': 'ligament reconstruction'},
#   {'label': 'treatment', 'value': 'osteotomy'}],
#  [{'label': 'chronic_disease', 'value': 'congestive heart failure'}],
#  [{'label': 'treatment', 'value': 'ongoing, tapering therapy'},
#   {'label': 'clinical_variable', 'value': 'resolved acute GVHD'}],
#  [{'label': 'treatment', 'value': 'IV docetaxel'},
#   {'label': 'clinical_variable', 'value': '75 mg/m^2'},
#   {'label': 'clinical_variable', 'value': '5 mg/m^2'},
#   {'label': 'treatment', 'value': 'carboplatin'},
#   {'label': 'clinical_variable', 'value': 'AUC 5-6'},
#   {'label': 'clinical_variable', 'value': 'every 21 days'}],
#  [{'label': 'contraception_consent',
#    'value': 'effective form of birth control'}],
#  [{'label': 'chronic_disease', 'value': 'HIV-positive patients'},
#   {'label': 'treatment', 'value': 'combination antiretroviral therapy'},
#   {'label': 'clinical_variable', 'value': 'LY2606368'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG performance status'},
#   {'label': 'clinical_variable', 'value': 'Karnofsky'},
#   {'label': 'lower_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '60%'}],
#  [{'label': 'Cancer', 'value': 'Metastatic breast cancer'},
#   {'label': 'clinical_variable', 'value': 'triple negative'},
#   {'label': 'clinical_variable', 'value': 'ER'},
#   {'label': 'clinical_variable', 'value': 'CCND1c'},
#   {'label': 'clinical_variable', 'value': 'HER2'},
#   {'label': 'treatment', 'value': 'trastuzumab and PD0332991 therapy'},
#   {'label': 'upper_bound', 'value': '55'}],
#  [{'label': 'age', 'value': '18'},
#   {'label': 'lower_bound', 'value': 'years old'}],
#  [{'label': 'treatment', 'value': 'recurrent or refractory solid tumors'},
#   {'label': 'clinical_variable', 'value': 'central nervous system CNS tumors'},
#   {'label': 'clinical_variable', 'value': 'CNS metastases'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'chronic_disease',
#    'value': 'acquired immunodeficiency syndrome AIDS'}],
#  [{'label': 'treatment', 'value': 'planned surgery'},
#   {'label': 'treatment', 'value': 'general anesthesia'},
#   {'label': 'clinical_variable', 'value': 'pharmacotherapy period'}],
#  [{'label': 'clinical_variable', 'value': 'Maximal diameter'},
#   {'label': 'clinical_variable', 'value': 'hepatocellular carcinoma'},
#   {'label': 'upper_bound', 'value': '15 cm'}],
#  [{'label': 'gender', 'value': 'Females'},
#   {'label': 'clinical_variable', 'value': 'menopausal'},
#   {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'}],
#  [{'label': 'gender', 'value': 'female'}],
#  [{'label': 'clinical_variable', 'value': 'ADHD'},
#   {'label': 'clinical_variable', 'value': 'clinician administered CAADID'},
#   {'label': 'clinical_variable', 'value': 'clinical interview'}],
#  [{'label': 'clinical_variable', 'value': 'active malignancy'},
#   {'label': 'upper_bound', 'value': '3 years prior to registration'}],
#  [{'label': 'treatment', 'value': 'intensive induction chemotherapy'},
#   {'label': 'treatment', 'value': 'radiotherapy'},
#   {'label': 'treatment', 'value': 'biologic treatment'},
#   {'label': 'clinical_variable', 'value': 'active malignancy'},
#   {'label': 'treatment', 'value': 'maintenance chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'study medical monitor'}],
#  [{'label': 'treatment', 'value': 'CEM carboplatin'},
#   {'label': 'treatment', 'value': 'etoposide'},
#   {'label': 'treatment', 'value': 'melphalan therapy'},
#   {'label': 'lower_bound', 'value': '30 days prior to 131I-MIBG therapy'},
#   {'label': 'treatment', 'value': '131I-MIBG therapy'},
#   {'label': 'lower_bound',
#    'value': '30 days following administration of 131I-MIBG'}],
#  [{'label': 'clinical_variable', 'value': 'HIV positive'},
#   {'label': 'clinical_variable', 'value': 'CD4 count'},
#   {'label': 'lower_bound', 'value': '350 cells/microliter'}],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [{'label': 'clinical_variable', 'value': 'Preoperative evaluation'},
#   {'label': 'treatment', 'value': 'CT scan'},
#   {'label': 'treatment', 'value': 'MRI'},
#   {'label': 'treatment', 'value': 'ultrasound'}],
#  [{'label': 'clinical_variable', 'value': 'claustrophobic'}],
#  [{'label': 'chronic_disease', 'value': 'malignancy'}],
#  [{'label': 'clinical_variable', 'value': 'drinking'},
#   {'label': 'clinical_variable', 'value': 'past 90 days'},
#   {'label': 'upper_bound', 'value': '80%'}],
#  [{'label': 'language_fluency', 'value': 'English'}],
#  [{'label': 'chronic_disease', 'value': 'cerebrovascular accident CVA'},
#   {'label': 'chronic_disease', 'value': 'transient ischemic attack TIA'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'treatment', 'value': 'platinum-containing chemotherapy'},
#   {'label': 'treatment', 'value': 'neoadjuvant or adjuvant treatment'},
#   {'label': 'treatment', 'value': 'platinum-containing chemotherapy'},
#   {'label': 'upper_bound', 'value': '1 2 months'}],
#  [{'label': 'treatment', 'value': 'investigational drug'},
#   {'label': 'lower_bound', 'value': '4 weeks'}],
#  [{'label': 'allergy_name', 'value': 'gadolinium Gd contrast material'}],
#  [{'label': 'clinical_variable', 'value': 'Wheezing'}],
#  [{'label': 'treatment', 'value': 'toxic effects'},
#   {'label': 'clinical_variable', 'value': 'prior therapy'}],
#  [{'label': 'chronic_disease', 'value': 'uncontrolled inter-current illness'},
#   {'label': 'clinical_variable', 'value': 'ongoing or active infection'},
#   {'label': 'clinical_variable',
#    'value': 'symptomatic congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'NYHA Gr.2 or >'},
#   {'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': 'unstable angina pectoris'},
#   {'label': 'clinical_variable', 'value': 'past 12 months'}],
#  [{'label': 'age', 'value': '18'},
#   {'label': 'lower_bound', 'value': '75 years'}],
#  [{'label': 'Cancer', 'value': 'recurrent carcinoma of the vulva'},
#   {'label': 'treatment', 'value': 'previous treatment'}],
#  [{'label': 'clinical_variable', 'value': 'PaO2/FiO2'},
#   {'label': 'lower_bound', 'value': '300'}],
#  [{'label': 'clinical_variable', 'value': 'amyloid imaging disclosure'}],
#  [{'label': 'age', 'value': '4 to 6 months'}],
#  [{'label': 'chronic_disease', 'value': 'asthma'}],
#  [{'label': 'chronic_disease', 'value': 'bleeding disorder'}],
#  [{'label': 'age', 'value': '18 years or older'}],
#  [{'label': 'treatment', 'value': 'second line hormonal therapy'},
#   {'label': 'treatment', 'value': 'bicalutamide'},
#   {'label': 'treatment', 'value': 'nilutamide'},
#   {'label': 'treatment', 'value': 'flutamide'},
#   {'label': 'treatment', 'value': 'ketoconazole'},
#   {'label': 'treatment', 'value': 'abiraterone'},
#   {'label': 'treatment', 'value': 'enzalutamide'},
#   {'label': 'treatment', 'value': 'ARN-509'}],
#  [{'label': 'clinical_variable', 'value': 'endometrial cancer'},
#   {'label': 'treatment', 'value': 'routinely'},
#   {'label': 'treatment', 'value': 'newly diagnosed'},
#   {'label': 'treatment', 'value': 'centers'},
#   {'label': 'treatment', 'value': 'US'}],
#  [{'label': 'clinical_variable', 'value': 'central nervous system lymphoma'},
#   {'label': 'clinical_variable', 'value': 'active'}],
#  [{'label': 'chronic_disease', 'value': 'autoimmune diseases'}],
#  [{'label': 'Cancer', 'value': 'acute myeloid leukemia AML'},
#   {'label': 'Cancer', 'value': 'acute lymphoblastic leukemia ALL'},
#   {'label': 'Cancer', 'value': 'chronic myelogenous leukemia CML'},
#   {'label': 'Cancer', 'value': 'chronic lymphocytic leukemia CLL'},
#   {'label': 'Cancer', 'value': 'non-Hodgkin lymphoma NHL'},
#   {'label': 'Cancer', 'value': 'Hodgkin lymphoma NHL'},
#   {'label': 'Cancer', 'value': 'Hodgkin lymphoma'},
#   {'label': 'Cancer', 'value': 'multiple myeloma MM'},
#   {'label': 'Cancer', 'value': 'myelodysplastic syndrome MDS'},
#   {'label': 'Cancer', 'value': 'AL amyloidosis'},
#   {'label': 'Cancer', 'value': 'diamond blackfan anemia'},
#   {'label': 'Cancer', 'value': 'myelofibrosis'},
#   {'label': 'Cancer', 'value': 'myeloproliferative disease'},
#   {'label': 'Cancer', 'value': 'sickle cell anemia'},
#   {'label': 'Cancer', 'value': 'thalassemia'}],
#  [{'label': 'Cancer', 'value': 'HPV p16'},
#   {'label': 'Cancer', 'value': 'PD-L1'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG status'},
#   {'label': 'lower_bound', 'value': '3'},
#   {'label': 'upper_bound', 'value': '4'}],
#  [{'label': 'chronic_disease',
#    'value': 'pre-existing medical psychiatric or other condition'}],
#  [{'label': 'chronic_disease', 'value': 'medical conditions'},
#   {'label': 'chronic_disease', 'value': 'orthopedic injuries'},
#   {'label': 'chronic_disease', 'value': 'cardiovascular diseases'},
#   {'label': 'chronic_disease', 'value': 'liver diseases'},
#   {'label': 'chronic_disease', 'value': 'endocrine diseases'},
#   {'label': 'chronic_disease', 'value': 'pulmonary diseases'}],
#  [{'label': 'Cancer', 'value': 'lung cancer'}],
#  [{'label': 'chronic_disease', 'value': 'cord compression'},
#   {'label': 'chronic_disease', 'value': 'syrinx in the spinal cord'},
#   {'label': 'chronic_disease', 'value': 'spinal cord disease'},
#   {'label': 'chronic_disease', 'value': 'spinal stenosis'},
#   {'label': 'chronic_disease', 'value': 'spina bifida'},
#   {'label': 'chronic_disease', 'value': 'herniated cervical disk'}],
#  [{'label': 'gender', 'value': 'nursing woman'}],
#  [{'label': 'gender', 'value': 'pregnant women'}],
#  [{'label': 'chronic_disease', 'value': 'myocardial infarction'},
#   {'label': 'lower_bound', 'value': '6 months before enrollment'}],
#  [{'label': 'chronic_disease', 'value': 'Sickle cell anemia'}],
#  [{'label': 'chronic_disease', 'value': 'Myelodysplastic syndrome'}],
#  [{'label': 'treatment', 'value': 'corneal transplants'},
#   {'label': 'treatment', 'value': 'cadaver skin'},
#   {'label': 'treatment', 'value': 'bone transplants'}],
#  [{'label': 'treatment', 'value': 'Lovaza prescription fish oil'},
#   {'label': 'treatment', 'value': 'Lovaza'},
#   {'label': 'clinical_variable', 'value': '3 weeks'}],
#  [{'label': 'chronic_disease', 'value': 'cardiac condition'},
#   {'label': 'chronic_disease', 'value': 'asthma'},
#   {'label': 'chronic_disease', 'value': 'obstructive pulmonary disease'},
#   {'label': 'chronic_disease', 'value': 'seizure disorder'},
#   {'label': 'chronic_disease', 'value': 'urinary incontinence'},
#   {'label': 'chronic_disease', 'value': 'peptic ulcer disease'},
#   {'label': 'treatment', 'value': 'concurrent NSAIDs'}],
#  [{'label': 'clinical_variable', 'value': 'Karnofsky performance status'},
#   {'label': 'lower_bound', 'value': '70%'}],
#  [{'label': 'clinical_variable', 'value': 'Grade 4 - Fibrosis'}],
#  [{'label': 'clinical_variable', 'value': 'Follicular 17-hydroxyprogesterone'},
#   {'label': 'upper_bound', 'value': '300 ng/dl'},
#   {'label': 'clinical_variable', 'value': 'congenital adrenal hyperplasia'}],
#  [{'label': 'clinical_variable', 'value': 'Current oral steroid use'},
#   {'label': 'upper_bound', 'value': '4 weeks prior to registration'}],
#  [{'label': 'pregnancy', 'value': 'Not pregnant'}],
#  [{'label': 'chronic_disease',
#    'value': 'History of DVT or pulmonary embolism'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'chronic_disease', 'value': 'Hepatitis C'},
#   {'label': 'treatment', 'value': 'donor liver'}],
#  [{'label': 'clinical_variable', 'value': 'Renal insufficiency'},
#   {'label': 'clinical_variable', 'value': 'creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 mg/dL'}],
#  [{'label': 'treatment', 'value': 'investigational agent'},
#   {'label': 'upper_bound', 'value': '30 days prior to pre-registration'}],
#  [{'label': 'treatment', 'value': 'warfarin'},
#   {'label': 'clinical_variable', 'value': 'prophylaxis'},
#   {'label': 'clinical_variable', 'value': 'treatment of thrombosis'},
#   {'label': 'clinical_variable', 'value': 'INR values'}],
#  [{'label': 'age', 'value': '18 years'},
#   {'label': 'lower_bound', 'value': '18'}],
#  [{'label': 'chronic_disease', 'value': 'cerebral vascular event stroke'},
#   {'label': 'chronic_disease', 'value': 'transient ischemic attack'},
#   {'label': 'chronic_disease',
#    'value': 'unstable angina myocardial infarction'},
#   {'label': 'chronic_disease', 'value': 'cardiac symptoms'},
#   {'label': 'chronic_disease', 'value': 'congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'New York Heart Association Class'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'treatment', 'value': 'breast conserving surgery'},
#   {'label': 'treatment', 'value': 'lumpectomy'},
#   {'label': 'treatment', 'value': 'radiation'}],
#  [{'label': 'age', 'value': 'age'}, {'label': 'lower_bound', 'value': '49'}],
#  [{'label': 'treatment', 'value': 'medication'},
#   {'label': 'clinical_variable', 'value': 'potentially dangerous interaction'},
#   {'label': 'treatment', 'value': 'propranolol'}],
#  [{'label': 'treatment', 'value': 'rIX-FP'},
#   {'label': 'clinical_variable', 'value': '100 EDs single-dose cohorts'},
#   {'label': 'clinical_variable', 'value': '50 EDs repeated-dose cohort'}],
#  [{'label': 'clinical_variable', 'value': 'Bilirubin'},
#   {'label': 'upper_bound', 'value': '2 x the ULN'}],
#  [{'label': 'chronic_disease', 'value': 'organ allograft'},
#   {'label': 'clinical_variable', 'value': 'corneal transplant'}],
#  [{'label': 'treatment', 'value': 'Autologous stem cell transplantation SCT'},
#   {'label': 'clinical_variable', 'value': '100 days prior to study drug'},
#   {'label': 'treatment', 'value': 'allogeneic SCT'},
#   {'label': 'treatment', 'value': 'solid organ transplantation'}],
#  [{'label': 'diagnosis', 'value': 'type 2 diabetes'}],
#  [{'label': 'history', 'value': 'active malignancy'},
#   {'label': 'upper_bound', 'value': 'last 3 years'}],
#  [{'label': 'clinical_variable', 'value': 'adverse events Grade'},
#   {'label': 'upper_bound', 'value': '> 1'},
#   {'label': 'treatment',
#    'value': 'prior therapies chemotherapy radiotherapy and/or surgery'},
#   {'label': 'clinical_variable', 'value': 'alopecia'}],
#  [{'label': 'clinical_variable', 'value': 'Pre-bronchodilator 50% FEV1'},
#   {'label': 'lower_bound', 'value': '< 85 %'},
#   {'label': 'clinical_variable', 'value': 'predicted normal value'},
#   {'label': 'clinical_variable', 'value': 'patient'},
#   {'label': 'clinical_variable', 'value': 'withholding bronchodilators'},
#   {'label': 'clinical_variable', 'value': 'Visit 101'},
#   {'label': 'clinical_variable', 'value': 'Visit 102'},
#   {'label': 'clinical_variable', 'value': 'ATS/ERS criteria'}],
#  [{'label': 'treatment', 'value': 'cetuximab'},
#   {'label': 'clinical_variable', 'value': 'incurable disease'}],
#  [{'label': 'treatment', 'value': 'herbal alternative medicines'}],
#  [{'label': 'age', 'value': '21 years'}],
#  [{'label': 'treatment', 'value': 'intravesical chemotherapy'}],
#  [{'label': 'clinical_variable', 'value': 'medication'},
#   {'label': 'clinical_variable', 'value': 'precautionary list'},
#   {'label': 'clinical_variable', 'value': 'nitroglycerin'}],
#  [{'label': 'clinical_variable', 'value': 'Severe aortic regurgitation'},
#   {'label': 'lower_bound', 'value': '3'}],
#  [{'label': 'clinical_variable', 'value': 'psychiatric or medical condition'},
#   {'label': 'treatment', 'value': 'interfere with treatment'}],
#  [{'label': 'age', 'value': '17'}, {'label': 'lower_bound', 'value': '17'}],
#  [{'label': 'Cancer', 'value': 'FL'},
#   {'label': 'clinical_variable', 'value': 'histopathologic confirmation'}],
#  [{'label': 'age', 'value': '16 years of age or older'},
#   {'label': 'clinical_variable', 'value': 'weighs'}],
#  [{'label': 'clinical_variable',
#    'value': 'Interval from start of initial radiation therapy to enrollment'},
#   {'label': 'lower_bound', 'value': '9 months'}],
#  [{'label': 'chronic_disease', 'value': 'diabetes requiring medication'}],
#  [{'label': 'contraception_consent', 'value': 'Not pregnant or nursing'},
#   {'label': 'contraception_consent',
#    'value': 'report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant women'}],
#  [{'label': 'chronic_disease', 'value': 'hepatitis B'},
#   {'label': 'chronic_disease', 'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis B virus surface antigen HBsAg reactive'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis C virus HCV ribonucleic acid RNA qualitative is detected'}],
#  [{'label': 'clinical_variable',
#    'value': 'pretreatment calculated creatinine clearance'},
#   {'label': 'lower_bound', 'value': '>= 50 mL/minute'}],
#  [{'label': 'Cancer', 'value': 'Second primary malignancy'},
#   {'label': 'Cancer', 'value': 'in situ carcinoma of the cervix'},
#   {'label': 'Cancer',
#    'value': 'adequately treated non-melanomatous carcinoma of the skin'},
#   {'label': 'Cancer',
#    'value': 'other malignancy treated at least 5 years previously with no evidence of recurrence'}],
#  [{'label': 'treatment', 'value': 'iodinated intravenous contrast'},
#   {'label': 'clinical_variable', 'value': 'radiographic procedure'},
#   {'label': 'upper_bound', 'value': 'within 3 months of study registration'}],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [{'label': 'chronic_disease', 'value': 'cancer'},
#   {'label': 'chronic_disease', 'value': 'acute myocardial infarction'}],
#  [{'label': 'clinical_variable', 'value': 'Aspartate aminotransferase AST'},
#   {'label': 'clinical_variable', 'value': 'alanine aminotransferase ALT'},
#   {'label': 'upper_bound',
#    'value': '3 x the institutional upper limit of normal'}],
#  [{'label': 'clinical_variable', 'value': 'hepatitis B surface antigen'}],
#  [{'label': 'age', 'value': 'age'},
#   {'label': 'lower_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '40'}],
#  [{'label': 'chronic_disease', 'value': 'Epilepsy partial seizure'}],
#  [{'label': 'contraception_consent',
#    'value': 'effective > 90% reliability form of contraception'},
#   {'label': 'upper_bound', 'value': '90%'},
#   {'label': 'contraception_consent',
#    'value': 'for 4 weeks following the last study drug administration'}],
#  [{'label': 'treatment', 'value': 'vascular access'},
#   {'label': 'treatment', 'value': 'study drug'},
#   {'label': 'treatment', 'value': 'blood sampling'},
#   {'label': 'treatment', 'value': 'study drug infusion'}],
#  [{'label': 'chronic_disease', 'value': 'sleep apnea'},
#   {'label': 'clinical_variable', 'value': 'Untreated'}],
#  [{'label': 'chronic_disease', 'value': 'secondary headache disorder'},
#   {'label': 'clinical_variable', 'value': 'brain tumor'}],
#  [{'label': 'treatment', 'value': 'bilateral orchiectomy'},
#   {'label': 'treatment', 'value': 'Prior'}],
#  [{'label': 'chronic_disease', 'value': 'drug or alcohol abuser'},
#   {'label': 'chronic_disease', 'value': 'psychological disorder'}],
#  [{'label': 'clinical_variable', 'value': 'Serum total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '1.5 times the upper limit of normal ULN'}],
#  [{'label': 'chronic_disease', 'value': 'HIV-positive patients'},
#   {'label': 'treatment',
#    'value': 'highly active antiretroviral therapy HAART'},
#   {'label': 'clinical_variable', 'value': 'CD4 count'},
#   {'label': 'lower_bound', 'value': '200 cells/microliter'},
#   {'label': 'upper_bound', 'value': '30 days prior to registration'}],
#  [{'label': 'clinical_variable', 'value': 'total bilirubin'},
#   {'label': 'upper_bound', 'value': 'upper normal institutional limits'},
#   {'label': 'chronic_disease', 'value': "Gilbert's disease"},
#   {'label': 'clinical_variable', 'value': 'elevated serum bilirubin level'}],
#  [{'label': 'treatment', 'value': 'prior RAI therapy therapy'},
#   {'label': 'upper_bound',
#    'value': '6 months prior to initiation of therapy on this protocol'}],
#  [{'label': 'pregnancy', 'value': 'wish to become pregnant'},
#   {'label': 'clinical_variable', 'value': 'study period'}],
#  [{'label': 'pregnancy', 'value': 'lactating'}],
#  [{'label': 'chronic_disease', 'value': 'Poorly controlled depression'}],
#  [{'label': 'gender', 'value': 'Male'},
#   {'label': 'gender', 'value': 'females'}],
#  [{'label': 'age', 'value': 'ages'},
#   {'label': 'lower_bound', 'value': '18'},
#   {'label': 'upper_bound', 'value': '70'}],
#  [{'label': 'technology_access', 'value': 'venous access'},
#   {'label': 'clinical_variable', 'value': 'blood drawing'},
#   {'label': 'clinical_variable', 'value': '5 day infusions'},
#   {'label': 'clinical_variable', 'value': 'lymphapheresis'}],
#  [{'label': 'clinical_variable',
#    'value': 'Eastern Cooperative Oncology Group ECOG performance status'},
#   {'label': 'clinical_variable', 'value': 'PS'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '1'},
#   {'label': 'clinical_variable', 'value': '2'}],
#  [{'label': 'clinical_variable', 'value': 'Insomnia complaints'},
#   {'label': 'lower_bound', 'value': '6'},
#   {'label': 'clinical_variable', 'value': 'months'}],
#  [{'label': 'clinical_variable', 'value': 'blood donation'},
#   {'label': 'clinical_variable', 'value': 'sperm donation'},
#   {'label': 'clinical_variable', 'value': 'semen donation'},
#   {'label': 'clinical_variable', 'value': 'study therapy'},
#   {'label': 'lower_bound', 'value': '28'},
#   {'label': 'clinical_variable', 'value': 'days'}],
#  [{'label': 'clinical_variable', 'value': 'hysterectomy'},
#   {'label': 'clinical_variable', 'value': 'benign indication'},
#   {'label': 'clinical_variable', 'value': 'abnormal uterine bleeding'},
#   {'label': 'clinical_variable', 'value': 'menorrhagia'},
#   {'label': 'clinical_variable', 'value': 'uterine fibroids'},
#   {'label': 'clinical_variable', 'value': 'adenomyosis'},
#   {'label': 'clinical_variable', 'value': 'pelvic pain'},
#   {'label': 'clinical_variable', 'value': 'dysmenorrhea'},
#   {'label': 'clinical_variable', 'value': 'pelvic organ prolapse'},
#   {'label': 'clinical_variable', 'value': 'endometriosis'}],
#  [{'label': 'chronic_disease',
#    'value': 'uncontrolled bacterial viral or fungal infection'},
#   {'label': 'treatment', 'value': 'currently taking medication'},
#   {'label': 'clinical_variable',
#    'value': 'progression or no clinical improvement'},
#   {'label': 'clinical_variable', 'value': 'time of enrollment'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'pregnancy', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'negative pregnancy test'}],
#  [{'label': 'treatment', 'value': 'biopsy'},
#   {'label': 'clinical_variable', 'value': 'site of disease'},
#   {'label': 'clinical_variable', 'value': 'lung/pleura'},
#   {'label': 'clinical_variable', 'value': 'bone'},
#   {'label': 'clinical_variable', 'value': 'unsafe'},
#   {'label': 'clinical_variable', 'value': 'principal investigator'}],
#  [{'label': 'clinical_variable', 'value': 'distant metastases'}],
#  [{'label': 'clinical_variable', 'value': 'Insulin requirement'},
#   {'label': 'clinical_variable', 'value': '> 1.0 U/kg/day'},
#   {'label': 'clinical_variable', 'value': '> 60 U/day total'},
#   {'label': 'clinical_variable', 'value': '< 15 U/day'}],
#  [{'label': 'clinical_variable', 'value': 'Residual symptoms'},
#   {'label': 'clinical_variable', 'value': 'total score'},
#   {'label': 'clinical_variable', 'value': 'PANSS'},
#   {'label': 'clinical_variable', 'value': 'Visit 1 evaluations'},
#   {'label': 'lower_bound', 'value': '110'},
#   {'label': 'lower_bound', 'value': '60'}],
#  [{'label': 'clinical_variable', 'value': 'probability'},
#   {'label': 'clinical_variable', 'value': 'BRCA mutation'},
#   {'label': 'clinical_variable', 'value': 'BRCAPRO'},
#   {'label': 'clinical_variable', 'value': 'similar model'},
#   {'label': 'lower_bound', 'value': '10%'}],
#  [{'label': 'treatment', 'value': 'therapeutic radiation'},
#   {'label': 'clinical_variable', 'value': 'region'},
#   {'label': 'clinical_variable', 'value': 'study eye'}],
#  [{'label': 'clinical_variable', 'value': 'Metallic implant'}],
#  [{'label': 'allergy_name', 'value': 'Fluoxetine'}],
#  [{'label': 'chronic_disease', 'value': 'Therapy-related MDS'},
#   {'label': 'clinical_variable', 'value': 'MDS'},
#   {'label': 'treatment', 'value': 'systemic chemotherapy'},
#   {'label': 'treatment', 'value': 'radiation'},
#   {'label': 'treatment', 'value': 'malignancy'}],
#  [{'label': 'clinical_variable', 'value': 'weight change'},
#   {'label': 'clinical_variable', 'value': '+/- 25 pounds'},
#   {'label': 'clinical_variable', 'value': '1 year'}],
#  [{'label': 'chronic_disease', 'value': 'Active varicella zoster infection'}],
#  [{'label': 'clinical_variable', 'value': 'fluid resuscitation'},
#   {'label': 'clinical_variable',
#    'value': 'Clinical definition of kidney damage'}],
#  [{'label': 'treatment', 'value': 'monoclonal antibody'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to study'}],
#  [{'label': 'chronic_disease', 'value': 'carotid artery disease'}],
#  [{'label': 'clinical_variable', 'value': 'Hypocitraturic CaP stone formers'}],
#  [{'label': 'treatment',
#    'value': 'non-permitted inflammatory bowel disease IBD therapies'},
#   {'label': 'treatment', 'value': 'natalizumab'},
#   {'label': 'treatment', 'value': 'vedolizumab'},
#   {'label': 'treatment', 'value': 'efalizumab'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'chronic_disease', 'value': 'infectious hepatitis type B'},
#   {'label': 'chronic_disease', 'value': 'infectious hepatitis type C'}],
#  [{'label': 'clinical_variable', 'value': 'Measurable disease'},
#   {'label': 'clinical_variable', 'value': 'RECIST v1.1 criteria'},
#   {'label': 'clinical_variable', 'value': 'Baseline measurements'},
#   {'label': 'clinical_variable', 'value': 'ALL sites of disease'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to Enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'performance status'},
#   {'label': 'clinical_variable', 'value': 'ECOG Performance Scale'},
#   {'label': 'clinical_variable', 'value': 'life expectancy'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '3 months'}],
#  [{'label': 'clinical_variable', 'value': 'substrates'},
#   {'label': 'clinical_variable', 'value': 'CYP 3A4/5'},
#   {'label': 'clinical_variable', 'value': 'CYP1A2'},
#   {'label': 'clinical_variable', 'value': 'therapeutic window'},
#   {'label': 'lower_bound', 'value': 'three weeks'}],
#  [{'label': 'clinical_variable', 'value': 'CPP'},
#   {'label': 'clinical_variable', 'value': 'pelvic pain'},
#   {'label': 'clinical_variable', 'value': 'non-cyclical'},
#   {'label': 'clinical_variable', 'value': 'duration'},
#   {'label': 'lower_bound', 'value': '6 months'},
#   {'label': 'clinical_variable', 'value': 'refractory'},
#   {'label': 'clinical_variable', 'value': 'other treatments'}],
#  [{'label': 'clinical_variable', 'value': 'current use'},
#   {'label': 'clinical_variable', 'value': 'opioid pain medications'}],
#  [{'label': 'clinical_variable', 'value': 'diet'},
#   {'label': 'clinical_variable', 'value': 'oily fish'},
#   {'label': 'lower_bound', 'value': '1-2 days per week'},
#   {'label': 'clinical_variable', 'value': 'mackerel'},
#   {'label': 'clinical_variable', 'value': 'salmon'},
#   {'label': 'clinical_variable', 'value': 'sardines'},
#   {'label': 'clinical_variable', 'value': 'cold water fish'}],
#  [{'label': 'allergy_name', 'value': 'iodine'}],
#  [{'label': 'clinical_variable', 'value': 'NYHA classification'},
#   {'label': 'clinical_variable', 'value': 'III'},
#   {'label': 'clinical_variable', 'value': 'IV'}],
#  [{'label': 'chronic_disease', 'value': 'connective tissue disorder'},
#   {'label': 'clinical_variable',
#    'value': "vascular Ehlers Danlos Marfan's syndrome"},
#   {'label': 'clinical_variable',
#    'value': 'prior open surgical aortic replacement'},
#   {'label': 'clinical_variable', 'value': 'endovascular repair'},
#   {'label': 'clinical_variable', 'value': 'surgical graft'},
#   {'label': 'clinical_variable', 'value': 'endograft'},
#   {'label': 'clinical_variable', 'value': 'investigational endograft'}],
#  [{'label': 'treatment', 'value': 'PDEV inhibition'},
#   {'label': 'clinical_variable', 'value': 'erectile dysfunction'},
#   {'label': 'clinical_variable', 'value': 'medication'}],
#  [{'label': 'clinical_variable', 'value': 'surgical procedure'},
#   {'label': 'clinical_variable', 'value': 'lumbar levels'},
#   {'label': 'lower_bound', 'value': 'more than one'}],
#  [{'label': 'pregnancy', 'value': 'pregnant'},
#   {'label': 'exclusion_criteria',
#    'value': 'become pregnant after enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'alkaline phosphatase AP'},
#   {'label': 'upper_bound', 'value': '> 3 upper limit of normal ULN'},
#   {'label': 'time_frame', 'value': 'within 3 months of screening'}],
#  [{'label': 'clinical_variable', 'value': 'Implanted pacemaker'},
#   {'label': 'clinical_variable', 'value': 'cardiac defibrillator'}],
#  [{'label': 'consent', 'value': 'Informed consent'},
#   {'label': 'consent_type', 'value': 'written consent'},
#   {'label': 'consent_signer',
#    'value': "participant's legally authorized guardian"}],
#  [{'label': 'exclusion_criteria', 'value': 'Major birth defect'},
#   {'label': 'exclusion_criteria', 'value': 'malformation syndrome'}],
#  [{'label': 'age', 'value': '18 - 39 years'},
#   {'label': 'clinical_variable', 'value': '15% TBSA'}],
#  [{'label': 'gender', 'value': 'female'}],
#  [{'label': 'allergy_name', 'value': 'allopurinol'},
#   {'label': 'allergy_name', 'value': 'rasburicase'}],
#  [{'label': 'chronic_disease', 'value': 'Malabsorption syndrome'}],
#  [{'label': 'clinical_variable', 'value': 'cognitively impaired'}],
#  [{'label': 'chronic_disease', 'value': 'Phantom limb pain'}],
#  [{'label': 'pregnancy', 'value': 'Pregnancy'}],
#  [{'label': 'clinical_variable',
#    'value': 'Child not completing all pre-procedure work-up'},
#   {'label': 'clinical_variable', 'value': 'Stage II Glenn surgery'},
#   {'label': 'clinical_variable', 'value': 'section 6 of this protocol'},
#   {'label': 'clinical_variable', 'value': 'pre-procedure work-up documented'},
#   {'label': 'clinical_variable', 'value': 'safety concern'},
#   {'label': 'clinical_variable', 'value': 'site investigator'}],
#  [{'label': 'clinical_variable', 'value': 'Presence of any non-healing wound'},
#   {'label': 'clinical_variable', 'value': 'fracture'},
#   {'label': 'clinical_variable', 'value': 'ulcer'}],
#  [{'label': 'gender', 'value': 'nursing women'}],
#  [{'label': 'Cancer', 'value': 'past cancer history'},
#   {'label': 'clinical_variable', 'value': '2 years'},
#   {'label': 'clinical_variable', 'value': 'ongoing active malignancy'},
#   {'label': 'clinical_variable',
#    'value': 'substantial potential for recurrence'},
#   {'label': 'treatment', 'value': 'discussed with the Sponsor'},
#   {'label': 'treatment', 'value': 'study entry'}],
#  [{'label': 'clinical_variable',
#    'value': 'second or third degree heart block'},
#   {'label': 'clinical_variable',
#    'value': 'subject currently has a pacemaker'}],
#  [{'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': '6 months'},
#   {'label': 'clinical_variable', 'value': 'prior to registration'}],
#  [{'label': 'treatment', 'value': 'chronic transfusions'},
#   {'label': 'clinical_variable', 'value': 'clinical stroke'},
#   {'label': 'clinical_variable', 'value': 'MRA cerebral vasculopathy'},
#   {'label': 'treatment', 'value': 'excluded'},
#   {'label': 'treatment', 'value': 'SWITCH study'},
#   {'label': 'treatment', 'value': 'hydroxyurea arm'},
#   {'label': 'clinical_variable', 'value': 'recurrent stroke'},
#   {'label': 'clinical_variable', 'value': 'chronic transfusion arm'}],
#  [{'label': 'treatment', 'value': 'Concomitant cardiac surgery'}],
#  [{'label': 'clinical_variable', 'value': 'Alcohol use'},
#   {'label': 'upper_bound', 'value': 'more than 4 drinks per day'}],
#  [{'label': 'age', 'value': 'Age'},
#   {'label': 'lower_bound', 'value': '18 years'}],
#  [{'label': 'chronic_disease', 'value': 'acute pancreatitis'},
#   {'label': 'chronic_disease', 'value': 'chronic pancreatitis'},
#   {'label': 'lower_bound', 'value': '1 year'}],
#  [{'label': 'clinical_variable',
#    'value': 'Estimated glomerular filtration rate'},
#   {'label': 'lower_bound', 'value': '< 60 mL/min 1.73m2'}],
#  [{'label': 'clinical_variable', 'value': 'Cochlear nerve deficiency'}],
#  [{'label': 'clinical_variable', 'value': 'Creatinine'},
#   {'label': 'upper_bound',
#    'value': '1.5 x institutional upper limit of normal'},
#   {'label': 'clinical_variable', 'value': 'creatinine clearance'},
#   {'label': 'lower_bound', 'value': '> 60 mL/min/1.73 m2'}],
#  [{'label': 'treatment', 'value': 'Radiation therapy'},
#   {'label': 'treatment', 'value': 'external radiation therapy'},
#   {'label': 'treatment', 'value': 'systemic treatment with radionuclides'},
#   {'label': 'upper_bound', 'value': '2 weeks'},
#   {'label': 'upper_bound', 'value': '4 weeks'},
#   {'label': 'clinical_variable', 'value': 'bone or brain metastasis'},
#   {'label': 'clinical_variable',
#    'value': 'clinically relevant ongoing complications'}],
#  [{'label': 'clinical_variable', 'value': 'Platelets'},
#   {'label': 'lower_bound', 'value': '>= 100,000/mcL'}],
#  [{'label': 'clinical_variable', 'value': 'HIV-1 infected'},
#   {'label': 'clinical_variable', 'value': 'treatment-experienced'},
#   {'label': 'clinical_variable', 'value': 'virologically suppressed'},
#   {'label': 'gender', 'value': 'males'}],
#  [{'label': 'clinical_variable', 'value': 'Active'},
#   {'label': 'clinical_variable', 'value': 'autoimmune disease'}],
#  [{'label': 'Cancer', 'value': 'prostate cancer'},
#   {'label': 'treatment', 'value': 'LHRH agonists or antagonists'}],
#  [{'label': 'age', 'value': '18 yo'},
#   {'label': 'age', 'value': '60 yo'},
#   {'label': 'treatment', 'value': 'Cohort 1 only'}],
#  [{'label': 'clinical_variable', 'value': 'Third degree heart block'}],
#  [{'label': 'Cancer', 'value': 'intrahepatic carcinoma'},
#   {'label': 'clinical_variable', 'value': 'Confirmed diagnosis'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'chronic_disease', 'value': 'Liver cirrhosis'},
#   {'label': 'clinical_variable', 'value': 'transaminases'},
#   {'label': 'upper_bound', 'value': '3x of normal limits'},
#   {'label': 'clinical_variable', 'value': 'bilirubin'},
#   {'label': 'upper_bound', 'value': '2.0'}],
#  [{'label': 'clinical_variable', 'value': 'Absolute contraindications'},
#   {'label': 'clinical_variable', 'value': 'liver biopsy'},
#   {'label': 'clinical_variable', 'value': 'coagulopathy'}],
#  [{'label': 'language_fluency', 'value': 'English speaking'}],
#  [{'label': 'age', 'value': 'At least 18 years of age'}],
#  [{'label': 'Cancer', 'value': 'CD20- positive B-cell lymphoma'},
#   {'label': 'clinical_variable', 'value': 'Histologically documented'},
#   {'label': 'clinical_variable', 'value': 'local laboratory'}],
#  [{'label': 'clinical_variable', 'value': 'Bilirubin', 'lower_bound': '< 3x'},
#   {'label': 'clinical_variable', 'value': 'AST', 'lower_bound': '< 3x'},
#   {'label': 'clinical_variable',
#    'value': 'Serum creatinine',
#    'lower_bound': '< 2x upper limit of normal'},
#   {'label': 'clinical_variable', 'value': 'Hgb', 'lower_bound': '> 8.0'},
#   {'label': 'clinical_variable', 'value': 'plts', 'lower_bound': '> 20'}],
#  [{'label': 'clinical_variable', 'value': 'mTBI'},
#   {'label': 'clinical_variable',
#    'value': 'Veterans Health Administration VHA /Department of Defense DoD criteria'},
#   {'label': 'clinical_variable',
#    'value': 'persisting symptoms',
#    'lower_bound': '> 3 months post injury'}],
#  [{'label': 'clinical_variable', 'value': 'optimally medicated'},
#   {'label': 'clinical_variable',
#    'value': 'change in mediction type or dosage',
#    'lower_bound': '3 months prior to enrolling in the study'},
#   {'label': 'clinical_variable',
#    'value': 'medications',
#    'lower_bound': 'not causing significant or serious advese effects'}],
#  [{'label': 'gender', 'value': 'women'},
#   {'label': 'pregnancy', 'value': 'breast feeding'}],
#  [{'label': 'clinical_variable',
#    'value': 'uncontrolled coagulation blood disorders like haemophilia'},
#   {'label': 'Cancer', 'value': 'malignant tumors'},
#   {'label': 'clinical_variable', 'value': 'fear of needles'}],
#  [{'label': 'chronic_disease', 'value': 'recurrent seizures'}],
#  [{'label': 'Cancer', 'value': 'malignancies'}],
#  [{'label': 'clinical_variable', 'value': '> 25% decrease'},
#   {'label': 'clinical_variable', 'value': 'depressive symptoms'},
#   {'label': 'clinical_variable', 'value': 'QIDS-SR score'},
#   {'label': 'clinical_variable', 'value': 'Screening'},
#   {'label': 'clinical_variable', 'value': 'Randomization'}],
#  [{'label': 'clinical_variable', 'value': 'Severe hypersensitivity'},
#   {'label': 'clinical_variable', 'value': 'Grade 3'},
#   {'label': 'treatment', 'value': 'pembrolizumab'},
#   {'label': 'clinical_variable', 'value': 'excipients'}],
#  [{'label': 'clinical_variable', 'value': 'Available for follow-up'},
#   {'label': 'clinical_variable', 'value': '12 months'}],
#  [{'label': 'clinical_variable', 'value': 'Invasive infection'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'age', 'value': '40-80'},
#   {'label': 'clinical_variable', 'value': 'good health'}],
#  [{'label': 'clinical_variable', 'value': 'Reversible causes'},
#   {'label': 'clinical_variable', 'value': 'atrial arrhythmia'},
#   {'label': 'clinical_variable', 'value': 'hyperthyroidism'},
#   {'label': 'clinical_variable', 'value': 'sarcoidosis'},
#   {'label': 'clinical_variable', 'value': 'pulmonary embolism'}],
#  [{'label': 'treatment', 'value': 'prostanoid'},
#   {'label': 'clinical_variable', 'value': 'portopulmonary hypertension'}],
#  [{'label': 'chronic_disease', 'value': 'diabetes'}],
#  [{'label': 'clinical_variable', 'value': 'Score'},
#   {'label': 'clinical_variable', 'value': 'screening ISR Erythema Index'},
#   {'label': 'upper_bound', 'value': '50'}],
#  [{'label': 'clinical_variable', 'value': 'Atrial fibrillation'},
#   {'label': 'clinical_variable', 'value': 'rapid ventricular response'}],
#  [{'label': 'clinical_variable', 'value': 'Pre-existing stable medication'},
#   {'label': 'clinical_variable', 'value': 'tic'},
#   {'label': 'clinical_variable', 'value': 'family agrees'},
#   {'label': 'clinical_variable', 'value': 'med changes'},
#   {'label': 'clinical_variable', 'value': 'acute phase of the study'}],
#  [{'label': 'chronic_disease', 'value': 'active autoimmune disease'},
#   {'label': 'upper_bound', 'value': 'past 2 years'}],
#  [{'label': 'clinical_variable', 'value': 'Bone lesions'},
#   {'label': 'clinical_variable', 'value': 'osteolytic lesions'},
#   {'label': 'clinical_variable',
#    'value': 'skeletal radiography computerized tomography CT'},
#   {'label': 'clinical_variable',
#    'value': '2-deoxy-2 F-18 fluoro-D-glucose positron emission tomography CT PET-CT'}],
#  [{'label': 'chronic_disease', 'value': 'pulmonary embolus'}],
#  [{'label': 'chronic_disease',
#    'value': 'New York Heart Association congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'class 3 or higher'}],
#  [{'label': 'age', 'value': '18'}],
#  [{'label': 'chronic_disease', 'value': 'bariatric surgery'}],
#  [{'label': 'clinical_variable', 'value': 'Castrate testosterone levels'},
#   {'label': 'lower_bound', 'value': '50 ng/dL'}],
#  [{'label': 'chronic_disease', 'value': 'solid organ transplant'},
#   {'label': 'chronic_disease', 'value': 'bone marrow transplant'}],
#  [{'label': 'clinical_variable', 'value': 'asthma'},
#   {'label': 'clinical_variable', 'value': 'bronchiectasis'},
#   {'label': 'clinical_variable', 'value': 'cystic fibrosis'},
#   {'label': 'clinical_variable',
#    'value': 'severe alpha-1 antitrypsin deficiency'}],
#  [{'label': 'clinical_variable', 'value': 'esophageal spasm'}],
#  [{'label': 'clinical_variable', 'value': 'bone marrow biopsy'},
#   {'label': 'clinical_variable', 'value': 'baseline fibrosis score'},
#   {'label': 'clinical_variable', 'value': 'consent'},
#   {'label': 'clinical_variable', 'value': 'tissue collection'},
#   {'label': 'clinical_variable', 'value': 'protocol mandated testing'},
#   {'label': 'upper_bound', 'value': 'four weeks'}],
#  [{'label': 'clinical_variable', 'value': 'neurodegenerative diseases'},
#   {'label': 'clinical_variable', 'value': 'MS'}],
#  [{'label': 'clinical_variable', 'value': 'Coronary Artery Calcium scanning'},
#   {'label': 'upper_bound', 'value': '6 months'},
#   {'label': 'gender', 'value': 'gender'},
#   {'label': 'clinical_variable', 'value': 'CAC score'}],
#  [{'label': 'clinical_variable', 'value': 'CKD stage 5'},
# ...
#   {'label': 'clinical_variable', 'value': 'active'}],
#  [{'label': 'treatment', 'value': 'support person'},
#   {'label': 'clinical_variable', 'value': 'Spouse'},
#   {'label': 'clinical_variable', 'value': 'partner'},
#   {'label': 'clinical_variable', 'value': 'mother'}],
#  [{'label': 'Cancer', 'value': 'esophageal cancer'},
#   {'label': 'Cancer', 'value': 'gastric cancer'},
#   {'label': 'lower_bound', 'value': '15'},
#   {'label': 'upper_bound', 'value': '30'}],
#  [{'label': 'clinical_variable', 'value': 'severe adverse reaction'},
#   {'label': 'treatment', 'value': 'study medications'}],
#  [{'label': 'age', 'value': '18-69 years'}],
#  [{'label': 'treatment',
#    'value': 'red blood cell and/or platelet transfusions'}],
#  [{'label': 'treatment', 'value': 'Immunotherapy'},
#   {'label': 'treatment', 'value': 'Interferons'},
#   {'label': 'treatment', 'value': 'Cytokines'},
#   {'label': 'treatment', 'value': 'PD-1/PD-L1 antagonists'}],
#  [{'label': 'clinical_variable', 'value': 'Elevated serum PSA'},
#   {'label': 'clinical_variable', 'value': 'prostate specific antigen'},
#   {'label': 'lower_bound', 'value': '> 4 ng/ml'},
#   {'label': 'clinical_variable', 'value': 'abnormal digital rectal exam'}],
#  [{'label': 'technology_access', 'value': 'smart phone'},
#   {'label': 'technology_access', 'value': 'device'},
#   {'label': 'treatment', 'value': 'app usage'}],
#  [{'label': 'Cancer', 'value': 'Relapsed or primary refractory metastatic'}],
#  [{'label': 'clinical_variable', 'value': 'Head trauma'},
#   {'label': 'clinical_variable', 'value': 'central nervous system injury'}],
#  [{'label': 'clinical_variable', 'value': 'serious suicide'},
#   {'label': 'clinical_variable', 'value': 'homicide risk'}],
#  [{'label': 'clinical_variable', 'value': 'acute decompensated HF'}],
#  [{'label': 'clinical_variable', 'value': 'diabetic retinopathy'}],
#  [{'label': 'chronic_disease', 'value': 'liver cirrhosis'},
#   {'label': 'clinical_variable', 'value': 'severity'},
#   {'label': 'treatment', 'value': 'cyclosporine'},
#   {'label': 'treatment', 'value': 'eltrombopag'},
#   {'label': 'clinical_variable', 'value': 'albumin'},
#   {'label': 'lower_bound', 'value': '< 35g/L'}],
#  [{'label': 'clinical_variable', 'value': 'platelets'},
#   {'label': 'lower_bound', 'value': '< 100,000/ L'}],
#  [{'label': 'clinical_variable', 'value': 'primary anxiety disorder'},
#   {'label': 'clinical_variable', 'value': 'primary eating disorders'},
#   {'label': 'clinical_variable', 'value': 'functional impairment'}],
#  [{'label': 'clinical_variable', 'value': 'stabilizing implants'},
#   {'label': 'clinical_variable', 'value': 'bone'},
#   {'label': 'clinical_variable', 'value': 'cyst'}],
#  [{'label': 'clinical_variable', 'value': 'HIV'},
#   {'label': 'clinical_variable', 'value': 'HIV antibody test'},
#   {'label': 'clinical_variable', 'value': 'confirmatory tests'},
#   {'label': 'clinical_variable', 'value': 'screening'},
#   {'label': 'lower_bound', 'value': 'within 12 months before screening'},
#   {'label': 'lower_bound', 'value': 'at screening'}],
#  [{'label': 'clinical_variable', 'value': 'Breath alcohol level'},
#   {'label': 'upper_bound', 'value': '0.01'}],
#  [{'label': 'clinical_variable', 'value': 'Total bilirubin'},
#   {'label': 'upper_bound', 'value': '1.5 x ULN'}],
#  [{'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'clinical_variable', 'value': 'AST'},
#   {'label': 'upper_bound', 'value': '2.5 X upper limit of normal ULN'}],
#  [{'label': 'clinical_variable',
#    'value': 'uncontrolled bacterial fungal or viral infection'},
#   {'label': 'clinical_variable', 'value': 'progressive symptoms'},
#   {'label': 'clinical_variable', 'value': 'therapy'},
#   {'label': 'clinical_variable', 'value': 'CD8+ memory T-cell infusion'}],
#  [{'label': 'contraception_consent', 'value': 'birth control'}],
#  [{'label': 'Cancer', 'value': 'ovarian cancer'}],
#  [{'label': 'language_fluency', 'value': 'English'}],
#  [{'label': 'treatment', 'value': 'whole-lung or hemi-thorax irradiation'},
#   {'label': 'clinical_variable', 'value': '12 Gy'},
#   {'label': 'clinical_variable', 'value': '6 months'}],
#  [{'label': 'chronic_disease', 'value': 'deep vein thrombosis'},
#   {'label': 'chronic_disease', 'value': 'pulmonary embolus'}],
#  [{'label': 'pregnancy', 'value': 'lactating females'}],
#  [{'label': 'clinical_variable',
#    'value': 'Eastern Cooperative Oncology Group ECOG Performance Status'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '2'}],
#  [{'label': 'Cancer', 'value': 'acute lymphoblastic leukemia lymphoma'}],
#  [{'label': 'treatment', 'value': 'ketotifen'},
#   {'label': 'previous', 'value': 'previous'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'},
#   {'label': 'pregnancy', 'value': 'breast-feeding'},
#   {'label': 'gender', 'value': 'females'},
#   {'label': 'exclusion', 'value': 'excluded'},
#   {'label': 'clinical_variable', 'value': 'mutagenic effects'},
#   {'label': 'clinical_variable', 'value': 'developing fetus'},
#   {'label': 'clinical_variable', 'value': 'newborn'}],
#  [{'label': 'Cancer', 'value': 'Infiltrating ductal carcinoma'},
#   {'label': 'Cancer', 'value': 'DCIS'},
#   {'label': 'clinical_variable', 'value': 'stage'},
#   {'label': 'clinical_variable', 'value': 'T0'},
#   {'label': 'clinical_variable', 'value': 'T1'},
#   {'label': 'clinical_variable', 'value': 'T2'},
#   {'label': 'upper_bound', 'value': '3.0 cm'},
#   {'label': 'clinical_variable', 'value': 'N0'},
#   {'label': 'clinical_variable', 'value': 'M0'}],
#  [{'label': 'Cancer', 'value': 'non-melanomatous skin cancer'},
#   {'label': 'Cancer', 'value': 'lentigo maligna'}],
#  [{'label': 'chronic_disease',
#    'value': 'Insulin dependent diabetes mellitus'}],
#  [{'label': 'clinical_variable', 'value': 'total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '2.5 X institutional upper limit of normal'}],
#  [{'label': 'treatment', 'value': 'IV tPA'},
#   {'label': 'upper_bound', 'value': '> 3 hours from stroke onset'}],
#  [{'label': 'clinical_variable',
#    'value': 'Hamilton Depression Rating Scale-24 HRSD-24 score'},
#   {'label': 'lower_bound', 'value': '8'},
#   {'label': 'upper_bound', 'value': '24'}],
#  [{'label': 'treatment', 'value': 'Surgery intent'},
#   {'label': 'upper_bound', 'value': '4 weeks'}],
#  [{'label': 'gender', 'value': 'female'},
#   {'label': 'contraception_consent', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'sexually mature woman'},
#   {'label': 'clinical_variable', 'value': 'hysterectomy'},
#   {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'},
#   {'label': 'clinical_variable', 'value': 'naturally postmenopausal'},
#   {'label': 'lower_bound', 'value': '24 consecutive months'},
#   {'label': 'clinical_variable', 'value': 'menses'},
#   {'label': 'lower_bound', 'value': 'preceding 24 consecutive months'}],
#  [{'label': 'chronic_disease', 'value': 'active acute infections'},
#   {'label': 'chronic_disease', 'value': 'chronic infections'},
#   {'label': 'chronic_disease', 'value': 'uncontrolled severe infections'}],
#  [{'label': 'clinical_variable', 'value': 'diagnosis'},
#   {'label': 'clinical_variable', 'value': 'PAH isolated left heart disease'},
#   {'label': 'clinical_variable',
#    'value': 'lung disease chronic obstructive pulmonary disease'},
#   {'label': 'clinical_variable', 'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable', 'value': 'CTEPH'},
#   {'label': 'clinical_variable', 'value': 'established clinical criteria'}],
#  [{'label': 'treatment', 'value': 'initiate treatment'},
#   {'label': 'treatment', 'value': 'doxorubicin'},
#   {'label': 'clinical_variable', 'value': 'starting dose'},
#   {'label': 'clinical_variable', 'value': '75 mg/m2'},
#   {'label': 'clinical_variable', 'value': 'routine care'}],
#  [{'label': 'chronic_disease', 'value': 'psychiatric disorder'},
#   {'label': 'chronic_disease', 'value': 'substance abuse disorder'}],
#  [{'label': 'clinical_variable', 'value': 'catheter-associated UTI'}],
#  [{'label': 'clinical_variable',
#    'value': 'malignancy-associated microcalcifications'},
#   {'label': 'clinical_variable', 'value': 'post-excision mammography'}],
#  [{'label': 'clinical_variable', 'value': 'lung involvement'},
#   {'label': 'clinical_variable', 'value': 'organ involvement'},
#   {'label': 'clinical_variable', 'value': 'renal angiomyolipomas'},
#   {'label': 'clinical_variable', 'value': 'chylous effusions'},
#   {'label': 'clinical_variable', 'value': 'lymphangioleiomyomas'}],
#  [{'label': 'chronic_disease', 'value': 'epilepsy'},
#   {'label': 'clinical_variable', 'value': 'seizures'}],
#  [{'label': 'treatment', 'value': 'amifostine'},
#   {'label': 'treatment', 'value': 'abdominal radiotherapy'},
#   {'label': 'treatment', 'value': 'quinolone antibiotic therapy'}],
#  [{'label': 'clinical_variable', 'value': 'ambulate'},
#   {'label': 'clinical_variable', 'value': 'household distances'},
#   {'label': 'lower_bound', 'value': '50ft'}],
#  [{'label': 'age', 'value': '18'}, {'label': 'lower_bound', 'value': '18'}],
#  [{'label': 'gender', 'value': 'Male'}],
#  [{'label': 'Cancer', 'value': 'CNS metastases'},
#   {'label': 'clinical_variable', 'value': 'active CNS metastases'}],
#  [{'label': 'clinical_variable', 'value': 'MAS'},
#   {'label': 'clinical_variable', 'value': '98-D-0145'}],
#  [{'label': 'treatment', 'value': 'standard neoadjuvant chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'anthracycline'},
#   {'label': 'clinical_variable', 'value': 'taxane-based regimen'},
#   {'label': 'lower_bound', 'value': '8 weeks'}],
#  [{'label': 'clinical_variable', 'value': 'bone marrow metastases'},
#   {'label': 'clinical_variable', 'value': 'high urine catecholamine levels'}],
#  [{'label': 'chronic_disease', 'value': 'Osteoporosis'},
#   {'label': 'clinical_variable', 'value': 'recent fracture'},
#   {'label': 'clinical_variable', 'value': 'hip'},
#   {'label': 'clinical_variable', 'value': 'spinal joints'}],
#  [{'label': 'clinical_variable', 'value': 'unilateral inguinal herna'},
#   {'label': 'clinical_variable', 'value': 'bilateral inguinal herna'},
#   {'label': 'treatment', 'value': 'laparoscopic repair'}],
#  [{'label': 'treatment', 'value': 'Corticosteroid injection'},
#   {'label': 'clinical_variable', 'value': 'treatment site'},
#   {'label': 'lower_bound', 'value': 'within 1 month'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG Performance Status'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '1'}],
#  [{'label': 'allergy_name', 'value': 'dextromethorphan'},
#   {'label': 'allergy_name', 'value': 'vitamin A'},
#   {'label': 'allergy_name', 'value': 'isotretinoin'}],
#  [{'label': 'treatment', 'value': 'investigational drug or device study'},
#   {'label': 'lower_bound', 'value': 'within the past 6 weeks'}],
#  [{'label': 'allergy_name', 'value': 'conductive hydrogels'}],
#  [{'label': 'chronic_disease', 'value': 'severe cognitive impairment'}],
#  [{'label': 'clinical_variable', 'value': 'Current smoking'},
#   {'label': 'clinical_variable', 'value': 'history of smoking'},
#   {'label': 'clinical_variable', 'value': 'past 12 months'}],
#  [{'label': 'age', 'value': '18 year olds'}],
#  [{'label': 'chronic_disease',
#    'value': 'history of prior pelvic irradiation'}],
#  [{'label': 'clinical_variable',
#    'value': 'lifetime history of suicide attempt'},
#   {'label': 'clinical_variable', 'value': 'active attempt'},
#   {'label': 'clinical_variable', 'value': 'interrupted attempt'},
#   {'label': 'clinical_variable', 'value': 'aborted attempt'},
#   {'label': 'clinical_variable', 'value': 'suicidal ideation'},
#   {'label': 'clinical_variable', 'value': 'past 6 months'},
#   {'label': 'clinical_variable', 'value': "positive response 'Yes'"},
#   {'label': 'clinical_variable', 'value': 'Question 4'},
#   {'label': 'clinical_variable', 'value': 'Question 5'},
#   {'label': 'clinical_variable', 'value': 'C-SSRS'},
#   {'label': 'clinical_variable', 'value': 'Screening'}],
#  [{'label': 'clinical_variable', 'value': 'AST'},
#   {'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'upper_bound', 'value': '2 times upper limit of normal ULN'}],
#  [{'label': 'clinical_variable',
#    'value': 'Human papillomavirus HPV 16-positive disease'},
#   {'label': 'clinical_variable', 'value': 'PCR'}],
#  [{'label': 'treatment', 'value': 'LY2606368'},
#   {'label': 'treatment', 'value': 'Chk inhibitors'}],
#  [{'label': 'clinical_variable', 'value': 'cannabis use'},
#   {'label': 'clinical_variable', 'value': 'urine'},
#   {'label': 'clinical_variable', 'value': 'screening visit'},
#   {'label': 'clinical_variable',
#    'value': 'Gas Chromatography GC Mass Spectrometry MS laboratory test'},
#   {'label': 'clinical_variable', 'value': 'clinic admission'}],
#  [{'label': 'chronic_disease', 'value': 'schizophrenia'}],
#  [{'label': 'gender', 'value': 'women of childbearing potential'}],
#  [{'label': 'treatment', 'value': 'gonadal steroid preparations'},
#   {'label': 'lower_bound', 'value': '1 month'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'clinical_variable', 'value': 'Absolute neutrophil count'},
#   {'label': 'lower_bound', 'value': '1,500/mcL'}],
#  [{'label': 'allergy_name', 'value': 'Everolimus'},
#   {'label': 'allergy_name', 'value': 'rapamycins'},
#   {'label': 'allergy_name', 'value': 'sirolimus'},
#   {'label': 'allergy_name', 'value': 'temsirolimus'}],
#  [{'label': 'chronic_disease', 'value': 'cardiac/cardiovascular disease'},
#   {'label': 'clinical_variable', 'value': 'pulmonary compromise'}],
#  [{'label': 'chronic_disease', 'value': 'radiculopathy'}],
#  [{'label': 'age', 'value': '18 years'},
#   {'label': 'lower_bound', 'value': 'older'}],
#  [{'label': 'chronic_disease', 'value': 'Gastrointestinal Bleed'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable', 'value': 'active infectious hepatitis'},
#   {'label': 'clinical_variable', 'value': 'type A'},
#   {'label': 'clinical_variable', 'value': 'type B'},
#   {'label': 'clinical_variable', 'value': 'type C'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'clinical_variable', 'value': 'serious psychiatric symptoms'},
#   {'label': 'clinical_variable', 'value': 'CNO trained staff'}],
#  [{'label': 'clinical_variable', 'value': 'disease relapse'},
#   {'label': 'clinical_variable', 'value': 'active GVHD'},
#   {'label': 'clinical_variable',
#    'value': 'history of more than Stage 1 skin acute GVHD'},
#   {'label': 'clinical_variable', 'value': 'history of cGVHD'}],
#  [{'label': 'chronic_disease', 'value': 'thyroid disease'}],
#  [{'label': 'clinical_variable', 'value': 'Immunocompromised patients'},
#   {'label': 'clinical_variable',
#    'value': 'serologically positive for human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable', 'value': 'receiving antiviral therapy'}],
#  [{'label': 'clinical_variable',
#    'value': 'positive Hepatitis B surface antigen'},
#   {'label': 'clinical_variable', 'value': 'antihepatitis B core antibody'}],
#  [{'label': 'gender', 'value': 'Men'},
#   {'label': 'contraception_consent', 'value': 'adequate contraception'},
#   {'label': 'clinical_variable', 'value': 'duration of study participation'},
#   {'label': 'clinical_variable', 'value': '3 months'}],
#  [{'label': 'clinical_variable', 'value': 'Serum creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 x ULN'}],
#  [{'label': 'chronic_disease', 'value': 'seizure disorder'}],
#  [{'label': 'treatment', 'value': 'investigational agents'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to enrollment'},
#   {'label': 'treatment', 'value': 'radiation therapy'}],
#  [{'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'clinical_variable', 'value': 'BUN'},
#   {'label': 'upper_bound', 'value': '2.0 ULN'},
#   {'label': 'clinical_variable', 'value': 'estimated creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 X ULN'},
#   {'label': 'clinical_variable', 'value': 'age'},
#   {'label': 'clinical_variable', 'value': 'laboratory abnormality'},
#   {'label': 'clinical_variable', 'value': 'Investigator'},
#   {'label': 'clinical_variable', 'value': 'clinically significant'},
#   {'label': 'clinical_variable', 'value': '14 days before Screening'}]]

# %%
print(f"Total cost in for {total_batches*batch_size} sentences is : $ {round(total_cost,4)}")
print(f"Total cost in for {total_batches*batch_size} sentences is : Rs. {round(total_cost*doller_to_rs, 4)}")
# Out:
# Total cost in for 500 sentences is : $ 0.1811
# Total cost in for 500 sentences is : Rs. 15.0661

# %%
# This function finds the indexes of the entites identifed by the GPT Model
def find_entities_in_sentence(entities : List, sentence:str)->List:
    """
    This Function finds the start index, end index for the entites from the given sentence
    Args
    entities: List of Entities for which indexes to be found
    sentence : Respective sentence from which index will be found
    
    Returns
    List of entities with start index, end index
    """
    
    matched_entities = []
    
    for entity in entities:
        label = entity['label']
        value = entity['value']
        start_idx = sentence.find(value)
        
        while start_idx != -1:
            end_idx = start_idx + len(value)
            matched_entities.append({
                'label': label,
                'start': start_idx,
                'end': end_idx,
                'value': value
            })
            
            start_idx = sentence.find(value, end_idx)
    
    return matched_entities

# %%
final_result_gpt
# Out:
# [[{'label': 'treatment', 'value': 'oral administration'},
#   {'label': 'treatment', 'value': 'study drug'}],
#  [{'label': 'pregnancy', 'value': 'Current pregnancy'}],
#  [{'label': 'pregnancy', 'value': 'Singleton pregnancy'}],
#  [{'label': 'clinical_variable', 'value': 'steroids'},
#   {'label': 'clinical_variable', 'value': 'surgery'},
#   {'label': 'clinical_variable', 'value': 'recovery period'},
#   {'label': 'clinical_variable', 'value': 'betamethasone hypersensitivity'}],
#  [{'label': 'clinical_variable', 'value': 'rheumatic valve disease'},
#   {'label': 'clinical_variable', 'value': 'AF phenotype'}],
#  [{'label': 'chronic_disease', 'value': 'Severe liver dysfunction'},
#   {'label': 'clinical_variable', 'value': 'LFT'},
#   {'label': 'upper_bound', 'value': '3X upper limit of normal'}],
#  [{'label': 'clinical_variable', 'value': 'Serum M-protein'},
#   {'label': 'lower_bound', 'value': '1.0 g/dL'}],
#  [{'label': 'gender', 'value': 'Males or females'}],
#  [{'label': 'Cancer', 'value': 'Negative for malignancy'},
#   {'label': 'clinical_variable', 'value': 'past 5 years'}],
#  [{'label': 'technology_access',
#    'value': 'available for up to 6 hrs every day'},
#   {'label': 'clinical_variable', 'value': 'two 2-week test periods'},
#   {'label': 'clinical_variable',
#    'value': 'intervening break of 7- 10 days each'}],
#  [{'label': 'Cancer', 'value': 'recurrent and/or metastatic thyroid cancer'}],
#  [{'label': 'treatment', 'value': 'paclitaxel'}],
#  [{'label': 'clinical_variable', 'value': 'Mean arterial pressure'},
#   {'label': 'lower_bound', 'value': '65'}],
#  [{'label': 'clinical_variable', 'value': 'White blood cells WBC'},
#   {'label': 'upper_bound', 'value': '15,000 cells/mcL'}],
#  [{'label': 'chronic_disease', 'value': 'Acute medical illness'}],
#  [{'label': 'treatment', 'value': 'chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'prior'}],
#  [{'label': 'chronic_disease', 'value': 'thromboembolism'},
#   {'label': 'clinical_variable', 'value': 'thrombophilia'}],
#  [{'label': 'clinical_variable', 'value': 'stationary position'},
#   {'label': 'treatment', 'value': 'HIFU'}],
#  [{'label': 'chronic_disease', 'value': 'hepatitis B'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis B survace antigen HBsAg reactive'},
#   {'label': 'clinical_variable', 'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'value': 'HCV RNA qualitative is detected infection'}],
#  [{'label': 'chronic_disease', 'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable', 'value': 'severely impaired lung function'}],
#  [{'label': 'chronic_disease', 'value': 'Diabetes Mellitus'}],
#  [{'label': 'chronic_disease',
#    'value': 'Seizure disorder requiring medication'}],
#  [{'label': 'bmi', 'value': 'BMI'},
#   {'label': 'lower_bound', 'value': '25 kg/m^2'}],
#  [{'label': 'clinical_variable', 'value': 'Life expectancy'},
#   {'label': 'lower_bound', 'value': '12 weeks'}],
#  [{'label': 'clinical_variable', 'value': 'History/physical examination'},
#   {'label': 'clinical_variable', 'value': 'digital rectal examination'},
#   {'label': 'clinical_variable', 'value': 'prostate examination'},
#   {'label': 'clinical_variable', 'value': 'skeletal system examination'},
#   {'label': 'clinical_variable', 'value': 'abdomen examination'},
#   {'label': 'lower_bound', 'value': '90 days prior to registration'}],
#  [{'label': 'Cancer', 'value': 'secondary primary lung cancer'},
#   {'label': 'chronic_disease', 'value': 'lung cancer'},
#   {'label': 'upper_bound', 'value': '2 year prior to registration'}],
#  [{'label': 'clinical_variable',
#    'value': 'serum human chorionic gonadotropin hCG'},
#   {'label': 'pregnancy', 'value': 'positive'}],
#  [{'label': 'clinical_variable', 'value': 'Total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '=< 1.5 x institutional upper limit of normal ULN'},
#   {'label': 'upper_bound',
#    'value': "=< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation"},
#   {'label': 'upper_bound',
#    'value': '3.0 mg/dL within 2 weeks prior to enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'Other neurological diagnosis'}],
#  [{'label': 'clinical_variable', 'value': 'Major neurological disorder'}],
#  [{'label': 'treatment', 'value': 'Anti-tumor necrosis factor agents'}],
#  [{'label': 'chronic_disease',
#    'value': 'Clinically significant heart disease'},
#   {'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': 'arterial thrombotic events'},
#   {'label': 'clinical_variable', 'value': 'severe or unstable angina'},
#   {'label': 'clinical_variable',
#    'value': 'New York Heart Association NYHA class II- IV heart disease'}],
#  [{'label': 'clinical_variable', 'value': 'normal sinus rhythm'},
#   {'label': 'clinical_variable', 'value': 'ECG documented'},
#   {'label': 'clinical_variable',
#    'value': 'within the two weeks prior to the screening Holter'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'clinical_variable', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'negative pregnancy test'}],
#  [{'label': 'clinical_variable', 'value': 'Hematologic abnormalities'},
#   {'label': 'clinical_variable', 'value': 'pancytopenia'},
#   {'label': 'clinical_variable', 'value': 'aplastic anemia'}],
#  [{'label': 'language_fluency', 'value': 'Poor English comprehension'}],
#  [{'label': 'clinical_variable', 'value': 'multiple myeloma'},
#   {'label': 'clinical_variable',
#    'value': 'International Myeloma Working Group IMWG diagnostic criteria'}],
#  [{'label': 'chronic_disease', 'value': 'hypercontractile bladder'},
#   {'label': 'chronic_disease', 'value': 'non-compliant bladder'},
#   {'label': 'chronic_disease', 'value': 'hydronephrosis'},
#   {'label': 'chronic_disease', 'value': 'neurogenic bladder'}],
#  [{'label': 'age', 'value': '40'},
#   {'label': 'age', 'value': '59'},
#   {'label': 'clinical_variable', 'value': '15% TBSA'}],
#  [{'label': 'age', 'value': '2'},
#   {'label': 'lower_bound', 'value': 'at least'}],
#  [{'label': 'age', 'value': '1 year'},
#   {'label': 'upper_bound', 'value': '18 years'}],
#  [{'label': 'treatment', 'value': 'Therapeutic antibodies'},
#   {'label': 'treatment', 'value': 'bevacizumab'}],
#  [{'label': 'clinical_variable', 'value': 'postmenopausal status'},
#   {'label': 'clinical_variable', 'value': 'surgical/natural menopause'},
#   {'label': 'clinical_variable', 'value': 'ovarian suppression'},
#   {'label': 'clinical_variable', 'value': '28 days'},
#   {'label': 'clinical_variable', 'value': 'Day 1 of Cycle 1'},
#   {'label': 'clinical_variable', 'value': 'gonadotropin-releasing hormone'},
#   {'label': 'clinical_variable', 'value': 'goserelin'}],
#  [{'label': 'Cancer', 'value': 'Pancreatic Cancer'},
#   {'label': 'clinical_variable',
#    'value': 'potentially surgically resectable'}],
#  [{'label': 'clinical_variable', 'value': 'lower urinary tract symptoms'},
#   {'label': 'clinical_variable', 'value': 'LUTS'},
#   {'label': 'clinical_variable', 'value': '1 year'}],
#  [{'label': 'treatment', 'value': 'pacemaker ICD'}],
#  [{'label': 'treatment', 'value': 'spinal block'},
#   {'label': 'treatment', 'value': 'BBBD chemotherapy'}],
#  [{'label': 'clinical_variable', 'value': 'linked to care/evaluation'},
#   {'label': 'upper_bound', 'value': '30 days'}],
#  [{'label': 'clinical_variable', 'value': 'Dry weight'},
#   {'label': 'clinical_variable', 'value': 'height'},
#   {'label': 'upper_bound', 'value': '7 days'}],
#  [{'label': 'treatment', 'value': 'antipsychotics'}],
#  [{'label': 'gender', 'value': 'lactating women'}],
#  [{'label': 'clinical_variable', 'value': 'SGPT ALT'},
#   {'label': 'upper_bound', 'value': '5 x ULN for age'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'chronic_disease', 'value': 'anaphylaxis'},
#   {'label': 'treatment', 'value': 'echinocandin'}],
#  [{'label': 'pregnancy', 'value': 'possibly pregnant'}],
#  [{'label': 'treatment', 'value': 'ipsilateral knee surgery'},
#   {'label': 'treatment', 'value': 'ligament reconstruction'},
#   {'label': 'treatment', 'value': 'osteotomy'}],
#  [{'label': 'chronic_disease', 'value': 'congestive heart failure'}],
#  [{'label': 'treatment', 'value': 'ongoing, tapering therapy'},
#   {'label': 'clinical_variable', 'value': 'resolved acute GVHD'}],
#  [{'label': 'treatment', 'value': 'IV docetaxel'},
#   {'label': 'clinical_variable', 'value': '75 mg/m^2'},
#   {'label': 'clinical_variable', 'value': '5 mg/m^2'},
#   {'label': 'treatment', 'value': 'carboplatin'},
#   {'label': 'clinical_variable', 'value': 'AUC 5-6'},
#   {'label': 'clinical_variable', 'value': 'every 21 days'}],
#  [{'label': 'contraception_consent',
#    'value': 'effective form of birth control'}],
#  [{'label': 'chronic_disease', 'value': 'HIV-positive patients'},
#   {'label': 'treatment', 'value': 'combination antiretroviral therapy'},
#   {'label': 'clinical_variable', 'value': 'LY2606368'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG performance status'},
#   {'label': 'clinical_variable', 'value': 'Karnofsky'},
#   {'label': 'lower_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '60%'}],
#  [{'label': 'Cancer', 'value': 'Metastatic breast cancer'},
#   {'label': 'clinical_variable', 'value': 'triple negative'},
#   {'label': 'clinical_variable', 'value': 'ER'},
#   {'label': 'clinical_variable', 'value': 'CCND1c'},
#   {'label': 'clinical_variable', 'value': 'HER2'},
#   {'label': 'treatment', 'value': 'trastuzumab and PD0332991 therapy'},
#   {'label': 'upper_bound', 'value': '55'}],
#  [{'label': 'age', 'value': '18'},
#   {'label': 'lower_bound', 'value': 'years old'}],
#  [{'label': 'treatment', 'value': 'recurrent or refractory solid tumors'},
#   {'label': 'clinical_variable', 'value': 'central nervous system CNS tumors'},
#   {'label': 'clinical_variable', 'value': 'CNS metastases'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'chronic_disease',
#    'value': 'acquired immunodeficiency syndrome AIDS'}],
#  [{'label': 'treatment', 'value': 'planned surgery'},
#   {'label': 'treatment', 'value': 'general anesthesia'},
#   {'label': 'clinical_variable', 'value': 'pharmacotherapy period'}],
#  [{'label': 'clinical_variable', 'value': 'Maximal diameter'},
#   {'label': 'clinical_variable', 'value': 'hepatocellular carcinoma'},
#   {'label': 'upper_bound', 'value': '15 cm'}],
#  [{'label': 'gender', 'value': 'Females'},
#   {'label': 'clinical_variable', 'value': 'menopausal'},
#   {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'}],
#  [{'label': 'gender', 'value': 'female'}],
#  [{'label': 'clinical_variable', 'value': 'ADHD'},
#   {'label': 'clinical_variable', 'value': 'clinician administered CAADID'},
#   {'label': 'clinical_variable', 'value': 'clinical interview'}],
#  [{'label': 'clinical_variable', 'value': 'active malignancy'},
#   {'label': 'upper_bound', 'value': '3 years prior to registration'}],
#  [{'label': 'treatment', 'value': 'intensive induction chemotherapy'},
#   {'label': 'treatment', 'value': 'radiotherapy'},
#   {'label': 'treatment', 'value': 'biologic treatment'},
#   {'label': 'clinical_variable', 'value': 'active malignancy'},
#   {'label': 'treatment', 'value': 'maintenance chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'study medical monitor'}],
#  [{'label': 'treatment', 'value': 'CEM carboplatin'},
#   {'label': 'treatment', 'value': 'etoposide'},
#   {'label': 'treatment', 'value': 'melphalan therapy'},
#   {'label': 'lower_bound', 'value': '30 days prior to 131I-MIBG therapy'},
#   {'label': 'treatment', 'value': '131I-MIBG therapy'},
#   {'label': 'lower_bound',
#    'value': '30 days following administration of 131I-MIBG'}],
#  [{'label': 'clinical_variable', 'value': 'HIV positive'},
#   {'label': 'clinical_variable', 'value': 'CD4 count'},
#   {'label': 'lower_bound', 'value': '350 cells/microliter'}],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [{'label': 'clinical_variable', 'value': 'Preoperative evaluation'},
#   {'label': 'treatment', 'value': 'CT scan'},
#   {'label': 'treatment', 'value': 'MRI'},
#   {'label': 'treatment', 'value': 'ultrasound'}],
#  [{'label': 'clinical_variable', 'value': 'claustrophobic'}],
#  [{'label': 'chronic_disease', 'value': 'malignancy'}],
#  [{'label': 'clinical_variable', 'value': 'drinking'},
#   {'label': 'clinical_variable', 'value': 'past 90 days'},
#   {'label': 'upper_bound', 'value': '80%'}],
#  [{'label': 'language_fluency', 'value': 'English'}],
#  [{'label': 'chronic_disease', 'value': 'cerebrovascular accident CVA'},
#   {'label': 'chronic_disease', 'value': 'transient ischemic attack TIA'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'treatment', 'value': 'platinum-containing chemotherapy'},
#   {'label': 'treatment', 'value': 'neoadjuvant or adjuvant treatment'},
#   {'label': 'treatment', 'value': 'platinum-containing chemotherapy'},
#   {'label': 'upper_bound', 'value': '1 2 months'}],
#  [{'label': 'treatment', 'value': 'investigational drug'},
#   {'label': 'lower_bound', 'value': '4 weeks'}],
#  [{'label': 'allergy_name', 'value': 'gadolinium Gd contrast material'}],
#  [{'label': 'clinical_variable', 'value': 'Wheezing'}],
#  [{'label': 'treatment', 'value': 'toxic effects'},
#   {'label': 'clinical_variable', 'value': 'prior therapy'}],
#  [{'label': 'chronic_disease', 'value': 'uncontrolled inter-current illness'},
#   {'label': 'clinical_variable', 'value': 'ongoing or active infection'},
#   {'label': 'clinical_variable',
#    'value': 'symptomatic congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'NYHA Gr.2 or >'},
#   {'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': 'unstable angina pectoris'},
#   {'label': 'clinical_variable', 'value': 'past 12 months'}],
#  [{'label': 'age', 'value': '18'},
#   {'label': 'lower_bound', 'value': '75 years'}],
#  [{'label': 'Cancer', 'value': 'recurrent carcinoma of the vulva'},
#   {'label': 'treatment', 'value': 'previous treatment'}],
#  [{'label': 'clinical_variable', 'value': 'PaO2/FiO2'},
#   {'label': 'lower_bound', 'value': '300'}],
#  [{'label': 'clinical_variable', 'value': 'amyloid imaging disclosure'}],
#  [{'label': 'age', 'value': '4 to 6 months'}],
#  [{'label': 'chronic_disease', 'value': 'asthma'}],
#  [{'label': 'chronic_disease', 'value': 'bleeding disorder'}],
#  [{'label': 'age', 'value': '18 years or older'}],
#  [{'label': 'treatment', 'value': 'second line hormonal therapy'},
#   {'label': 'treatment', 'value': 'bicalutamide'},
#   {'label': 'treatment', 'value': 'nilutamide'},
#   {'label': 'treatment', 'value': 'flutamide'},
#   {'label': 'treatment', 'value': 'ketoconazole'},
#   {'label': 'treatment', 'value': 'abiraterone'},
#   {'label': 'treatment', 'value': 'enzalutamide'},
#   {'label': 'treatment', 'value': 'ARN-509'}],
#  [{'label': 'clinical_variable', 'value': 'endometrial cancer'},
#   {'label': 'treatment', 'value': 'routinely'},
#   {'label': 'treatment', 'value': 'newly diagnosed'},
#   {'label': 'treatment', 'value': 'centers'},
#   {'label': 'treatment', 'value': 'US'}],
#  [{'label': 'clinical_variable', 'value': 'central nervous system lymphoma'},
#   {'label': 'clinical_variable', 'value': 'active'}],
#  [{'label': 'chronic_disease', 'value': 'autoimmune diseases'}],
#  [{'label': 'Cancer', 'value': 'acute myeloid leukemia AML'},
#   {'label': 'Cancer', 'value': 'acute lymphoblastic leukemia ALL'},
#   {'label': 'Cancer', 'value': 'chronic myelogenous leukemia CML'},
#   {'label': 'Cancer', 'value': 'chronic lymphocytic leukemia CLL'},
#   {'label': 'Cancer', 'value': 'non-Hodgkin lymphoma NHL'},
#   {'label': 'Cancer', 'value': 'Hodgkin lymphoma NHL'},
#   {'label': 'Cancer', 'value': 'Hodgkin lymphoma'},
#   {'label': 'Cancer', 'value': 'multiple myeloma MM'},
#   {'label': 'Cancer', 'value': 'myelodysplastic syndrome MDS'},
#   {'label': 'Cancer', 'value': 'AL amyloidosis'},
#   {'label': 'Cancer', 'value': 'diamond blackfan anemia'},
#   {'label': 'Cancer', 'value': 'myelofibrosis'},
#   {'label': 'Cancer', 'value': 'myeloproliferative disease'},
#   {'label': 'Cancer', 'value': 'sickle cell anemia'},
#   {'label': 'Cancer', 'value': 'thalassemia'}],
#  [{'label': 'Cancer', 'value': 'HPV p16'},
#   {'label': 'Cancer', 'value': 'PD-L1'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG status'},
#   {'label': 'lower_bound', 'value': '3'},
#   {'label': 'upper_bound', 'value': '4'}],
#  [{'label': 'chronic_disease',
#    'value': 'pre-existing medical psychiatric or other condition'}],
#  [{'label': 'chronic_disease', 'value': 'medical conditions'},
#   {'label': 'chronic_disease', 'value': 'orthopedic injuries'},
#   {'label': 'chronic_disease', 'value': 'cardiovascular diseases'},
#   {'label': 'chronic_disease', 'value': 'liver diseases'},
#   {'label': 'chronic_disease', 'value': 'endocrine diseases'},
#   {'label': 'chronic_disease', 'value': 'pulmonary diseases'}],
#  [{'label': 'Cancer', 'value': 'lung cancer'}],
#  [{'label': 'chronic_disease', 'value': 'cord compression'},
#   {'label': 'chronic_disease', 'value': 'syrinx in the spinal cord'},
#   {'label': 'chronic_disease', 'value': 'spinal cord disease'},
#   {'label': 'chronic_disease', 'value': 'spinal stenosis'},
#   {'label': 'chronic_disease', 'value': 'spina bifida'},
#   {'label': 'chronic_disease', 'value': 'herniated cervical disk'}],
#  [{'label': 'gender', 'value': 'nursing woman'}],
#  [{'label': 'gender', 'value': 'pregnant women'}],
#  [{'label': 'chronic_disease', 'value': 'myocardial infarction'},
#   {'label': 'lower_bound', 'value': '6 months before enrollment'}],
#  [{'label': 'chronic_disease', 'value': 'Sickle cell anemia'}],
#  [{'label': 'chronic_disease', 'value': 'Myelodysplastic syndrome'}],
#  [{'label': 'treatment', 'value': 'corneal transplants'},
#   {'label': 'treatment', 'value': 'cadaver skin'},
#   {'label': 'treatment', 'value': 'bone transplants'}],
#  [{'label': 'treatment', 'value': 'Lovaza prescription fish oil'},
#   {'label': 'treatment', 'value': 'Lovaza'},
#   {'label': 'clinical_variable', 'value': '3 weeks'}],
#  [{'label': 'chronic_disease', 'value': 'cardiac condition'},
#   {'label': 'chronic_disease', 'value': 'asthma'},
#   {'label': 'chronic_disease', 'value': 'obstructive pulmonary disease'},
#   {'label': 'chronic_disease', 'value': 'seizure disorder'},
#   {'label': 'chronic_disease', 'value': 'urinary incontinence'},
#   {'label': 'chronic_disease', 'value': 'peptic ulcer disease'},
#   {'label': 'treatment', 'value': 'concurrent NSAIDs'}],
#  [{'label': 'clinical_variable', 'value': 'Karnofsky performance status'},
#   {'label': 'lower_bound', 'value': '70%'}],
#  [{'label': 'clinical_variable', 'value': 'Grade 4 - Fibrosis'}],
#  [{'label': 'clinical_variable', 'value': 'Follicular 17-hydroxyprogesterone'},
#   {'label': 'upper_bound', 'value': '300 ng/dl'},
#   {'label': 'clinical_variable', 'value': 'congenital adrenal hyperplasia'}],
#  [{'label': 'clinical_variable', 'value': 'Current oral steroid use'},
#   {'label': 'upper_bound', 'value': '4 weeks prior to registration'}],
#  [{'label': 'pregnancy', 'value': 'Not pregnant'}],
#  [{'label': 'chronic_disease',
#    'value': 'History of DVT or pulmonary embolism'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'chronic_disease', 'value': 'Hepatitis C'},
#   {'label': 'treatment', 'value': 'donor liver'}],
#  [{'label': 'clinical_variable', 'value': 'Renal insufficiency'},
#   {'label': 'clinical_variable', 'value': 'creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 mg/dL'}],
#  [{'label': 'treatment', 'value': 'investigational agent'},
#   {'label': 'upper_bound', 'value': '30 days prior to pre-registration'}],
#  [{'label': 'treatment', 'value': 'warfarin'},
#   {'label': 'clinical_variable', 'value': 'prophylaxis'},
#   {'label': 'clinical_variable', 'value': 'treatment of thrombosis'},
#   {'label': 'clinical_variable', 'value': 'INR values'}],
#  [{'label': 'age', 'value': '18 years'},
#   {'label': 'lower_bound', 'value': '18'}],
#  [{'label': 'chronic_disease', 'value': 'cerebral vascular event stroke'},
#   {'label': 'chronic_disease', 'value': 'transient ischemic attack'},
#   {'label': 'chronic_disease',
#    'value': 'unstable angina myocardial infarction'},
#   {'label': 'chronic_disease', 'value': 'cardiac symptoms'},
#   {'label': 'chronic_disease', 'value': 'congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'New York Heart Association Class'},
#   {'label': 'upper_bound', 'value': '6 months'}],
#  [{'label': 'treatment', 'value': 'breast conserving surgery'},
#   {'label': 'treatment', 'value': 'lumpectomy'},
#   {'label': 'treatment', 'value': 'radiation'}],
#  [{'label': 'age', 'value': 'age'}, {'label': 'lower_bound', 'value': '49'}],
#  [{'label': 'treatment', 'value': 'medication'},
#   {'label': 'clinical_variable', 'value': 'potentially dangerous interaction'},
#   {'label': 'treatment', 'value': 'propranolol'}],
#  [{'label': 'treatment', 'value': 'rIX-FP'},
#   {'label': 'clinical_variable', 'value': '100 EDs single-dose cohorts'},
#   {'label': 'clinical_variable', 'value': '50 EDs repeated-dose cohort'}],
#  [{'label': 'clinical_variable', 'value': 'Bilirubin'},
#   {'label': 'upper_bound', 'value': '2 x the ULN'}],
#  [{'label': 'chronic_disease', 'value': 'organ allograft'},
#   {'label': 'clinical_variable', 'value': 'corneal transplant'}],
#  [{'label': 'treatment', 'value': 'Autologous stem cell transplantation SCT'},
#   {'label': 'clinical_variable', 'value': '100 days prior to study drug'},
#   {'label': 'treatment', 'value': 'allogeneic SCT'},
#   {'label': 'treatment', 'value': 'solid organ transplantation'}],
#  [{'label': 'diagnosis', 'value': 'type 2 diabetes'}],
#  [{'label': 'history', 'value': 'active malignancy'},
#   {'label': 'upper_bound', 'value': 'last 3 years'}],
#  [{'label': 'clinical_variable', 'value': 'adverse events Grade'},
#   {'label': 'upper_bound', 'value': '> 1'},
#   {'label': 'treatment',
#    'value': 'prior therapies chemotherapy radiotherapy and/or surgery'},
#   {'label': 'clinical_variable', 'value': 'alopecia'}],
#  [{'label': 'clinical_variable', 'value': 'Pre-bronchodilator 50% FEV1'},
#   {'label': 'lower_bound', 'value': '< 85 %'},
#   {'label': 'clinical_variable', 'value': 'predicted normal value'},
#   {'label': 'clinical_variable', 'value': 'patient'},
#   {'label': 'clinical_variable', 'value': 'withholding bronchodilators'},
#   {'label': 'clinical_variable', 'value': 'Visit 101'},
#   {'label': 'clinical_variable', 'value': 'Visit 102'},
#   {'label': 'clinical_variable', 'value': 'ATS/ERS criteria'}],
#  [{'label': 'treatment', 'value': 'cetuximab'},
#   {'label': 'clinical_variable', 'value': 'incurable disease'}],
#  [{'label': 'treatment', 'value': 'herbal alternative medicines'}],
#  [{'label': 'age', 'value': '21 years'}],
#  [{'label': 'treatment', 'value': 'intravesical chemotherapy'}],
#  [{'label': 'clinical_variable', 'value': 'medication'},
#   {'label': 'clinical_variable', 'value': 'precautionary list'},
#   {'label': 'clinical_variable', 'value': 'nitroglycerin'}],
#  [{'label': 'clinical_variable', 'value': 'Severe aortic regurgitation'},
#   {'label': 'lower_bound', 'value': '3'}],
#  [{'label': 'clinical_variable', 'value': 'psychiatric or medical condition'},
#   {'label': 'treatment', 'value': 'interfere with treatment'}],
#  [{'label': 'age', 'value': '17'}, {'label': 'lower_bound', 'value': '17'}],
#  [{'label': 'Cancer', 'value': 'FL'},
#   {'label': 'clinical_variable', 'value': 'histopathologic confirmation'}],
#  [{'label': 'age', 'value': '16 years of age or older'},
#   {'label': 'clinical_variable', 'value': 'weighs'}],
#  [{'label': 'clinical_variable',
#    'value': 'Interval from start of initial radiation therapy to enrollment'},
#   {'label': 'lower_bound', 'value': '9 months'}],
#  [{'label': 'chronic_disease', 'value': 'diabetes requiring medication'}],
#  [{'label': 'contraception_consent', 'value': 'Not pregnant or nursing'},
#   {'label': 'contraception_consent',
#    'value': 'report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant women'}],
#  [{'label': 'chronic_disease', 'value': 'hepatitis B'},
#   {'label': 'chronic_disease', 'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis B virus surface antigen HBsAg reactive'},
#   {'label': 'clinical_variable',
#    'value': 'hepatitis C virus HCV ribonucleic acid RNA qualitative is detected'}],
#  [{'label': 'clinical_variable',
#    'value': 'pretreatment calculated creatinine clearance'},
#   {'label': 'lower_bound', 'value': '>= 50 mL/minute'}],
#  [{'label': 'Cancer', 'value': 'Second primary malignancy'},
#   {'label': 'Cancer', 'value': 'in situ carcinoma of the cervix'},
#   {'label': 'Cancer',
#    'value': 'adequately treated non-melanomatous carcinoma of the skin'},
#   {'label': 'Cancer',
#    'value': 'other malignancy treated at least 5 years previously with no evidence of recurrence'}],
#  [{'label': 'treatment', 'value': 'iodinated intravenous contrast'},
#   {'label': 'clinical_variable', 'value': 'radiographic procedure'},
#   {'label': 'upper_bound', 'value': 'within 3 months of study registration'}],
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  [{'label': 'chronic_disease', 'value': 'cancer'},
#   {'label': 'chronic_disease', 'value': 'acute myocardial infarction'}],
#  [{'label': 'clinical_variable', 'value': 'Aspartate aminotransferase AST'},
#   {'label': 'clinical_variable', 'value': 'alanine aminotransferase ALT'},
#   {'label': 'upper_bound',
#    'value': '3 x the institutional upper limit of normal'}],
#  [{'label': 'clinical_variable', 'value': 'hepatitis B surface antigen'}],
#  [{'label': 'age', 'value': 'age'},
#   {'label': 'lower_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '40'}],
#  [{'label': 'chronic_disease', 'value': 'Epilepsy partial seizure'}],
#  [{'label': 'contraception_consent',
#    'value': 'effective > 90% reliability form of contraception'},
#   {'label': 'upper_bound', 'value': '90%'},
#   {'label': 'contraception_consent',
#    'value': 'for 4 weeks following the last study drug administration'}],
#  [{'label': 'treatment', 'value': 'vascular access'},
#   {'label': 'treatment', 'value': 'study drug'},
#   {'label': 'treatment', 'value': 'blood sampling'},
#   {'label': 'treatment', 'value': 'study drug infusion'}],
#  [{'label': 'chronic_disease', 'value': 'sleep apnea'},
#   {'label': 'clinical_variable', 'value': 'Untreated'}],
#  [{'label': 'chronic_disease', 'value': 'secondary headache disorder'},
#   {'label': 'clinical_variable', 'value': 'brain tumor'}],
#  [{'label': 'treatment', 'value': 'bilateral orchiectomy'},
#   {'label': 'treatment', 'value': 'Prior'}],
#  [{'label': 'chronic_disease', 'value': 'drug or alcohol abuser'},
#   {'label': 'chronic_disease', 'value': 'psychological disorder'}],
#  [{'label': 'clinical_variable', 'value': 'Serum total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '1.5 times the upper limit of normal ULN'}],
#  [{'label': 'chronic_disease', 'value': 'HIV-positive patients'},
#   {'label': 'treatment',
#    'value': 'highly active antiretroviral therapy HAART'},
#   {'label': 'clinical_variable', 'value': 'CD4 count'},
#   {'label': 'lower_bound', 'value': '200 cells/microliter'},
#   {'label': 'upper_bound', 'value': '30 days prior to registration'}],
#  [{'label': 'clinical_variable', 'value': 'total bilirubin'},
#   {'label': 'upper_bound', 'value': 'upper normal institutional limits'},
#   {'label': 'chronic_disease', 'value': "Gilbert's disease"},
#   {'label': 'clinical_variable', 'value': 'elevated serum bilirubin level'}],
#  [{'label': 'treatment', 'value': 'prior RAI therapy therapy'},
#   {'label': 'upper_bound',
#    'value': '6 months prior to initiation of therapy on this protocol'}],
#  [{'label': 'pregnancy', 'value': 'wish to become pregnant'},
#   {'label': 'clinical_variable', 'value': 'study period'}],
#  [{'label': 'pregnancy', 'value': 'lactating'}],
#  [{'label': 'chronic_disease', 'value': 'Poorly controlled depression'}],
#  [{'label': 'gender', 'value': 'Male'},
#   {'label': 'gender', 'value': 'females'}],
#  [{'label': 'age', 'value': 'ages'},
#   {'label': 'lower_bound', 'value': '18'},
#   {'label': 'upper_bound', 'value': '70'}],
#  [{'label': 'technology_access', 'value': 'venous access'},
#   {'label': 'clinical_variable', 'value': 'blood drawing'},
#   {'label': 'clinical_variable', 'value': '5 day infusions'},
#   {'label': 'clinical_variable', 'value': 'lymphapheresis'}],
#  [{'label': 'clinical_variable',
#    'value': 'Eastern Cooperative Oncology Group ECOG performance status'},
#   {'label': 'clinical_variable', 'value': 'PS'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '1'},
#   {'label': 'clinical_variable', 'value': '2'}],
#  [{'label': 'clinical_variable', 'value': 'Insomnia complaints'},
#   {'label': 'lower_bound', 'value': '6'},
#   {'label': 'clinical_variable', 'value': 'months'}],
#  [{'label': 'clinical_variable', 'value': 'blood donation'},
#   {'label': 'clinical_variable', 'value': 'sperm donation'},
#   {'label': 'clinical_variable', 'value': 'semen donation'},
#   {'label': 'clinical_variable', 'value': 'study therapy'},
#   {'label': 'lower_bound', 'value': '28'},
#   {'label': 'clinical_variable', 'value': 'days'}],
#  [{'label': 'clinical_variable', 'value': 'hysterectomy'},
#   {'label': 'clinical_variable', 'value': 'benign indication'},
#   {'label': 'clinical_variable', 'value': 'abnormal uterine bleeding'},
#   {'label': 'clinical_variable', 'value': 'menorrhagia'},
#   {'label': 'clinical_variable', 'value': 'uterine fibroids'},
#   {'label': 'clinical_variable', 'value': 'adenomyosis'},
#   {'label': 'clinical_variable', 'value': 'pelvic pain'},
#   {'label': 'clinical_variable', 'value': 'dysmenorrhea'},
#   {'label': 'clinical_variable', 'value': 'pelvic organ prolapse'},
#   {'label': 'clinical_variable', 'value': 'endometriosis'}],
#  [{'label': 'chronic_disease',
#    'value': 'uncontrolled bacterial viral or fungal infection'},
#   {'label': 'treatment', 'value': 'currently taking medication'},
#   {'label': 'clinical_variable',
#    'value': 'progression or no clinical improvement'},
#   {'label': 'clinical_variable', 'value': 'time of enrollment'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'pregnancy', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'negative pregnancy test'}],
#  [{'label': 'treatment', 'value': 'biopsy'},
#   {'label': 'clinical_variable', 'value': 'site of disease'},
#   {'label': 'clinical_variable', 'value': 'lung/pleura'},
#   {'label': 'clinical_variable', 'value': 'bone'},
#   {'label': 'clinical_variable', 'value': 'unsafe'},
#   {'label': 'clinical_variable', 'value': 'principal investigator'}],
#  [{'label': 'clinical_variable', 'value': 'distant metastases'}],
#  [{'label': 'clinical_variable', 'value': 'Insulin requirement'},
#   {'label': 'clinical_variable', 'value': '> 1.0 U/kg/day'},
#   {'label': 'clinical_variable', 'value': '> 60 U/day total'},
#   {'label': 'clinical_variable', 'value': '< 15 U/day'}],
#  [{'label': 'clinical_variable', 'value': 'Residual symptoms'},
#   {'label': 'clinical_variable', 'value': 'total score'},
#   {'label': 'clinical_variable', 'value': 'PANSS'},
#   {'label': 'clinical_variable', 'value': 'Visit 1 evaluations'},
#   {'label': 'lower_bound', 'value': '110'},
#   {'label': 'lower_bound', 'value': '60'}],
#  [{'label': 'clinical_variable', 'value': 'probability'},
#   {'label': 'clinical_variable', 'value': 'BRCA mutation'},
#   {'label': 'clinical_variable', 'value': 'BRCAPRO'},
#   {'label': 'clinical_variable', 'value': 'similar model'},
#   {'label': 'lower_bound', 'value': '10%'}],
#  [{'label': 'treatment', 'value': 'therapeutic radiation'},
#   {'label': 'clinical_variable', 'value': 'region'},
#   {'label': 'clinical_variable', 'value': 'study eye'}],
#  [{'label': 'clinical_variable', 'value': 'Metallic implant'}],
#  [{'label': 'allergy_name', 'value': 'Fluoxetine'}],
#  [{'label': 'chronic_disease', 'value': 'Therapy-related MDS'},
#   {'label': 'clinical_variable', 'value': 'MDS'},
#   {'label': 'treatment', 'value': 'systemic chemotherapy'},
#   {'label': 'treatment', 'value': 'radiation'},
#   {'label': 'treatment', 'value': 'malignancy'}],
#  [{'label': 'clinical_variable', 'value': 'weight change'},
#   {'label': 'clinical_variable', 'value': '+/- 25 pounds'},
#   {'label': 'clinical_variable', 'value': '1 year'}],
#  [{'label': 'chronic_disease', 'value': 'Active varicella zoster infection'}],
#  [{'label': 'clinical_variable', 'value': 'fluid resuscitation'},
#   {'label': 'clinical_variable',
#    'value': 'Clinical definition of kidney damage'}],
#  [{'label': 'treatment', 'value': 'monoclonal antibody'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to study'}],
#  [{'label': 'chronic_disease', 'value': 'carotid artery disease'}],
#  [{'label': 'clinical_variable', 'value': 'Hypocitraturic CaP stone formers'}],
#  [{'label': 'treatment',
#    'value': 'non-permitted inflammatory bowel disease IBD therapies'},
#   {'label': 'treatment', 'value': 'natalizumab'},
#   {'label': 'treatment', 'value': 'vedolizumab'},
#   {'label': 'treatment', 'value': 'efalizumab'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'chronic_disease', 'value': 'infectious hepatitis type B'},
#   {'label': 'chronic_disease', 'value': 'infectious hepatitis type C'}],
#  [{'label': 'clinical_variable', 'value': 'Measurable disease'},
#   {'label': 'clinical_variable', 'value': 'RECIST v1.1 criteria'},
#   {'label': 'clinical_variable', 'value': 'Baseline measurements'},
#   {'label': 'clinical_variable', 'value': 'ALL sites of disease'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to Enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'performance status'},
#   {'label': 'clinical_variable', 'value': 'ECOG Performance Scale'},
#   {'label': 'clinical_variable', 'value': 'life expectancy'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '2'},
#   {'label': 'upper_bound', 'value': '3 months'}],
#  [{'label': 'clinical_variable', 'value': 'substrates'},
#   {'label': 'clinical_variable', 'value': 'CYP 3A4/5'},
#   {'label': 'clinical_variable', 'value': 'CYP1A2'},
#   {'label': 'clinical_variable', 'value': 'therapeutic window'},
#   {'label': 'lower_bound', 'value': 'three weeks'}],
#  [{'label': 'clinical_variable', 'value': 'CPP'},
#   {'label': 'clinical_variable', 'value': 'pelvic pain'},
#   {'label': 'clinical_variable', 'value': 'non-cyclical'},
#   {'label': 'clinical_variable', 'value': 'duration'},
#   {'label': 'lower_bound', 'value': '6 months'},
#   {'label': 'clinical_variable', 'value': 'refractory'},
#   {'label': 'clinical_variable', 'value': 'other treatments'}],
#  [{'label': 'clinical_variable', 'value': 'current use'},
#   {'label': 'clinical_variable', 'value': 'opioid pain medications'}],
#  [{'label': 'clinical_variable', 'value': 'diet'},
#   {'label': 'clinical_variable', 'value': 'oily fish'},
#   {'label': 'lower_bound', 'value': '1-2 days per week'},
#   {'label': 'clinical_variable', 'value': 'mackerel'},
#   {'label': 'clinical_variable', 'value': 'salmon'},
#   {'label': 'clinical_variable', 'value': 'sardines'},
#   {'label': 'clinical_variable', 'value': 'cold water fish'}],
#  [{'label': 'allergy_name', 'value': 'iodine'}],
#  [{'label': 'clinical_variable', 'value': 'NYHA classification'},
#   {'label': 'clinical_variable', 'value': 'III'},
#   {'label': 'clinical_variable', 'value': 'IV'}],
#  [{'label': 'chronic_disease', 'value': 'connective tissue disorder'},
#   {'label': 'clinical_variable',
#    'value': "vascular Ehlers Danlos Marfan's syndrome"},
#   {'label': 'clinical_variable',
#    'value': 'prior open surgical aortic replacement'},
#   {'label': 'clinical_variable', 'value': 'endovascular repair'},
#   {'label': 'clinical_variable', 'value': 'surgical graft'},
#   {'label': 'clinical_variable', 'value': 'endograft'},
#   {'label': 'clinical_variable', 'value': 'investigational endograft'}],
#  [{'label': 'treatment', 'value': 'PDEV inhibition'},
#   {'label': 'clinical_variable', 'value': 'erectile dysfunction'},
#   {'label': 'clinical_variable', 'value': 'medication'}],
#  [{'label': 'clinical_variable', 'value': 'surgical procedure'},
#   {'label': 'clinical_variable', 'value': 'lumbar levels'},
#   {'label': 'lower_bound', 'value': 'more than one'}],
#  [{'label': 'pregnancy', 'value': 'pregnant'},
#   {'label': 'exclusion_criteria',
#    'value': 'become pregnant after enrollment'}],
#  [{'label': 'clinical_variable', 'value': 'alkaline phosphatase AP'},
#   {'label': 'upper_bound', 'value': '> 3 upper limit of normal ULN'},
#   {'label': 'time_frame', 'value': 'within 3 months of screening'}],
#  [{'label': 'clinical_variable', 'value': 'Implanted pacemaker'},
#   {'label': 'clinical_variable', 'value': 'cardiac defibrillator'}],
#  [{'label': 'consent', 'value': 'Informed consent'},
#   {'label': 'consent_type', 'value': 'written consent'},
#   {'label': 'consent_signer',
#    'value': "participant's legally authorized guardian"}],
#  [{'label': 'exclusion_criteria', 'value': 'Major birth defect'},
#   {'label': 'exclusion_criteria', 'value': 'malformation syndrome'}],
#  [{'label': 'age', 'value': '18 - 39 years'},
#   {'label': 'clinical_variable', 'value': '15% TBSA'}],
#  [{'label': 'gender', 'value': 'female'}],
#  [{'label': 'allergy_name', 'value': 'allopurinol'},
#   {'label': 'allergy_name', 'value': 'rasburicase'}],
#  [{'label': 'chronic_disease', 'value': 'Malabsorption syndrome'}],
#  [{'label': 'clinical_variable', 'value': 'cognitively impaired'}],
#  [{'label': 'chronic_disease', 'value': 'Phantom limb pain'}],
#  [{'label': 'pregnancy', 'value': 'Pregnancy'}],
#  [{'label': 'clinical_variable',
#    'value': 'Child not completing all pre-procedure work-up'},
#   {'label': 'clinical_variable', 'value': 'Stage II Glenn surgery'},
#   {'label': 'clinical_variable', 'value': 'section 6 of this protocol'},
#   {'label': 'clinical_variable', 'value': 'pre-procedure work-up documented'},
#   {'label': 'clinical_variable', 'value': 'safety concern'},
#   {'label': 'clinical_variable', 'value': 'site investigator'}],
#  [{'label': 'clinical_variable', 'value': 'Presence of any non-healing wound'},
#   {'label': 'clinical_variable', 'value': 'fracture'},
#   {'label': 'clinical_variable', 'value': 'ulcer'}],
#  [{'label': 'gender', 'value': 'nursing women'}],
#  [{'label': 'Cancer', 'value': 'past cancer history'},
#   {'label': 'clinical_variable', 'value': '2 years'},
#   {'label': 'clinical_variable', 'value': 'ongoing active malignancy'},
#   {'label': 'clinical_variable',
#    'value': 'substantial potential for recurrence'},
#   {'label': 'treatment', 'value': 'discussed with the Sponsor'},
#   {'label': 'treatment', 'value': 'study entry'}],
#  [{'label': 'clinical_variable',
#    'value': 'second or third degree heart block'},
#   {'label': 'clinical_variable',
#    'value': 'subject currently has a pacemaker'}],
#  [{'label': 'clinical_variable', 'value': 'myocardial infarction'},
#   {'label': 'clinical_variable', 'value': '6 months'},
#   {'label': 'clinical_variable', 'value': 'prior to registration'}],
#  [{'label': 'treatment', 'value': 'chronic transfusions'},
#   {'label': 'clinical_variable', 'value': 'clinical stroke'},
#   {'label': 'clinical_variable', 'value': 'MRA cerebral vasculopathy'},
#   {'label': 'treatment', 'value': 'excluded'},
#   {'label': 'treatment', 'value': 'SWITCH study'},
#   {'label': 'treatment', 'value': 'hydroxyurea arm'},
#   {'label': 'clinical_variable', 'value': 'recurrent stroke'},
#   {'label': 'clinical_variable', 'value': 'chronic transfusion arm'}],
#  [{'label': 'treatment', 'value': 'Concomitant cardiac surgery'}],
#  [{'label': 'clinical_variable', 'value': 'Alcohol use'},
#   {'label': 'upper_bound', 'value': 'more than 4 drinks per day'}],
#  [{'label': 'age', 'value': 'Age'},
#   {'label': 'lower_bound', 'value': '18 years'}],
#  [{'label': 'chronic_disease', 'value': 'acute pancreatitis'},
#   {'label': 'chronic_disease', 'value': 'chronic pancreatitis'},
#   {'label': 'lower_bound', 'value': '1 year'}],
#  [{'label': 'clinical_variable',
#    'value': 'Estimated glomerular filtration rate'},
#   {'label': 'lower_bound', 'value': '< 60 mL/min 1.73m2'}],
#  [{'label': 'clinical_variable', 'value': 'Cochlear nerve deficiency'}],
#  [{'label': 'clinical_variable', 'value': 'Creatinine'},
#   {'label': 'upper_bound',
#    'value': '1.5 x institutional upper limit of normal'},
#   {'label': 'clinical_variable', 'value': 'creatinine clearance'},
#   {'label': 'lower_bound', 'value': '> 60 mL/min/1.73 m2'}],
#  [{'label': 'treatment', 'value': 'Radiation therapy'},
#   {'label': 'treatment', 'value': 'external radiation therapy'},
#   {'label': 'treatment', 'value': 'systemic treatment with radionuclides'},
#   {'label': 'upper_bound', 'value': '2 weeks'},
#   {'label': 'upper_bound', 'value': '4 weeks'},
#   {'label': 'clinical_variable', 'value': 'bone or brain metastasis'},
#   {'label': 'clinical_variable',
#    'value': 'clinically relevant ongoing complications'}],
#  [{'label': 'clinical_variable', 'value': 'Platelets'},
#   {'label': 'lower_bound', 'value': '>= 100,000/mcL'}],
#  [{'label': 'clinical_variable', 'value': 'HIV-1 infected'},
#   {'label': 'clinical_variable', 'value': 'treatment-experienced'},
#   {'label': 'clinical_variable', 'value': 'virologically suppressed'},
#   {'label': 'gender', 'value': 'males'}],
#  [{'label': 'clinical_variable', 'value': 'Active'},
#   {'label': 'clinical_variable', 'value': 'autoimmune disease'}],
#  [{'label': 'Cancer', 'value': 'prostate cancer'},
#   {'label': 'treatment', 'value': 'LHRH agonists or antagonists'}],
#  [{'label': 'age', 'value': '18 yo'},
#   {'label': 'age', 'value': '60 yo'},
#   {'label': 'treatment', 'value': 'Cohort 1 only'}],
#  [{'label': 'clinical_variable', 'value': 'Third degree heart block'}],
#  [{'label': 'Cancer', 'value': 'intrahepatic carcinoma'},
#   {'label': 'clinical_variable', 'value': 'Confirmed diagnosis'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'chronic_disease', 'value': 'Liver cirrhosis'},
#   {'label': 'clinical_variable', 'value': 'transaminases'},
#   {'label': 'upper_bound', 'value': '3x of normal limits'},
#   {'label': 'clinical_variable', 'value': 'bilirubin'},
#   {'label': 'upper_bound', 'value': '2.0'}],
#  [{'label': 'clinical_variable', 'value': 'Absolute contraindications'},
#   {'label': 'clinical_variable', 'value': 'liver biopsy'},
#   {'label': 'clinical_variable', 'value': 'coagulopathy'}],
#  [{'label': 'language_fluency', 'value': 'English speaking'}],
#  [{'label': 'age', 'value': 'At least 18 years of age'}],
#  [{'label': 'Cancer', 'value': 'CD20- positive B-cell lymphoma'},
#   {'label': 'clinical_variable', 'value': 'Histologically documented'},
#   {'label': 'clinical_variable', 'value': 'local laboratory'}],
#  [{'label': 'clinical_variable', 'value': 'Bilirubin', 'lower_bound': '< 3x'},
#   {'label': 'clinical_variable', 'value': 'AST', 'lower_bound': '< 3x'},
#   {'label': 'clinical_variable',
#    'value': 'Serum creatinine',
#    'lower_bound': '< 2x upper limit of normal'},
#   {'label': 'clinical_variable', 'value': 'Hgb', 'lower_bound': '> 8.0'},
#   {'label': 'clinical_variable', 'value': 'plts', 'lower_bound': '> 20'}],
#  [{'label': 'clinical_variable', 'value': 'mTBI'},
#   {'label': 'clinical_variable',
#    'value': 'Veterans Health Administration VHA /Department of Defense DoD criteria'},
#   {'label': 'clinical_variable',
#    'value': 'persisting symptoms',
#    'lower_bound': '> 3 months post injury'}],
#  [{'label': 'clinical_variable', 'value': 'optimally medicated'},
#   {'label': 'clinical_variable',
#    'value': 'change in mediction type or dosage',
#    'lower_bound': '3 months prior to enrolling in the study'},
#   {'label': 'clinical_variable',
#    'value': 'medications',
#    'lower_bound': 'not causing significant or serious advese effects'}],
#  [{'label': 'gender', 'value': 'women'},
#   {'label': 'pregnancy', 'value': 'breast feeding'}],
#  [{'label': 'clinical_variable',
#    'value': 'uncontrolled coagulation blood disorders like haemophilia'},
#   {'label': 'Cancer', 'value': 'malignant tumors'},
#   {'label': 'clinical_variable', 'value': 'fear of needles'}],
#  [{'label': 'chronic_disease', 'value': 'recurrent seizures'}],
#  [{'label': 'Cancer', 'value': 'malignancies'}],
#  [{'label': 'clinical_variable', 'value': '> 25% decrease'},
#   {'label': 'clinical_variable', 'value': 'depressive symptoms'},
#   {'label': 'clinical_variable', 'value': 'QIDS-SR score'},
#   {'label': 'clinical_variable', 'value': 'Screening'},
#   {'label': 'clinical_variable', 'value': 'Randomization'}],
#  [{'label': 'clinical_variable', 'value': 'Severe hypersensitivity'},
#   {'label': 'clinical_variable', 'value': 'Grade 3'},
#   {'label': 'treatment', 'value': 'pembrolizumab'},
#   {'label': 'clinical_variable', 'value': 'excipients'}],
#  [{'label': 'clinical_variable', 'value': 'Available for follow-up'},
#   {'label': 'clinical_variable', 'value': '12 months'}],
#  [{'label': 'clinical_variable', 'value': 'Invasive infection'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'age', 'value': '40-80'},
#   {'label': 'clinical_variable', 'value': 'good health'}],
#  [{'label': 'clinical_variable', 'value': 'Reversible causes'},
#   {'label': 'clinical_variable', 'value': 'atrial arrhythmia'},
#   {'label': 'clinical_variable', 'value': 'hyperthyroidism'},
#   {'label': 'clinical_variable', 'value': 'sarcoidosis'},
#   {'label': 'clinical_variable', 'value': 'pulmonary embolism'}],
#  [{'label': 'treatment', 'value': 'prostanoid'},
#   {'label': 'clinical_variable', 'value': 'portopulmonary hypertension'}],
#  [{'label': 'chronic_disease', 'value': 'diabetes'}],
#  [{'label': 'clinical_variable', 'value': 'Score'},
#   {'label': 'clinical_variable', 'value': 'screening ISR Erythema Index'},
#   {'label': 'upper_bound', 'value': '50'}],
#  [{'label': 'clinical_variable', 'value': 'Atrial fibrillation'},
#   {'label': 'clinical_variable', 'value': 'rapid ventricular response'}],
#  [{'label': 'clinical_variable', 'value': 'Pre-existing stable medication'},
#   {'label': 'clinical_variable', 'value': 'tic'},
#   {'label': 'clinical_variable', 'value': 'family agrees'},
#   {'label': 'clinical_variable', 'value': 'med changes'},
#   {'label': 'clinical_variable', 'value': 'acute phase of the study'}],
#  [{'label': 'chronic_disease', 'value': 'active autoimmune disease'},
#   {'label': 'upper_bound', 'value': 'past 2 years'}],
#  [{'label': 'clinical_variable', 'value': 'Bone lesions'},
#   {'label': 'clinical_variable', 'value': 'osteolytic lesions'},
#   {'label': 'clinical_variable',
#    'value': 'skeletal radiography computerized tomography CT'},
#   {'label': 'clinical_variable',
#    'value': '2-deoxy-2 F-18 fluoro-D-glucose positron emission tomography CT PET-CT'}],
#  [{'label': 'chronic_disease', 'value': 'pulmonary embolus'}],
#  [{'label': 'chronic_disease',
#    'value': 'New York Heart Association congestive heart failure'},
#   {'label': 'clinical_variable', 'value': 'class 3 or higher'}],
#  [{'label': 'age', 'value': '18'}],
#  [{'label': 'chronic_disease', 'value': 'bariatric surgery'}],
#  [{'label': 'clinical_variable', 'value': 'Castrate testosterone levels'},
#   {'label': 'lower_bound', 'value': '50 ng/dL'}],
#  [{'label': 'chronic_disease', 'value': 'solid organ transplant'},
#   {'label': 'chronic_disease', 'value': 'bone marrow transplant'}],
#  [{'label': 'clinical_variable', 'value': 'asthma'},
#   {'label': 'clinical_variable', 'value': 'bronchiectasis'},
#   {'label': 'clinical_variable', 'value': 'cystic fibrosis'},
#   {'label': 'clinical_variable',
#    'value': 'severe alpha-1 antitrypsin deficiency'}],
#  [{'label': 'clinical_variable', 'value': 'esophageal spasm'}],
#  [{'label': 'clinical_variable', 'value': 'bone marrow biopsy'},
#   {'label': 'clinical_variable', 'value': 'baseline fibrosis score'},
#   {'label': 'clinical_variable', 'value': 'consent'},
#   {'label': 'clinical_variable', 'value': 'tissue collection'},
#   {'label': 'clinical_variable', 'value': 'protocol mandated testing'},
#   {'label': 'upper_bound', 'value': 'four weeks'}],
#  [{'label': 'clinical_variable', 'value': 'neurodegenerative diseases'},
#   {'label': 'clinical_variable', 'value': 'MS'}],
#  [{'label': 'clinical_variable', 'value': 'Coronary Artery Calcium scanning'},
#   {'label': 'upper_bound', 'value': '6 months'},
#   {'label': 'gender', 'value': 'gender'},
#   {'label': 'clinical_variable', 'value': 'CAC score'}],
#  [{'label': 'clinical_variable', 'value': 'CKD stage 5'},
# ...
#   {'label': 'clinical_variable', 'value': 'active'}],
#  [{'label': 'treatment', 'value': 'support person'},
#   {'label': 'clinical_variable', 'value': 'Spouse'},
#   {'label': 'clinical_variable', 'value': 'partner'},
#   {'label': 'clinical_variable', 'value': 'mother'}],
#  [{'label': 'Cancer', 'value': 'esophageal cancer'},
#   {'label': 'Cancer', 'value': 'gastric cancer'},
#   {'label': 'lower_bound', 'value': '15'},
#   {'label': 'upper_bound', 'value': '30'}],
#  [{'label': 'clinical_variable', 'value': 'severe adverse reaction'},
#   {'label': 'treatment', 'value': 'study medications'}],
#  [{'label': 'age', 'value': '18-69 years'}],
#  [{'label': 'treatment',
#    'value': 'red blood cell and/or platelet transfusions'}],
#  [{'label': 'treatment', 'value': 'Immunotherapy'},
#   {'label': 'treatment', 'value': 'Interferons'},
#   {'label': 'treatment', 'value': 'Cytokines'},
#   {'label': 'treatment', 'value': 'PD-1/PD-L1 antagonists'}],
#  [{'label': 'clinical_variable', 'value': 'Elevated serum PSA'},
#   {'label': 'clinical_variable', 'value': 'prostate specific antigen'},
#   {'label': 'lower_bound', 'value': '> 4 ng/ml'},
#   {'label': 'clinical_variable', 'value': 'abnormal digital rectal exam'}],
#  [{'label': 'technology_access', 'value': 'smart phone'},
#   {'label': 'technology_access', 'value': 'device'},
#   {'label': 'treatment', 'value': 'app usage'}],
#  [{'label': 'Cancer', 'value': 'Relapsed or primary refractory metastatic'}],
#  [{'label': 'clinical_variable', 'value': 'Head trauma'},
#   {'label': 'clinical_variable', 'value': 'central nervous system injury'}],
#  [{'label': 'clinical_variable', 'value': 'serious suicide'},
#   {'label': 'clinical_variable', 'value': 'homicide risk'}],
#  [{'label': 'clinical_variable', 'value': 'acute decompensated HF'}],
#  [{'label': 'clinical_variable', 'value': 'diabetic retinopathy'}],
#  [{'label': 'chronic_disease', 'value': 'liver cirrhosis'},
#   {'label': 'clinical_variable', 'value': 'severity'},
#   {'label': 'treatment', 'value': 'cyclosporine'},
#   {'label': 'treatment', 'value': 'eltrombopag'},
#   {'label': 'clinical_variable', 'value': 'albumin'},
#   {'label': 'lower_bound', 'value': '< 35g/L'}],
#  [{'label': 'clinical_variable', 'value': 'platelets'},
#   {'label': 'lower_bound', 'value': '< 100,000/ L'}],
#  [{'label': 'clinical_variable', 'value': 'primary anxiety disorder'},
#   {'label': 'clinical_variable', 'value': 'primary eating disorders'},
#   {'label': 'clinical_variable', 'value': 'functional impairment'}],
#  [{'label': 'clinical_variable', 'value': 'stabilizing implants'},
#   {'label': 'clinical_variable', 'value': 'bone'},
#   {'label': 'clinical_variable', 'value': 'cyst'}],
#  [{'label': 'clinical_variable', 'value': 'HIV'},
#   {'label': 'clinical_variable', 'value': 'HIV antibody test'},
#   {'label': 'clinical_variable', 'value': 'confirmatory tests'},
#   {'label': 'clinical_variable', 'value': 'screening'},
#   {'label': 'lower_bound', 'value': 'within 12 months before screening'},
#   {'label': 'lower_bound', 'value': 'at screening'}],
#  [{'label': 'clinical_variable', 'value': 'Breath alcohol level'},
#   {'label': 'upper_bound', 'value': '0.01'}],
#  [{'label': 'clinical_variable', 'value': 'Total bilirubin'},
#   {'label': 'upper_bound', 'value': '1.5 x ULN'}],
#  [{'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'clinical_variable', 'value': 'AST'},
#   {'label': 'upper_bound', 'value': '2.5 X upper limit of normal ULN'}],
#  [{'label': 'clinical_variable',
#    'value': 'uncontrolled bacterial fungal or viral infection'},
#   {'label': 'clinical_variable', 'value': 'progressive symptoms'},
#   {'label': 'clinical_variable', 'value': 'therapy'},
#   {'label': 'clinical_variable', 'value': 'CD8+ memory T-cell infusion'}],
#  [{'label': 'contraception_consent', 'value': 'birth control'}],
#  [{'label': 'Cancer', 'value': 'ovarian cancer'}],
#  [{'label': 'language_fluency', 'value': 'English'}],
#  [{'label': 'treatment', 'value': 'whole-lung or hemi-thorax irradiation'},
#   {'label': 'clinical_variable', 'value': '12 Gy'},
#   {'label': 'clinical_variable', 'value': '6 months'}],
#  [{'label': 'chronic_disease', 'value': 'deep vein thrombosis'},
#   {'label': 'chronic_disease', 'value': 'pulmonary embolus'}],
#  [{'label': 'pregnancy', 'value': 'lactating females'}],
#  [{'label': 'clinical_variable',
#    'value': 'Eastern Cooperative Oncology Group ECOG Performance Status'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '2'}],
#  [{'label': 'Cancer', 'value': 'acute lymphoblastic leukemia lymphoma'}],
#  [{'label': 'treatment', 'value': 'ketotifen'},
#   {'label': 'previous', 'value': 'previous'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'},
#   {'label': 'pregnancy', 'value': 'breast-feeding'},
#   {'label': 'gender', 'value': 'females'},
#   {'label': 'exclusion', 'value': 'excluded'},
#   {'label': 'clinical_variable', 'value': 'mutagenic effects'},
#   {'label': 'clinical_variable', 'value': 'developing fetus'},
#   {'label': 'clinical_variable', 'value': 'newborn'}],
#  [{'label': 'Cancer', 'value': 'Infiltrating ductal carcinoma'},
#   {'label': 'Cancer', 'value': 'DCIS'},
#   {'label': 'clinical_variable', 'value': 'stage'},
#   {'label': 'clinical_variable', 'value': 'T0'},
#   {'label': 'clinical_variable', 'value': 'T1'},
#   {'label': 'clinical_variable', 'value': 'T2'},
#   {'label': 'upper_bound', 'value': '3.0 cm'},
#   {'label': 'clinical_variable', 'value': 'N0'},
#   {'label': 'clinical_variable', 'value': 'M0'}],
#  [{'label': 'Cancer', 'value': 'non-melanomatous skin cancer'},
#   {'label': 'Cancer', 'value': 'lentigo maligna'}],
#  [{'label': 'chronic_disease',
#    'value': 'Insulin dependent diabetes mellitus'}],
#  [{'label': 'clinical_variable', 'value': 'total bilirubin'},
#   {'label': 'upper_bound',
#    'value': '2.5 X institutional upper limit of normal'}],
#  [{'label': 'treatment', 'value': 'IV tPA'},
#   {'label': 'upper_bound', 'value': '> 3 hours from stroke onset'}],
#  [{'label': 'clinical_variable',
#    'value': 'Hamilton Depression Rating Scale-24 HRSD-24 score'},
#   {'label': 'lower_bound', 'value': '8'},
#   {'label': 'upper_bound', 'value': '24'}],
#  [{'label': 'treatment', 'value': 'Surgery intent'},
#   {'label': 'upper_bound', 'value': '4 weeks'}],
#  [{'label': 'gender', 'value': 'female'},
#   {'label': 'contraception_consent', 'value': 'childbearing potential'},
#   {'label': 'clinical_variable', 'value': 'sexually mature woman'},
#   {'label': 'clinical_variable', 'value': 'hysterectomy'},
#   {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'},
#   {'label': 'clinical_variable', 'value': 'naturally postmenopausal'},
#   {'label': 'lower_bound', 'value': '24 consecutive months'},
#   {'label': 'clinical_variable', 'value': 'menses'},
#   {'label': 'lower_bound', 'value': 'preceding 24 consecutive months'}],
#  [{'label': 'chronic_disease', 'value': 'active acute infections'},
#   {'label': 'chronic_disease', 'value': 'chronic infections'},
#   {'label': 'chronic_disease', 'value': 'uncontrolled severe infections'}],
#  [{'label': 'clinical_variable', 'value': 'diagnosis'},
#   {'label': 'clinical_variable', 'value': 'PAH isolated left heart disease'},
#   {'label': 'clinical_variable',
#    'value': 'lung disease chronic obstructive pulmonary disease'},
#   {'label': 'clinical_variable', 'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable', 'value': 'CTEPH'},
#   {'label': 'clinical_variable', 'value': 'established clinical criteria'}],
#  [{'label': 'treatment', 'value': 'initiate treatment'},
#   {'label': 'treatment', 'value': 'doxorubicin'},
#   {'label': 'clinical_variable', 'value': 'starting dose'},
#   {'label': 'clinical_variable', 'value': '75 mg/m2'},
#   {'label': 'clinical_variable', 'value': 'routine care'}],
#  [{'label': 'chronic_disease', 'value': 'psychiatric disorder'},
#   {'label': 'chronic_disease', 'value': 'substance abuse disorder'}],
#  [{'label': 'clinical_variable', 'value': 'catheter-associated UTI'}],
#  [{'label': 'clinical_variable',
#    'value': 'malignancy-associated microcalcifications'},
#   {'label': 'clinical_variable', 'value': 'post-excision mammography'}],
#  [{'label': 'clinical_variable', 'value': 'lung involvement'},
#   {'label': 'clinical_variable', 'value': 'organ involvement'},
#   {'label': 'clinical_variable', 'value': 'renal angiomyolipomas'},
#   {'label': 'clinical_variable', 'value': 'chylous effusions'},
#   {'label': 'clinical_variable', 'value': 'lymphangioleiomyomas'}],
#  [{'label': 'chronic_disease', 'value': 'epilepsy'},
#   {'label': 'clinical_variable', 'value': 'seizures'}],
#  [{'label': 'treatment', 'value': 'amifostine'},
#   {'label': 'treatment', 'value': 'abdominal radiotherapy'},
#   {'label': 'treatment', 'value': 'quinolone antibiotic therapy'}],
#  [{'label': 'clinical_variable', 'value': 'ambulate'},
#   {'label': 'clinical_variable', 'value': 'household distances'},
#   {'label': 'lower_bound', 'value': '50ft'}],
#  [{'label': 'age', 'value': '18'}, {'label': 'lower_bound', 'value': '18'}],
#  [{'label': 'gender', 'value': 'Male'}],
#  [{'label': 'Cancer', 'value': 'CNS metastases'},
#   {'label': 'clinical_variable', 'value': 'active CNS metastases'}],
#  [{'label': 'clinical_variable', 'value': 'MAS'},
#   {'label': 'clinical_variable', 'value': '98-D-0145'}],
#  [{'label': 'treatment', 'value': 'standard neoadjuvant chemotherapy'},
#   {'label': 'clinical_variable', 'value': 'anthracycline'},
#   {'label': 'clinical_variable', 'value': 'taxane-based regimen'},
#   {'label': 'lower_bound', 'value': '8 weeks'}],
#  [{'label': 'clinical_variable', 'value': 'bone marrow metastases'},
#   {'label': 'clinical_variable', 'value': 'high urine catecholamine levels'}],
#  [{'label': 'chronic_disease', 'value': 'Osteoporosis'},
#   {'label': 'clinical_variable', 'value': 'recent fracture'},
#   {'label': 'clinical_variable', 'value': 'hip'},
#   {'label': 'clinical_variable', 'value': 'spinal joints'}],
#  [{'label': 'clinical_variable', 'value': 'unilateral inguinal herna'},
#   {'label': 'clinical_variable', 'value': 'bilateral inguinal herna'},
#   {'label': 'treatment', 'value': 'laparoscopic repair'}],
#  [{'label': 'treatment', 'value': 'Corticosteroid injection'},
#   {'label': 'clinical_variable', 'value': 'treatment site'},
#   {'label': 'lower_bound', 'value': 'within 1 month'}],
#  [{'label': 'clinical_variable', 'value': 'ECOG Performance Status'},
#   {'label': 'lower_bound', 'value': '0'},
#   {'label': 'upper_bound', 'value': '1'}],
#  [{'label': 'allergy_name', 'value': 'dextromethorphan'},
#   {'label': 'allergy_name', 'value': 'vitamin A'},
#   {'label': 'allergy_name', 'value': 'isotretinoin'}],
#  [{'label': 'treatment', 'value': 'investigational drug or device study'},
#   {'label': 'lower_bound', 'value': 'within the past 6 weeks'}],
#  [{'label': 'allergy_name', 'value': 'conductive hydrogels'}],
#  [{'label': 'chronic_disease', 'value': 'severe cognitive impairment'}],
#  [{'label': 'clinical_variable', 'value': 'Current smoking'},
#   {'label': 'clinical_variable', 'value': 'history of smoking'},
#   {'label': 'clinical_variable', 'value': 'past 12 months'}],
#  [{'label': 'age', 'value': '18 year olds'}],
#  [{'label': 'chronic_disease',
#    'value': 'history of prior pelvic irradiation'}],
#  [{'label': 'clinical_variable',
#    'value': 'lifetime history of suicide attempt'},
#   {'label': 'clinical_variable', 'value': 'active attempt'},
#   {'label': 'clinical_variable', 'value': 'interrupted attempt'},
#   {'label': 'clinical_variable', 'value': 'aborted attempt'},
#   {'label': 'clinical_variable', 'value': 'suicidal ideation'},
#   {'label': 'clinical_variable', 'value': 'past 6 months'},
#   {'label': 'clinical_variable', 'value': "positive response 'Yes'"},
#   {'label': 'clinical_variable', 'value': 'Question 4'},
#   {'label': 'clinical_variable', 'value': 'Question 5'},
#   {'label': 'clinical_variable', 'value': 'C-SSRS'},
#   {'label': 'clinical_variable', 'value': 'Screening'}],
#  [{'label': 'clinical_variable', 'value': 'AST'},
#   {'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'upper_bound', 'value': '2 times upper limit of normal ULN'}],
#  [{'label': 'clinical_variable',
#    'value': 'Human papillomavirus HPV 16-positive disease'},
#   {'label': 'clinical_variable', 'value': 'PCR'}],
#  [{'label': 'treatment', 'value': 'LY2606368'},
#   {'label': 'treatment', 'value': 'Chk inhibitors'}],
#  [{'label': 'clinical_variable', 'value': 'cannabis use'},
#   {'label': 'clinical_variable', 'value': 'urine'},
#   {'label': 'clinical_variable', 'value': 'screening visit'},
#   {'label': 'clinical_variable',
#    'value': 'Gas Chromatography GC Mass Spectrometry MS laboratory test'},
#   {'label': 'clinical_variable', 'value': 'clinic admission'}],
#  [{'label': 'chronic_disease', 'value': 'schizophrenia'}],
#  [{'label': 'gender', 'value': 'women of childbearing potential'}],
#  [{'label': 'treatment', 'value': 'gonadal steroid preparations'},
#   {'label': 'lower_bound', 'value': '1 month'}],
#  [{'label': 'pregnancy', 'value': 'Pregnant'}],
#  [{'label': 'clinical_variable', 'value': 'Absolute neutrophil count'},
#   {'label': 'lower_bound', 'value': '1,500/mcL'}],
#  [{'label': 'allergy_name', 'value': 'Everolimus'},
#   {'label': 'allergy_name', 'value': 'rapamycins'},
#   {'label': 'allergy_name', 'value': 'sirolimus'},
#   {'label': 'allergy_name', 'value': 'temsirolimus'}],
#  [{'label': 'chronic_disease', 'value': 'cardiac/cardiovascular disease'},
#   {'label': 'clinical_variable', 'value': 'pulmonary compromise'}],
#  [{'label': 'chronic_disease', 'value': 'radiculopathy'}],
#  [{'label': 'age', 'value': '18 years'},
#   {'label': 'lower_bound', 'value': 'older'}],
#  [{'label': 'chronic_disease', 'value': 'Gastrointestinal Bleed'}],
#  [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable', 'value': 'active infectious hepatitis'},
#   {'label': 'clinical_variable', 'value': 'type A'},
#   {'label': 'clinical_variable', 'value': 'type B'},
#   {'label': 'clinical_variable', 'value': 'type C'}],
#  [{'label': 'gender', 'value': 'Women'},
#   {'label': 'clinical_variable', 'value': 'serious psychiatric symptoms'},
#   {'label': 'clinical_variable', 'value': 'CNO trained staff'}],
#  [{'label': 'clinical_variable', 'value': 'disease relapse'},
#   {'label': 'clinical_variable', 'value': 'active GVHD'},
#   {'label': 'clinical_variable',
#    'value': 'history of more than Stage 1 skin acute GVHD'},
#   {'label': 'clinical_variable', 'value': 'history of cGVHD'}],
#  [{'label': 'chronic_disease', 'value': 'thyroid disease'}],
#  [{'label': 'clinical_variable', 'value': 'Immunocompromised patients'},
#   {'label': 'clinical_variable',
#    'value': 'serologically positive for human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable', 'value': 'receiving antiviral therapy'}],
#  [{'label': 'clinical_variable',
#    'value': 'positive Hepatitis B surface antigen'},
#   {'label': 'clinical_variable', 'value': 'antihepatitis B core antibody'}],
#  [{'label': 'gender', 'value': 'Men'},
#   {'label': 'contraception_consent', 'value': 'adequate contraception'},
#   {'label': 'clinical_variable', 'value': 'duration of study participation'},
#   {'label': 'clinical_variable', 'value': '3 months'}],
#  [{'label': 'clinical_variable', 'value': 'Serum creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 x ULN'}],
#  [{'label': 'chronic_disease', 'value': 'seizure disorder'}],
#  [{'label': 'treatment', 'value': 'investigational agents'},
#   {'label': 'clinical_variable', 'value': '4 weeks prior to enrollment'},
#   {'label': 'treatment', 'value': 'radiation therapy'}],
#  [{'label': 'clinical_variable', 'value': 'ALT'},
#   {'label': 'clinical_variable', 'value': 'BUN'},
#   {'label': 'upper_bound', 'value': '2.0 ULN'},
#   {'label': 'clinical_variable', 'value': 'estimated creatinine'},
#   {'label': 'upper_bound', 'value': '1.5 X ULN'},
#   {'label': 'clinical_variable', 'value': 'age'},
#   {'label': 'clinical_variable', 'value': 'laboratory abnormality'},
#   {'label': 'clinical_variable', 'value': 'Investigator'},
#   {'label': 'clinical_variable', 'value': 'clinically significant'},
#   {'label': 'clinical_variable', 'value': '14 days before Screening'}]]

# %%
gpt_res_with_indexes = []
for entity, sentence in zip(final_result_gpt, sentences_to_predict):
    if entity is not "None":
        print(entity)
        gpt_res_with_indexes.append(find_entities_in_sentence(entity, sentence))
# Out:
# [{'label': 'treatment', 'value': 'oral administration'}, {'label': 'treatment', 'value': 'study drug'}]
# [{'label': 'pregnancy', 'value': 'Current pregnancy'}]
# [{'label': 'pregnancy', 'value': 'Singleton pregnancy'}]
# [{'label': 'clinical_variable', 'value': 'steroids'}, {'label': 'clinical_variable', 'value': 'surgery'}, {'label': 'clinical_variable', 'value': 'recovery period'}, {'label': 'clinical_variable', 'value': 'betamethasone hypersensitivity'}]
# [{'label': 'clinical_variable', 'value': 'rheumatic valve disease'}, {'label': 'clinical_variable', 'value': 'AF phenotype'}]
# [{'label': 'chronic_disease', 'value': 'Severe liver dysfunction'}, {'label': 'clinical_variable', 'value': 'LFT'}, {'label': 'upper_bound', 'value': '3X upper limit of normal'}]
# [{'label': 'clinical_variable', 'value': 'Serum M-protein'}, {'label': 'lower_bound', 'value': '1.0 g/dL'}]
# [{'label': 'gender', 'value': 'Males or females'}]
# [{'label': 'Cancer', 'value': 'Negative for malignancy'}, {'label': 'clinical_variable', 'value': 'past 5 years'}]
# [{'label': 'technology_access', 'value': 'available for up to 6 hrs every day'}, {'label': 'clinical_variable', 'value': 'two 2-week test periods'}, {'label': 'clinical_variable', 'value': 'intervening break of 7- 10 days each'}]
# [{'label': 'Cancer', 'value': 'recurrent and/or metastatic thyroid cancer'}]
# [{'label': 'treatment', 'value': 'paclitaxel'}]
# [{'label': 'clinical_variable', 'value': 'Mean arterial pressure'}, {'label': 'lower_bound', 'value': '65'}]
# [{'label': 'clinical_variable', 'value': 'White blood cells WBC'}, {'label': 'upper_bound', 'value': '15,000 cells/mcL'}]
# [{'label': 'chronic_disease', 'value': 'Acute medical illness'}]
# [{'label': 'treatment', 'value': 'chemotherapy'}, {'label': 'clinical_variable', 'value': 'prior'}]
# [{'label': 'chronic_disease', 'value': 'thromboembolism'}, {'label': 'clinical_variable', 'value': 'thrombophilia'}]
# [{'label': 'clinical_variable', 'value': 'stationary position'}, {'label': 'treatment', 'value': 'HIFU'}]
# [{'label': 'chronic_disease', 'value': 'hepatitis B'}, {'label': 'clinical_variable', 'value': 'hepatitis B survace antigen HBsAg reactive'}, {'label': 'clinical_variable', 'value': 'hepatitis C'}, {'label': 'clinical_variable', 'value': 'HCV RNA qualitative is detected infection'}]
# [{'label': 'chronic_disease', 'value': 'interstitial lung disease'}, {'label': 'clinical_variable', 'value': 'severely impaired lung function'}]
# [{'label': 'chronic_disease', 'value': 'Diabetes Mellitus'}]
# [{'label': 'chronic_disease', 'value': 'Seizure disorder requiring medication'}]
# [{'label': 'bmi', 'value': 'BMI'}, {'label': 'lower_bound', 'value': '25 kg/m^2'}]
# [{'label': 'clinical_variable', 'value': 'Life expectancy'}, {'label': 'lower_bound', 'value': '12 weeks'}]
# [{'label': 'clinical_variable', 'value': 'History/physical examination'}, {'label': 'clinical_variable', 'value': 'digital rectal examination'}, {'label': 'clinical_variable', 'value': 'prostate examination'}, {'label': 'clinical_variable', 'value': 'skeletal system examination'}, {'label': 'clinical_variable', 'value': 'abdomen examination'}, {'label': 'lower_bound', 'value': '90 days prior to registration'}]
# [{'label': 'Cancer', 'value': 'secondary primary lung cancer'}, {'label': 'chronic_disease', 'value': 'lung cancer'}, {'label': 'upper_bound', 'value': '2 year prior to registration'}]
# [{'label': 'clinical_variable', 'value': 'serum human chorionic gonadotropin hCG'}, {'label': 'pregnancy', 'value': 'positive'}]
# [{'label': 'clinical_variable', 'value': 'Total bilirubin'}, {'label': 'upper_bound', 'value': '=< 1.5 x institutional upper limit of normal ULN'}, {'label': 'upper_bound', 'value': "=< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation"}, {'label': 'upper_bound', 'value': '3.0 mg/dL within 2 weeks prior to enrollment'}]
# [{'label': 'clinical_variable', 'value': 'Other neurological diagnosis'}]
# [{'label': 'clinical_variable', 'value': 'Major neurological disorder'}]
# [{'label': 'treatment', 'value': 'Anti-tumor necrosis factor agents'}]
# [{'label': 'chronic_disease', 'value': 'Clinically significant heart disease'}, {'label': 'clinical_variable', 'value': 'myocardial infarction'}, {'label': 'clinical_variable', 'value': 'arterial thrombotic events'}, {'label': 'clinical_variable', 'value': 'severe or unstable angina'}, {'label': 'clinical_variable', 'value': 'New York Heart Association NYHA class II- IV heart disease'}]
# [{'label': 'clinical_variable', 'value': 'normal sinus rhythm'}, {'label': 'clinical_variable', 'value': 'ECG documented'}, {'label': 'clinical_variable', 'value': 'within the two weeks prior to the screening Holter'}]
# [{'label': 'gender', 'value': 'Women'}, {'label': 'clinical_variable', 'value': 'childbearing potential'}, {'label': 'clinical_variable', 'value': 'negative pregnancy test'}]
# [{'label': 'clinical_variable', 'value': 'Hematologic abnormalities'}, {'label': 'clinical_variable', 'value': 'pancytopenia'}, {'label': 'clinical_variable', 'value': 'aplastic anemia'}]
# [{'label': 'language_fluency', 'value': 'Poor English comprehension'}]
# [{'label': 'clinical_variable', 'value': 'multiple myeloma'}, {'label': 'clinical_variable', 'value': 'International Myeloma Working Group IMWG diagnostic criteria'}]
# [{'label': 'chronic_disease', 'value': 'hypercontractile bladder'}, {'label': 'chronic_disease', 'value': 'non-compliant bladder'}, {'label': 'chronic_disease', 'value': 'hydronephrosis'}, {'label': 'chronic_disease', 'value': 'neurogenic bladder'}]
# [{'label': 'age', 'value': '40'}, {'label': 'age', 'value': '59'}, {'label': 'clinical_variable', 'value': '15% TBSA'}]
# [{'label': 'age', 'value': '2'}, {'label': 'lower_bound', 'value': 'at least'}]
# [{'label': 'age', 'value': '1 year'}, {'label': 'upper_bound', 'value': '18 years'}]
# [{'label': 'treatment', 'value': 'Therapeutic antibodies'}, {'label': 'treatment', 'value': 'bevacizumab'}]
# [{'label': 'clinical_variable', 'value': 'postmenopausal status'}, {'label': 'clinical_variable', 'value': 'surgical/natural menopause'}, {'label': 'clinical_variable', 'value': 'ovarian suppression'}, {'label': 'clinical_variable', 'value': '28 days'}, {'label': 'clinical_variable', 'value': 'Day 1 of Cycle 1'}, {'label': 'clinical_variable', 'value': 'gonadotropin-releasing hormone'}, {'label': 'clinical_variable', 'value': 'goserelin'}]
# [{'label': 'Cancer', 'value': 'Pancreatic Cancer'}, {'label': 'clinical_variable', 'value': 'potentially surgically resectable'}]
# [{'label': 'clinical_variable', 'value': 'lower urinary tract symptoms'}, {'label': 'clinical_variable', 'value': 'LUTS'}, {'label': 'clinical_variable', 'value': '1 year'}]
# [{'label': 'treatment', 'value': 'pacemaker ICD'}]
# [{'label': 'treatment', 'value': 'spinal block'}, {'label': 'treatment', 'value': 'BBBD chemotherapy'}]
# [{'label': 'clinical_variable', 'value': 'linked to care/evaluation'}, {'label': 'upper_bound', 'value': '30 days'}]
# [{'label': 'clinical_variable', 'value': 'Dry weight'}, {'label': 'clinical_variable', 'value': 'height'}, {'label': 'upper_bound', 'value': '7 days'}]
# [{'label': 'treatment', 'value': 'antipsychotics'}]
# [{'label': 'gender', 'value': 'lactating women'}]
# [{'label': 'clinical_variable', 'value': 'SGPT ALT'}, {'label': 'upper_bound', 'value': '5 x ULN for age'}]
# [{'label': 'pregnancy', 'value': 'Pregnant'}]
# [{'label': 'chronic_disease', 'value': 'anaphylaxis'}, {'label': 'treatment', 'value': 'echinocandin'}]
# [{'label': 'pregnancy', 'value': 'possibly pregnant'}]
# [{'label': 'treatment', 'value': 'ipsilateral knee surgery'}, {'label': 'treatment', 'value': 'ligament reconstruction'}, {'label': 'treatment', 'value': 'osteotomy'}]
# [{'label': 'chronic_disease', 'value': 'congestive heart failure'}]
# [{'label': 'treatment', 'value': 'ongoing, tapering therapy'}, {'label': 'clinical_variable', 'value': 'resolved acute GVHD'}]
# [{'label': 'treatment', 'value': 'IV docetaxel'}, {'label': 'clinical_variable', 'value': '75 mg/m^2'}, {'label': 'clinical_variable', 'value': '5 mg/m^2'}, {'label': 'treatment', 'value': 'carboplatin'}, {'label': 'clinical_variable', 'value': 'AUC 5-6'}, {'label': 'clinical_variable', 'value': 'every 21 days'}]
# [{'label': 'contraception_consent', 'value': 'effective form of birth control'}]
# [{'label': 'chronic_disease', 'value': 'HIV-positive patients'}, {'label': 'treatment', 'value': 'combination antiretroviral therapy'}, {'label': 'clinical_variable', 'value': 'LY2606368'}]
# [{'label': 'clinical_variable', 'value': 'ECOG performance status'}, {'label': 'clinical_variable', 'value': 'Karnofsky'}, {'label': 'lower_bound', 'value': '2'}, {'label': 'upper_bound', 'value': '60%'}]
# [{'label': 'Cancer', 'value': 'Metastatic breast cancer'}, {'label': 'clinical_variable', 'value': 'triple negative'}, {'label': 'clinical_variable', 'value': 'ER'}, {'label': 'clinical_variable', 'value': 'CCND1c'}, {'label': 'clinical_variable', 'value': 'HER2'}, {'label': 'treatment', 'value': 'trastuzumab and PD0332991 therapy'}, {'label': 'upper_bound', 'value': '55'}]
# [{'label': 'age', 'value': '18'}, {'label': 'lower_bound', 'value': 'years old'}]
# [{'label': 'treatment', 'value': 'recurrent or refractory solid tumors'}, {'label': 'clinical_variable', 'value': 'central nervous system CNS tumors'}, {'label': 'clinical_variable', 'value': 'CNS metastases'}]
# [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'}, {'label': 'chronic_disease', 'value': 'acquired immunodeficiency syndrome AIDS'}]
# [{'label': 'treatment', 'value': 'planned surgery'}, {'label': 'treatment', 'value': 'general anesthesia'}, {'label': 'clinical_variable', 'value': 'pharmacotherapy period'}]
# [{'label': 'clinical_variable', 'value': 'Maximal diameter'}, {'label': 'clinical_variable', 'value': 'hepatocellular carcinoma'}, {'label': 'upper_bound', 'value': '15 cm'}]
# [{'label': 'gender', 'value': 'Females'}, {'label': 'clinical_variable', 'value': 'menopausal'}, {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'}]
# [{'label': 'gender', 'value': 'female'}]
# [{'label': 'clinical_variable', 'value': 'ADHD'}, {'label': 'clinical_variable', 'value': 'clinician administered CAADID'}, {'label': 'clinical_variable', 'value': 'clinical interview'}]
# [{'label': 'clinical_variable', 'value': 'active malignancy'}, {'label': 'upper_bound', 'value': '3 years prior to registration'}]
# [{'label': 'treatment', 'value': 'intensive induction chemotherapy'}, {'label': 'treatment', 'value': 'radiotherapy'}, {'label': 'treatment', 'value': 'biologic treatment'}, {'label': 'clinical_variable', 'value': 'active malignancy'}, {'label': 'treatment', 'value': 'maintenance chemotherapy'}, {'label': 'clinical_variable', 'value': 'study medical monitor'}]
# [{'label': 'treatment', 'value': 'CEM carboplatin'}, {'label': 'treatment', 'value': 'etoposide'}, {'label': 'treatment', 'value': 'melphalan therapy'}, {'label': 'lower_bound', 'value': '30 days prior to 131I-MIBG therapy'}, {'label': 'treatment', 'value': '131I-MIBG therapy'}, {'label': 'lower_bound', 'value': '30 days following administration of 131I-MIBG'}]
# [{'label': 'clinical_variable', 'value': 'HIV positive'}, {'label': 'clinical_variable', 'value': 'CD4 count'}, {'label': 'lower_bound', 'value': '350 cells/microliter'}]
# [{'label': 'clinical_variable', 'value': 'Preoperative evaluation'}, {'label': 'treatment', 'value': 'CT scan'}, {'label': 'treatment', 'value': 'MRI'}, {'label': 'treatment', 'value': 'ultrasound'}]
# [{'label': 'clinical_variable', 'value': 'claustrophobic'}]
# [{'label': 'chronic_disease', 'value': 'malignancy'}]
# [{'label': 'clinical_variable', 'value': 'drinking'}, {'label': 'clinical_variable', 'value': 'past 90 days'}, {'label': 'upper_bound', 'value': '80%'}]
# [{'label': 'language_fluency', 'value': 'English'}]
# [{'label': 'chronic_disease', 'value': 'cerebrovascular accident CVA'}, {'label': 'chronic_disease', 'value': 'transient ischemic attack TIA'}, {'label': 'upper_bound', 'value': '6 months'}]
# [{'label': 'treatment', 'value': 'platinum-containing chemotherapy'}, {'label': 'treatment', 'value': 'neoadjuvant or adjuvant treatment'}, {'label': 'treatment', 'value': 'platinum-containing chemotherapy'}, {'label': 'upper_bound', 'value': '1 2 months'}]
# [{'label': 'treatment', 'value': 'investigational drug'}, {'label': 'lower_bound', 'value': '4 weeks'}]
# [{'label': 'allergy_name', 'value': 'gadolinium Gd contrast material'}]
# [{'label': 'clinical_variable', 'value': 'Wheezing'}]
# [{'label': 'treatment', 'value': 'toxic effects'}, {'label': 'clinical_variable', 'value': 'prior therapy'}]
# [{'label': 'chronic_disease', 'value': 'uncontrolled inter-current illness'}, {'label': 'clinical_variable', 'value': 'ongoing or active infection'}, {'label': 'clinical_variable', 'value': 'symptomatic congestive heart failure'}, {'label': 'clinical_variable', 'value': 'NYHA Gr.2 or >'}, {'label': 'clinical_variable', 'value': 'myocardial infarction'}, {'label': 'clinical_variable', 'value': 'unstable angina pectoris'}, {'label': 'clinical_variable', 'value': 'past 12 months'}]
# [{'label': 'age', 'value': '18'}, {'label': 'lower_bound', 'value': '75 years'}]
# [{'label': 'Cancer', 'value': 'recurrent carcinoma of the vulva'}, {'label': 'treatment', 'value': 'previous treatment'}]
# [{'label': 'clinical_variable', 'value': 'PaO2/FiO2'}, {'label': 'lower_bound', 'value': '300'}]
# [{'label': 'clinical_variable', 'value': 'amyloid imaging disclosure'}]
# [{'label': 'age', 'value': '4 to 6 months'}]
# [{'label': 'chronic_disease', 'value': 'asthma'}]
# [{'label': 'chronic_disease', 'value': 'bleeding disorder'}]
# [{'label': 'age', 'value': '18 years or older'}]
# [{'label': 'treatment', 'value': 'second line hormonal therapy'}, {'label': 'treatment', 'value': 'bicalutamide'}, {'label': 'treatment', 'value': 'nilutamide'}, {'label': 'treatment', 'value': 'flutamide'}, {'label': 'treatment', 'value': 'ketoconazole'}, {'label': 'treatment', 'value': 'abiraterone'}, {'label': 'treatment', 'value': 'enzalutamide'}, {'label': 'treatment', 'value': 'ARN-509'}]
# [{'label': 'clinical_variable', 'value': 'endometrial cancer'}, {'label': 'treatment', 'value': 'routinely'}, {'label': 'treatment', 'value': 'newly diagnosed'}, {'label': 'treatment', 'value': 'centers'}, {'label': 'treatment', 'value': 'US'}]
# [{'label': 'clinical_variable', 'value': 'central nervous system lymphoma'}, {'label': 'clinical_variable', 'value': 'active'}]
# [{'label': 'chronic_disease', 'value': 'autoimmune diseases'}]
# [{'label': 'Cancer', 'value': 'acute myeloid leukemia AML'}, {'label': 'Cancer', 'value': 'acute lymphoblastic leukemia ALL'}, {'label': 'Cancer', 'value': 'chronic myelogenous leukemia CML'}, {'label': 'Cancer', 'value': 'chronic lymphocytic leukemia CLL'}, {'label': 'Cancer', 'value': 'non-Hodgkin lymphoma NHL'}, {'label': 'Cancer', 'value': 'Hodgkin lymphoma NHL'}, {'label': 'Cancer', 'value': 'Hodgkin lymphoma'}, {'label': 'Cancer', 'value': 'multiple myeloma MM'}, {'label': 'Cancer', 'value': 'myelodysplastic syndrome MDS'}, {'label': 'Cancer', 'value': 'AL amyloidosis'}, {'label': 'Cancer', 'value': 'diamond blackfan anemia'}, {'label': 'Cancer', 'value': 'myelofibrosis'}, {'label': 'Cancer', 'value': 'myeloproliferative disease'}, {'label': 'Cancer', 'value': 'sickle cell anemia'}, {'label': 'Cancer', 'value': 'thalassemia'}]
# [{'label': 'Cancer', 'value': 'HPV p16'}, {'label': 'Cancer', 'value': 'PD-L1'}]
# [{'label': 'clinical_variable', 'value': 'ECOG status'}, {'label': 'lower_bound', 'value': '3'}, {'label': 'upper_bound', 'value': '4'}]
# [{'label': 'chronic_disease', 'value': 'pre-existing medical psychiatric or other condition'}]
# [{'label': 'chronic_disease', 'value': 'medical conditions'}, {'label': 'chronic_disease', 'value': 'orthopedic injuries'}, {'label': 'chronic_disease', 'value': 'cardiovascular diseases'}, {'label': 'chronic_disease', 'value': 'liver diseases'}, {'label': 'chronic_disease', 'value': 'endocrine diseases'}, {'label': 'chronic_disease', 'value': 'pulmonary diseases'}]
# [{'label': 'Cancer', 'value': 'lung cancer'}]
# [{'label': 'chronic_disease', 'value': 'cord compression'}, {'label': 'chronic_disease', 'value': 'syrinx in the spinal cord'}, {'label': 'chronic_disease', 'value': 'spinal cord disease'}, {'label': 'chronic_disease', 'value': 'spinal stenosis'}, {'label': 'chronic_disease', 'value': 'spina bifida'}, {'label': 'chronic_disease', 'value': 'herniated cervical disk'}]
# [{'label': 'gender', 'value': 'nursing woman'}]
# [{'label': 'gender', 'value': 'pregnant women'}]
# [{'label': 'chronic_disease', 'value': 'myocardial infarction'}, {'label': 'lower_bound', 'value': '6 months before enrollment'}]
# [{'label': 'chronic_disease', 'value': 'Sickle cell anemia'}]
# [{'label': 'chronic_disease', 'value': 'Myelodysplastic syndrome'}]
# [{'label': 'treatment', 'value': 'corneal transplants'}, {'label': 'treatment', 'value': 'cadaver skin'}, {'label': 'treatment', 'value': 'bone transplants'}]
# [{'label': 'treatment', 'value': 'Lovaza prescription fish oil'}, {'label': 'treatment', 'value': 'Lovaza'}, {'label': 'clinical_variable', 'value': '3 weeks'}]
# [{'label': 'chronic_disease', 'value': 'cardiac condition'}, {'label': 'chronic_disease', 'value': 'asthma'}, {'label': 'chronic_disease', 'value': 'obstructive pulmonary disease'}, {'label': 'chronic_disease', 'value': 'seizure disorder'}, {'label': 'chronic_disease', 'value': 'urinary incontinence'}, {'label': 'chronic_disease', 'value': 'peptic ulcer disease'}, {'label': 'treatment', 'value': 'concurrent NSAIDs'}]
# [{'label': 'clinical_variable', 'value': 'Karnofsky performance status'}, {'label': 'lower_bound', 'value': '70%'}]
# [{'label': 'clinical_variable', 'value': 'Grade 4 - Fibrosis'}]
# [{'label': 'clinical_variable', 'value': 'Follicular 17-hydroxyprogesterone'}, {'label': 'upper_bound', 'value': '300 ng/dl'}, {'label': 'clinical_variable', 'value': 'congenital adrenal hyperplasia'}]
# [{'label': 'clinical_variable', 'value': 'Current oral steroid use'}, {'label': 'upper_bound', 'value': '4 weeks prior to registration'}]
# [{'label': 'pregnancy', 'value': 'Not pregnant'}]
# [{'label': 'chronic_disease', 'value': 'History of DVT or pulmonary embolism'}, {'label': 'upper_bound', 'value': '6 months'}]
# [{'label': 'chronic_disease', 'value': 'Hepatitis C'}, {'label': 'treatment', 'value': 'donor liver'}]
# [{'label': 'clinical_variable', 'value': 'Renal insufficiency'}, {'label': 'clinical_variable', 'value': 'creatinine'}, {'label': 'upper_bound', 'value': '1.5 mg/dL'}]
# [{'label': 'treatment', 'value': 'investigational agent'}, {'label': 'upper_bound', 'value': '30 days prior to pre-registration'}]
# [{'label': 'treatment', 'value': 'warfarin'}, {'label': 'clinical_variable', 'value': 'prophylaxis'}, {'label': 'clinical_variable', 'value': 'treatment of thrombosis'}, {'label': 'clinical_variable', 'value': 'INR values'}]
# [{'label': 'age', 'value': '18 years'}, {'label': 'lower_bound', 'value': '18'}]
# [{'label': 'chronic_disease', 'value': 'cerebral vascular event stroke'}, {'label': 'chronic_disease', 'value': 'transient ischemic attack'}, {'label': 'chronic_disease', 'value': 'unstable angina myocardial infarction'}, {'label': 'chronic_disease', 'value': 'cardiac symptoms'}, {'label': 'chronic_disease', 'value': 'congestive heart failure'}, {'label': 'clinical_variable', 'value': 'New York Heart Association Class'}, {'label': 'upper_bound', 'value': '6 months'}]
# [{'label': 'treatment', 'value': 'breast conserving surgery'}, {'label': 'treatment', 'value': 'lumpectomy'}, {'label': 'treatment', 'value': 'radiation'}]
# [{'label': 'age', 'value': 'age'}, {'label': 'lower_bound', 'value': '49'}]
# [{'label': 'treatment', 'value': 'medication'}, {'label': 'clinical_variable', 'value': 'potentially dangerous interaction'}, {'label': 'treatment', 'value': 'propranolol'}]
# [{'label': 'treatment', 'value': 'rIX-FP'}, {'label': 'clinical_variable', 'value': '100 EDs single-dose cohorts'}, {'label': 'clinical_variable', 'value': '50 EDs repeated-dose cohort'}]
# [{'label': 'clinical_variable', 'value': 'Bilirubin'}, {'label': 'upper_bound', 'value': '2 x the ULN'}]
# [{'label': 'chronic_disease', 'value': 'organ allograft'}, {'label': 'clinical_variable', 'value': 'corneal transplant'}]
# [{'label': 'treatment', 'value': 'Autologous stem cell transplantation SCT'}, {'label': 'clinical_variable', 'value': '100 days prior to study drug'}, {'label': 'treatment', 'value': 'allogeneic SCT'}, {'label': 'treatment', 'value': 'solid organ transplantation'}]
# [{'label': 'diagnosis', 'value': 'type 2 diabetes'}]
# [{'label': 'history', 'value': 'active malignancy'}, {'label': 'upper_bound', 'value': 'last 3 years'}]
# [{'label': 'clinical_variable', 'value': 'adverse events Grade'}, {'label': 'upper_bound', 'value': '> 1'}, {'label': 'treatment', 'value': 'prior therapies chemotherapy radiotherapy and/or surgery'}, {'label': 'clinical_variable', 'value': 'alopecia'}]
# [{'label': 'clinical_variable', 'value': 'Pre-bronchodilator 50% FEV1'}, {'label': 'lower_bound', 'value': '< 85 %'}, {'label': 'clinical_variable', 'value': 'predicted normal value'}, {'label': 'clinical_variable', 'value': 'patient'}, {'label': 'clinical_variable', 'value': 'withholding bronchodilators'}, {'label': 'clinical_variable', 'value': 'Visit 101'}, {'label': 'clinical_variable', 'value': 'Visit 102'}, {'label': 'clinical_variable', 'value': 'ATS/ERS criteria'}]
# [{'label': 'treatment', 'value': 'cetuximab'}, {'label': 'clinical_variable', 'value': 'incurable disease'}]
# [{'label': 'treatment', 'value': 'herbal alternative medicines'}]
# [{'label': 'age', 'value': '21 years'}]
# [{'label': 'treatment', 'value': 'intravesical chemotherapy'}]
# [{'label': 'clinical_variable', 'value': 'medication'}, {'label': 'clinical_variable', 'value': 'precautionary list'}, {'label': 'clinical_variable', 'value': 'nitroglycerin'}]
# [{'label': 'clinical_variable', 'value': 'Severe aortic regurgitation'}, {'label': 'lower_bound', 'value': '3'}]
# [{'label': 'clinical_variable', 'value': 'psychiatric or medical condition'}, {'label': 'treatment', 'value': 'interfere with treatment'}]
# [{'label': 'age', 'value': '17'}, {'label': 'lower_bound', 'value': '17'}]
# [{'label': 'Cancer', 'value': 'FL'}, {'label': 'clinical_variable', 'value': 'histopathologic confirmation'}]
# [{'label': 'age', 'value': '16 years of age or older'}, {'label': 'clinical_variable', 'value': 'weighs'}]
# [{'label': 'clinical_variable', 'value': 'Interval from start of initial radiation therapy to enrollment'}, {'label': 'lower_bound', 'value': '9 months'}]
# [{'label': 'chronic_disease', 'value': 'diabetes requiring medication'}]
# [{'label': 'contraception_consent', 'value': 'Not pregnant or nursing'}, {'label': 'contraception_consent', 'value': 'report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal'}]
# [{'label': 'pregnancy', 'value': 'Pregnant women'}]
# [{'label': 'chronic_disease', 'value': 'hepatitis B'}, {'label': 'chronic_disease', 'value': 'hepatitis C'}, {'label': 'clinical_variable', 'value': 'hepatitis B virus surface antigen HBsAg reactive'}, {'label': 'clinical_variable', 'value': 'hepatitis C virus HCV ribonucleic acid RNA qualitative is detected'}]
# [{'label': 'clinical_variable', 'value': 'pretreatment calculated creatinine clearance'}, {'label': 'lower_bound', 'value': '>= 50 mL/minute'}]
# [{'label': 'Cancer', 'value': 'Second primary malignancy'}, {'label': 'Cancer', 'value': 'in situ carcinoma of the cervix'}, {'label': 'Cancer', 'value': 'adequately treated non-melanomatous carcinoma of the skin'}, {'label': 'Cancer', 'value': 'other malignancy treated at least 5 years previously with no evidence of recurrence'}]
# [{'label': 'treatment', 'value': 'iodinated intravenous contrast'}, {'label': 'clinical_variable', 'value': 'radiographic procedure'}, {'label': 'upper_bound', 'value': 'within 3 months of study registration'}]
# [{'label': 'chronic_disease', 'value': 'cancer'}, {'label': 'chronic_disease', 'value': 'acute myocardial infarction'}]
# [{'label': 'clinical_variable', 'value': 'Aspartate aminotransferase AST'}, {'label': 'clinical_variable', 'value': 'alanine aminotransferase ALT'}, {'label': 'upper_bound', 'value': '3 x the institutional upper limit of normal'}]
# [{'label': 'clinical_variable', 'value': 'hepatitis B surface antigen'}]
# [{'label': 'age', 'value': 'age'}, {'label': 'lower_bound', 'value': '2'}, {'label': 'upper_bound', 'value': '40'}]
# [{'label': 'chronic_disease', 'value': 'Epilepsy partial seizure'}]
# [{'label': 'contraception_consent', 'value': 'effective > 90% reliability form of contraception'}, {'label': 'upper_bound', 'value': '90%'}, {'label': 'contraception_consent', 'value': 'for 4 weeks following the last study drug administration'}]
# [{'label': 'treatment', 'value': 'vascular access'}, {'label': 'treatment', 'value': 'study drug'}, {'label': 'treatment', 'value': 'blood sampling'}, {'label': 'treatment', 'value': 'study drug infusion'}]
# [{'label': 'chronic_disease', 'value': 'sleep apnea'}, {'label': 'clinical_variable', 'value': 'Untreated'}]
# [{'label': 'chronic_disease', 'value': 'secondary headache disorder'}, {'label': 'clinical_variable', 'value': 'brain tumor'}]
# [{'label': 'treatment', 'value': 'bilateral orchiectomy'}, {'label': 'treatment', 'value': 'Prior'}]
# [{'label': 'chronic_disease', 'value': 'drug or alcohol abuser'}, {'label': 'chronic_disease', 'value': 'psychological disorder'}]
# [{'label': 'clinical_variable', 'value': 'Serum total bilirubin'}, {'label': 'upper_bound', 'value': '1.5 times the upper limit of normal ULN'}]
# [{'label': 'chronic_disease', 'value': 'HIV-positive patients'}, {'label': 'treatment', 'value': 'highly active antiretroviral therapy HAART'}, {'label': 'clinical_variable', 'value': 'CD4 count'}, {'label': 'lower_bound', 'value': '200 cells/microliter'}, {'label': 'upper_bound', 'value': '30 days prior to registration'}]
# [{'label': 'clinical_variable', 'value': 'total bilirubin'}, {'label': 'upper_bound', 'value': 'upper normal institutional limits'}, {'label': 'chronic_disease', 'value': "Gilbert's disease"}, {'label': 'clinical_variable', 'value': 'elevated serum bilirubin level'}]
# [{'label': 'treatment', 'value': 'prior RAI therapy therapy'}, {'label': 'upper_bound', 'value': '6 months prior to initiation of therapy on this protocol'}]
# [{'label': 'pregnancy', 'value': 'wish to become pregnant'}, {'label': 'clinical_variable', 'value': 'study period'}]
# [{'label': 'pregnancy', 'value': 'lactating'}]
# [{'label': 'chronic_disease', 'value': 'Poorly controlled depression'}]
# [{'label': 'gender', 'value': 'Male'}, {'label': 'gender', 'value': 'females'}]
# [{'label': 'age', 'value': 'ages'}, {'label': 'lower_bound', 'value': '18'}, {'label': 'upper_bound', 'value': '70'}]
# [{'label': 'technology_access', 'value': 'venous access'}, {'label': 'clinical_variable', 'value': 'blood drawing'}, {'label': 'clinical_variable', 'value': '5 day infusions'}, {'label': 'clinical_variable', 'value': 'lymphapheresis'}]
# [{'label': 'clinical_variable', 'value': 'Eastern Cooperative Oncology Group ECOG performance status'}, {'label': 'clinical_variable', 'value': 'PS'}, {'label': 'lower_bound', 'value': '0'}, {'label': 'upper_bound', 'value': '1'}, {'label': 'clinical_variable', 'value': '2'}]
# [{'label': 'clinical_variable', 'value': 'Insomnia complaints'}, {'label': 'lower_bound', 'value': '6'}, {'label': 'clinical_variable', 'value': 'months'}]
# [{'label': 'clinical_variable', 'value': 'blood donation'}, {'label': 'clinical_variable', 'value': 'sperm donation'}, {'label': 'clinical_variable', 'value': 'semen donation'}, {'label': 'clinical_variable', 'value': 'study therapy'}, {'label': 'lower_bound', 'value': '28'}, {'label': 'clinical_variable', 'value': 'days'}]
# [{'label': 'clinical_variable', 'value': 'hysterectomy'}, {'label': 'clinical_variable', 'value': 'benign indication'}, {'label': 'clinical_variable', 'value': 'abnormal uterine bleeding'}, {'label': 'clinical_variable', 'value': 'menorrhagia'}, {'label': 'clinical_variable', 'value': 'uterine fibroids'}, {'label': 'clinical_variable', 'value': 'adenomyosis'}, {'label': 'clinical_variable', 'value': 'pelvic pain'}, {'label': 'clinical_variable', 'value': 'dysmenorrhea'}, {'label': 'clinical_variable', 'value': 'pelvic organ prolapse'}, {'label': 'clinical_variable', 'value': 'endometriosis'}]
# [{'label': 'chronic_disease', 'value': 'uncontrolled bacterial viral or fungal infection'}, {'label': 'treatment', 'value': 'currently taking medication'}, {'label': 'clinical_variable', 'value': 'progression or no clinical improvement'}, {'label': 'clinical_variable', 'value': 'time of enrollment'}]
# [{'label': 'gender', 'value': 'Women'}, {'label': 'pregnancy', 'value': 'childbearing potential'}, {'label': 'clinical_variable', 'value': 'negative pregnancy test'}]
# [{'label': 'treatment', 'value': 'biopsy'}, {'label': 'clinical_variable', 'value': 'site of disease'}, {'label': 'clinical_variable', 'value': 'lung/pleura'}, {'label': 'clinical_variable', 'value': 'bone'}, {'label': 'clinical_variable', 'value': 'unsafe'}, {'label': 'clinical_variable', 'value': 'principal investigator'}]
# [{'label': 'clinical_variable', 'value': 'distant metastases'}]
# [{'label': 'clinical_variable', 'value': 'Insulin requirement'}, {'label': 'clinical_variable', 'value': '> 1.0 U/kg/day'}, {'label': 'clinical_variable', 'value': '> 60 U/day total'}, {'label': 'clinical_variable', 'value': '< 15 U/day'}]
# [{'label': 'clinical_variable', 'value': 'Residual symptoms'}, {'label': 'clinical_variable', 'value': 'total score'}, {'label': 'clinical_variable', 'value': 'PANSS'}, {'label': 'clinical_variable', 'value': 'Visit 1 evaluations'}, {'label': 'lower_bound', 'value': '110'}, {'label': 'lower_bound', 'value': '60'}]
# [{'label': 'clinical_variable', 'value': 'probability'}, {'label': 'clinical_variable', 'value': 'BRCA mutation'}, {'label': 'clinical_variable', 'value': 'BRCAPRO'}, {'label': 'clinical_variable', 'value': 'similar model'}, {'label': 'lower_bound', 'value': '10%'}]
# [{'label': 'treatment', 'value': 'therapeutic radiation'}, {'label': 'clinical_variable', 'value': 'region'}, {'label': 'clinical_variable', 'value': 'study eye'}]
# [{'label': 'clinical_variable', 'value': 'Metallic implant'}]
# [{'label': 'allergy_name', 'value': 'Fluoxetine'}]
# [{'label': 'chronic_disease', 'value': 'Therapy-related MDS'}, {'label': 'clinical_variable', 'value': 'MDS'}, {'label': 'treatment', 'value': 'systemic chemotherapy'}, {'label': 'treatment', 'value': 'radiation'}, {'label': 'treatment', 'value': 'malignancy'}]
# [{'label': 'clinical_variable', 'value': 'weight change'}, {'label': 'clinical_variable', 'value': '+/- 25 pounds'}, {'label': 'clinical_variable', 'value': '1 year'}]
# [{'label': 'chronic_disease', 'value': 'Active varicella zoster infection'}]
# [{'label': 'clinical_variable', 'value': 'fluid resuscitation'}, {'label': 'clinical_variable', 'value': 'Clinical definition of kidney damage'}]
# [{'label': 'treatment', 'value': 'monoclonal antibody'}, {'label': 'clinical_variable', 'value': '4 weeks prior to study'}]
# [{'label': 'chronic_disease', 'value': 'carotid artery disease'}]
# [{'label': 'clinical_variable', 'value': 'Hypocitraturic CaP stone formers'}]
# [{'label': 'treatment', 'value': 'non-permitted inflammatory bowel disease IBD therapies'}, {'label': 'treatment', 'value': 'natalizumab'}, {'label': 'treatment', 'value': 'vedolizumab'}, {'label': 'treatment', 'value': 'efalizumab'}]
# [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'}, {'label': 'chronic_disease', 'value': 'infectious hepatitis type B'}, {'label': 'chronic_disease', 'value': 'infectious hepatitis type C'}]
# [{'label': 'clinical_variable', 'value': 'Measurable disease'}, {'label': 'clinical_variable', 'value': 'RECIST v1.1 criteria'}, {'label': 'clinical_variable', 'value': 'Baseline measurements'}, {'label': 'clinical_variable', 'value': 'ALL sites of disease'}, {'label': 'clinical_variable', 'value': '4 weeks prior to Enrollment'}]
# [{'label': 'clinical_variable', 'value': 'performance status'}, {'label': 'clinical_variable', 'value': 'ECOG Performance Scale'}, {'label': 'clinical_variable', 'value': 'life expectancy'}, {'label': 'lower_bound', 'value': '0'}, {'label': 'upper_bound', 'value': '2'}, {'label': 'upper_bound', 'value': '3 months'}]
# [{'label': 'clinical_variable', 'value': 'substrates'}, {'label': 'clinical_variable', 'value': 'CYP 3A4/5'}, {'label': 'clinical_variable', 'value': 'CYP1A2'}, {'label': 'clinical_variable', 'value': 'therapeutic window'}, {'label': 'lower_bound', 'value': 'three weeks'}]
# [{'label': 'clinical_variable', 'value': 'CPP'}, {'label': 'clinical_variable', 'value': 'pelvic pain'}, {'label': 'clinical_variable', 'value': 'non-cyclical'}, {'label': 'clinical_variable', 'value': 'duration'}, {'label': 'lower_bound', 'value': '6 months'}, {'label': 'clinical_variable', 'value': 'refractory'}, {'label': 'clinical_variable', 'value': 'other treatments'}]
# [{'label': 'clinical_variable', 'value': 'current use'}, {'label': 'clinical_variable', 'value': 'opioid pain medications'}]
# [{'label': 'clinical_variable', 'value': 'diet'}, {'label': 'clinical_variable', 'value': 'oily fish'}, {'label': 'lower_bound', 'value': '1-2 days per week'}, {'label': 'clinical_variable', 'value': 'mackerel'}, {'label': 'clinical_variable', 'value': 'salmon'}, {'label': 'clinical_variable', 'value': 'sardines'}, {'label': 'clinical_variable', 'value': 'cold water fish'}]
# [{'label': 'allergy_name', 'value': 'iodine'}]
# [{'label': 'clinical_variable', 'value': 'NYHA classification'}, {'label': 'clinical_variable', 'value': 'III'}, {'label': 'clinical_variable', 'value': 'IV'}]
# [{'label': 'chronic_disease', 'value': 'connective tissue disorder'}, {'label': 'clinical_variable', 'value': "vascular Ehlers Danlos Marfan's syndrome"}, {'label': 'clinical_variable', 'value': 'prior open surgical aortic replacement'}, {'label': 'clinical_variable', 'value': 'endovascular repair'}, {'label': 'clinical_variable', 'value': 'surgical graft'}, {'label': 'clinical_variable', 'value': 'endograft'}, {'label': 'clinical_variable', 'value': 'investigational endograft'}]
# [{'label': 'treatment', 'value': 'PDEV inhibition'}, {'label': 'clinical_variable', 'value': 'erectile dysfunction'}, {'label': 'clinical_variable', 'value': 'medication'}]
# [{'label': 'clinical_variable', 'value': 'surgical procedure'}, {'label': 'clinical_variable', 'value': 'lumbar levels'}, {'label': 'lower_bound', 'value': 'more than one'}]
# [{'label': 'pregnancy', 'value': 'pregnant'}, {'label': 'exclusion_criteria', 'value': 'become pregnant after enrollment'}]
# [{'label': 'clinical_variable', 'value': 'alkaline phosphatase AP'}, {'label': 'upper_bound', 'value': '> 3 upper limit of normal ULN'}, {'label': 'time_frame', 'value': 'within 3 months of screening'}]
# [{'label': 'clinical_variable', 'value': 'Implanted pacemaker'}, {'label': 'clinical_variable', 'value': 'cardiac defibrillator'}]
# [{'label': 'consent', 'value': 'Informed consent'}, {'label': 'consent_type', 'value': 'written consent'}, {'label': 'consent_signer', 'value': "participant's legally authorized guardian"}]
# [{'label': 'exclusion_criteria', 'value': 'Major birth defect'}, {'label': 'exclusion_criteria', 'value': 'malformation syndrome'}]
# [{'label': 'age', 'value': '18 - 39 years'}, {'label': 'clinical_variable', 'value': '15% TBSA'}]
# [{'label': 'gender', 'value': 'female'}]
# [{'label': 'allergy_name', 'value': 'allopurinol'}, {'label': 'allergy_name', 'value': 'rasburicase'}]
# [{'label': 'chronic_disease', 'value': 'Malabsorption syndrome'}]
# [{'label': 'clinical_variable', 'value': 'cognitively impaired'}]
# [{'label': 'chronic_disease', 'value': 'Phantom limb pain'}]
# [{'label': 'pregnancy', 'value': 'Pregnancy'}]
# [{'label': 'clinical_variable', 'value': 'Child not completing all pre-procedure work-up'}, {'label': 'clinical_variable', 'value': 'Stage II Glenn surgery'}, {'label': 'clinical_variable', 'value': 'section 6 of this protocol'}, {'label': 'clinical_variable', 'value': 'pre-procedure work-up documented'}, {'label': 'clinical_variable', 'value': 'safety concern'}, {'label': 'clinical_variable', 'value': 'site investigator'}]
# [{'label': 'clinical_variable', 'value': 'Presence of any non-healing wound'}, {'label': 'clinical_variable', 'value': 'fracture'}, {'label': 'clinical_variable', 'value': 'ulcer'}]
# [{'label': 'gender', 'value': 'nursing women'}]
# [{'label': 'Cancer', 'value': 'past cancer history'}, {'label': 'clinical_variable', 'value': '2 years'}, {'label': 'clinical_variable', 'value': 'ongoing active malignancy'}, {'label': 'clinical_variable', 'value': 'substantial potential for recurrence'}, {'label': 'treatment', 'value': 'discussed with the Sponsor'}, {'label': 'treatment', 'value': 'study entry'}]
# [{'label': 'clinical_variable', 'value': 'second or third degree heart block'}, {'label': 'clinical_variable', 'value': 'subject currently has a pacemaker'}]
# [{'label': 'clinical_variable', 'value': 'myocardial infarction'}, {'label': 'clinical_variable', 'value': '6 months'}, {'label': 'clinical_variable', 'value': 'prior to registration'}]
# [{'label': 'treatment', 'value': 'chronic transfusions'}, {'label': 'clinical_variable', 'value': 'clinical stroke'}, {'label': 'clinical_variable', 'value': 'MRA cerebral vasculopathy'}, {'label': 'treatment', 'value': 'excluded'}, {'label': 'treatment', 'value': 'SWITCH study'}, {'label': 'treatment', 'value': 'hydroxyurea arm'}, {'label': 'clinical_variable', 'value': 'recurrent stroke'}, {'label': 'clinical_variable', 'value': 'chronic transfusion arm'}]
# [{'label': 'treatment', 'value': 'Concomitant cardiac surgery'}]
# [{'label': 'clinical_variable', 'value': 'Alcohol use'}, {'label': 'upper_bound', 'value': 'more than 4 drinks per day'}]
# [{'label': 'age', 'value': 'Age'}, {'label': 'lower_bound', 'value': '18 years'}]
# [{'label': 'chronic_disease', 'value': 'acute pancreatitis'}, {'label': 'chronic_disease', 'value': 'chronic pancreatitis'}, {'label': 'lower_bound', 'value': '1 year'}]
# [{'label': 'clinical_variable', 'value': 'Estimated glomerular filtration rate'}, {'label': 'lower_bound', 'value': '< 60 mL/min 1.73m2'}]
# [{'label': 'clinical_variable', 'value': 'Cochlear nerve deficiency'}]
# [{'label': 'clinical_variable', 'value': 'Creatinine'}, {'label': 'upper_bound', 'value': '1.5 x institutional upper limit of normal'}, {'label': 'clinical_variable', 'value': 'creatinine clearance'}, {'label': 'lower_bound', 'value': '> 60 mL/min/1.73 m2'}]
# [{'label': 'treatment', 'value': 'Radiation therapy'}, {'label': 'treatment', 'value': 'external radiation therapy'}, {'label': 'treatment', 'value': 'systemic treatment with radionuclides'}, {'label': 'upper_bound', 'value': '2 weeks'}, {'label': 'upper_bound', 'value': '4 weeks'}, {'label': 'clinical_variable', 'value': 'bone or brain metastasis'}, {'label': 'clinical_variable', 'value': 'clinically relevant ongoing complications'}]
# [{'label': 'clinical_variable', 'value': 'Platelets'}, {'label': 'lower_bound', 'value': '>= 100,000/mcL'}]
# [{'label': 'clinical_variable', 'value': 'HIV-1 infected'}, {'label': 'clinical_variable', 'value': 'treatment-experienced'}, {'label': 'clinical_variable', 'value': 'virologically suppressed'}, {'label': 'gender', 'value': 'males'}]
# [{'label': 'clinical_variable', 'value': 'Active'}, {'label': 'clinical_variable', 'value': 'autoimmune disease'}]
# [{'label': 'Cancer', 'value': 'prostate cancer'}, {'label': 'treatment', 'value': 'LHRH agonists or antagonists'}]
# [{'label': 'age', 'value': '18 yo'}, {'label': 'age', 'value': '60 yo'}, {'label': 'treatment', 'value': 'Cohort 1 only'}]
# [{'label': 'clinical_variable', 'value': 'Third degree heart block'}]
# [{'label': 'Cancer', 'value': 'intrahepatic carcinoma'}, {'label': 'clinical_variable', 'value': 'Confirmed diagnosis'}]
# [{'label': 'pregnancy', 'value': 'Pregnant'}]
# [{'label': 'chronic_disease', 'value': 'Liver cirrhosis'}, {'label': 'clinical_variable', 'value': 'transaminases'}, {'label': 'upper_bound', 'value': '3x of normal limits'}, {'label': 'clinical_variable', 'value': 'bilirubin'}, {'label': 'upper_bound', 'value': '2.0'}]
# [{'label': 'clinical_variable', 'value': 'Absolute contraindications'}, {'label': 'clinical_variable', 'value': 'liver biopsy'}, {'label': 'clinical_variable', 'value': 'coagulopathy'}]
# [{'label': 'language_fluency', 'value': 'English speaking'}]
# [{'label': 'age', 'value': 'At least 18 years of age'}]
# [{'label': 'Cancer', 'value': 'CD20- positive B-cell lymphoma'}, {'label': 'clinical_variable', 'value': 'Histologically documented'}, {'label': 'clinical_variable', 'value': 'local laboratory'}]
# [{'label': 'clinical_variable', 'value': 'Bilirubin', 'lower_bound': '< 3x'}, {'label': 'clinical_variable', 'value': 'AST', 'lower_bound': '< 3x'}, {'label': 'clinical_variable', 'value': 'Serum creatinine', 'lower_bound': '< 2x upper limit of normal'}, {'label': 'clinical_variable', 'value': 'Hgb', 'lower_bound': '> 8.0'}, {'label': 'clinical_variable', 'value': 'plts', 'lower_bound': '> 20'}]
# [{'label': 'clinical_variable', 'value': 'mTBI'}, {'label': 'clinical_variable', 'value': 'Veterans Health Administration VHA /Department of Defense DoD criteria'}, {'label': 'clinical_variable', 'value': 'persisting symptoms', 'lower_bound': '> 3 months post injury'}]
# [{'label': 'clinical_variable', 'value': 'optimally medicated'}, {'label': 'clinical_variable', 'value': 'change in mediction type or dosage', 'lower_bound': '3 months prior to enrolling in the study'}, {'label': 'clinical_variable', 'value': 'medications', 'lower_bound': 'not causing significant or serious advese effects'}]
# [{'label': 'gender', 'value': 'women'}, {'label': 'pregnancy', 'value': 'breast feeding'}]
# [{'label': 'clinical_variable', 'value': 'uncontrolled coagulation blood disorders like haemophilia'}, {'label': 'Cancer', 'value': 'malignant tumors'}, {'label': 'clinical_variable', 'value': 'fear of needles'}]
# [{'label': 'chronic_disease', 'value': 'recurrent seizures'}]
# [{'label': 'Cancer', 'value': 'malignancies'}]
# [{'label': 'clinical_variable', 'value': '> 25% decrease'}, {'label': 'clinical_variable', 'value': 'depressive symptoms'}, {'label': 'clinical_variable', 'value': 'QIDS-SR score'}, {'label': 'clinical_variable', 'value': 'Screening'}, {'label': 'clinical_variable', 'value': 'Randomization'}]
# [{'label': 'clinical_variable', 'value': 'Severe hypersensitivity'}, {'label': 'clinical_variable', 'value': 'Grade 3'}, {'label': 'treatment', 'value': 'pembrolizumab'}, {'label': 'clinical_variable', 'value': 'excipients'}]
# [{'label': 'clinical_variable', 'value': 'Available for follow-up'}, {'label': 'clinical_variable', 'value': '12 months'}]
# [{'label': 'clinical_variable', 'value': 'Invasive infection'}]
# [{'label': 'gender', 'value': 'Women'}, {'label': 'age', 'value': '40-80'}, {'label': 'clinical_variable', 'value': 'good health'}]
# [{'label': 'clinical_variable', 'value': 'Reversible causes'}, {'label': 'clinical_variable', 'value': 'atrial arrhythmia'}, {'label': 'clinical_variable', 'value': 'hyperthyroidism'}, {'label': 'clinical_variable', 'value': 'sarcoidosis'}, {'label': 'clinical_variable', 'value': 'pulmonary embolism'}]
# [{'label': 'treatment', 'value': 'prostanoid'}, {'label': 'clinical_variable', 'value': 'portopulmonary hypertension'}]
# [{'label': 'chronic_disease', 'value': 'diabetes'}]
# [{'label': 'clinical_variable', 'value': 'Score'}, {'label': 'clinical_variable', 'value': 'screening ISR Erythema Index'}, {'label': 'upper_bound', 'value': '50'}]
# [{'label': 'clinical_variable', 'value': 'Atrial fibrillation'}, {'label': 'clinical_variable', 'value': 'rapid ventricular response'}]
# [{'label': 'clinical_variable', 'value': 'Pre-existing stable medication'}, {'label': 'clinical_variable', 'value': 'tic'}, {'label': 'clinical_variable', 'value': 'family agrees'}, {'label': 'clinical_variable', 'value': 'med changes'}, {'label': 'clinical_variable', 'value': 'acute phase of the study'}]
# [{'label': 'chronic_disease', 'value': 'active autoimmune disease'}, {'label': 'upper_bound', 'value': 'past 2 years'}]
# [{'label': 'clinical_variable', 'value': 'Bone lesions'}, {'label': 'clinical_variable', 'value': 'osteolytic lesions'}, {'label': 'clinical_variable', 'value': 'skeletal radiography computerized tomography CT'}, {'label': 'clinical_variable', 'value': '2-deoxy-2 F-18 fluoro-D-glucose positron emission tomography CT PET-CT'}]
# [{'label': 'chronic_disease', 'value': 'pulmonary embolus'}]
# [{'label': 'chronic_disease', 'value': 'New York Heart Association congestive heart failure'}, {'label': 'clinical_variable', 'value': 'class 3 or higher'}]
# [{'label': 'age', 'value': '18'}]
# [{'label': 'chronic_disease', 'value': 'bariatric surgery'}]
# [{'label': 'clinical_variable', 'value': 'Castrate testosterone levels'}, {'label': 'lower_bound', 'value': '50 ng/dL'}]
# [{'label': 'chronic_disease', 'value': 'solid organ transplant'}, {'label': 'chronic_disease', 'value': 'bone marrow transplant'}]
# [{'label': 'clinical_variable', 'value': 'asthma'}, {'label': 'clinical_variable', 'value': 'bronchiectasis'}, {'label': 'clinical_variable', 'value': 'cystic fibrosis'}, {'label': 'clinical_variable', 'value': 'severe alpha-1 antitrypsin deficiency'}]
# [{'label': 'clinical_variable', 'value': 'esophageal spasm'}]
# [{'label': 'clinical_variable', 'value': 'bone marrow biopsy'}, {'label': 'clinical_variable', 'value': 'baseline fibrosis score'}, {'label': 'clinical_variable', 'value': 'consent'}, {'label': 'clinical_variable', 'value': 'tissue collection'}, {'label': 'clinical_variable', 'value': 'protocol mandated testing'}, {'label': 'upper_bound', 'value': 'four weeks'}]
# [{'label': 'clinical_variable', 'value': 'neurodegenerative diseases'}, {'label': 'clinical_variable', 'value': 'MS'}]
# [{'label': 'clinical_variable', 'value': 'Coronary Artery Calcium scanning'}, {'label': 'upper_bound', 'value': '6 months'}, {'label': 'gender', 'value': 'gender'}, {'label': 'clinical_variable', 'value': 'CAC score'}]
# [{'label': 'clinical_variable', 'value': 'CKD stage 5'}, {'label': 'clinical_variable', 'value': 'End Stage Renal Disease ESRD'}]
# [{'label': 'chronic_disease', 'value': 'Any other disease'}, {'label': 'clinical_variable', 'value': 'metabolic dysfunction'}, {'label': 'clinical_variable', 'value': 'physical examination finding'}, {'label': 'clinical_variable', 'value': 'clinical laboratory finding'}, {'label': 'clinical_variable', 'value': 'investigational drug'}, {'label': 'clinical_variable', 'value': 'interpretation of the results'}, {'label': 'clinical_variable', 'value': 'participant at high risk'}, {'label': 'treatment', 'value': 'treatment complications'}]
# [{'label': 'treatment', 'value': 'consuming alcohol'}, {'label': 'upper_bound', 'value': '72 hours'}, {'label': 'clinical_variable', 'value': 'rTMS session'}]
# [{'label': 'treatment', 'value': 'primary debulking surgery'}, {'label': 'clinical_variable', 'value': 'stage III or IV disease'}, {'label': 'treatment', 'value': 'surgery'}, {'label': 'treatment', 'value': 'removal of the uterus ovaries and fallopian tubes'}]
# [{'label': 'pregnancy', 'value': 'Pregnant Women'}]
# [{'label': 'clinical_variable', 'value': 'Lesion'}, {'label': 'upper_bound', 'value': '3 cm'}, {'label': 'clinical_variable', 'value': 'diameter'}]
# [{'label': 'chronic_disease', 'value': 'Connective tissue disease'}]
# [{'label': 'clinical_variable', 'value': '12-lead electrocardiogram ECG'}, {'label': 'clinical_variable', 'value': 'screening visit'}, {'label': 'clinical_variable', 'value': 'normal limits'}, {'label': 'clinical_variable', 'value': 'abnormal'}, {'label': 'clinical_variable', 'value': 'not clinically significant'}, {'label': 'clinical_variable', 'value': 'Investigator'}]
# ...
# [{'label': 'treatment', 'value': 'Transplant recipient'}]
# [{'label': 'Cancer', 'value': 'visceral metastases'}, {'label': 'Cancer', 'value': 'lymphadenopathy'}, {'label': 'clinical_variable', 'value': '> 3 cm'}]
# [{'label': 'chronic_disease', 'value': 'liver disease'}, {'label': 'clinical_variable', 'value': 'cirrhosis'}, {'label': 'clinical_variable', 'value': 'elevated transaminases'}, {'label': 'upper_bound', 'value': '3-fold upper limit of normal'}]
# [{'label': 'chronic_disease', 'value': 'systemic infection'}, {'label': 'clinical_variable', 'value': 'active'}]
# [{'label': 'treatment', 'value': 'support person'}, {'label': 'clinical_variable', 'value': 'Spouse'}, {'label': 'clinical_variable', 'value': 'partner'}, {'label': 'clinical_variable', 'value': 'mother'}]
# [{'label': 'Cancer', 'value': 'esophageal cancer'}, {'label': 'Cancer', 'value': 'gastric cancer'}, {'label': 'lower_bound', 'value': '15'}, {'label': 'upper_bound', 'value': '30'}]
# [{'label': 'clinical_variable', 'value': 'severe adverse reaction'}, {'label': 'treatment', 'value': 'study medications'}]
# [{'label': 'age', 'value': '18-69 years'}]
# [{'label': 'treatment', 'value': 'red blood cell and/or platelet transfusions'}]
# [{'label': 'treatment', 'value': 'Immunotherapy'}, {'label': 'treatment', 'value': 'Interferons'}, {'label': 'treatment', 'value': 'Cytokines'}, {'label': 'treatment', 'value': 'PD-1/PD-L1 antagonists'}]
# [{'label': 'clinical_variable', 'value': 'Elevated serum PSA'}, {'label': 'clinical_variable', 'value': 'prostate specific antigen'}, {'label': 'lower_bound', 'value': '> 4 ng/ml'}, {'label': 'clinical_variable', 'value': 'abnormal digital rectal exam'}]
# [{'label': 'technology_access', 'value': 'smart phone'}, {'label': 'technology_access', 'value': 'device'}, {'label': 'treatment', 'value': 'app usage'}]
# [{'label': 'Cancer', 'value': 'Relapsed or primary refractory metastatic'}]
# [{'label': 'clinical_variable', 'value': 'Head trauma'}, {'label': 'clinical_variable', 'value': 'central nervous system injury'}]
# [{'label': 'clinical_variable', 'value': 'serious suicide'}, {'label': 'clinical_variable', 'value': 'homicide risk'}]
# [{'label': 'clinical_variable', 'value': 'acute decompensated HF'}]
# [{'label': 'clinical_variable', 'value': 'diabetic retinopathy'}]
# [{'label': 'chronic_disease', 'value': 'liver cirrhosis'}, {'label': 'clinical_variable', 'value': 'severity'}, {'label': 'treatment', 'value': 'cyclosporine'}, {'label': 'treatment', 'value': 'eltrombopag'}, {'label': 'clinical_variable', 'value': 'albumin'}, {'label': 'lower_bound', 'value': '< 35g/L'}]
# [{'label': 'clinical_variable', 'value': 'platelets'}, {'label': 'lower_bound', 'value': '< 100,000/ L'}]
# [{'label': 'clinical_variable', 'value': 'primary anxiety disorder'}, {'label': 'clinical_variable', 'value': 'primary eating disorders'}, {'label': 'clinical_variable', 'value': 'functional impairment'}]
# [{'label': 'clinical_variable', 'value': 'stabilizing implants'}, {'label': 'clinical_variable', 'value': 'bone'}, {'label': 'clinical_variable', 'value': 'cyst'}]
# [{'label': 'clinical_variable', 'value': 'HIV'}, {'label': 'clinical_variable', 'value': 'HIV antibody test'}, {'label': 'clinical_variable', 'value': 'confirmatory tests'}, {'label': 'clinical_variable', 'value': 'screening'}, {'label': 'lower_bound', 'value': 'within 12 months before screening'}, {'label': 'lower_bound', 'value': 'at screening'}]
# [{'label': 'clinical_variable', 'value': 'Breath alcohol level'}, {'label': 'upper_bound', 'value': '0.01'}]
# [{'label': 'clinical_variable', 'value': 'Total bilirubin'}, {'label': 'upper_bound', 'value': '1.5 x ULN'}]
# [{'label': 'clinical_variable', 'value': 'ALT'}, {'label': 'clinical_variable', 'value': 'AST'}, {'label': 'upper_bound', 'value': '2.5 X upper limit of normal ULN'}]
# [{'label': 'clinical_variable', 'value': 'uncontrolled bacterial fungal or viral infection'}, {'label': 'clinical_variable', 'value': 'progressive symptoms'}, {'label': 'clinical_variable', 'value': 'therapy'}, {'label': 'clinical_variable', 'value': 'CD8+ memory T-cell infusion'}]
# [{'label': 'contraception_consent', 'value': 'birth control'}]
# [{'label': 'Cancer', 'value': 'ovarian cancer'}]
# [{'label': 'language_fluency', 'value': 'English'}]
# [{'label': 'treatment', 'value': 'whole-lung or hemi-thorax irradiation'}, {'label': 'clinical_variable', 'value': '12 Gy'}, {'label': 'clinical_variable', 'value': '6 months'}]
# [{'label': 'chronic_disease', 'value': 'deep vein thrombosis'}, {'label': 'chronic_disease', 'value': 'pulmonary embolus'}]
# [{'label': 'pregnancy', 'value': 'lactating females'}]
# [{'label': 'clinical_variable', 'value': 'Eastern Cooperative Oncology Group ECOG Performance Status'}, {'label': 'lower_bound', 'value': '0'}, {'label': 'upper_bound', 'value': '2'}]
# [{'label': 'Cancer', 'value': 'acute lymphoblastic leukemia lymphoma'}]
# [{'label': 'treatment', 'value': 'ketotifen'}, {'label': 'previous', 'value': 'previous'}]
# [{'label': 'pregnancy', 'value': 'Pregnant'}, {'label': 'pregnancy', 'value': 'breast-feeding'}, {'label': 'gender', 'value': 'females'}, {'label': 'exclusion', 'value': 'excluded'}, {'label': 'clinical_variable', 'value': 'mutagenic effects'}, {'label': 'clinical_variable', 'value': 'developing fetus'}, {'label': 'clinical_variable', 'value': 'newborn'}]
# [{'label': 'Cancer', 'value': 'Infiltrating ductal carcinoma'}, {'label': 'Cancer', 'value': 'DCIS'}, {'label': 'clinical_variable', 'value': 'stage'}, {'label': 'clinical_variable', 'value': 'T0'}, {'label': 'clinical_variable', 'value': 'T1'}, {'label': 'clinical_variable', 'value': 'T2'}, {'label': 'upper_bound', 'value': '3.0 cm'}, {'label': 'clinical_variable', 'value': 'N0'}, {'label': 'clinical_variable', 'value': 'M0'}]
# [{'label': 'Cancer', 'value': 'non-melanomatous skin cancer'}, {'label': 'Cancer', 'value': 'lentigo maligna'}]
# [{'label': 'chronic_disease', 'value': 'Insulin dependent diabetes mellitus'}]
# [{'label': 'clinical_variable', 'value': 'total bilirubin'}, {'label': 'upper_bound', 'value': '2.5 X institutional upper limit of normal'}]
# [{'label': 'treatment', 'value': 'IV tPA'}, {'label': 'upper_bound', 'value': '> 3 hours from stroke onset'}]
# [{'label': 'clinical_variable', 'value': 'Hamilton Depression Rating Scale-24 HRSD-24 score'}, {'label': 'lower_bound', 'value': '8'}, {'label': 'upper_bound', 'value': '24'}]
# [{'label': 'treatment', 'value': 'Surgery intent'}, {'label': 'upper_bound', 'value': '4 weeks'}]
# [{'label': 'gender', 'value': 'female'}, {'label': 'contraception_consent', 'value': 'childbearing potential'}, {'label': 'clinical_variable', 'value': 'sexually mature woman'}, {'label': 'clinical_variable', 'value': 'hysterectomy'}, {'label': 'clinical_variable', 'value': 'bilateral oophorectomy'}, {'label': 'clinical_variable', 'value': 'naturally postmenopausal'}, {'label': 'lower_bound', 'value': '24 consecutive months'}, {'label': 'clinical_variable', 'value': 'menses'}, {'label': 'lower_bound', 'value': 'preceding 24 consecutive months'}]
# [{'label': 'chronic_disease', 'value': 'active acute infections'}, {'label': 'chronic_disease', 'value': 'chronic infections'}, {'label': 'chronic_disease', 'value': 'uncontrolled severe infections'}]
# [{'label': 'clinical_variable', 'value': 'diagnosis'}, {'label': 'clinical_variable', 'value': 'PAH isolated left heart disease'}, {'label': 'clinical_variable', 'value': 'lung disease chronic obstructive pulmonary disease'}, {'label': 'clinical_variable', 'value': 'interstitial lung disease'}, {'label': 'clinical_variable', 'value': 'CTEPH'}, {'label': 'clinical_variable', 'value': 'established clinical criteria'}]
# [{'label': 'treatment', 'value': 'initiate treatment'}, {'label': 'treatment', 'value': 'doxorubicin'}, {'label': 'clinical_variable', 'value': 'starting dose'}, {'label': 'clinical_variable', 'value': '75 mg/m2'}, {'label': 'clinical_variable', 'value': 'routine care'}]
# [{'label': 'chronic_disease', 'value': 'psychiatric disorder'}, {'label': 'chronic_disease', 'value': 'substance abuse disorder'}]
# [{'label': 'clinical_variable', 'value': 'catheter-associated UTI'}]
# [{'label': 'clinical_variable', 'value': 'malignancy-associated microcalcifications'}, {'label': 'clinical_variable', 'value': 'post-excision mammography'}]
# [{'label': 'clinical_variable', 'value': 'lung involvement'}, {'label': 'clinical_variable', 'value': 'organ involvement'}, {'label': 'clinical_variable', 'value': 'renal angiomyolipomas'}, {'label': 'clinical_variable', 'value': 'chylous effusions'}, {'label': 'clinical_variable', 'value': 'lymphangioleiomyomas'}]
# [{'label': 'chronic_disease', 'value': 'epilepsy'}, {'label': 'clinical_variable', 'value': 'seizures'}]
# [{'label': 'treatment', 'value': 'amifostine'}, {'label': 'treatment', 'value': 'abdominal radiotherapy'}, {'label': 'treatment', 'value': 'quinolone antibiotic therapy'}]
# [{'label': 'clinical_variable', 'value': 'ambulate'}, {'label': 'clinical_variable', 'value': 'household distances'}, {'label': 'lower_bound', 'value': '50ft'}]
# [{'label': 'age', 'value': '18'}, {'label': 'lower_bound', 'value': '18'}]
# [{'label': 'gender', 'value': 'Male'}]
# [{'label': 'Cancer', 'value': 'CNS metastases'}, {'label': 'clinical_variable', 'value': 'active CNS metastases'}]
# [{'label': 'clinical_variable', 'value': 'MAS'}, {'label': 'clinical_variable', 'value': '98-D-0145'}]
# [{'label': 'treatment', 'value': 'standard neoadjuvant chemotherapy'}, {'label': 'clinical_variable', 'value': 'anthracycline'}, {'label': 'clinical_variable', 'value': 'taxane-based regimen'}, {'label': 'lower_bound', 'value': '8 weeks'}]
# [{'label': 'clinical_variable', 'value': 'bone marrow metastases'}, {'label': 'clinical_variable', 'value': 'high urine catecholamine levels'}]
# [{'label': 'chronic_disease', 'value': 'Osteoporosis'}, {'label': 'clinical_variable', 'value': 'recent fracture'}, {'label': 'clinical_variable', 'value': 'hip'}, {'label': 'clinical_variable', 'value': 'spinal joints'}]
# [{'label': 'clinical_variable', 'value': 'unilateral inguinal herna'}, {'label': 'clinical_variable', 'value': 'bilateral inguinal herna'}, {'label': 'treatment', 'value': 'laparoscopic repair'}]
# [{'label': 'treatment', 'value': 'Corticosteroid injection'}, {'label': 'clinical_variable', 'value': 'treatment site'}, {'label': 'lower_bound', 'value': 'within 1 month'}]
# [{'label': 'clinical_variable', 'value': 'ECOG Performance Status'}, {'label': 'lower_bound', 'value': '0'}, {'label': 'upper_bound', 'value': '1'}]
# [{'label': 'allergy_name', 'value': 'dextromethorphan'}, {'label': 'allergy_name', 'value': 'vitamin A'}, {'label': 'allergy_name', 'value': 'isotretinoin'}]
# [{'label': 'treatment', 'value': 'investigational drug or device study'}, {'label': 'lower_bound', 'value': 'within the past 6 weeks'}]
# [{'label': 'allergy_name', 'value': 'conductive hydrogels'}]
# [{'label': 'chronic_disease', 'value': 'severe cognitive impairment'}]
# [{'label': 'clinical_variable', 'value': 'Current smoking'}, {'label': 'clinical_variable', 'value': 'history of smoking'}, {'label': 'clinical_variable', 'value': 'past 12 months'}]
# [{'label': 'age', 'value': '18 year olds'}]
# [{'label': 'chronic_disease', 'value': 'history of prior pelvic irradiation'}]
# [{'label': 'clinical_variable', 'value': 'lifetime history of suicide attempt'}, {'label': 'clinical_variable', 'value': 'active attempt'}, {'label': 'clinical_variable', 'value': 'interrupted attempt'}, {'label': 'clinical_variable', 'value': 'aborted attempt'}, {'label': 'clinical_variable', 'value': 'suicidal ideation'}, {'label': 'clinical_variable', 'value': 'past 6 months'}, {'label': 'clinical_variable', 'value': "positive response 'Yes'"}, {'label': 'clinical_variable', 'value': 'Question 4'}, {'label': 'clinical_variable', 'value': 'Question 5'}, {'label': 'clinical_variable', 'value': 'C-SSRS'}, {'label': 'clinical_variable', 'value': 'Screening'}]
# [{'label': 'clinical_variable', 'value': 'AST'}, {'label': 'clinical_variable', 'value': 'ALT'}, {'label': 'upper_bound', 'value': '2 times upper limit of normal ULN'}]
# [{'label': 'clinical_variable', 'value': 'Human papillomavirus HPV 16-positive disease'}, {'label': 'clinical_variable', 'value': 'PCR'}]
# [{'label': 'treatment', 'value': 'LY2606368'}, {'label': 'treatment', 'value': 'Chk inhibitors'}]
# [{'label': 'clinical_variable', 'value': 'cannabis use'}, {'label': 'clinical_variable', 'value': 'urine'}, {'label': 'clinical_variable', 'value': 'screening visit'}, {'label': 'clinical_variable', 'value': 'Gas Chromatography GC Mass Spectrometry MS laboratory test'}, {'label': 'clinical_variable', 'value': 'clinic admission'}]
# [{'label': 'chronic_disease', 'value': 'schizophrenia'}]
# [{'label': 'gender', 'value': 'women of childbearing potential'}]
# [{'label': 'treatment', 'value': 'gonadal steroid preparations'}, {'label': 'lower_bound', 'value': '1 month'}]
# [{'label': 'pregnancy', 'value': 'Pregnant'}]
# [{'label': 'clinical_variable', 'value': 'Absolute neutrophil count'}, {'label': 'lower_bound', 'value': '1,500/mcL'}]
# [{'label': 'allergy_name', 'value': 'Everolimus'}, {'label': 'allergy_name', 'value': 'rapamycins'}, {'label': 'allergy_name', 'value': 'sirolimus'}, {'label': 'allergy_name', 'value': 'temsirolimus'}]
# [{'label': 'chronic_disease', 'value': 'cardiac/cardiovascular disease'}, {'label': 'clinical_variable', 'value': 'pulmonary compromise'}]
# [{'label': 'chronic_disease', 'value': 'radiculopathy'}]
# [{'label': 'age', 'value': '18 years'}, {'label': 'lower_bound', 'value': 'older'}]
# [{'label': 'chronic_disease', 'value': 'Gastrointestinal Bleed'}]
# [{'label': 'chronic_disease', 'value': 'human immunodeficiency virus HIV'}, {'label': 'clinical_variable', 'value': 'active infectious hepatitis'}, {'label': 'clinical_variable', 'value': 'type A'}, {'label': 'clinical_variable', 'value': 'type B'}, {'label': 'clinical_variable', 'value': 'type C'}]
# [{'label': 'gender', 'value': 'Women'}, {'label': 'clinical_variable', 'value': 'serious psychiatric symptoms'}, {'label': 'clinical_variable', 'value': 'CNO trained staff'}]
# [{'label': 'clinical_variable', 'value': 'disease relapse'}, {'label': 'clinical_variable', 'value': 'active GVHD'}, {'label': 'clinical_variable', 'value': 'history of more than Stage 1 skin acute GVHD'}, {'label': 'clinical_variable', 'value': 'history of cGVHD'}]
# [{'label': 'chronic_disease', 'value': 'thyroid disease'}]
# [{'label': 'clinical_variable', 'value': 'Immunocompromised patients'}, {'label': 'clinical_variable', 'value': 'serologically positive for human immunodeficiency virus HIV'}, {'label': 'clinical_variable', 'value': 'receiving antiviral therapy'}]
# [{'label': 'clinical_variable', 'value': 'positive Hepatitis B surface antigen'}, {'label': 'clinical_variable', 'value': 'antihepatitis B core antibody'}]
# [{'label': 'gender', 'value': 'Men'}, {'label': 'contraception_consent', 'value': 'adequate contraception'}, {'label': 'clinical_variable', 'value': 'duration of study participation'}, {'label': 'clinical_variable', 'value': '3 months'}]
# [{'label': 'clinical_variable', 'value': 'Serum creatinine'}, {'label': 'upper_bound', 'value': '1.5 x ULN'}]
# [{'label': 'chronic_disease', 'value': 'seizure disorder'}]
# [{'label': 'treatment', 'value': 'investigational agents'}, {'label': 'clinical_variable', 'value': '4 weeks prior to enrollment'}, {'label': 'treatment', 'value': 'radiation therapy'}]
# [{'label': 'clinical_variable', 'value': 'ALT'}, {'label': 'clinical_variable', 'value': 'BUN'}, {'label': 'upper_bound', 'value': '2.0 ULN'}, {'label': 'clinical_variable', 'value': 'estimated creatinine'}, {'label': 'upper_bound', 'value': '1.5 X ULN'}, {'label': 'clinical_variable', 'value': 'age'}, {'label': 'clinical_variable', 'value': 'laboratory abnormality'}, {'label': 'clinical_variable', 'value': 'Investigator'}, {'label': 'clinical_variable', 'value': 'clinically significant'}, {'label': 'clinical_variable', 'value': '14 days before Screening'}]

# %%
gpt_res_with_indexes
# Out:
# [[{'label': 'treatment',
#    'start': 24,
#    'end': 43,
#    'value': 'oral administration'},
#   {'label': 'treatment', 'start': 47, 'end': 57, 'value': 'study drug'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 17, 'value': 'Current pregnancy'}],
#  [{'label': 'pregnancy',
#    'start': 0,
#    'end': 19,
#    'value': 'Singleton pregnancy'}],
#  [{'label': 'clinical_variable', 'start': 30, 'end': 38, 'value': 'steroids'},
#   {'label': 'clinical_variable', 'start': 54, 'end': 61, 'value': 'surgery'},
#   {'label': 'clinical_variable',
#    'start': 85,
#    'end': 100,
#    'value': 'recovery period'},
#   {'label': 'clinical_variable',
#    'start': 126,
#    'end': 156,
#    'value': 'betamethasone hypersensitivity'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 23,
#    'value': 'rheumatic valve disease'},
#   {'label': 'clinical_variable',
#    'start': 53,
#    'end': 65,
#    'value': 'AF phenotype'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 24,
#    'value': 'Severe liver dysfunction'},
#   {'label': 'clinical_variable', 'start': 25, 'end': 28, 'value': 'LFT'},
#   {'label': 'upper_bound',
#    'start': 29,
#    'end': 53,
#    'value': '3X upper limit of normal'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'Serum M-protein'},
#   {'label': 'lower_bound', 'start': 19, 'end': 27, 'value': '1.0 g/dL'}],
#  [{'label': 'gender', 'start': 0, 'end': 16, 'value': 'Males or females'}],
#  [{'label': 'Cancer',
#    'start': 0,
#    'end': 23,
#    'value': 'Negative for malignancy'},
#   {'label': 'clinical_variable',
#    'start': 28,
#    'end': 40,
#    'value': 'past 5 years'}],
#  [{'label': 'technology_access',
#    'start': 0,
#    'end': 35,
#    'value': 'available for up to 6 hrs every day'},
#   {'label': 'clinical_variable',
#    'start': 40,
#    'end': 63,
#    'value': 'two 2-week test periods'},
#   {'label': 'clinical_variable',
#    'start': 72,
#    'end': 108,
#    'value': 'intervening break of 7- 10 days each'}],
#  [{'label': 'Cancer',
#    'start': 13,
#    'end': 55,
#    'value': 'recurrent and/or metastatic thyroid cancer'}],
#  [{'label': 'treatment', 'start': 93, 'end': 103, 'value': 'paclitaxel'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 22,
#    'value': 'Mean arterial pressure'},
#   {'label': 'lower_bound', 'start': 25, 'end': 27, 'value': '65'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 21,
#    'value': 'White blood cells WBC'},
#   {'label': 'upper_bound',
#    'start': 24,
#    'end': 40,
#    'value': '15,000 cells/mcL'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 21,
#    'value': 'Acute medical illness'}],
#  [{'label': 'treatment', 'start': 19, 'end': 31, 'value': 'chemotherapy'},
#   {'label': 'clinical_variable', 'start': 13, 'end': 18, 'value': 'prior'}],
#  [{'label': 'chronic_disease',
#    'start': 17,
#    'end': 32,
#    'value': 'thromboembolism'},
#   {'label': 'clinical_variable',
#    'start': 44,
#    'end': 57,
#    'value': 'thrombophilia'}],
#  [{'label': 'clinical_variable',
#    'start': 22,
#    'end': 41,
#    'value': 'stationary position'},
#   {'label': 'treatment', 'start': 49, 'end': 53, 'value': 'HIFU'}],
#  [{'label': 'chronic_disease', 'start': 17, 'end': 28, 'value': 'hepatitis B'},
#   {'label': 'chronic_disease', 'start': 40, 'end': 51, 'value': 'hepatitis B'},
#   {'label': 'clinical_variable',
#    'start': 40,
#    'end': 82,
#    'value': 'hepatitis B survace antigen HBsAg reactive'},
#   {'label': 'clinical_variable',
#    'start': 99,
#    'end': 110,
#    'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'start': 122,
#    'end': 163,
#    'value': 'HCV RNA qualitative is detected infection'}],
#  [{'label': 'chronic_disease',
#    'start': 35,
#    'end': 60,
#    'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable',
#    'start': 84,
#    'end': 115,
#    'value': 'severely impaired lung function'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 17,
#    'value': 'Diabetes Mellitus'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 37,
#    'value': 'Seizure disorder requiring medication'}],
#  [{'label': 'bmi', 'start': 16, 'end': 19, 'value': 'BMI'},
#   {'label': 'lower_bound', 'start': 23, 'end': 32, 'value': '25 kg/m^2'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'Life expectancy'},
#   {'label': 'lower_bound', 'start': 28, 'end': 36, 'value': '12 weeks'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 28,
#    'value': 'History/physical examination'},
#   {'label': 'clinical_variable',
#    'start': 53,
#    'end': 79,
#    'value': 'digital rectal examination'},
#   {'label': 'lower_bound',
#    'start': 154,
#    'end': 183,
#    'value': '90 days prior to registration'}],
#  [{'label': 'Cancer',
#    'start': 3,
#    'end': 32,
#    'value': 'secondary primary lung cancer'},
#   {'label': 'chronic_disease', 'start': 21, 'end': 32, 'value': 'lung cancer'},
#   {'label': 'upper_bound',
#    'start': 66,
#    'end': 94,
#    'value': '2 year prior to registration'}],
#  [{'label': 'clinical_variable',
#    'start': 29,
#    'end': 67,
#    'value': 'serum human chorionic gonadotropin hCG'},
#   {'label': 'pregnancy', 'start': 20, 'end': 28, 'value': 'positive'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'Total bilirubin'},
#   {'label': 'upper_bound',
#    'start': 17,
#    'end': 65,
#    'value': '=< 1.5 x institutional upper limit of normal ULN'},
#   {'label': 'upper_bound',
#    'start': 69,
#    'end': 222,
#    'value': "=< 3 x ULN for participants with Gilbert's disease or with atazanavir- or indinavir- induced unconjugated hyperbilirubinemia without AST or ALT elevation"},
#   {'label': 'upper_bound',
#    'start': 266,
#    'end': 310,
#    'value': '3.0 mg/dL within 2 weeks prior to enrollment'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 28,
#    'value': 'Other neurological diagnosis'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 27,
#    'value': 'Major neurological disorder'}],
#  [{'label': 'treatment',
#    'start': 0,
#    'end': 33,
#    'value': 'Anti-tumor necrosis factor agents'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 36,
#    'value': 'Clinically significant heart disease'},
#   {'label': 'clinical_variable',
#    'start': 53,
#    'end': 74,
#    'value': 'myocardial infarction'},
#   {'label': 'clinical_variable',
#    'start': 78,
#    'end': 104,
#    'value': 'arterial thrombotic events'},
#   {'label': 'clinical_variable',
#    'start': 126,
#    'end': 151,
#    'value': 'severe or unstable angina'},
#   {'label': 'clinical_variable',
#    'start': 155,
#    'end': 213,
#    'value': 'New York Heart Association NYHA class II- IV heart disease'}],
#  [{'label': 'clinical_variable',
#    'start': 3,
#    'end': 22,
#    'value': 'normal sinus rhythm'},
#   {'label': 'clinical_variable',
#    'start': 23,
#    'end': 37,
#    'value': 'ECG documented'},
#   {'label': 'clinical_variable',
#    'start': 38,
#    'end': 88,
#    'value': 'within the two weeks prior to the screening Holter'}],
#  [{'label': 'gender', 'start': 0, 'end': 5, 'value': 'Women'},
#   {'label': 'clinical_variable',
#    'start': 9,
#    'end': 31,
#    'value': 'childbearing potential'},
#   {'label': 'clinical_variable',
#    'start': 44,
#    'end': 67,
#    'value': 'negative pregnancy test'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 25,
#    'value': 'Hematologic abnormalities'},
#   {'label': 'clinical_variable',
#    'start': 32,
#    'end': 44,
#    'value': 'pancytopenia'},
#   {'label': 'clinical_variable',
#    'start': 45,
#    'end': 60,
#    'value': 'aplastic anemia'}],
#  [{'label': 'language_fluency',
#    'start': 0,
#    'end': 26,
#    'value': 'Poor English comprehension'}],
#  [{'label': 'clinical_variable',
#    'start': 24,
#    'end': 40,
#    'value': 'multiple myeloma'},
#   {'label': 'clinical_variable',
#    'start': 54,
#    'end': 114,
#    'value': 'International Myeloma Working Group IMWG diagnostic criteria'}],
#  [{'label': 'chronic_disease',
#    'start': 27,
#    'end': 51,
#    'value': 'hypercontractile bladder'},
#   {'label': 'chronic_disease',
#    'start': 52,
#    'end': 73,
#    'value': 'non-compliant bladder'},
#   {'label': 'chronic_disease',
#    'start': 74,
#    'end': 88,
#    'value': 'hydronephrosis'},
#   {'label': 'chronic_disease',
#    'start': 92,
#    'end': 110,
#    'value': 'neurogenic bladder'}],
#  [{'label': 'age', 'start': 9, 'end': 11, 'value': '40'},
#   {'label': 'age', 'start': 14, 'end': 16, 'value': '59'},
#   {'label': 'clinical_variable', 'start': 35, 'end': 43, 'value': '15% TBSA'}],
#  [{'label': 'age', 'start': 9, 'end': 10, 'value': '2'},
#   {'label': 'lower_bound', 'start': 0, 'end': 8, 'value': 'at least'}],
#  [{'label': 'age', 'start': 25, 'end': 31, 'value': '1 year'},
#   {'label': 'upper_bound', 'start': 37, 'end': 45, 'value': '18 years'}],
#  [{'label': 'treatment',
#    'start': 0,
#    'end': 22,
#    'value': 'Therapeutic antibodies'},
#   {'label': 'treatment', 'start': 31, 'end': 42, 'value': 'bevacizumab'}],
#  [{'label': 'clinical_variable',
#    'start': 5,
#    'end': 26,
#    'value': 'postmenopausal status'},
#   {'label': 'clinical_variable',
#    'start': 41,
#    'end': 67,
#    'value': 'surgical/natural menopause'},
#   {'label': 'clinical_variable',
#    'start': 71,
#    'end': 90,
#    'value': 'ovarian suppression'},
#   {'label': 'clinical_variable', 'start': 110, 'end': 117, 'value': '28 days'},
#   {'label': 'clinical_variable',
#    'start': 127,
#    'end': 143,
#    'value': 'Day 1 of Cycle 1'},
#   {'label': 'clinical_variable',
#    'start': 151,
#    'end': 181,
#    'value': 'gonadotropin-releasing hormone'},
#   {'label': 'clinical_variable',
#    'start': 203,
#    'end': 212,
#    'value': 'goserelin'}],
#  [{'label': 'Cancer', 'start': 0, 'end': 17, 'value': 'Pancreatic Cancer'},
#   {'label': 'clinical_variable',
#    'start': 35,
#    'end': 68,
#    'value': 'potentially surgically resectable'}],
#  [{'label': 'clinical_variable',
#    'start': 24,
#    'end': 52,
#    'value': 'lower urinary tract symptoms'},
#   {'label': 'clinical_variable', 'start': 53, 'end': 57, 'value': 'LUTS'},
#   {'label': 'clinical_variable', 'start': 71, 'end': 77, 'value': '1 year'}],
#  [{'label': 'treatment', 'start': 24, 'end': 37, 'value': 'pacemaker ICD'}],
#  [{'label': 'treatment', 'start': 0, 'end': 12, 'value': 'spinal block'},
#   {'label': 'treatment',
#    'start': 35,
#    'end': 52,
#    'value': 'BBBD chemotherapy'}],
#  [{'label': 'clinical_variable',
#    'start': 4,
#    'end': 29,
#    'value': 'linked to care/evaluation'},
#   {'label': 'upper_bound', 'start': 37, 'end': 44, 'value': '30 days'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 10, 'value': 'Dry weight'},
#   {'label': 'clinical_variable', 'start': 15, 'end': 21, 'value': 'height'},
#   {'label': 'upper_bound', 'start': 49, 'end': 55, 'value': '7 days'}],
#  [{'label': 'treatment', 'start': 0, 'end': 14, 'value': 'antipsychotics'}],
#  [{'label': 'gender', 'start': 0, 'end': 15, 'value': 'lactating women'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 8, 'value': 'SGPT ALT'},
#   {'label': 'upper_bound', 'start': 9, 'end': 24, 'value': '5 x ULN for age'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 8, 'value': 'Pregnant'}],
#  [{'label': 'chronic_disease', 'start': 26, 'end': 37, 'value': 'anaphylaxis'},
#   {'label': 'treatment', 'start': 55, 'end': 67, 'value': 'echinocandin'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 17, 'value': 'possibly pregnant'}],
#  [{'label': 'treatment',
#    'start': 6,
#    'end': 30,
#    'value': 'ipsilateral knee surgery'},
#   {'label': 'treatment',
#    'start': 39,
#    'end': 62,
#    'value': 'ligament reconstruction'},
#   {'label': 'treatment', 'start': 66, 'end': 75, 'value': 'osteotomy'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 24,
#    'value': 'congestive heart failure'}],
#  [{'label': 'clinical_variable',
#    'start': 30,
#    'end': 49,
#    'value': 'resolved acute GVHD'}],
#  [{'label': 'treatment', 'start': 0, 'end': 12, 'value': 'IV docetaxel'},
#   {'label': 'clinical_variable', 'start': 13, 'end': 22, 'value': '75 mg/m^2'},
#   {'label': 'clinical_variable', 'start': 14, 'end': 22, 'value': '5 mg/m^2'},
#   {'label': 'clinical_variable', 'start': 23, 'end': 31, 'value': '5 mg/m^2'},
#   {'label': 'treatment', 'start': 36, 'end': 47, 'value': 'carboplatin'},
#   {'label': 'clinical_variable',
#    'start': 57,
#    'end': 70,
#    'value': 'every 21 days'}],
#  [{'label': 'contraception_consent',
#    'start': 31,
#    'end': 62,
#    'value': 'effective form of birth control'}],
#  [{'label': 'treatment',
#    'start': 26,
#    'end': 60,
#    'value': 'combination antiretroviral therapy'},
#   {'label': 'clinical_variable',
#    'start': 139,
#    'end': 148,
#    'value': 'LY2606368'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 23,
#    'value': 'ECOG performance status'},
#   {'label': 'clinical_variable', 'start': 48, 'end': 57, 'value': 'Karnofsky'},
#   {'label': 'lower_bound', 'start': 46, 'end': 47, 'value': '2'},
#   {'label': 'upper_bound', 'start': 83, 'end': 86, 'value': '60%'}],
#  [{'label': 'Cancer',
#    'start': 0,
#    'end': 24,
#    'value': 'Metastatic breast cancer'},
#   {'label': 'clinical_variable',
#    'start': 27,
#    'end': 42,
#    'value': 'triple negative'},
#   {'label': 'clinical_variable', 'start': 47, 'end': 49, 'value': 'ER'},
#   {'label': 'clinical_variable', 'start': 133, 'end': 135, 'value': 'ER'},
#   {'label': 'clinical_variable', 'start': 103, 'end': 109, 'value': 'CCND1c'},
#   {'label': 'clinical_variable', 'start': 132, 'end': 136, 'value': 'HER2'},
#   {'label': 'treatment',
#    'start': 153,
#    'end': 186,
#    'value': 'trastuzumab and PD0332991 therapy'},
#   {'label': 'upper_bound', 'start': 193, 'end': 195, 'value': '55'}],
#  [{'label': 'age', 'start': 2, 'end': 4, 'value': '18'},
#   {'label': 'lower_bound', 'start': 5, 'end': 14, 'value': 'years old'}],
#  [{'label': 'treatment',
#    'start': 27,
#    'end': 63,
#    'value': 'recurrent or refractory solid tumors'},
#   {'label': 'clinical_variable',
#    'start': 72,
#    'end': 105,
#    'value': 'central nervous system CNS tumors'},
#   {'label': 'clinical_variable',
#    'start': 115,
#    'end': 129,
#    'value': 'CNS metastases'}],
#  [{'label': 'chronic_disease',
#    'start': 38,
#    'end': 70,
#    'value': 'human immunodeficiency virus HIV'},
#   {'label': 'chronic_disease',
#    'start': 80,
#    'end': 119,
#    'value': 'acquired immunodeficiency syndrome AIDS'}],
#  [{'label': 'treatment', 'start': 0, 'end': 15, 'value': 'planned surgery'},
#   {'label': 'treatment',
#    'start': 26,
#    'end': 44,
#    'value': 'general anesthesia'},
#   {'label': 'clinical_variable',
#    'start': 56,
#    'end': 78,
#    'value': 'pharmacotherapy period'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 16,
#    'value': 'Maximal diameter'},
#   {'label': 'clinical_variable',
#    'start': 28,
#    'end': 52,
#    'value': 'hepatocellular carcinoma'},
#   {'label': 'upper_bound', 'start': 55, 'end': 60, 'value': '15 cm'}],
#  [{'label': 'gender', 'start': 0, 'end': 7, 'value': 'Females'},
#   {'label': 'clinical_variable',
#    'start': 16,
#    'end': 26,
#    'value': 'menopausal'},
#   {'label': 'clinical_variable',
#    'start': 41,
#    'end': 63,
#    'value': 'bilateral oophorectomy'}],
#  [{'label': 'gender', 'start': 0, 'end': 6, 'value': 'female'}],
#  [{'label': 'clinical_variable', 'start': 35, 'end': 39, 'value': 'ADHD'},
#   {'label': 'clinical_variable',
#    'start': 57,
#    'end': 86,
#    'value': 'clinician administered CAADID'},
#   {'label': 'clinical_variable',
#    'start': 91,
#    'end': 109,
#    'value': 'clinical interview'}],
#  [{'label': 'clinical_variable',
#    'start': 6,
#    'end': 23,
#    'value': 'active malignancy'},
#   {'label': 'upper_bound',
#    'start': 27,
#    'end': 56,
#    'value': '3 years prior to registration'}],
#  [{'label': 'treatment',
#    'start': 11,
#    'end': 43,
#    'value': 'intensive induction chemotherapy'},
#   {'label': 'treatment', 'start': 44, 'end': 56, 'value': 'radiotherapy'},
#   {'label': 'treatment',
#    'start': 60,
#    'end': 78,
#    'value': 'biologic treatment'},
#   {'label': 'clinical_variable',
#    'start': 83,
#    'end': 100,
#    'value': 'active malignancy'},
#   {'label': 'treatment',
#    'start': 113,
#    'end': 137,
#    'value': 'maintenance chemotherapy'},
#   {'label': 'clinical_variable',
#    'start': 187,
#    'end': 208,
#    'value': 'study medical monitor'}],
#  [{'label': 'treatment', 'start': 17, 'end': 32, 'value': 'CEM carboplatin'},
#   {'label': 'treatment', 'start': 34, 'end': 43, 'value': 'etoposide'},
#   {'label': 'treatment', 'start': 45, 'end': 62, 'value': 'melphalan therapy'},
#   {'label': 'lower_bound',
#    'start': 102,
#    'end': 136,
#    'value': '30 days prior to 131I-MIBG therapy'},
#   {'label': 'treatment',
#    'start': 119,
#    'end': 136,
#    'value': '131I-MIBG therapy'},
#   {'label': 'treatment',
#    'start': 137,
#    'end': 154,
#    'value': '131I-MIBG therapy'},
#   {'label': 'lower_bound',
#    'start': 198,
#    'end': 243,
#    'value': '30 days following administration of 131I-MIBG'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 12,
#    'value': 'HIV positive'},
#   {'label': 'clinical_variable', 'start': 18, 'end': 27, 'value': 'CD4 count'},
#   {'label': 'lower_bound',
#    'start': 30,
#    'end': 50,
#    'value': '350 cells/microliter'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 23,
#    'value': 'Preoperative evaluation'},
#   {'label': 'treatment', 'start': 70, 'end': 77, 'value': 'CT scan'},
#   {'label': 'treatment', 'start': 79, 'end': 82, 'value': 'MRI'},
#   {'label': 'treatment', 'start': 87, 'end': 97, 'value': 'ultrasound'}],
#  [{'label': 'clinical_variable',
#    'start': 25,
#    'end': 39,
#    'value': 'claustrophobic'}],
#  [{'label': 'chronic_disease', 'start': 31, 'end': 41, 'value': 'malignancy'}],
#  [{'label': 'clinical_variable', 'start': 7, 'end': 15, 'value': 'drinking'},
#   {'label': 'clinical_variable',
#    'start': 38,
#    'end': 50,
#    'value': 'past 90 days'},
#   {'label': 'upper_bound', 'start': 19, 'end': 22, 'value': '80%'}],
#  [{'label': 'language_fluency', 'start': 18, 'end': 25, 'value': 'English'}],
#  [{'label': 'chronic_disease',
#    'start': 53,
#    'end': 81,
#    'value': 'cerebrovascular accident CVA'},
#   {'label': 'chronic_disease',
#    'start': 87,
#    'end': 116,
#    'value': 'transient ischemic attack TIA'},
#   {'label': 'upper_bound', 'start': 14, 'end': 22, 'value': '6 months'}],
#  [{'label': 'treatment',
#    'start': 37,
#    'end': 69,
#    'value': 'platinum-containing chemotherapy'},
#   {'label': 'treatment',
#    'start': 133,
#    'end': 165,
#    'value': 'platinum-containing chemotherapy'},
#   {'label': 'treatment',
#    'start': 94,
#    'end': 127,
#    'value': 'neoadjuvant or adjuvant treatment'},
#   {'label': 'treatment',
#    'start': 37,
#    'end': 69,
#    'value': 'platinum-containing chemotherapy'},
#   {'label': 'treatment',
#    'start': 133,
#    'end': 165,
#    'value': 'platinum-containing chemotherapy'},
#   {'label': 'upper_bound', 'start': 80, 'end': 90, 'value': '1 2 months'}],
#  [{'label': 'treatment',
#    'start': 37,
#    'end': 57,
#    'value': 'investigational drug'},
#   {'label': 'lower_bound', 'start': 9, 'end': 16, 'value': '4 weeks'}],
#  [{'label': 'allergy_name',
#    'start': 19,
#    'end': 50,
#    'value': 'gadolinium Gd contrast material'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 8, 'value': 'Wheezing'}],
#  [{'label': 'treatment', 'start': 34, 'end': 47, 'value': 'toxic effects'},
#   {'label': 'clinical_variable',
#    'start': 51,
#    'end': 64,
#    'value': 'prior therapy'}],
#  [{'label': 'chronic_disease',
#    'start': 24,
#    'end': 58,
#    'value': 'uncontrolled inter-current illness'},
#   {'label': 'clinical_variable',
#    'start': 69,
#    'end': 96,
#    'value': 'ongoing or active infection'},
#   {'label': 'clinical_variable',
#    'start': 97,
#    'end': 133,
#    'value': 'symptomatic congestive heart failure'},
#   {'label': 'clinical_variable',
#    'start': 134,
#    'end': 148,
#    'value': 'NYHA Gr.2 or >'},
#   {'label': 'clinical_variable',
#    'start': 151,
#    'end': 172,
#    'value': 'myocardial infarction'},
#   {'label': 'clinical_variable',
#    'start': 173,
#    'end': 197,
#    'value': 'unstable angina pectoris'},
#   {'label': 'clinical_variable',
#    'start': 209,
#    'end': 223,
#    'value': 'past 12 months'}],
#  [{'label': 'age', 'start': 6, 'end': 8, 'value': '18'},
#   {'label': 'lower_bound', 'start': 15, 'end': 23, 'value': '75 years'}],
#  [{'label': 'Cancer',
#    'start': 14,
#    'end': 46,
#    'value': 'recurrent carcinoma of the vulva'},
#   {'label': 'treatment',
#    'start': 61,
#    'end': 79,
#    'value': 'previous treatment'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 9, 'value': 'PaO2/FiO2'},
#   {'label': 'lower_bound', 'start': 10, 'end': 13, 'value': '300'}],
#  [{'label': 'clinical_variable',
#    'start': 69,
#    'end': 95,
#    'value': 'amyloid imaging disclosure'}],
#  [{'label': 'age', 'start': 16, 'end': 29, 'value': '4 to 6 months'}],
#  [{'label': 'chronic_disease', 'start': 12, 'end': 18, 'value': 'asthma'}],
#  [],
#  [{'label': 'age', 'start': 4, 'end': 21, 'value': '18 years or older'}],
#  [{'label': 'treatment',
#    'start': 23,
#    'end': 51,
#    'value': 'second line hormonal therapy'},
#   {'label': 'treatment', 'start': 68, 'end': 80, 'value': 'bicalutamide'},
#   {'label': 'treatment', 'start': 81, 'end': 91, 'value': 'nilutamide'},
#   {'label': 'treatment', 'start': 92, 'end': 101, 'value': 'flutamide'},
#   {'label': 'treatment', 'start': 102, 'end': 114, 'value': 'ketoconazole'},
#   {'label': 'treatment', 'start': 115, 'end': 126, 'value': 'abiraterone'},
#   {'label': 'treatment', 'start': 127, 'end': 139, 'value': 'enzalutamide'},
#   {'label': 'treatment', 'start': 140, 'end': 147, 'value': 'ARN-509'}],
#  [{'label': 'clinical_variable',
#    'start': 58,
#    'end': 76,
#    'value': 'endometrial cancer'},
#   {'label': 'treatment', 'start': 22, 'end': 31, 'value': 'routinely'},
#   {'label': 'treatment', 'start': 42, 'end': 57, 'value': 'newly diagnosed'},
#   {'label': 'treatment', 'start': 93, 'end': 100, 'value': 'centers'},
#   {'label': 'treatment', 'start': 108, 'end': 110, 'value': 'US'}],
#  [{'label': 'clinical_variable',
#    'start': 7,
#    'end': 38,
#    'value': 'central nervous system lymphoma'}],
#  [{'label': 'chronic_disease',
#    'start': 6,
#    'end': 25,
#    'value': 'autoimmune diseases'}],
#  [{'label': 'Cancer',
#    'start': 38,
#    'end': 64,
#    'value': 'acute myeloid leukemia AML'},
#   {'label': 'Cancer',
#    'start': 65,
#    'end': 97,
#    'value': 'acute lymphoblastic leukemia ALL'},
#   {'label': 'Cancer',
#    'start': 98,
#    'end': 130,
#    'value': 'chronic myelogenous leukemia CML'},
#   {'label': 'Cancer',
#    'start': 131,
#    'end': 163,
#    'value': 'chronic lymphocytic leukemia CLL'},
#   {'label': 'Cancer',
#    'start': 164,
#    'end': 188,
#    'value': 'non-Hodgkin lymphoma NHL'},
#   {'label': 'Cancer',
#    'start': 168,
#    'end': 188,
#    'value': 'Hodgkin lymphoma NHL'},
#   {'label': 'Cancer',
#    'start': 189,
#    'end': 209,
#    'value': 'Hodgkin lymphoma NHL'},
#   {'label': 'Cancer', 'start': 168, 'end': 184, 'value': 'Hodgkin lymphoma'},
#   {'label': 'Cancer', 'start': 189, 'end': 205, 'value': 'Hodgkin lymphoma'},
#   {'label': 'Cancer', 'start': 212, 'end': 228, 'value': 'Hodgkin lymphoma'},
#   {'label': 'Cancer',
#    'start': 230,
#    'end': 249,
#    'value': 'multiple myeloma MM'},
#   {'label': 'Cancer',
#    'start': 250,
#    'end': 278,
#    'value': 'myelodysplastic syndrome MDS'},
#   {'label': 'Cancer', 'start': 279, 'end': 293, 'value': 'AL amyloidosis'},
#   {'label': 'Cancer',
#    'start': 294,
#    'end': 317,
#    'value': 'diamond blackfan anemia'},
#   {'label': 'Cancer', 'start': 318, 'end': 331, 'value': 'myelofibrosis'},
#   {'label': 'Cancer',
#    'start': 341,
#    'end': 367,
#    'value': 'myeloproliferative disease'},
#   {'label': 'Cancer', 'start': 368, 'end': 386, 'value': 'sickle cell anemia'},
#   {'label': 'Cancer', 'start': 391, 'end': 402, 'value': 'thalassemia'}],
#  [{'label': 'Cancer', 'start': 35, 'end': 42, 'value': 'HPV p16'},
#   {'label': 'Cancer', 'start': 47, 'end': 52, 'value': 'PD-L1'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 11,
#    'value': 'ECOG status'},
#   {'label': 'lower_bound', 'start': 12, 'end': 13, 'value': '3'},
#   {'label': 'upper_bound', 'start': 17, 'end': 18, 'value': '4'}],
#  [{'label': 'chronic_disease',
#    'start': 28,
#    'end': 79,
#    'value': 'pre-existing medical psychiatric or other condition'}],
#  [{'label': 'chronic_disease',
#    'start': 9,
#    'end': 27,
#    'value': 'medical conditions'},
#   {'label': 'chronic_disease',
#    'start': 78,
#    'end': 97,
#    'value': 'orthopedic injuries'},
#   {'label': 'chronic_disease',
#    'start': 133,
#    'end': 151,
#    'value': 'pulmonary diseases'}],
#  [{'label': 'Cancer', 'start': 35, 'end': 46, 'value': 'lung cancer'}],
#  [{'label': 'chronic_disease',
#    'start': 8,
#    'end': 24,
#    'value': 'cord compression'},
#   {'label': 'chronic_disease',
#    'start': 30,
#    'end': 55,
#    'value': 'syrinx in the spinal cord'},
#   {'label': 'chronic_disease',
#    'start': 77,
#    'end': 96,
#    'value': 'spinal cord disease'},
#   {'label': 'chronic_disease',
#    'start': 105,
#    'end': 120,
#    'value': 'spinal stenosis'},
#   {'label': 'chronic_disease',
#    'start': 121,
#    'end': 133,
#    'value': 'spina bifida'},
#   {'label': 'chronic_disease',
#    'start': 137,
#    'end': 160,
#    'value': 'herniated cervical disk'}],
#  [{'label': 'gender', 'start': 0, 'end': 13, 'value': 'nursing woman'}],
#  [{'label': 'gender', 'start': 0, 'end': 14, 'value': 'pregnant women'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 21,
#    'value': 'myocardial infarction'},
#   {'label': 'lower_bound',
#    'start': 24,
#    'end': 50,
#    'value': '6 months before enrollment'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 18,
#    'value': 'Sickle cell anemia'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 24,
#    'value': 'Myelodysplastic syndrome'}],
#  [{'label': 'treatment',
#    'start': 27,
#    'end': 46,
#    'value': 'corneal transplants'},
#   {'label': 'treatment', 'start': 47, 'end': 59, 'value': 'cadaver skin'},
#   {'label': 'treatment', 'start': 63, 'end': 79, 'value': 'bone transplants'}],
#  [{'label': 'treatment',
#    'start': 0,
#    'end': 28,
#    'value': 'Lovaza prescription fish oil'},
#   {'label': 'treatment', 'start': 0, 'end': 6, 'value': 'Lovaza'},
#   {'label': 'treatment', 'start': 55, 'end': 61, 'value': 'Lovaza'},
#   {'label': 'clinical_variable', 'start': 66, 'end': 73, 'value': '3 weeks'}],
#  [{'label': 'chronic_disease',
#    'start': 12,
#    'end': 29,
#    'value': 'cardiac condition'},
#   {'label': 'chronic_disease', 'start': 31, 'end': 37, 'value': 'asthma'},
#   {'label': 'chronic_disease',
#    'start': 38,
#    'end': 67,
#    'value': 'obstructive pulmonary disease'},
#   {'label': 'chronic_disease',
#    'start': 68,
#    'end': 84,
#    'value': 'seizure disorder'},
#   {'label': 'chronic_disease',
#    'start': 85,
#    'end': 105,
#    'value': 'urinary incontinence'},
#   {'label': 'chronic_disease',
#    'start': 113,
#    'end': 133,
#    'value': 'peptic ulcer disease'},
#   {'label': 'treatment',
#    'start': 144,
#    'end': 161,
#    'value': 'concurrent NSAIDs'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 28,
#    'value': 'Karnofsky performance status'},
#   {'label': 'lower_bound', 'start': 32, 'end': 35, 'value': '70%'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 18,
#    'value': 'Grade 4 - Fibrosis'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 33,
#    'value': 'Follicular 17-hydroxyprogesterone'},
#   {'label': 'upper_bound', 'start': 36, 'end': 45, 'value': '300 ng/dl'},
#   {'label': 'clinical_variable',
#    'start': 80,
#    'end': 110,
#    'value': 'congenital adrenal hyperplasia'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 24,
#    'value': 'Current oral steroid use'},
#   {'label': 'upper_bound',
#    'start': 27,
#    'end': 56,
#    'value': '4 weeks prior to registration'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 12, 'value': 'Not pregnant'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 36,
#    'value': 'History of DVT or pulmonary embolism'},
#   {'label': 'upper_bound', 'start': 44, 'end': 52, 'value': '6 months'}],
#  [{'label': 'chronic_disease', 'start': 0, 'end': 11, 'value': 'Hepatitis C'},
#   {'label': 'treatment', 'start': 21, 'end': 32, 'value': 'donor liver'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 19,
#    'value': 'Renal insufficiency'},
#   {'label': 'clinical_variable',
#    'start': 20,
#    'end': 30,
#    'value': 'creatinine'},
#   {'label': 'upper_bound', 'start': 33, 'end': 42, 'value': '1.5 mg/dL'}],
#  [{'label': 'treatment',
#    'start': 22,
#    'end': 43,
#    'value': 'investigational agent'},
#   {'label': 'upper_bound',
#    'start': 47,
#    'end': 80,
#    'value': '30 days prior to pre-registration'}],
#  [{'label': 'treatment', 'start': 31, 'end': 39, 'value': 'warfarin'},
#   {'label': 'clinical_variable',
#    'start': 44,
#    'end': 55,
#    'value': 'prophylaxis'},
#   {'label': 'clinical_variable',
#    'start': 59,
#    'end': 82,
#    'value': 'treatment of thrombosis'},
#   {'label': 'clinical_variable',
#    'start': 83,
#    'end': 93,
#    'value': 'INR values'}],
#  [{'label': 'age', 'start': 21, 'end': 29, 'value': '18 years'},
#   {'label': 'lower_bound', 'start': 21, 'end': 23, 'value': '18'}],
#  [{'label': 'chronic_disease',
#    'start': 24,
#    'end': 54,
#    'value': 'cerebral vascular event stroke'},
#   {'label': 'chronic_disease',
#    'start': 58,
#    'end': 83,
#    'value': 'transient ischemic attack'},
#   {'label': 'chronic_disease',
#    'start': 86,
#    'end': 123,
#    'value': 'unstable angina myocardial infarction'},
#   {'label': 'chronic_disease',
#    'start': 127,
#    'end': 143,
#    'value': 'cardiac symptoms'},
#   {'label': 'chronic_disease',
#    'start': 154,
#    'end': 178,
#    'value': 'congestive heart failure'},
#   {'label': 'clinical_variable',
#    'start': 195,
#    'end': 227,
#    'value': 'New York Heart Association Class'},
#   {'label': 'upper_bound', 'start': 243, 'end': 251, 'value': '6 months'}],
#  [{'label': 'treatment',
#    'start': 13,
#    'end': 38,
#    'value': 'breast conserving surgery'},
#   {'label': 'treatment', 'start': 39, 'end': 49, 'value': 'lumpectomy'},
#   {'label': 'treatment', 'start': 54, 'end': 63, 'value': 'radiation'}],
#  [{'label': 'age', 'start': 0, 'end': 3, 'value': 'age'},
#   {'label': 'lower_bound', 'start': 6, 'end': 8, 'value': '49'}],
#  [{'label': 'treatment', 'start': 15, 'end': 25, 'value': 'medication'},
#   {'label': 'clinical_variable',
#    'start': 43,
#    'end': 76,
#    'value': 'potentially dangerous interaction'},
#   {'label': 'treatment', 'start': 82, 'end': 93, 'value': 'propranolol'}],
#  [{'label': 'treatment', 'start': 27, 'end': 33, 'value': 'rIX-FP'},
#   {'label': 'clinical_variable',
#    'start': 38,
#    'end': 65,
#    'value': '100 EDs single-dose cohorts'},
#   {'label': 'clinical_variable',
#    'start': 73,
#    'end': 100,
#    'value': '50 EDs repeated-dose cohort'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 9, 'value': 'Bilirubin'},
#   {'label': 'upper_bound', 'start': 10, 'end': 21, 'value': '2 x the ULN'}],
#  [{'label': 'chronic_disease',
#    'start': 11,
#    'end': 26,
#    'value': 'organ allograft'},
#   {'label': 'clinical_variable',
#    'start': 37,
#    'end': 55,
#    'value': 'corneal transplant'}],
#  [{'label': 'treatment',
#    'start': 0,
#    'end': 40,
#    'value': 'Autologous stem cell transplantation SCT'},
#   {'label': 'clinical_variable',
#    'start': 48,
#    'end': 76,
#    'value': '100 days prior to study drug'},
#   {'label': 'treatment', 'start': 90, 'end': 104, 'value': 'allogeneic SCT'},
#   {'label': 'treatment',
#    'start': 108,
#    'end': 135,
#    'value': 'solid organ transplantation'}],
#  [{'label': 'diagnosis', 'start': 13, 'end': 28, 'value': 'type 2 diabetes'}],
#  [{'label': 'history', 'start': 14, 'end': 31, 'value': 'active malignancy'},
#   {'label': 'upper_bound', 'start': 43, 'end': 55, 'value': 'last 3 years'}],
#  [{'label': 'clinical_variable',
#    'start': 4,
#    'end': 24,
#    'value': 'adverse events Grade'},
#   {'label': 'upper_bound', 'start': 25, 'end': 28, 'value': '> 1'},
#   {'label': 'treatment',
#    'start': 40,
#    'end': 96,
#    'value': 'prior therapies chemotherapy radiotherapy and/or surgery'},
#   {'label': 'clinical_variable',
#    'start': 126,
#    'end': 134,
#    'value': 'alopecia'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 27,
#    'value': 'Pre-bronchodilator 50% FEV1'},
#   {'label': 'lower_bound', 'start': 31, 'end': 37, 'value': '< 85 %'},
#   {'label': 'clinical_variable',
#    'start': 45,
#    'end': 67,
#    'value': 'predicted normal value'},
#   {'label': 'clinical_variable', 'start': 76, 'end': 83, 'value': 'patient'},
#   {'label': 'clinical_variable',
#    'start': 90,
#    'end': 117,
#    'value': 'withholding bronchodilators'},
#   {'label': 'clinical_variable',
#    'start': 126,
#    'end': 135,
#    'value': 'Visit 101'},
#   {'label': 'clinical_variable',
#    'start': 158,
#    'end': 174,
#    'value': 'ATS/ERS criteria'}],
#  [{'label': 'treatment', 'start': 21, 'end': 30, 'value': 'cetuximab'},
#   {'label': 'clinical_variable',
#    'start': 35,
#    'end': 52,
#    'value': 'incurable disease'}],
#  [{'label': 'treatment',
#    'start': 28,
#    'end': 56,
#    'value': 'herbal alternative medicines'}],
#  [{'label': 'age', 'start': 4, 'end': 12, 'value': '21 years'}],
#  [{'label': 'treatment',
#    'start': 33,
#    'end': 58,
#    'value': 'intravesical chemotherapy'}],
#  [{'label': 'clinical_variable',
#    'start': 65,
#    'end': 75,
#    'value': 'medication'},
#   {'label': 'clinical_variable',
#    'start': 79,
#    'end': 97,
#    'value': 'precautionary list'},
#   {'label': 'clinical_variable',
#    'start': 104,
#    'end': 117,
#    'value': 'nitroglycerin'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 27,
#    'value': 'Severe aortic regurgitation'},
#   {'label': 'lower_bound', 'start': 30, 'end': 31, 'value': '3'}],
#  [{'label': 'clinical_variable',
#    'start': 10,
#    'end': 42,
#    'value': 'psychiatric or medical condition'},
#   {'label': 'treatment',
#    'start': 92,
#    'end': 116,
#    'value': 'interfere with treatment'}],
#  [{'label': 'age', 'start': 18, 'end': 20, 'value': '17'},
#   {'label': 'lower_bound', 'start': 18, 'end': 20, 'value': '17'}],
#  [{'label': 'Cancer', 'start': 9, 'end': 11, 'value': 'FL'},
#   {'label': 'clinical_variable',
#    'start': 36,
#    'end': 64,
#    'value': 'histopathologic confirmation'}],
#  [{'label': 'age', 'start': 4, 'end': 28, 'value': '16 years of age or older'},
#   {'label': 'clinical_variable', 'start': 33, 'end': 39, 'value': 'weighs'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 62,
#    'value': 'Interval from start of initial radiation therapy to enrollment'},
#   {'label': 'lower_bound', 'start': 65, 'end': 73, 'value': '9 months'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 29,
#    'value': 'diabetes requiring medication'}],
#  [{'label': 'contraception_consent',
#    'start': 0,
#    'end': 23,
#    'value': 'Not pregnant or nursing'},
#   {'label': 'contraception_consent',
#    'start': 28,
#    'end': 165,
#    'value': 'report using oral, implant, patch, ring, IUD, injection, or barrier contraceptives or report being surgically sterile, or post menopausal'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 14, 'value': 'Pregnant women'}],
#  [{'label': 'chronic_disease', 'start': 13, 'end': 24, 'value': 'hepatitis B'},
#   {'label': 'chronic_disease', 'start': 25, 'end': 36, 'value': 'hepatitis B'},
#   {'label': 'chronic_disease', 'start': 43, 'end': 54, 'value': 'hepatitis B'},
#   {'label': 'chronic_disease',
#    'start': 95,
#    'end': 106,
#    'value': 'hepatitis C'},
#   {'label': 'chronic_disease',
#    'start': 113,
#    'end': 124,
#    'value': 'hepatitis C'},
#   {'label': 'clinical_variable',
#    'start': 43,
#    'end': 91,
#    'value': 'hepatitis B virus surface antigen HBsAg reactive'},
#   {'label': 'clinical_variable',
#    'start': 113,
#    'end': 179,
#    'value': 'hepatitis C virus HCV ribonucleic acid RNA qualitative is detected'}],
#  [{'label': 'clinical_variable',
#    'start': 19,
#    'end': 63,
#    'value': 'pretreatment calculated creatinine clearance'},
#   {'label': 'lower_bound',
#    'start': 67,
#    'end': 82,
#    'value': '>= 50 mL/minute'}],
#  [{'label': 'Cancer',
#    'start': 0,
#    'end': 25,
#    'value': 'Second primary malignancy'},
#   {'label': 'Cancer',
#    'start': 69,
#    'end': 100,
#    'value': 'in situ carcinoma of the cervix'},
#   {'label': 'Cancer',
#    'start': 101,
#    'end': 158,
#    'value': 'adequately treated non-melanomatous carcinoma of the skin'},
#   {'label': 'Cancer',
#    'start': 162,
#    'end': 245,
#    'value': 'other malignancy treated at least 5 years previously with no evidence of recurrence'}],
#  [{'label': 'treatment',
#    'start': 22,
#    'end': 52,
#    'value': 'iodinated intravenous contrast'},
#   {'label': 'clinical_variable',
#    'start': 66,
#    'end': 88,
#    'value': 'radiographic procedure'},
#   {'label': 'upper_bound',
#    'start': 89,
#    'end': 126,
#    'value': 'within 3 months of study registration'}],
#  [{'label': 'chronic_disease', 'start': 51, 'end': 57, 'value': 'cancer'},
#   {'label': 'chronic_disease',
#    'start': 61,
#    'end': 88,
#    'value': 'acute myocardial infarction'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 30,
#    'value': 'Aspartate aminotransferase AST'},
#   {'label': 'clinical_variable',
#    'start': 35,
#    'end': 63,
#    'value': 'alanine aminotransferase ALT'},
#   {'label': 'upper_bound',
#    'start': 66,
#    'end': 109,
#    'value': '3 x the institutional upper limit of normal'}],
#  [{'label': 'clinical_variable',
#    'start': 6,
#    'end': 33,
#    'value': 'hepatitis B surface antigen'}],
#  [{'label': 'age', 'start': 34, 'end': 37, 'value': 'age'},
#   {'label': 'lower_bound', 'start': 16, 'end': 17, 'value': '2'},
#   {'label': 'upper_bound', 'start': 22, 'end': 24, 'value': '40'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 24,
#    'value': 'Epilepsy partial seizure'}],
#  [{'label': 'contraception_consent',
#    'start': 75,
#    'end': 124,
#    'value': 'effective > 90% reliability form of contraception'},
#   {'label': 'upper_bound', 'start': 87, 'end': 90, 'value': '90%'},
#   {'label': 'upper_bound', 'start': 125, 'end': 128, 'value': '90%'},
#   {'label': 'contraception_consent',
#    'start': 184,
#    'end': 240,
#    'value': 'for 4 weeks following the last study drug administration'}],
#  [{'label': 'treatment', 'start': 11, 'end': 26, 'value': 'vascular access'},
#   {'label': 'treatment', 'start': 38, 'end': 48, 'value': 'study drug'},
#   {'label': 'treatment', 'start': 105, 'end': 115, 'value': 'study drug'},
#   {'label': 'treatment', 'start': 62, 'end': 76, 'value': 'blood sampling'},
#   {'label': 'treatment',
#    'start': 105,
#    'end': 124,
#    'value': 'study drug infusion'}],
#  [{'label': 'chronic_disease', 'start': 10, 'end': 21, 'value': 'sleep apnea'},
#   {'label': 'clinical_variable', 'start': 0, 'end': 9, 'value': 'Untreated'}],
#  [{'label': 'chronic_disease',
#    'start': 14,
#    'end': 41,
#    'value': 'secondary headache disorder'},
#   {'label': 'clinical_variable',
#    'start': 48,
#    'end': 59,
#    'value': 'brain tumor'}],
#  [{'label': 'treatment',
#    'start': 6,
#    'end': 27,
#    'value': 'bilateral orchiectomy'},
#   {'label': 'treatment', 'start': 0, 'end': 5, 'value': 'Prior'}],
#  [{'label': 'chronic_disease',
#    'start': 11,
#    'end': 33,
#    'value': 'drug or alcohol abuser'},
#   {'label': 'chronic_disease',
#    'start': 43,
#    'end': 65,
#    'value': 'psychological disorder'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 21,
#    'value': 'Serum total bilirubin'},
#   {'label': 'upper_bound',
#    'start': 24,
#    'end': 63,
#    'value': '1.5 times the upper limit of normal ULN'}],
#  [{'label': 'treatment',
#    'start': 76,
#    'end': 118,
#    'value': 'highly active antiretroviral therapy HAART'},
#   {'label': 'clinical_variable',
#    'start': 130,
#    'end': 139,
#    'value': 'CD4 count'},
#   {'label': 'lower_bound',
#    'start': 143,
#    'end': 163,
#    'value': '200 cells/microliter'},
#   {'label': 'upper_bound',
#    'start': 177,
#    'end': 206,
#    'value': '30 days prior to registration'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'total bilirubin'},
#   {'label': 'upper_bound',
#    'start': 19,
#    'end': 52,
#    'value': 'upper normal institutional limits'},
#   {'label': 'chronic_disease',
#    'start': 78,
#    'end': 95,
#    'value': "Gilbert's disease"},
#   {'label': 'clinical_variable',
#    'start': 121,
#    'end': 151,
#    'value': 'elevated serum bilirubin level'}],
#  [{'label': 'treatment',
#    'start': 3,
#    'end': 28,
#    'value': 'prior RAI therapy therapy'},
#   {'label': 'upper_bound',
#    'start': 42,
#    'end': 98,
#    'value': '6 months prior to initiation of therapy on this protocol'}],
#  [{'label': 'pregnancy',
#    'start': 4,
#    'end': 27,
#    'value': 'wish to become pregnant'},
#   {'label': 'clinical_variable',
#    'start': 39,
#    'end': 51,
#    'value': 'study period'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 9, 'value': 'lactating'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 28,
#    'value': 'Poorly controlled depression'}],
#  [{'label': 'gender', 'start': 0, 'end': 4, 'value': 'Male'},
#   {'label': 'gender', 'start': 9, 'end': 16, 'value': 'females'}],
#  [{'label': 'age', 'start': 0, 'end': 4, 'value': 'ages'},
#   {'label': 'lower_bound', 'start': 5, 'end': 7, 'value': '18'},
#   {'label': 'upper_bound', 'start': 11, 'end': 13, 'value': '70'}],
#  [{'label': 'technology_access',
#    'start': 9,
#    'end': 22,
#    'value': 'venous access'},
#   {'label': 'clinical_variable',
#    'start': 39,
#    'end': 52,
#    'value': 'blood drawing'},
#   {'label': 'clinical_variable',
#    'start': 57,
#    'end': 72,
#    'value': '5 day infusions'},
#   {'label': 'clinical_variable',
#    'start': 78,
#    'end': 92,
#    'value': 'lymphapheresis'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 58,
#    'value': 'Eastern Cooperative Oncology Group ECOG performance status'},
#   {'label': 'clinical_variable', 'start': 59, 'end': 61, 'value': 'PS'},
#   {'label': 'lower_bound', 'start': 62, 'end': 63, 'value': '0'},
#   {'label': 'upper_bound', 'start': 64, 'end': 65, 'value': '1'},
#   {'label': 'clinical_variable', 'start': 70, 'end': 71, 'value': '2'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 19,
#    'value': 'Insomnia complaints'},
#   {'label': 'lower_bound', 'start': 24, 'end': 25, 'value': '6'},
#   {'label': 'clinical_variable', 'start': 27, 'end': 33, 'value': 'months'}],
#  [{'label': 'clinical_variable',
#    'start': 20,
#    'end': 34,
#    'value': 'semen donation'},
#   {'label': 'clinical_variable',
#    'start': 78,
#    'end': 91,
#    'value': 'study therapy'},
#   {'label': 'lower_bound', 'start': 50, 'end': 52, 'value': '28'},
#   {'label': 'clinical_variable', 'start': 53, 'end': 57, 'value': 'days'}],
#  [{'label': 'clinical_variable',
#    'start': 24,
#    'end': 36,
#    'value': 'hysterectomy'},
#   {'label': 'clinical_variable',
#    'start': 45,
#    'end': 62,
#    'value': 'benign indication'},
#   {'label': 'clinical_variable',
#    'start': 92,
#    'end': 117,
#    'value': 'abnormal uterine bleeding'},
#   {'label': 'clinical_variable',
#    'start': 118,
#    'end': 129,
#    'value': 'menorrhagia'},
#   {'label': 'clinical_variable',
#    'start': 130,
#    'end': 146,
#    'value': 'uterine fibroids'},
#   {'label': 'clinical_variable',
#    'start': 147,
#    'end': 158,
#    'value': 'adenomyosis'},
#   {'label': 'clinical_variable',
#    'start': 159,
#    'end': 170,
#    'value': 'pelvic pain'},
#   {'label': 'clinical_variable',
#    'start': 171,
#    'end': 183,
#    'value': 'dysmenorrhea'},
#   {'label': 'clinical_variable',
#    'start': 184,
#    'end': 205,
#    'value': 'pelvic organ prolapse'},
#   {'label': 'clinical_variable',
#    'start': 209,
#    'end': 222,
#    'value': 'endometriosis'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 48,
#    'value': 'uncontrolled bacterial viral or fungal infection'},
#   {'label': 'treatment',
#    'start': 49,
#    'end': 76,
#    'value': 'currently taking medication'},
#   {'label': 'clinical_variable',
#    'start': 86,
#    'end': 124,
#    'value': 'progression or no clinical improvement'},
#   {'label': 'clinical_variable',
#    'start': 128,
#    'end': 146,
#    'value': 'time of enrollment'}],
#  [{'label': 'gender', 'start': 0, 'end': 5, 'value': 'Women'},
#   {'label': 'pregnancy',
#    'start': 9,
#    'end': 31,
#    'value': 'childbearing potential'},
#   {'label': 'clinical_variable',
#    'start': 44,
#    'end': 67,
#    'value': 'negative pregnancy test'}],
#  [{'label': 'treatment', 'start': 26, 'end': 32, 'value': 'biopsy'},
#   {'label': 'clinical_variable',
#    'start': 38,
#    'end': 53,
#    'value': 'site of disease'},
#   {'label': 'clinical_variable',
#    'start': 70,
#    'end': 85,
#    'value': 'site of disease'},
#   {'label': 'clinical_variable',
#    'start': 89,
#    'end': 100,
#    'value': 'lung/pleura'},
#   {'label': 'clinical_variable', 'start': 102, 'end': 106, 'value': 'bone'},
#   {'label': 'clinical_variable', 'start': 118, 'end': 124, 'value': 'unsafe'},
#   {'label': 'clinical_variable',
#    'start': 132,
#    'end': 154,
#    'value': 'principal investigator'}],
#  [{'label': 'clinical_variable',
#    'start': 3,
#    'end': 21,
#    'value': 'distant metastases'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 19,
#    'value': 'Insulin requirement'},
#   {'label': 'clinical_variable',
#    'start': 23,
#    'end': 37,
#    'value': '> 1.0 U/kg/day'},
#   {'label': 'clinical_variable',
#    'start': 42,
#    'end': 58,
#    'value': '> 60 U/day total'},
#   {'label': 'clinical_variable',
#    'start': 62,
#    'end': 72,
#    'value': '< 15 U/day'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 17,
#    'value': 'Residual symptoms'},
#   {'label': 'clinical_variable',
#    'start': 39,
#    'end': 50,
#    'value': 'total score'},
#   {'label': 'clinical_variable', 'start': 68, 'end': 73, 'value': 'PANSS'},
#   {'label': 'clinical_variable',
#    'start': 78,
#    'end': 97,
#    'value': 'Visit 1 evaluations'},
#   {'label': 'lower_bound', 'start': 54, 'end': 57, 'value': '110'},
#   {'label': 'lower_bound', 'start': 62, 'end': 64, 'value': '60'}],
#  [{'label': 'clinical_variable',
#    'start': 12,
#    'end': 23,
#    'value': 'probability'},
#   {'label': 'clinical_variable',
#    'start': 27,
#    'end': 40,
#    'value': 'BRCA mutation'},
#   {'label': 'clinical_variable', 'start': 44, 'end': 51, 'value': 'BRCAPRO'},
#   {'label': 'clinical_variable',
#    'start': 55,
#    'end': 68,
#    'value': 'similar model'},
#   {'label': 'lower_bound', 'start': 0, 'end': 3, 'value': '10%'}],
#  [{'label': 'treatment',
#    'start': 9,
#    'end': 30,
#    'value': 'therapeutic radiation'},
#   {'label': 'clinical_variable', 'start': 38, 'end': 44, 'value': 'region'},
#   {'label': 'clinical_variable',
#    'start': 52,
#    'end': 61,
#    'value': 'study eye'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 16,
#    'value': 'Metallic implant'}],
#  [{'label': 'allergy_name', 'start': 0, 'end': 10, 'value': 'Fluoxetine'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 19,
#    'value': 'Therapy-related MDS'},
#   {'label': 'clinical_variable', 'start': 16, 'end': 19, 'value': 'MDS'},
#   {'label': 'clinical_variable', 'start': 20, 'end': 23, 'value': 'MDS'},
#   {'label': 'clinical_variable', 'start': 53, 'end': 56, 'value': 'MDS'},
#   {'label': 'treatment',
#    'start': 82,
#    'end': 103,
#    'value': 'systemic chemotherapy'},
#   {'label': 'treatment', 'start': 111, 'end': 120, 'value': 'radiation'},
#   {'label': 'treatment', 'start': 125, 'end': 135, 'value': 'malignancy'}],
#  [{'label': 'clinical_variable',
#    'start': 7,
#    'end': 20,
#    'value': 'weight change'},
#   {'label': 'clinical_variable',
#    'start': 21,
#    'end': 34,
#    'value': '+/- 25 pounds'},
#   {'label': 'clinical_variable', 'start': 38, 'end': 44, 'value': '1 year'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 33,
#    'value': 'Active varicella zoster infection'}],
#  [{'label': 'clinical_variable',
#    'start': 6,
#    'end': 25,
#    'value': 'fluid resuscitation'},
#   {'label': 'clinical_variable',
#    'start': 26,
#    'end': 62,
#    'value': 'Clinical definition of kidney damage'}],
#  [{'label': 'treatment',
#    'start': 6,
#    'end': 25,
#    'value': 'monoclonal antibody'},
#   {'label': 'clinical_variable',
#    'start': 33,
#    'end': 55,
#    'value': '4 weeks prior to study'}],
#  [{'label': 'chronic_disease',
#    'start': 30,
#    'end': 52,
#    'value': 'carotid artery disease'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 32,
#    'value': 'Hypocitraturic CaP stone formers'}],
#  [{'label': 'treatment',
#    'start': 13,
#    'end': 67,
# ...
#    'end': 90,
#    'value': 'mutagenic effects'},
#   {'label': 'clinical_variable',
#    'start': 96,
#    'end': 112,
#    'value': 'developing fetus'},
#   {'label': 'clinical_variable',
#    'start': 116,
#    'end': 123,
#    'value': 'newborn'}],
#  [{'label': 'Cancer',
#    'start': 0,
#    'end': 29,
#    'value': 'Infiltrating ductal carcinoma'},
#   {'label': 'Cancer', 'start': 33, 'end': 37, 'value': 'DCIS'},
#   {'label': 'clinical_variable', 'start': 38, 'end': 43, 'value': 'stage'},
#   {'label': 'clinical_variable', 'start': 44, 'end': 46, 'value': 'T0'},
#   {'label': 'clinical_variable', 'start': 47, 'end': 49, 'value': 'T1'},
#   {'label': 'clinical_variable', 'start': 54, 'end': 56, 'value': 'T2'},
#   {'label': 'upper_bound', 'start': 79, 'end': 85, 'value': '3.0 cm'},
#   {'label': 'clinical_variable', 'start': 86, 'end': 88, 'value': 'N0'},
#   {'label': 'clinical_variable', 'start': 93, 'end': 95, 'value': 'M0'}],
#  [{'label': 'Cancer',
#    'start': 19,
#    'end': 47,
#    'value': 'non-melanomatous skin cancer'},
#   {'label': 'Cancer', 'start': 51, 'end': 66, 'value': 'lentigo maligna'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 35,
#    'value': 'Insulin dependent diabetes mellitus'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'total bilirubin'},
#   {'label': 'upper_bound',
#    'start': 16,
#    'end': 57,
#    'value': '2.5 X institutional upper limit of normal'}],
#  [{'label': 'treatment', 'start': 19, 'end': 25, 'value': 'IV tPA'},
#   {'label': 'upper_bound',
#    'start': 26,
#    'end': 53,
#    'value': '> 3 hours from stroke onset'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 49,
#    'value': 'Hamilton Depression Rating Scale-24 HRSD-24 score'},
#   {'label': 'lower_bound', 'start': 70, 'end': 71, 'value': '8'},
#   {'label': 'upper_bound', 'start': 33, 'end': 35, 'value': '24'},
#   {'label': 'upper_bound', 'start': 41, 'end': 43, 'value': '24'},
#   {'label': 'upper_bound', 'start': 50, 'end': 52, 'value': '24'},
#   {'label': 'upper_bound', 'start': 58, 'end': 60, 'value': '24'},
#   {'label': 'upper_bound', 'start': 73, 'end': 75, 'value': '24'}],
#  [{'label': 'treatment', 'start': 0, 'end': 14, 'value': 'Surgery intent'},
#   {'label': 'upper_bound', 'start': 22, 'end': 29, 'value': '4 weeks'}],
#  [{'label': 'gender', 'start': 2, 'end': 8, 'value': 'female'},
#   {'label': 'contraception_consent',
#    'start': 12,
#    'end': 34,
#    'value': 'childbearing potential'},
#   {'label': 'clinical_variable',
#    'start': 40,
#    'end': 61,
#    'value': 'sexually mature woman'},
#   {'label': 'clinical_variable',
#    'start': 89,
#    'end': 101,
#    'value': 'hysterectomy'},
#   {'label': 'clinical_variable',
#    'start': 105,
#    'end': 127,
#    'value': 'bilateral oophorectomy'},
#   {'label': 'clinical_variable',
#    'start': 146,
#    'end': 170,
#    'value': 'naturally postmenopausal'},
#   {'label': 'lower_bound',
#    'start': 184,
#    'end': 205,
#    'value': '24 consecutive months'},
#   {'label': 'lower_bound',
#    'start': 256,
#    'end': 277,
#    'value': '24 consecutive months'},
#   {'label': 'clinical_variable', 'start': 220, 'end': 226, 'value': 'menses'},
#   {'label': 'lower_bound',
#    'start': 246,
#    'end': 277,
#    'value': 'preceding 24 consecutive months'}],
#  [{'label': 'chronic_disease',
#    'start': 27,
#    'end': 57,
#    'value': 'uncontrolled severe infections'}],
#  [{'label': 'clinical_variable', 'start': 13, 'end': 22, 'value': 'diagnosis'},
#   {'label': 'clinical_variable',
#    'start': 26,
#    'end': 57,
#    'value': 'PAH isolated left heart disease'},
#   {'label': 'clinical_variable',
#    'start': 61,
#    'end': 111,
#    'value': 'lung disease chronic obstructive pulmonary disease'},
#   {'label': 'clinical_variable',
#    'start': 115,
#    'end': 140,
#    'value': 'interstitial lung disease'},
#   {'label': 'clinical_variable', 'start': 144, 'end': 149, 'value': 'CTEPH'},
#   {'label': 'clinical_variable',
#    'start': 156,
#    'end': 185,
#    'value': 'established clinical criteria'}],
#  [{'label': 'treatment',
#    'start': 12,
#    'end': 30,
#    'value': 'initiate treatment'},
#   {'label': 'treatment', 'start': 36, 'end': 47, 'value': 'doxorubicin'},
#   {'label': 'clinical_variable',
#    'start': 48,
#    'end': 61,
#    'value': 'starting dose'},
#   {'label': 'clinical_variable', 'start': 62, 'end': 70, 'value': '75 mg/m2'},
#   {'label': 'clinical_variable',
#    'start': 74,
#    'end': 86,
#    'value': 'routine care'}],
#  [{'label': 'chronic_disease',
#    'start': 27,
#    'end': 51,
#    'value': 'substance abuse disorder'}],
#  [],
#  [{'label': 'clinical_variable',
#    'start': 74,
#    'end': 99,
#    'value': 'post-excision mammography'}],
#  [{'label': 'clinical_variable',
#    'start': 27,
#    'end': 44,
#    'value': 'organ involvement'},
#   {'label': 'clinical_variable',
#    'start': 45,
#    'end': 66,
#    'value': 'renal angiomyolipomas'},
#   {'label': 'clinical_variable',
#    'start': 67,
#    'end': 84,
#    'value': 'chylous effusions'},
#   {'label': 'clinical_variable',
#    'start': 85,
#    'end': 105,
#    'value': 'lymphangioleiomyomas'}],
#  [{'label': 'clinical_variable', 'start': 25, 'end': 33, 'value': 'seizures'}],
#  [{'label': 'treatment', 'start': 18, 'end': 28, 'value': 'amifostine'},
#   {'label': 'treatment',
#    'start': 40,
#    'end': 62,
#    'value': 'abdominal radiotherapy'},
#   {'label': 'treatment',
#    'start': 81,
#    'end': 109,
#    'value': 'quinolone antibiotic therapy'}],
#  [{'label': 'clinical_variable', 'start': 11, 'end': 19, 'value': 'ambulate'},
#   {'label': 'clinical_variable',
#    'start': 29,
#    'end': 48,
#    'value': 'household distances'},
#   {'label': 'lower_bound', 'start': 49, 'end': 53, 'value': '50ft'}],
#  [{'label': 'age', 'start': 9, 'end': 11, 'value': '18'},
#   {'label': 'lower_bound', 'start': 9, 'end': 11, 'value': '18'}],
#  [{'label': 'gender', 'start': 0, 'end': 4, 'value': 'Male'}],
#  [{'label': 'Cancer', 'start': 13, 'end': 27, 'value': 'CNS metastases'},
#   {'label': 'clinical_variable',
#    'start': 6,
#    'end': 27,
#    'value': 'active CNS metastases'}],
#  [{'label': 'clinical_variable', 'start': 15, 'end': 18, 'value': 'MAS'},
#   {'label': 'clinical_variable',
#    'start': 25,
#    'end': 34,
#    'value': '98-D-0145'}],
#  [{'label': 'treatment',
#    'start': 52,
#    'end': 85,
#    'value': 'standard neoadjuvant chemotherapy'},
#   {'label': 'clinical_variable',
#    'start': 103,
#    'end': 116,
#    'value': 'anthracycline'},
#   {'label': 'clinical_variable',
#    'start': 124,
#    'end': 144,
#    'value': 'taxane-based regimen'},
#   {'label': 'lower_bound', 'start': 41, 'end': 48, 'value': '8 weeks'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 22,
#    'value': 'bone marrow metastases'},
#   {'label': 'clinical_variable',
#    'start': 28,
#    'end': 59,
#    'value': 'high urine catecholamine levels'}],
#  [{'label': 'chronic_disease', 'start': 0, 'end': 12, 'value': 'Osteoporosis'},
#   {'label': 'clinical_variable',
#    'start': 16,
#    'end': 31,
#    'value': 'recent fracture'},
#   {'label': 'clinical_variable', 'start': 39, 'end': 42, 'value': 'hip'},
#   {'label': 'clinical_variable',
#    'start': 46,
#    'end': 59,
#    'value': 'spinal joints'}],
#  [{'label': 'clinical_variable',
#    'start': 19,
#    'end': 43,
#    'value': 'bilateral inguinal herna'},
#   {'label': 'treatment',
#    'start': 48,
#    'end': 67,
#    'value': 'laparoscopic repair'}],
#  [{'label': 'treatment',
#    'start': 0,
#    'end': 24,
#    'value': 'Corticosteroid injection'},
#   {'label': 'clinical_variable',
#    'start': 28,
#    'end': 42,
#    'value': 'treatment site'},
#   {'label': 'lower_bound', 'start': 43, 'end': 57, 'value': 'within 1 month'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 23,
#    'value': 'ECOG Performance Status'},
#   {'label': 'lower_bound', 'start': 24, 'end': 25, 'value': '0'},
#   {'label': 'upper_bound', 'start': 27, 'end': 28, 'value': '1'}],
#  [{'label': 'allergy_name',
#    'start': 31,
#    'end': 47,
#    'value': 'dextromethorphan'},
#   {'label': 'allergy_name', 'start': 48, 'end': 57, 'value': 'vitamin A'},
#   {'label': 'allergy_name', 'start': 61, 'end': 73, 'value': 'isotretinoin'}],
#  [{'label': 'treatment',
#    'start': 20,
#    'end': 56,
#    'value': 'investigational drug or device study'},
#   {'label': 'lower_bound',
#    'start': 196,
#    'end': 219,
#    'value': 'within the past 6 weeks'}],
#  [{'label': 'allergy_name',
#    'start': 21,
#    'end': 41,
#    'value': 'conductive hydrogels'}],
#  [{'label': 'chronic_disease',
#    'start': 10,
#    'end': 37,
#    'value': 'severe cognitive impairment'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 15,
#    'value': 'Current smoking'},
#   {'label': 'clinical_variable',
#    'start': 19,
#    'end': 37,
#    'value': 'history of smoking'},
#   {'label': 'clinical_variable',
#    'start': 45,
#    'end': 59,
#    'value': 'past 12 months'}],
#  [{'label': 'age', 'start': 4, 'end': 16, 'value': '18 year olds'}],
#  [{'label': 'chronic_disease',
#    'start': 14,
#    'end': 49,
#    'value': 'history of prior pelvic irradiation'}],
#  [{'label': 'clinical_variable',
#    'start': 14,
#    'end': 49,
#    'value': 'lifetime history of suicide attempt'},
#   {'label': 'clinical_variable',
#    'start': 63,
#    'end': 77,
#    'value': 'active attempt'},
#   {'label': 'clinical_variable',
#    'start': 79,
#    'end': 98,
#    'value': 'interrupted attempt'},
#   {'label': 'clinical_variable',
#    'start': 103,
#    'end': 118,
#    'value': 'aborted attempt'},
#   {'label': 'clinical_variable',
#    'start': 128,
#    'end': 145,
#    'value': 'suicidal ideation'},
#   {'label': 'clinical_variable',
#    'start': 153,
#    'end': 166,
#    'value': 'past 6 months'},
#   {'label': 'clinical_variable',
#    'start': 185,
#    'end': 208,
#    'value': "positive response 'Yes'"},
#   {'label': 'clinical_variable',
#    'start': 219,
#    'end': 229,
#    'value': 'Question 4'},
#   {'label': 'clinical_variable',
#    'start': 233,
#    'end': 243,
#    'value': 'Question 5'},
#   {'label': 'clinical_variable', 'start': 251, 'end': 257, 'value': 'C-SSRS'},
#   {'label': 'clinical_variable',
#    'start': 261,
#    'end': 270,
#    'value': 'Screening'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 3, 'value': 'AST'},
#   {'label': 'clinical_variable', 'start': 4, 'end': 7, 'value': 'ALT'},
#   {'label': 'upper_bound',
#    'start': 8,
#    'end': 41,
#    'value': '2 times upper limit of normal ULN'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 44,
#    'value': 'Human papillomavirus HPV 16-positive disease'},
#   {'label': 'clinical_variable', 'start': 48, 'end': 51, 'value': 'PCR'}],
#  [{'label': 'treatment', 'start': 43, 'end': 52, 'value': 'LY2606368'},
#   {'label': 'treatment', 'start': 62, 'end': 76, 'value': 'Chk inhibitors'}],
#  [{'label': 'clinical_variable',
#    'start': 25,
#    'end': 37,
#    'value': 'cannabis use'},
#   {'label': 'clinical_variable', 'start': 41, 'end': 46, 'value': 'urine'},
#   {'label': 'clinical_variable',
#    'start': 54,
#    'end': 69,
#    'value': 'screening visit'},
#   {'label': 'clinical_variable',
#    'start': 83,
#    'end': 141,
#    'value': 'Gas Chromatography GC Mass Spectrometry MS laboratory test'},
#   {'label': 'clinical_variable',
#    'start': 149,
#    'end': 165,
#    'value': 'clinic admission'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 13,
#    'value': 'schizophrenia'}],
#  [{'label': 'gender',
#    'start': 0,
#    'end': 31,
#    'value': 'women of childbearing potential'}],
#  [{'label': 'treatment',
#    'start': 21,
#    'end': 49,
#    'value': 'gonadal steroid preparations'},
#   {'label': 'lower_bound', 'start': 63, 'end': 70, 'value': '1 month'}],
#  [{'label': 'pregnancy', 'start': 0, 'end': 8, 'value': 'Pregnant'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 25,
#    'value': 'Absolute neutrophil count'},
#   {'label': 'lower_bound', 'start': 33, 'end': 42, 'value': '1,500/mcL'}],
#  [{'label': 'allergy_name', 'start': 42, 'end': 52, 'value': 'Everolimus'},
#   {'label': 'allergy_name', 'start': 62, 'end': 72, 'value': 'rapamycins'},
#   {'label': 'allergy_name', 'start': 73, 'end': 82, 'value': 'sirolimus'},
#   {'label': 'allergy_name', 'start': 86, 'end': 95, 'value': 'sirolimus'},
#   {'label': 'allergy_name', 'start': 83, 'end': 95, 'value': 'temsirolimus'}],
#  [{'label': 'chronic_disease',
#    'start': 23,
#    'end': 53,
#    'value': 'cardiac/cardiovascular disease'},
#   {'label': 'clinical_variable',
#    'start': 57,
#    'end': 77,
#    'value': 'pulmonary compromise'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 13,
#    'value': 'radiculopathy'}],
#  [{'label': 'age', 'start': 0, 'end': 8, 'value': '18 years'},
#   {'label': 'lower_bound', 'start': 19, 'end': 24, 'value': 'older'}],
#  [{'label': 'chronic_disease',
#    'start': 0,
#    'end': 22,
#    'value': 'Gastrointestinal Bleed'}],
#  [{'label': 'chronic_disease',
#    'start': 19,
#    'end': 51,
#    'value': 'human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable',
#    'start': 66,
#    'end': 93,
#    'value': 'active infectious hepatitis'},
#   {'label': 'clinical_variable', 'start': 95, 'end': 101, 'value': 'type A'}],
#  [{'label': 'gender', 'start': 0, 'end': 5, 'value': 'Women'},
#   {'label': 'clinical_variable',
#    'start': 18,
#    'end': 46,
#    'value': 'serious psychiatric symptoms'},
#   {'label': 'clinical_variable',
#    'start': 61,
#    'end': 78,
#    'value': 'CNO trained staff'}],
#  [{'label': 'clinical_variable',
#    'start': 18,
#    'end': 33,
#    'value': 'disease relapse'},
#   {'label': 'clinical_variable',
#    'start': 35,
#    'end': 46,
#    'value': 'active GVHD'},
#   {'label': 'clinical_variable',
#    'start': 50,
#    'end': 94,
#    'value': 'history of more than Stage 1 skin acute GVHD'},
#   {'label': 'clinical_variable',
#    'start': 95,
#    'end': 111,
#    'value': 'history of cGVHD'}],
#  [{'label': 'chronic_disease',
#    'start': 14,
#    'end': 29,
#    'value': 'thyroid disease'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 26,
#    'value': 'Immunocompromised patients'},
#   {'label': 'clinical_variable',
#    'start': 63,
#    'end': 122,
#    'value': 'serologically positive for human immunodeficiency virus HIV'},
#   {'label': 'clinical_variable',
#    'start': 131,
#    'end': 158,
#    'value': 'receiving antiviral therapy'}],
#  [{'label': 'clinical_variable',
#    'start': 16,
#    'end': 52,
#    'value': 'positive Hepatitis B surface antigen'},
#   {'label': 'clinical_variable',
#    'start': 60,
#    'end': 89,
#    'value': 'antihepatitis B core antibody'}],
#  [{'label': 'gender', 'start': 0, 'end': 3, 'value': 'Men'},
#   {'label': 'contraception_consent',
#    'start': 22,
#    'end': 44,
#    'value': 'adequate contraception'},
#   {'label': 'clinical_variable',
#    'start': 74,
#    'end': 105,
#    'value': 'duration of study participation'},
#   {'label': 'clinical_variable',
#    'start': 123,
#    'end': 131,
#    'value': '3 months'}],
#  [{'label': 'clinical_variable',
#    'start': 0,
#    'end': 16,
#    'value': 'Serum creatinine'},
#   {'label': 'upper_bound', 'start': 17, 'end': 26, 'value': '1.5 x ULN'}],
#  [{'label': 'chronic_disease',
#    'start': 11,
#    'end': 27,
#    'value': 'seizure disorder'}],
#  [{'label': 'treatment',
#    'start': 41,
#    'end': 63,
#    'value': 'investigational agents'},
#   {'label': 'clinical_variable',
#    'start': 75,
#    'end': 102,
#    'value': '4 weeks prior to enrollment'},
#   {'label': 'treatment',
#    'start': 115,
#    'end': 132,
#    'value': 'radiation therapy'}],
#  [{'label': 'clinical_variable', 'start': 0, 'end': 3, 'value': 'ALT'},
#   {'label': 'clinical_variable', 'start': 7, 'end': 10, 'value': 'BUN'},
#   {'label': 'upper_bound', 'start': 13, 'end': 20, 'value': '2.0 ULN'},
#   {'label': 'clinical_variable',
#    'start': 24,
#    'end': 44,
#    'value': 'estimated creatinine'},
#   {'label': 'upper_bound', 'start': 47, 'end': 56, 'value': '1.5 X ULN'},
#   {'label': 'clinical_variable', 'start': 61, 'end': 64, 'value': 'age'},
#   {'label': 'clinical_variable',
#    'start': 78,
#    'end': 100,
#    'value': 'laboratory abnormality'},
#   {'label': 'clinical_variable',
#    'start': 119,
#    'end': 131,
#    'value': 'Investigator'},
#   {'label': 'clinical_variable',
#    'start': 138,
#    'end': 160,
#    'value': 'clinically significant'},
#   {'label': 'clinical_variable',
#    'start': 168,
#    'end': 192,
#    'value': '14 days before Screening'}]]

# %%
sentences_to_predict[1]
# Out:
# 'Current pregnancy'

# %%
# making the result of GPT in same format of Rasa
for res in gpt_res_with_indexes:
    for ent in res:
        ent.pop("value")

# %%
gpt_res_with_indexes[0]
# Out:
# [{'label': 'treatment', 'start': 24, 'end': 43},
#  {'label': 'treatment', 'start': 47, 'end': 57}]

# %%
sentences_to_predict[0][47:57]
# Out:
# 'study drug'

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\expert\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\expert\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\expert\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\expert\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\expert\anaconda3\lib\site-packages (from requests) (2023.7.22)

# %%
import requests



# Define the endpoint URL of the Rasa server
rasa_endpoint = "http://192.168.29.197:5005"

# %%
conversation_outcome = []

# Send API requests for each message and store the response
i = 1
for sent in sentences_to_predict:
    print(f"iteration {i}")
    i+=1
    payload = {
        "text": sent,
        "message_id": None
    }
    response = requests.post(rasa_endpoint, json=payload)
    conversation_outcome.append(response.json())
# Out:
# iteration 1
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File ~\anaconda3\Lib\http\client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000211536442D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='192.168.29.197', port=5005): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000211536442D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[33], line 12
#       7 i+=1
#       8 payload = {
#       9     "text": sent,
#      10     "message_id": None
#      11 }
# ---> 12 response = requests.post(rasa_endpoint, json=payload)
#      13 conversation_outcome.append(response.json())
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='192.168.29.197', port=5005): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000211536442D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
